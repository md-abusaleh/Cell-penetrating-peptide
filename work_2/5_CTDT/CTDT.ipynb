# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 18.1 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
import os
import numpy as np
import pandas as pd
from Bio import SeqIO

# Amino acid alphabet
AminoAcids = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

# Generate all possible tri-peptide combinations as feature names (e.g., 'AAA', 'AAC', 'AAG', ...)
tri_peptide_names = [f"{a1}{a2}{a3}" for a1 in AminoAcids for a2 in AminoAcids for a3 in AminoAcids]

# Mapping of amino acid characters to integers (for counting occurrences)
aa_dict = {aa: i for i, aa in enumerate(AminoAcids)}

# Function to calculate the CTDT feature (correlation of tri-peptides)
def calculate_ctdt(sequence):
    tri_peptide_count = np.zeros((20, 20, 20))  # 3D array for counting tri-peptide transitions
    for i in range(len(sequence) - 2):
        first_aa = sequence[i]
        second_aa = sequence[i + 1]
        third_aa = sequence[i + 2]

        if first_aa in aa_dict and second_aa in aa_dict and third_aa in aa_dict:
            tri_peptide_count[aa_dict[first_aa], aa_dict[second_aa], aa_dict[third_aa]] += 1

    total_tri_peptides = np.sum(tri_peptide_count)

    if total_tri_peptides > 0:
        tri_peptide_count = tri_peptide_count / total_tri_peptides  # Normalize by total count

    # Flatten the 3D array into a 1D feature vector
    return tri_peptide_count.flatten()

# Function to extract CTDT features from sequences in FASTA format
def extract_ctdt_features(fasta_path):
    features = []
    for record in SeqIO.parse(fasta_path, "fasta"):
        seq = str(record.seq)
        ctdt_features = calculate_ctdt(seq)
        features.append(ctdt_features)

    # Convert the list of feature vectors into a DataFrame with letter-based feature names
    df = pd.DataFrame(features, columns=tri_peptide_names)
    return df

# Define file paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_main (2) (1).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_main (2) (1).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_validation (2) (1).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/NEGATIVE_validation (2) (1).fasta"

# Output directories for each file
output_dirs = {
    "main_positive": "/content/ctdt_main_positive_features.csv",
    "main_negative": "/content/ctdt_main_negative_features.csv",
    "validation_positive": "/content/ctdt_validation_positive_features.csv",
    "validation_negative": "/content/ctdt_validation_negative_features.csv"
}

# Function to ensure the directory exists
def ensure_directory_exists(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# Main workflow function
def main():
    # File paths for input FASTA files
    datasets = [
        (main_p, output_dirs["main_positive"]),
        (main_n, output_dirs["main_negative"]),
        (validation_p, output_dirs["validation_positive"]),
        (validation_n, output_dirs["validation_negative"])
    ]

    # Extract features and save to CSV
    for fasta_path, output_csv in datasets:
        print(f"Processing {fasta_path}...")

        # Ensure the directory for saving the output file exists
        ensure_directory_exists(output_csv)

        # Extract features and save to CSV
        features_df = extract_ctdt_features(fasta_path)
        features_df.to_csv(output_csv, index=False)
        print(f"CTDT features saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_main (2) (1).fasta...
# CTDT features saved to /content/ctdt_main_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_main (2) (1).fasta...
# CTDT features saved to /content/ctdt_main_negative_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/POSITIVE_validation (2) (1).fasta...
# CTDT features saved to /content/ctdt_validation_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/NEGATIVE_validation (2) (1).fasta...
# CTDT features saved to /content/ctdt_validation_negative_features.csv

# %% [markdown]
# # ***All Algorithm ***

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_negative_features.csv")

# %%
# Label the datasets
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the neural network models
models["Neural Network"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
models["MLP"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Store accuracies
results = []

# Train each model and evaluate
for name, model in models.items():
    print(f"\nTraining {name}...")

    if name in ["Neural Network", "MLP"]:
        # Neural Network training
        model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=0)
        train_pred = (model.predict(X_train) > 0.5).astype("int32")
        val_pred = (model.predict(X_val) > 0.5).astype("int32")
    else:
        # Traditional ML model training
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        val_pred = model.predict(X_val)

    # Calculate train and validation accuracy
    train_accuracy = accuracy_score(y_train, train_pred)
    val_accuracy = accuracy_score(y_val, val_pred)

    results.append({"Model": name, "Train Accuracy": train_accuracy, "Validation Accuracy": val_accuracy})
# Out:
# Training SVM...
#
# Training Decision Tree...
#
# Training Random Forest...
#
# Training Logistic Regression...
#
# Training k-NN...
#
# Training Naive Bayes...
#
# Training Gradient Boosting...
#
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:41:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001516 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Training CatBoost...
#
# Training AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training Neural Network...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Training MLP...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Convert to DataFrame and sort by Validation Accuracy and Train Accuracy in descending order
results_df = pd.DataFrame(results).sort_values(by=["Validation Accuracy", "Train Accuracy"], ascending=False).reset_index(drop=True)

# Display results
print("\nModel Accuracy Table (Descending Order of Validation Accuracy)")
print(results_df)
# Out:
# Model Accuracy Table (Descending Order of Validation Accuracy)
#                   Model  Train Accuracy  Validation Accuracy
# 0         Random Forest        0.995704             0.923333
# 1                   MLP        0.995704             0.900000
# 2              CatBoost        0.970790             0.900000
# 3        Neural Network        0.995704             0.896667
# 4               XGBoost        0.963918             0.896667
# 5         Decision Tree        0.995704             0.893333
# 6              AdaBoost        0.939863             0.890000
# 7     Gradient Boosting        0.935567             0.880000
# 8           Naive Bayes        0.959622             0.866667
# 9                  k-NN        0.928694             0.856667
# 10             LightGBM        0.887457             0.840000
# 11  Logistic Regression        0.849656             0.823333
# 12                  SVM        0.809278             0.773333

# %% [markdown]
# # **CROSS VALIDATION**

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
# Define Neural Network models
def create_neural_network(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

def create_mlp(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Cross-validation for traditional models
results = []

# For traditional ML models, we use cross_val_score
for name, model in models.items():
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Calculate cross-validation accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    mean_accuracy = np.mean(cv_scores)
    std_accuracy = np.std(cv_scores)

    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})

# Cross-validation for Neural Networks (manual implementation)
for name, create_model in [("Neural Network", create_neural_network), ("MLP", create_mlp)]:
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Custom function to calculate accuracy for neural networks
    def neural_network_cross_val(model_func, X_train, y_train):
        accuracies = []
        for train_index, val_index in cv.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = model_func(X_train.shape[1])  # Create a new model for each fold
            model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=32, verbose=0)

            y_pred = (model.predict(X_val_fold) > 0.5).astype("int32")
            accuracy = accuracy_score(y_val_fold, y_pred)
            accuracies.append(accuracy)

        return np.mean(accuracies), np.std(accuracies)

    mean_accuracy, std_accuracy = neural_network_cross_val(create_model, X_train, y_train)
    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})
# Out:
# Performing Cross-validation for SVM...
#
# Performing Cross-validation for Decision Tree...
#
# Performing Cross-validation for Random Forest...
#
# Performing Cross-validation for Logistic Regression...
#
# Performing Cross-validation for k-NN...
#
# Performing Cross-validation for Naive Bayes...
#
# Performing Cross-validation for Gradient Boosting...
#
# Performing Cross-validation for XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:50:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:50:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:50:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:50:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:50:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Performing Cross-validation for LightGBM...
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001052 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 631
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 81
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 610
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001001 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 621
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001056 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 654
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 84
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001000 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 932, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Performing Cross-validation for CatBoost...
#
# Performing Cross-validation for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing Cross-validation for Neural Network...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e7e57be2560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e7e36a2d1b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Performing Cross-validation for MLP...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# Convert to DataFrame and display
cv_results_df = pd.DataFrame(results).sort_values(by="Mean CV Accuracy", ascending=False).reset_index(drop=True)
print("\nCross-Validation Accuracy Table")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Table
#                   Model  Mean CV Accuracy  STD CV Accuracy
# 0                   MLP          0.929543         0.006546
# 1         Random Forest          0.928685         0.009711
# 2        Neural Network          0.924401         0.007462
# 3              CatBoost          0.898613         0.018209
# 4           Naive Bayes          0.892648         0.025944
# 5               XGBoost          0.888320         0.013813
# 6         Decision Tree          0.873694         0.016350
# 7     Gradient Boosting          0.871137         0.015565
# 8              AdaBoost          0.865980         0.013125
# 9                  k-NN          0.856504         0.022010
# 10  Logistic Regression          0.804976         0.016045
# 11             LightGBM          0.784372         0.013287
# 12                  SVM          0.766320         0.012068

# %% [markdown]
# # **Hyperparameter optimization with Optuna**

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 4.6 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 4.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]



# Define models with MLP included
models = {
    "SVM": lambda trial: SVC(
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}


results = []

def optimize_model(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        return accuracy_score(y_val, preds)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the results
    results.append({
        "Model": model_name,
        "Accuracy": study.best_value,
        "Best Params": study.best_params
    })

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model(model_name, model_func)


# Convert results to a DataFrame
results_df = pd.DataFrame(results)


# Display the DataFrame
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2024-12-28 14:39:16,430] A new study created in memory with name: no-name-a137c802-774f-4c6a-924d-b3ea24ce5d98
# Optimizing SVM...
# [I 2024-12-28 14:39:28,814] Trial 0 finished with value: 0.86 and parameters: {'C': 6.917740866662788, 'kernel': 'poly'}. Best is trial 0 with value: 0.86.
# [I 2024-12-28 14:39:36,716] Trial 1 finished with value: 0.8766666666666667 and parameters: {'C': 4.34503912163165, 'kernel': 'linear'}. Best is trial 1 with value: 0.8766666666666667.
# [I 2024-12-28 14:39:41,067] Trial 2 finished with value: 0.8866666666666667 and parameters: {'C': 9.155725309958758, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.8866666666666667.
# [I 2024-12-28 14:39:50,832] Trial 3 finished with value: 0.9033333333333333 and parameters: {'C': 4.814321539411033, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:00,170] Trial 4 finished with value: 0.9033333333333333 and parameters: {'C': 8.497728824928087, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:06,946] Trial 5 finished with value: 0.8833333333333333 and parameters: {'C': 9.233764053955, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:13,152] Trial 6 finished with value: 0.8833333333333333 and parameters: {'C': 9.288627991299029, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:21,173] Trial 7 finished with value: 0.87 and parameters: {'C': 2.4632677464134014, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:31,964] Trial 8 finished with value: 0.81 and parameters: {'C': 2.6814242821577325, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:41,295] Trial 9 finished with value: 0.9033333333333333 and parameters: {'C': 9.757948529204127, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:50,476] Trial 10 finished with value: 0.89 and parameters: {'C': 0.5404189820544074, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:40:59,963] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 6.670516621027067, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:09,566] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 5.864345860805796, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:19,428] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 4.393044359460625, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:23,773] Trial 14 finished with value: 0.8833333333333333 and parameters: {'C': 7.6615096855225024, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:33,709] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 3.16711669746774, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:43,189] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 7.895763799245948, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:41:52,716] Trial 17 finished with value: 0.9033333333333333 and parameters: {'C': 5.340511436879708, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:02,285] Trial 18 finished with value: 0.71 and parameters: {'C': 0.6834055743835199, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:07,231] Trial 19 finished with value: 0.8633333333333333 and parameters: {'C': 3.6874951667091453, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:17,130] Trial 20 finished with value: 0.9033333333333333 and parameters: {'C': 7.970986153378728, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:26,350] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 9.734027147547149, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:35,971] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 8.591139890740282, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:45,969] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 9.910310348440014, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:42:55,081] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 6.347640551628349, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:04,687] Trial 25 finished with value: 0.9033333333333333 and parameters: {'C': 7.289890645605521, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:14,603] Trial 26 finished with value: 0.9033333333333333 and parameters: {'C': 8.43324690218725, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:23,262] Trial 27 finished with value: 0.7766666666666666 and parameters: {'C': 1.4788472761718094, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:28,427] Trial 28 finished with value: 0.86 and parameters: {'C': 5.242869273711439, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:37,485] Trial 29 finished with value: 0.8533333333333334 and parameters: {'C': 5.892683600381426, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2024-12-28 14:43:37,487] A new study created in memory with name: no-name-98ea60c8-83fe-466e-9f61-9041885e41c0
# [I 2024-12-28 14:43:37,669] Trial 0 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 9}. Best is trial 0 with value: 0.7233333333333334.
# Optimizing Decision Tree...
# [I 2024-12-28 14:43:38,004] Trial 1 finished with value: 0.8433333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 9}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-28 14:43:38,287] Trial 2 finished with value: 0.8133333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 4}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-28 14:43:38,596] Trial 3 finished with value: 0.84 and parameters: {'max_depth': 15, 'min_samples_split': 10}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-28 14:43:38,799] Trial 4 finished with value: 0.76 and parameters: {'max_depth': 6, 'min_samples_split': 8}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-28 14:43:38,994] Trial 5 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 7}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-28 14:43:39,409] Trial 6 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 5}. Best is trial 6 with value: 0.85.
# [I 2024-12-28 14:43:39,769] Trial 7 finished with value: 0.7533333333333333 and parameters: {'max_depth': 6, 'min_samples_split': 6}. Best is trial 6 with value: 0.85.
# [I 2024-12-28 14:43:40,088] Trial 8 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 2}. Best is trial 6 with value: 0.85.
# [I 2024-12-28 14:43:40,444] Trial 9 finished with value: 0.77 and parameters: {'max_depth': 7, 'min_samples_split': 3}. Best is trial 6 with value: 0.85.
# [I 2024-12-28 14:43:41,052] Trial 10 finished with value: 0.8533333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 10 with value: 0.8533333333333334.
# [I 2024-12-28 14:43:41,665] Trial 11 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 11 with value: 0.86.
# [I 2024-12-28 14:43:42,281] Trial 12 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 11 with value: 0.86.
# [I 2024-12-28 14:43:42,886] Trial 13 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:43,485] Trial 14 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 7}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:43,843] Trial 15 finished with value: 0.8066666666666666 and parameters: {'max_depth': 10, 'min_samples_split': 6}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:44,217] Trial 16 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:44,516] Trial 17 finished with value: 0.82 and parameters: {'max_depth': 12, 'min_samples_split': 7}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:44,860] Trial 18 finished with value: 0.85 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:45,110] Trial 19 finished with value: 0.7933333333333333 and parameters: {'max_depth': 9, 'min_samples_split': 4}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:45,424] Trial 20 finished with value: 0.8133333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 6}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:45,778] Trial 21 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 5}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:46,140] Trial 22 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:46,483] Trial 23 finished with value: 0.8633333333333333 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:46,822] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:47,157] Trial 25 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 13 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:47,523] Trial 26 finished with value: 0.8666666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 26 with value: 0.8666666666666667.
# [I 2024-12-28 14:43:47,841] Trial 27 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 3}. Best is trial 26 with value: 0.8666666666666667.
# [I 2024-12-28 14:43:48,203] Trial 28 finished with value: 0.86 and parameters: {'max_depth': 19, 'min_samples_split': 2}. Best is trial 26 with value: 0.8666666666666667.
# [I 2024-12-28 14:43:48,542] Trial 29 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 26 with value: 0.8666666666666667.
# [I 2024-12-28 14:43:48,544] A new study created in memory with name: no-name-2f6b471f-30c3-44be-8341-f9bd0c8ba230
# Optimizing Random Forest...
# [I 2024-12-28 14:43:50,984] Trial 0 finished with value: 0.86 and parameters: {'n_estimators': 361, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 0 with value: 0.86.
# [I 2024-12-28 14:43:51,229] Trial 1 finished with value: 0.8 and parameters: {'n_estimators': 55, 'max_depth': 3, 'min_samples_split': 9}. Best is trial 0 with value: 0.86.
# [I 2024-12-28 14:43:52,162] Trial 2 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 164, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 0 with value: 0.86.
# [I 2024-12-28 14:43:52,708] Trial 3 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 71, 'max_depth': 16, 'min_samples_split': 6}. Best is trial 3 with value: 0.8633333333333333.
# [I 2024-12-28 14:43:54,994] Trial 4 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 241, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:43:58,755] Trial 5 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 452, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:01,231] Trial 6 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 454, 'max_depth': 12, 'min_samples_split': 3}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:02,351] Trial 7 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 388, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:04,473] Trial 8 finished with value: 0.84 and parameters: {'n_estimators': 466, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:07,822] Trial 9 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 489, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:10,495] Trial 10 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 244, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 4 with value: 0.8766666666666667.
# [I 2024-12-28 14:44:13,229] Trial 11 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 251, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 11 with value: 0.8866666666666667.
# [I 2024-12-28 14:44:15,354] Trial 12 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 264, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:17,904] Trial 13 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 324, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:18,780] Trial 14 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 177, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:20,801] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 285, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:21,831] Trial 16 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 169, 'max_depth': 14, 'min_samples_split': 10}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:22,786] Trial 17 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 221, 'max_depth': 6, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:24,137] Trial 18 finished with value: 0.87 and parameters: {'n_estimators': 113, 'max_depth': 18, 'min_samples_split': 6}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:27,247] Trial 19 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 311, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:29,934] Trial 20 finished with value: 0.86 and parameters: {'n_estimators': 384, 'max_depth': 18, 'min_samples_split': 5}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:32,027] Trial 21 finished with value: 0.87 and parameters: {'n_estimators': 291, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:34,073] Trial 22 finished with value: 0.89 and parameters: {'n_estimators': 269, 'max_depth': 19, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:36,138] Trial 23 finished with value: 0.87 and parameters: {'n_estimators': 251, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:38,137] Trial 24 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 206, 'max_depth': 19, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:41,432] Trial 25 finished with value: 0.86 and parameters: {'n_estimators': 316, 'max_depth': 16, 'min_samples_split': 4}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:44,058] Trial 26 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 342, 'max_depth': 19, 'min_samples_split': 2}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:45,799] Trial 27 finished with value: 0.85 and parameters: {'n_estimators': 273, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:46,725] Trial 28 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 129, 'max_depth': 17, 'min_samples_split': 7}. Best is trial 12 with value: 0.8966666666666666.
# [I 2024-12-28 14:44:49,150] Trial 29 finished with value: 0.87 and parameters: {'n_estimators': 364, 'max_depth': 17, 'min_samples_split': 4}. Best is trial
and parameters: {'n_neighbors': 18}. Best is trial 0 with value: 0.84.
# [I 2024-12-28 14:45:02,940] Trial 1 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 17}. Best is trial 1 with value: 0.8533333333333334.
# [I 2024-12-28 14:45:03,315] Trial 2 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 2 with value: 0.8566666666666667.
# [I 2024-12-28 14:45:03,703] Trial 3 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 14:45:04,078] Trial 4 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 14:45:04,456] Trial 5 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 14:45:04,835] Trial 6 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:05,222] Trial 7 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:05,615] Trial 8 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:05,991] Trial 9 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:06,364] Trial 10 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:06,769] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:07,202] Trial 12 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:07,826] Trial 13 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:08,440] Trial 14 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:09,048] Trial 15 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:09,654] Trial 16 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:10,272] Trial 17 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:10,881] Trial 18 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:11,510] Trial 19 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:12,111] Trial 20 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:12,487] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:12,863] Trial 22 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:13,263] Trial 23 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:13,639] Trial 24 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:14,031] Trial 25 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:14,410] Trial 26 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:14,815] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:15,210] Trial 28 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:15,588] Trial 29 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-28 14:45:15,590] A new study created in memory with name: no-name-311d579d-27d3-4591-b612-bd3f85fa0257
# Optimizing Naive Bayes...
# [I 2024-12-28 14:45:15,867] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:16,154] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:16,424] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:16,698] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:16,973] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:17,261] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:17,531] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:17,807] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:18,092] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:18,364] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:18,637] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:18,907] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:19,192] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:19,458] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:19,727] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:20,005] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:20,282] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:20,548] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:20,821] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:21,092] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:21,374] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:21,642] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:21,911] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:22,236] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:22,604] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:22,975] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:23,341] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:23,721] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:24,102] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:24,490] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 14:45:24,493] A new study created in memory with name: no-name-e0b092d1-67e9-489f-8c94-088a9af555ea
# Optimizing Gradient Boosting...
# [I 2024-12-28 14:46:55,278] Trial 0 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 498, 'learning_rate': 0.4340012232366628, 'max_depth': 9}. Best is trial 0 with value: 0.8733333333333333.
# [I 2024-12-28 14:47:54,279] Trial 1 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 199, 'learning_rate': 0.38870321813624475, 'max_depth': 16}. Best is trial 1 with value: 0.8933333333333333.
# [I 2024-12-28 14:48:33,405] Trial 2 finished with value: 0.9 and parameters: {'n_estimators': 122, 'learning_rate': 0.15969208207211305, 'max_depth': 18}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:48:49,871] Trial 3 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 65, 'learning_rate': 0.46569986588310347, 'max_depth': 13}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:49:09,244] Trial 4 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 57, 'learning_rate': 0.4669915664239524, 'max_depth': 19}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:50:15,433] Trial 5 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 209, 'learning_rate': 0.04388696174643525, 'max_depth': 18}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:51:34,564] Trial 6 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 282, 'learning_rate': 0.3385434544343703, 'max_depth': 15}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:51:49,579] Trial 7 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 73, 'learning_rate': 0.08195048295089563, 'max_depth': 11}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:52:47,145] Trial 8 finished with value: 0.89 and parameters: {'n_estimators': 174, 'learning_rate': 0.3158639963579698, 'max_depth': 18}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:52:50,990] Trial 9 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 61, 'learning_rate': 0.49717733413229964, 'max_depth': 3}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:53:37,861] Trial 10 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 361, 'learning_rate': 0.17585422641777076, 'max_depth': 6}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:54:31,059] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 379, 'learning_rate': 0.17618907087527808, 'max_depth': 6}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:55:27,321] Trial 12 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 351, 'learning_rate': 0.18645209779924762, 'max_depth': 8}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:55:57,170] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 425, 'learning_rate': 0.16424035971821058, 'max_depth': 3}. Best is trial 2 with value: 0.9.
# [I 2024-12-28 14:56:32,514] Trial 14 finished with value: 0.8966666666666666 and parameters: {'n_estimators':
10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:12:33,261] Trial 9 finished with value: 0.91 and parameters: {'n_estimators': 404, 'max_depth': 12, 'learning_rate': 0.25770801067372895}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:12:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:12:46,716] Trial 10 finished with value: 0.78 and parameters: {'n_estimators': 181, 'max_depth': 3, 'learning_rate': 0.015343642314281841}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:12:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:13:23,123] Trial 11 finished with value: 0.9 and parameters: {'n_estimators': 490, 'max_depth': 15, 'learning_rate': 0.47738017296308577}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:13:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:13:45,500] Trial 12 finished with value: 0.91 and parameters: {'n_estimators': 311, 'max_depth': 14, 'learning_rate': 0.40273002073943437}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:13:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:14:06,382] Trial 13 finished with value: 0.91 and parameters: {'n_estimators': 230, 'max_depth': 20, 'learning_rate': 0.32086753377841015}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:14:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:14:31,935] Trial 14 finished with value: 0.9 and parameters: {'n_estimators': 347, 'max_depth': 15, 'learning_rate': 0.3449706780515982}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:14:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:14:48,603] Trial 15 finished with value: 0.9 and parameters: {'n_estimators': 196, 'max_depth': 13, 'learning_rate': 0.40623140769246985}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:14:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:15:23,890] Trial 16 finished with value: 0.9 and parameters: {'n_estimators': 478, 'max_depth': 17, 'learning_rate': 0.01573751563798595}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:15:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:15:51,949] Trial 17 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 367, 'max_depth': 16, 'learning_rate': 0.2893626707724503}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:15:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:16:15,910] Trial 18 finished with value: 0.9 and parameters: {'n_estimators': 266, 'max_depth': 20, 'learning_rate': 0.40926405507640723}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:16:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:16:29,427] Trial 19 finished with value: 0.91 and parameters: {'n_estimators': 133, 'max_depth': 12, 'learning_rate': 0.23619815462923363}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:16:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:16:48,906] Trial 20 finished with value: 0.9 and parameters: {'n_estimators': 301, 'max_depth': 7, 'learning_rate': 0.060037951571919296}. Best is trial 6 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [15:16:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 15:17:17,313] Trial 21 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 390, 'max_depth': 12, 'learning_rate': 0.24155763191693394}. Best is trial 6 with value: 0.91.
# ...
# [I 2024-12-28 15:35:33,594] Trial 2 finished with value: 0.91 and parameters: {'hidden_layer_1': 29, 'hidden_layer_2': 32, 'learning_rate_init': 0.09562872230988455}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:35:52,704] Trial 3 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 45, 'hidden_layer_2': 90, 'learning_rate_init': 0.015171129065969301}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:35:59,375] Trial 4 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 13, 'hidden_layer_2': 31, 'learning_rate_init': 0.035926299216057375}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:36:20,882] Trial 5 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 40, 'learning_rate_init': 0.02465488405697943}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:36:34,771] Trial 6 finished with value: 0.89 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 72, 'learning_rate_init': 0.015922648568938054}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:36:56,819] Trial 7 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 92, 'learning_rate_init': 0.026795777753219358}. Best is trial 2 with value: 0.91.
# [I 2024-12-28 15:37:15,130] Trial 8 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 53, 'hidden_layer_2': 17, 'learning_rate_init': 0.058818080209716565}. Best is trial 8 with value: 0.9133333333333333.
# [I 2024-12-28 15:37:29,349] Trial 9 finished with value: 0.92 and parameters: {'hidden_layer_1': 17, 'hidden_layer_2': 25, 'learning_rate_init': 0.0908118967346098}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 15:37:46,990] Trial 10 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 15, 'hidden_layer_2': 66, 'learning_rate_init': 0.06790833586511619}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 15:38:06,115] Trial 11 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 71, 'hidden_layer_2': 13, 'learning_rate_init': 0.05783393247672956}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 15:38:35,631] Trial 12 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 94, 'hidden_layer_2': 23, 'learning_rate_init': 0.0780962086194546}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 15:39:04,868] Trial 13 finished with value: 0.93 and parameters: {'hidden_layer_1': 33, 'hidden_layer_2': 44, 'learning_rate_init': 0.0458860919848654}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:39:12,476] Trial 14 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 48, 'learning_rate_init': 0.044941131669398234}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:39:28,205] Trial 15 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 21, 'hidden_layer_2': 64, 'learning_rate_init': 0.09876042281539527}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:39:42,992] Trial 16 finished with value: 0.9 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 41, 'learning_rate_init': 0.0453434379961981}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:40:31,811] Trial 17 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 23, 'hidden_layer_2': 28, 'learning_rate_init': 0.0010052545367345705}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:40:44,742] Trial 18 finished with value: 0.9 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 41, 'learning_rate_init': 0.07446734170363588}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:40:59,065] Trial 19 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 76, 'learning_rate_init': 0.08936295121404178}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:41:15,313] Trial 20 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 80, 'learning_rate_init': 0.06318091254904049}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:41:32,443] Trial 21 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 43, 'hidden_layer_2': 59, 'learning_rate_init': 0.08899290760830912}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:41:57,717] Trial 22 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 24, 'hidden_layer_2': 82, 'learning_rate_init': 0.09111673210414364}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:42:11,317] Trial 23 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 48, 'learning_rate_init': 0.07120517674732507}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:42:31,615] Trial 24 finished with value: 0.91 and parameters: {'hidden_layer_1': 48, 'hidden_layer_2': 78, 'learning_rate_init': 0.08287875354972944}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:42:45,266] Trial 25 finished with value: 0.91 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 23, 'learning_rate_init': 0.05133449888535031}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:43:04,566] Trial 26 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 58, 'hidden_layer_2': 99, 'learning_rate_init': 0.03539225660115425}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:43:18,303] Trial 27 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 29, 'hidden_layer_2': 57, 'learning_rate_init': 0.08928966640648944}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:43:31,943] Trial 28 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 35, 'learning_rate_init': 0.05236896672188924}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:43:54,220] Trial 29 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 10, 'learning_rate_init': 0.08065350889216691}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 15:43:54,224] A new study created in memory with name: no-name-e48a8d93-322f-4345-a0f5-17415233c325
# Optimizing MLP...
# [I 2024-12-28 15:44:13,507] Trial 0 finished with value: 0.9066666666666666 and parameters: {'layer_1': 85, 'layer_2': 87, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09637475607675786}. Best is trial 0 with value: 0.9066666666666666.
# [I 2024-12-28 15:44:55,570] Trial 1 finished with value: 0.9166666666666666 and parameters: {'layer_1': 115, 'layer_2': 61, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.014057073428258952}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-12-28 15:45:23,946] Trial 2 finished with value: 0.9166666666666666 and parameters: {'layer_1': 98, 'layer_2': 100, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.02681734235581086}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-12-28 15:46:02,353] Trial 3 finished with value: 0.9233333333333333 and parameters: {'layer_1': 121, 'layer_2': 101, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0459982309745124}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:46:24,904] Trial 4 finished with value: 0.91 and parameters: {'layer_1': 68, 'layer_2': 55, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06062002824107152}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:47:06,204] Trial 5 finished with value: 0.9 and parameters: {'layer_1': 104, 'layer_2': 52, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.002463653314107829}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:47:38,950] Trial 6 finished with value: 0.8933333333333333 and parameters: {'layer_1': 111, 'layer_2': 124, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.07271528930471552}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:48:02,920] Trial 7 finished with value: 0.91 and parameters: {'layer_1': 108, 'layer_2': 121, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.050219034011890276}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:48:21,542] Trial 8 finished with value: 0.8933333333333333 and parameters: {'layer_1': 68, 'layer_2': 93, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.047284044072105874}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:48:45,442] Trial 9 finished with value: 0.9 and parameters: {'layer_1': 103, 'layer_2': 81, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.007176438258375172}. Best is trial 3 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 15:50:42,873] Trial 10 finished with value: 0.92 and parameters: {'layer_1': 145, 'layer_2': 148, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03267062714740615}. Best is trial 3 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 15:52:40,896] Trial 11 finished with value: 0.9133333333333333 and parameters: {'layer_1': 145, 'layer_2': 142, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.032296408082178596}. Best is trial 3 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 15:54:37,662] Trial 12 finished with value: 0.92 and parameters: {'layer_1': 144, 'layer_2': 150, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03234314377504458}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:55:30,937] Trial 13 finished with value: 0.9133333333333333 and parameters: {'layer_1': 131, 'layer_2': 125, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.07127031646809816}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:56:41,936] Trial 14 finished with value: 0.9166666666666666 and parameters: {'layer_1': 129, 'layer_2': 111, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.041160887149078076}. Best is trial 3 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 15:58:34,401] Trial 15 finished with value: 0.9166666666666666 and parameters: {'layer_1': 127, 'layer_2': 134, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02086863761932128}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 15:59:33,432] Trial 16 finished with value: 0.91 and parameters: {'layer_1': 147, 'layer_2': 111, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.06237718450860992}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:00:11,483] Trial 17 finished with value: 0.91 and parameters: {'layer_1': 50, 'layer_2': 75, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03864982615897871}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:00:58,015] Trial 18 finished with value: 0.9066666666666666 and parameters: {'layer_1': 133, 'layer_2': 73, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.08749799917922821}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:01:52,587] Trial 19 finished with value: 0.7 and parameters: {'layer_1': 120, 'layer_2': 109, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06142078406165665}. Best is trial 3 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 16:03:27,345] Trial 20 finished with value: 0.92 and parameters: {'layer_1': 91, 'layer_2': 135, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.020145705239483058}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:04:20,681] Trial 21 finished with value: 0.91 and parameters: {'layer_1': 141, 'layer_2': 150, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.034713005485111}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:05:38,852] Trial 22 finished with value: 0.9133333333333333 and parameters: {'layer_1': 150, 'layer_2': 150, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04558914609464067}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:07:35,919] Trial 23 finished with value: 0.9166666666666666 and parameters: {'layer_1': 138, 'layer_2': 139, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02804555086140906}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:08:28,523] Trial 24 finished with value: 0.9166666666666666 and parameters: {'layer_1': 123, 'layer_2': 144, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.05749991549126679}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:09:43,841] Trial 25 finished with value: 0.9133333333333333 and parameters: {'layer_1': 140, 'layer_2': 130, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04121614447558936}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:10:11,487] Trial 26 finished with value: 0.8933333333333333 and parameters: {'layer_1': 135, 'layer_2': 101, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.018878366700941715}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:10:58,799] Trial 27 finished with value: 0.9133333333333333 and parameters: {'layer_1': 121, 'layer_2': 118, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.05277739608866423}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:11:34,346] Trial 28 finished with value: 0.8866666666666667 and parameters: {'layer_1': 117, 'layer_2': 146, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.03055740906526031}. Best is trial 3 with value: 0.9233333333333333.
# [I 2024-12-28 16:12:17,355] Trial 29 finished with value: 0.9 and parameters: {'layer_1': 145, 'layer_2': 89, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06974353079955398}. Best is trial 3 with value: 0.9233333333333333.
#                   Model  Accuracy  \
# 0                   SVM  0.903333
# 1         Decision Tree  0.866667
# 2         Random Forest  0.896667
# 3   Logistic Regression  0.893333
# 4                  k-NN  0.883333
# 5           Naive Bayes  0.866667
# 6     Gradient Boosting  0.903333
# 7               XGBoost  0.910000
# 8              LightGBM  0.860000
# 9              AdaBoost  0.886667
# 10       Neural Network  0.930000
# 11                  MLP  0.923333
#
#                                           Best Params
# 0           {'C': 4.814321539411033, 'kernel': 'rbf'}
# 1           {'max_depth': 19, 'min_samples_split': 4}
# 2   {'n_estimators': 264, 'max_depth': 20, 'min_sa...
# 3         {'C': 9.989696614214784, 'solver': 'lbfgs'}
# 4                                  {'n_neighbors': 3}
# 5                                                  {}
# 6   {'n_estimators': 120, 'learning_rate': 0.25107...
# 7   {'n_estimators': 439, 'max_depth': 14, 'learni...
# 8   {'n_estimators': 168, 'max_depth': 13, 'learni...
# 9   {'n_estimators': 499, 'learning_rate': 0.98509...
# 10  {'hidden_layer_1': 33, 'hidden_layer_2': 44, '...
# 11  {'layer_1': 121, 'layer_2': 101, 'activation':...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, cohen_kappa_score, roc_auc_score # Import confusion_matrix and other metrics

# Function to calculate metrics with model name
def calculate_metrics(y_true, y_pred, model_name=None):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    mcc = matthews_corrcoef(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "Kappa": kappa,
        "AUC": auc,
    }

# Results storage
results = []

# Optimization function
def optimize_model_with_metrics(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        trial.set_user_attr("preds", preds)
        metrics = calculate_metrics(y_val, preds, model_name=model_name)
        return metrics["Accuracy"]

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the best trial metrics
    best_trial_preds = study.best_trial.user_attrs["preds"]
    best_metrics = calculate_metrics(y_val, best_trial_preds, model_name=model_name)
    best_metrics["Best Params"] = study.best_params
    results.append(best_metrics)

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model_with_metrics(model_name, model_func)

# Store the final results with selected metrics and best parameters
final_results = []
for result in results:
    final_results.append(
        {
            "Model": result["Model"],
            "Accuracy": result["Accuracy"],
            "Sensitivity": result["Sensitivity"],
            "Specificity": result["Specificity"],
            "MCC": result["MCC"],
            "Kappa": result["Kappa"],
            "AUC": result["AUC"],
            "Best Params": result["Best Params"],
        }
    )

# Convert results to a DataFrame and display it
final_results_df = pd.DataFrame(final_results)
print(final_results_df)
# Out:
# [I 2024-12-28 16:13:58,661] A new study created in memory with name: no-name-902f26ac-b73a-4759-90d3-6b700dada2bb
# Optimizing SVM...
# [I 2024-12-28 16:14:06,506] Trial 0 finished with value: 0.88 and parameters: {'C': 0.8414117865498301, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.88.
# [I 2024-12-28 16:14:16,147] Trial 1 finished with value: 0.86 and parameters: {'C': 8.14252033296222, 'kernel': 'poly'}. Best is trial 0 with value: 0.88.
# [I 2024-12-28 16:14:25,587] Trial 2 finished with value: 0.9033333333333333 and parameters: {'C': 7.9917166362691985, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-28
333333334 and parameters: {'max_depth': 15, 'min_samples_split': 6}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:26,454] Trial 8 finished with value: 0.8366666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 8}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:26,766] Trial 9 finished with value: 0.72 and parameters: {'max_depth': 4, 'min_samples_split': 6}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:27,268] Trial 10 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:27,666] Trial 11 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:28,041] Trial 12 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:28,394] Trial 13 finished with value: 0.8466666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 8}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:28,662] Trial 14 finished with value: 0.7833333333333333 and parameters: {'max_depth': 8, 'min_samples_split': 4}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:29,010] Trial 15 finished with value: 0.8466666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 9}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:29,384] Trial 16 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:29,721] Trial 17 finished with value: 0.8366666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 7}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:30,089] Trial 18 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:30,336] Trial 19 finished with value: 0.78 and parameters: {'max_depth': 8, 'min_samples_split': 9}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:30,665] Trial 20 finished with value: 0.8266666666666667 and parameters: {'max_depth': 14, 'min_samples_split': 3}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:31,037] Trial 21 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:31,388] Trial 22 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 10}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:31,764] Trial 23 finished with value: 0.8466666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 9}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:32,102] Trial 24 finished with value: 0.8466666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 8}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:32,467] Trial 25 finished with value: 0.8633333333333333 and parameters: {'max_depth': 19, 'min_samples_split': 7}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:32,827] Trial 26 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 5}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:33,190] Trial 27 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 7}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:33,474] Trial 28 finished with value: 0.82 and parameters: {'max_depth': 11, 'min_samples_split': 3}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:33,823] Trial 29 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 6}. Best is trial 2 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:33,836] A new study created in memory with name: no-name-b4602f66-8f17-4af5-af0b-a78ecd1ac00b
# Optimizing Random Forest...
# [I 2024-12-28 16:18:35,210] Trial 0 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 346, 'max_depth': 7, 'min_samples_split': 7}. Best is trial 0 with value: 0.8233333333333334.
# [I 2024-12-28 16:18:35,875] Trial 1 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 97, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 1 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:37,154] Trial 2 finished with value: 0.8 and parameters: {'n_estimators': 438, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 1 with value: 0.8633333333333333.
# [I 2024-12-28 16:18:39,876] Trial 3 finished with value: 0.88 and parameters: {'n_estimators': 246, 'max_depth': 19, 'min_samples_split': 8}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:41,984] Trial 4 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 414, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:42,918] Trial 5 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 129, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:43,628] Trial 6 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 91, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:44,234] Trial 7 finished with value: 0.84 and parameters: {'n_estimators': 118, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:44,667] Trial 8 finished with value: 0.81 and parameters: {'n_estimators': 64, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:45,753] Trial 9 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 220, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:47,471] Trial 10 finished with value: 0.86 and parameters: {'n_estimators': 239, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:48,915] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 189, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:50,893] Trial 12 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 312, 'max_depth': 16, 'min_samples_split': 7}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:52,478] Trial 13 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 188, 'max_depth': 17, 'min_samples_split': 8}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:54,546] Trial 14 finished with value: 0.87 and parameters: {'n_estimators': 176, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:18:56,809] Trial 15 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 280, 'max_depth': 14, 'min_samples_split': 9}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:00,134] Trial 16 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 496, 'max_depth': 18, 'min_samples_split': 6}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:02,371] Trial 17 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 343, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:03,380] Trial 18 finished with value: 0.86 and parameters: {'n_estimators': 176, 'max_depth': 12, 'min_samples_split': 7}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:05,310] Trial 19 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 268, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:06,633] Trial 20 finished with value: 0.88 and parameters: {'n_estimators': 150, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:08,545] Trial 21 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 157, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:10,860] Trial 22 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 226, 'max_depth': 18, 'min_samples_split': 5}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:12,295] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 211, 'max_depth': 16, 'min_samples_split': 4}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:13,433] Trial 24 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 146, 'max_depth': 19, 'min_samples_split': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:14,387] Trial 25 finished with value: 0.87 and parameters: {'n_estimators': 143, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:16,155] Trial 26 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 267, 'max_depth': 16, 'min_samples_split': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:16,680] Trial 27 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 54, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:17,236] Trial 28 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 93, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:19,441] Trial 29 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 301, 'max_depth': 19, 'min_samples_split': 4}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-28 16:19
finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 3 with value: 0.88.
# [I 2024-12-28 16:19:32,979] Trial 5 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:33,356] Trial 6 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 15}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:33,736] Trial 7 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:34,131] Trial 8 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:34,506] Trial 9 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:34,891] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:35,295] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:35,879] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:36,518] Trial 13 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:37,143] Trial 14 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:37,782] Trial 15 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:38,415] Trial 16 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:39,028] Trial 17 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:39,667] Trial 18 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 19}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:40,290] Trial 19 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:40,700] Trial 20 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 17}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:41,086] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:41,489] Trial 22 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:41,869] Trial 23 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:42,257] Trial 24 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:42,654] Trial 25 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:43,037] Trial 26 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:43,420] Trial 27 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:43,813] Trial 28 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:44,202] Trial 29 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-28 16:19:44,212] A new study created in memory with name: no-name-0e6860eb-c5a6-42c6-a224-5aa7afb1e070
# Optimizing Naive Bayes...
# [I 2024-12-28 16:19:44,484] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:44,749] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:45,017] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:45,284] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:45,561] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:45,822] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:46,086] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:46,357] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:46,630] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:46,899] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:47,170] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:47,433] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:47,710] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:47,978] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:48,247] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:48,516] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:48,781] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:49,053] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:49,320] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:49,585] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:49,859] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:50,127] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:50,416] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:50,783] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:51,146] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:51,516] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:51,898] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:52,264] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:52,630] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:52,990] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-28 16:19:53,007] A new study created in memory with name: no-name-0b0e3d8f-95b1-4434-a499-018813f3fca5
# Optimizing Gradient Boosting...
# [I 2024-12-28 16:20:45,924] Trial 0 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 231, 'learning_rate': 0.44698735012432356, 'max_depth': 12}. Best is trial 0 with value: 0.8833333333333333.
# [I 2024-12-28 16:21:06,427] Trial 1 finished with value: 0.88 and parameters: {'n_estimators': 141, 'learning_rate': 0.11987918348152053, 'max_depth': 7}. Best is trial 0 with value: 0.8833333333333333.
# [I 2024-12-28 16:21:48,824] Trial 2 finished with value: 0.88 and parameters: {'n_estimators': 399, 'learning_rate': 0.32648115109114706, 'max_depth': 5}. Best is trial 0 with value: 0.8833333333333333.
# [I 2024-12-28 16:23:39,660] Trial 3 finished with value: 0.89 and parameters: {'n_estimators': 323, 'learning_rate': 0.4601545695894388, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-28 16:25:01,706] Trial 4 finished with value: 0.87 and parameters: {'n_estimators': 382, 'learning_rate': 0.3093717791510879, 'max_depth': 11}. Best is trial 3 with value: 0.89.
# [I 2024-12-28 16:26:54,514] Trial 5 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 418, 'learning_rate': 0.018301968307888283, 'max_depth': 15}. Best is trial 5 with value: 0.8933333333333333.
# [I 2024-12-28 16:27:03,947] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 86, 'learning_rate': 0.3131629456000846, 'max_depth': 5}. Best is trial 5 with value: 0.8933333333333333.
# [I 2024-12-28 16:27:16,214] Trial 7 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 67, 'learning_rate': 0.1482141489293864, 'max_depth': 9}. Best is trial 7 with value: 0.8966666666666666.
# [I 2024-12-28 16:27:44,768] Trial 8 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 96, 'learning_rate': 0.3887572505032002, 'max_depth': 16}. Best is trial 7 with value: 0.8966666666666666.
# [I 2024-12-28 16:29:00,345] Trial 9 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 308, 'learning_rate': 0.26397334628244834, 'max_depth': 13}. Best is trial 7 with value: 0.8966666666666666.
# [I 2024-12-28 16:29:35,967] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_estimators':
finished with value: 0.9033333333333333 and parameters: {'n_estimators': 353, 'max_depth': 15, 'learning_rate': 0.14921781602526282}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:51:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:51:40,859] Trial 8 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 311, 'max_depth': 15, 'learning_rate': 0.2959688869175892}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:51:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:52:06,587] Trial 9 finished with value: 0.9 and parameters: {'n_estimators': 391, 'max_depth': 12, 'learning_rate': 0.36651714715141487}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:52:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:52:16,479] Trial 10 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 57, 'max_depth': 20, 'learning_rate': 0.25205106177133957}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:52:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:52:34,393] Trial 11 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 198, 'max_depth': 18, 'learning_rate': 0.019004639352729835}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:52:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:52:50,878] Trial 12 finished with value: 0.88 and parameters: {'n_estimators': 208, 'max_depth': 11, 'learning_rate': 0.02792937882285808}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:52:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:53:00,858] Trial 13 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 81, 'max_depth': 17, 'learning_rate': 0.2385968269101074}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:53:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:53:19,109] Trial 14 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 237, 'max_depth': 12, 'learning_rate': 0.08947626248189275}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:53:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:53:31,043] Trial 15 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 125, 'max_depth': 11, 'learning_rate': 0.15701378068706395}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:53:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:53:48,146] Trial 16 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 235, 'max_depth': 8, 'learning_rate': 0.3434384102230108}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:53:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:54:01,713] Trial 17 finished with value: 0.9 and parameters: {'n_estimators': 153, 'max_depth': 13, 'learning_rate': 0.20318492554127005}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:54:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:54:19,375] Trial 18 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 246, 'max_depth': 8, 'learning_rate': 0.0994859823589326}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:54:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:54:30,211] Trial 19 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 111, 'max_depth': 13, 'learning_rate': 0.12418869487458399}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:54:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:54:44,177] Trial 20 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 174, 'max_depth': 6, 'learning_rate': 0.49706839149922993}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:54:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 16:55:06,687] Trial 21 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 242, 'max_depth': 18, 'learning_rate': 0.06443580856445368}. Best is trial 14 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [16:55:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# [I 2024-12-28 17:15:18,844] Trial 9 finished with value: 0.9 and parameters: {'hidden_layer_1': 96, 'hidden_layer_2': 84, 'learning_rate_init': 0.015882782407168613}. Best is trial 0 with value: 0.9266666666666666.
# [I 2024-12-28 17:15:46,459] Trial 10 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 74, 'hidden_layer_2': 99, 'learning_rate_init': 0.0034406198503245528}. Best is trial 0 with value: 0.9266666666666666.
# [I 2024-12-28 17:16:05,877] Trial 11 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 78, 'learning_rate_init': 0.07136567621117754}. Best is trial 0 with value: 0.9266666666666666.
# [I 2024-12-28 17:16:16,495] Trial 12 finished with value: 0.91 and parameters: {'hidden_layer_1': 40, 'hidden_layer_2': 43, 'learning_rate_init': 0.07199240230319465}. Best is trial 0 with value: 0.9266666666666666.
# [I 2024-12-28 17:16:37,907] Trial 13 finished with value: 0.93 and parameters: {'hidden_layer_1': 79, 'hidden_layer_2': 97, 'learning_rate_init': 0.08860906365669588}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:17:01,992] Trial 14 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 100, 'learning_rate_init': 0.09929289705021482}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:17:29,144] Trial 15 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 83, 'hidden_layer_2': 84, 'learning_rate_init': 0.05661362794877732}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:17:47,457] Trial 16 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 73, 'learning_rate_init': 0.08509775909605725}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:18:13,736] Trial 17 finished with value: 0.91 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 89, 'learning_rate_init': 0.06087473209184203}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:18:40,650] Trial 18 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 93, 'learning_rate_init': 0.08601233465651077}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:19:06,872] Trial 19 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 72, 'learning_rate_init': 0.060004697380324296}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:19:32,511] Trial 20 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 67, 'learning_rate_init': 0.04432220973056323}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:19:51,991] Trial 21 finished with value: 0.91 and parameters: {'hidden_layer_1': 58, 'hidden_layer_2': 50, 'learning_rate_init': 0.08675401245761558}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:20:05,217] Trial 22 finished with value: 0.9 and parameters: {'hidden_layer_1': 43, 'hidden_layer_2': 36, 'learning_rate_init': 0.07833760936809729}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:20:29,011] Trial 23 finished with value: 0.89 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 28, 'learning_rate_init': 0.0665312323578106}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:20:52,831] Trial 24 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 88, 'hidden_layer_2': 51, 'learning_rate_init': 0.08984368774357623}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:21:10,718] Trial 25 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 29, 'learning_rate_init': 0.08220340979359331}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:21:24,035] Trial 26 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 30, 'hidden_layer_2': 10, 'learning_rate_init': 0.09240937797263335}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:21:48,124] Trial 27 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 91, 'learning_rate_init': 0.06576404691129722}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:22:08,113] Trial 28 finished with value: 0.91 and parameters: {'hidden_layer_1': 48, 'hidden_layer_2': 81, 'learning_rate_init': 0.07725894615772629}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:22:53,384] Trial 29 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 97, 'hidden_layer_2': 46, 'learning_rate_init': 0.055567335256518226}. Best is trial 13 with value: 0.93.
# [I 2024-12-28 17:22:53,408] A new study created in memory with name: no-name-7221064d-6c18-42bb-852c-4a347f48b620
# Optimizing MLP...
# [I 2024-12-28 17:23:28,131] Trial 0 finished with value: 0.9133333333333333 and parameters: {'layer_1': 69, 'layer_2': 144, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09291185986733802}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:24:05,216] Trial 1 finished with value: 0.9033333333333333 and parameters: {'layer_1': 100, 'layer_2': 143, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.034879873672968714}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:24:36,104] Trial 2 finished with value: 0.9033333333333333 and parameters: {'layer_1': 115, 'layer_2': 135, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06208070507133277}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:25:07,395] Trial 3 finished with value: 0.9 and parameters: {'layer_1': 103, 'layer_2': 101, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.09480438721201426}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:25:16,068] Trial 4 finished with value: 0.5 and parameters: {'layer_1': 136, 'layer_2': 106, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.004139767477863838}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:25:44,374] Trial 5 finished with value: 0.9033333333333333 and parameters: {'layer_1': 53, 'layer_2': 64, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.08911362170891851}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:26:04,106] Trial 6 finished with value: 0.9033333333333333 and parameters: {'layer_1': 142, 'layer_2': 107, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.048104591256818034}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:26:30,079] Trial 7 finished with value: 0.9066666666666666 and parameters: {'layer_1': 132, 'layer_2': 122, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.049569653398059084}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-28 17:27:14,162] Trial 8 finished with value: 0.9133333333333333 and parameters: {'layer_1': 78, 'layer_2': 90, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0796164813317331}. Best is trial 0 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:28:53,912] Trial 9 finished with value: 0.92 and parameters: {'layer_1': 114, 'layer_2': 88, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.034699076309549715}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:29:00,978] Trial 10 finished with value: 0.5 and parameters: {'layer_1': 117, 'layer_2': 50, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.015174846866701598}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:30:21,870] Trial 11 finished with value: 0.92 and parameters: {'layer_1': 74, 'layer_2': 81, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.029048869310852182}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:31:30,250] Trial 12 finished with value: 0.9166666666666666 and parameters: {'layer_1': 85, 'layer_2': 71, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.028956474541929282}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:32:04,326] Trial 13 finished with value: 0.9066666666666666 and parameters: {'layer_1': 52, 'layer_2': 84, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02826530801094546}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:32:50,382] Trial 14 finished with value: 0.9166666666666666 and parameters: {'layer_1': 89, 'layer_2': 80, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0632617928972921}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:34:06,213] Trial 15 finished with value: 0.9133333333333333 and parameters: {'layer_1': 69, 'layer_2': 63, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.015250863840933566}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:35:18,256] Trial 16 finished with value: 0.9166666666666666 and parameters: {'layer_1': 121, 'layer_2': 118, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03832849286446695}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:36:49,561] Trial 17 finished with value: 0.9166666666666666 and parameters: {'layer_1': 97, 'layer_2': 92, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.016051812258361067}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:37:34,127] Trial 18 finished with value: 0.8833333333333333 and parameters: {'layer_1': 149, 'layer_2': 75, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06316971320585876}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:37:41,675] Trial 19 finished with value: 0.5 and parameters: {'layer_1': 66, 'layer_2': 51, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.04143956080791506}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:38:00,141] Trial 20 finished with value: 0.6266666666666667 and parameters: {'layer_1': 109, 'layer_2': 91, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0010388306016372029}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:39:25,172] Trial 21 finished with value: 0.9166666666666666 and parameters: {'layer_1': 87, 'layer_2': 70, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02663580438416588}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:40:45,137] Trial 22 finished with value: 0.9166666666666666 and parameters: {'layer_1': 80, 'layer_2': 64, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.028233824495050467}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:42:13,408] Trial 23 finished with value: 0.9166666666666666 and parameters: {'layer_1': 90, 'layer_2': 82, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02443779461957834}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:42:59,220] Trial 24 finished with value: 0.9166666666666666 and parameters: {'layer_1': 80, 'layer_2': 73, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.043961479950994635}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:44:02,473] Trial 25 finished with value: 0.9166666666666666 and parameters: {'layer_1': 62, 'layer_2': 98, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.05546369542449803}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:44:47,065] Trial 26 finished with value: 0.91 and parameters: {'layer_1': 125, 'layer_2': 56, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.034417329202767175}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:46:24,726] Trial 27 finished with value: 0.92 and parameters: {'layer_1': 107, 'layer_2': 86, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.018110428636326475}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 17:47:51,787] Trial 28 finished with value: 0.8633333333333333 and parameters: {'layer_1': 95, 'layer_2': 114, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.008360555337436203}. Best is trial 9 with value: 0.92.
# [I 2024-12-28 17:48:00,987] Trial 29 finished with value: 0.5 and parameters: {'layer_1': 108, 'layer_2': 85, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.019938843644093734}. Best is trial 9 with value: 0.92.
#                   Model  Accuracy  Sensitivity  Specificity       MCC  \
# 0                   SVM  0.906667     0.873333     0.940000  0.815147
# 1         Decision Tree  0.863333     0.766667     0.960000  0.740640
# 2         Random Forest  0.883333     0.813333     0.953333  0.774292
# 3   Logistic Regression  0.886667     0.846667     0.926667  0.775820
# 4                  k-NN  0.883333     0.866667     0.900000  0.767093
# 5           Naive Bayes  0.866667     0.880000     0.853333  0.733594
# 6     Gradient Boosting  0.900000     0.866667     0.933333  0.801784
# 7               XGBoost  0.913333     0.893333     0.933333  0.827329
# 8              LightGBM  0.856667     0.780000     0.933333  0.721870
# 9              AdaBoost  0.876667     0.806667     0.946667  0.760826
# 10       Neural Network  0.930000     0.960000     0.900000  0.861552
# 11                  MLP  0.920000     0.933333     0.906667  0.840299
#
#        Kappa       AUC                                        Best Params
# 0   0.813333  0.906667         {'C': 1.5895917554870798, 'kernel': 'rbf'}
# 1   0.726667  0.863333          {'max_depth': 19, 'min_samples_split': 4}
# 2   0.766667  0.883333  {'n_estimators': 146, 'max_depth': 19, 'min_sa...
# 3   0.773333  0.886667     {'C': 5.78771569679225, 'solver': 'liblinear'}
# 4   0.766667  0.883333                                 {'n_neighbors': 3}
# 5   0.733333  0.866667                                                 {}
# 6   0.800000  0.900000  {'n_estimators': 51, 'learning_rate': 0.130395...
# 7   0.826667  0.913333  {'n_estimators': 237, 'max_depth': 12, 'learni...
# 8   0.713333  0.856667  {'n_estimators': 394, 'max_depth': 16, 'learni...
# 9   0.753333  0.876667  {'n_estimators': 495, 'learning_rate': 0.90883...
# 10  0.860000  0.930000  {'hidden_layer_1': 79, 'hidden_layer_2': 97, '...
# 11  0.840000  0.920000  {'layer_1': 114, 'layer_2': 88, 'activation': ...

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Define models
models = {
    "SVM": lambda trial: SVC(probability=True, C=trial.suggest_float("C", 0.1, 10.0), kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])),
    "Decision Tree": lambda trial: DecisionTreeClassifier(max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Random Forest": lambda trial: RandomForestClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Logistic Regression": lambda trial: LogisticRegression(C=trial.suggest_float("C", 0.1, 10.0), solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])),
    "k-NN": lambda trial: KNeighborsClassifier(n_neighbors=trial.suggest_int("n_neighbors", 3, 20)),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), max_depth=trial.suggest_int("max_depth", 3, 20)),
    "XGBoost": lambda trial: XGBClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": lambda trial: LGBMClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)),
    "AdaBoost": lambda trial: AdaBoostClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)),
    "Neural Network": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("hidden_layer_1", 10, 100), trial.suggest_int("hidden_layer_2", 10, 100)), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200),
    "MLP": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("layer_1", 50, 150), trial.suggest_int("layer_2", 50, 150)), activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]), solver=trial.suggest_categorical("solver", ["adam", "sgd"]), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200, random_state=42)
}

# Prepare a dictionary to store model probabilities horizontally
probabilities = {"Target": y_val}  # Starting with the target column (y_val)

# Run optimization and compute probabilities for each model
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    study = optuna.create_study(direction="maximize")

    # Objective function for Optuna
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        return accuracy_score(y_val, model.predict(X_val))

    study.optimize(objective, n_trials=30)

    # Train the best model using the best hyperparameters
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)

    # Get predicted probabilities for the positive class (class 1)
    probs = best_model.predict_proba(X_val)[:, 1]

    # Add to the probabilities dictionary
    probabilities[model_name] = probs

# Convert the probabilities dictionary to a DataFrame
probability_df = pd.DataFrame(probabilities)

# Save the probability dataset to a CSV file
probability_df.to_csv("N_CTDT_OPTUNA_probability_predictions.csv", index=False)

print("Dataset saved successfully!")
# Out:
# [I 2024-12-28 17:48:01,067] A new study created in memory with name: no-name-3705412d-028c-43b3-bf8a-ae7817892de9
# Optimizing SVM...
# [I 2024-12-28 17:48:42,537] Trial 0 finished with value: 0.8633333333333333 and parameters: {'C': 0.32921223780532827, 'kernel': 'rbf'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-28 17:49:17,719] Trial 1 finished with value: 0.83 and parameters: {'C': 3.733142784986342, 'kernel': 'poly'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-28 17:49:57,363] Trial 2 finished with value: 0.9033333333333333 and parameters: {'C': 8.278626171260056, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-28 17:50:17,085] Trial 3 finished with value: 0.8933333333333333 and parameters: {'C': 6.926065791270991, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-28 17
666666667 and parameters: {'max_depth': 13, 'min_samples_split': 7}. Best is trial 5 with value: 0.8566666666666667.
# [I 2024-12-28 18:07:16,513] Trial 7 finished with value: 0.7833333333333333 and parameters: {'max_depth': 8, 'min_samples_split': 3}. Best is trial 5 with value: 0.8566666666666667.
# [I 2024-12-28 18:07:16,706] Trial 8 finished with value: 0.7466666666666667 and parameters: {'max_depth': 5, 'min_samples_split': 8}. Best is trial 5 with value: 0.8566666666666667.
# [I 2024-12-28 18:07:17,004] Trial 9 finished with value: 0.83 and parameters: {'max_depth': 13, 'min_samples_split': 9}. Best is trial 5 with value: 0.8566666666666667.
# [I 2024-12-28 18:07:17,362] Trial 10 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:17,727] Trial 11 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:18,104] Trial 12 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:18,465] Trial 13 finished with value: 0.8533333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:18,813] Trial 14 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:19,084] Trial 15 finished with value: 0.81 and parameters: {'max_depth': 10, 'min_samples_split': 5}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:19,424] Trial 16 finished with value: 0.8466666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 6}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-28 18:07:19,789] Trial 17 finished with value: 0.8766666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:20,081] Trial 18 finished with value: 0.8133333333333334 and parameters: {'max_depth': 11, 'min_samples_split': 2}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:20,418] Trial 19 finished with value: 0.87 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:20,755] Trial 20 finished with value: 0.8533333333333334 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:21,126] Trial 21 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 3}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:21,473] Trial 22 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:21,797] Trial 23 finished with value: 0.8533333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:22,167] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:22,513] Trial 25 finished with value: 0.85 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:22,842] Trial 26 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:23,214] Trial 27 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 3}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:23,514] Trial 28 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 6}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:23,830] Trial 29 finished with value: 0.8333333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 2}. Best is trial 17 with value: 0.8766666666666667.
# [I 2024-12-28 18:07:24,194] A new study created in memory with name: no-name-d36d608a-ae03-4009-b1c9-a5874d8d73c0
# Optimizing Random Forest...
# [I 2024-12-28 18:07:25,726] Trial 0 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 453, 'max_depth': 4, 'min_samples_split': 10}. Best is trial 0 with value: 0.8133333333333334.
# [I 2024-12-28 18:07:27,432] Trial 1 finished with value: 0.81 and parameters: {'n_estimators': 318, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 0 with value: 0.8133333333333334.
# [I 2024-12-28 18:07:28,724] Trial 2 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 274, 'max_depth': 3, 'min_samples_split': 4}. Best is trial 0 with value: 0.8133333333333334.
# [I 2024-12-28 18:07:30,522] Trial 3 finished with value: 0.87 and parameters: {'n_estimators': 221, 'max_depth': 17, 'min_samples_split': 5}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:31,804] Trial 4 finished with value: 0.82 and parameters: {'n_estimators': 424, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:32,765] Trial 5 finished with value: 0.81 and parameters: {'n_estimators': 241, 'max_depth': 7, 'min_samples_split': 8}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:33,614] Trial 6 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 106, 'max_depth': 20, 'min_samples_split': 8}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:35,199] Trial 7 finished with value: 0.87 and parameters: {'n_estimators': 265, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:36,576] Trial 8 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 450, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 3 with value: 0.87.
# [I 2024-12-28 18:07:37,313] Trial 9 finished with value: 0.88 and parameters: {'n_estimators': 94, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07:37,691] Trial 10 finished with value: 0.86 and parameters: {'n_estimators': 50, 'max_depth': 11, 'min_samples_split': 6}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07:38,877] Trial 11 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 158, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07:40,420] Trial 12 finished with value: 0.88 and parameters: {'n_estimators': 163, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07:42,092] Trial 13 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 150, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07:42,991] Trial 14 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 90, 'max_depth': 11, 'min_samples_split': 5}. Best is trial 9 with value: 0.88.
# [I 2024-12-28 18:07
. Best is trial 22 with value: 0.9033333333333333.
# [I 2024-12-28 18:27:10,644] Trial 28 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 253, 'learning_rate': 0.2008636001090246, 'max_depth': 11}. Best is trial 22 with value: 0.9033333333333333.
# [I 2024-12-28 18:27:39,521] Trial 29 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 202, 'learning_rate': 0.46415141858277376, 'max_depth': 7}. Best is trial 22 with value: 0.9033333333333333.
# [I 2024-12-28 18:27:53,999] A new study created in memory with name: no-name-f6ada70b-e56d-4bec-81f4-5d7c55917d62
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:27:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:28:23,536] Trial 0 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 481, 'max_depth': 7, 'learning_rate': 0.3909385615422454}. Best is trial 0 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:28:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:28:49,435] Trial 1 finished with value: 0.9 and parameters: {'n_estimators': 405, 'max_depth': 7, 'learning_rate': 0.32637327194698346}. Best is trial 1 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:28:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:29:08,720] Trial 2 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 219, 'max_depth': 20, 'learning_rate': 0.3805839403165768}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:29:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:29:19,086] Trial 3 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 103, 'max_depth': 11, 'learning_rate': 0.03666159034251966}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:29:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:29:33,083] Trial 4 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 172, 'max_depth': 6, 'learning_rate': 0.10743372400725554}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:29:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:29:57,332] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 280, 'max_depth': 17, 'learning_rate': 0.3472684610373143}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:30:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:30:29,589] Trial 6 finished with value: 0.9 and parameters: {'n_estimators': 440, 'max_depth': 19, 'learning_rate': 0.2992208559648462}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:30:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:30:56,210] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 357, 'max_depth': 11, 'learning_rate': 0.020229441451780218}. Best is trial 2 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:30:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:31:14,721] Trial 8 finished with value: 0.91 and parameters: {'n_estimators': 245, 'max_depth': 13, 'learning_rate': 0.24582505424501777}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:31:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:31:29,105] Trial 9 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 154, 'max_depth': 18, 'learning_rate': 0.18159292564672003}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:31:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:31:38,526] Trial 10 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 55, 'max_depth': 14, 'learning_rate': 0.4875625071463584}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:31:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:31:58,032] Trial 11 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 252, 'max_depth': 15, 'learning_rate': 0.22145747177985176}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:32:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:32:13,542] Trial 12 finished with value: 0.9 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.4330959663730869}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:32:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:32:39,371] Trial 13 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 325, 'max_depth': 20, 'learning_rate': 0.2373598154354125}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:32:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:32:55,262] Trial 14 finished with value: 0.9 and parameters: {'n_estimators': 184, 'max_depth': 14, 'learning_rate': 0.16633405662750705}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:32:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:33:10,949] Trial 15 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 218, 'max_depth': 9, 'learning_rate': 0.40106187331613175}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:33:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:33:35,894] Trial 16 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 331, 'max_depth': 17, 'learning_rate': 0.29287362482679175}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:33:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:33:49,108] Trial 17 finished with value: 0.9 and parameters: {'n_estimators': 120, 'max_depth': 15, 'learning_rate': 0.4964179296751411}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:33:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:34:10,402] Trial 18 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 294, 'max_depth': 12, 'learning_rate': 0.12078824264531876}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:34:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:34:29,737] Trial 19 finished with value: 0.9 and parameters: {'n_estimators': 225, 'max_depth': 20, 'learning_rate': 0.3663447255759404}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:34:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:34:50,872] Trial 20 finished with value: 0.91 and parameters: {'n_estimators': 377, 'max_depth': 4, 'learning_rate': 0.2620252065231421}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:34:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:35:13,699] Trial 21 finished with value: 0.9 and parameters: {'n_estimators': 380, 'max_depth': 3, 'learning_rate': 0.26740432853265533}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:35:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-28 18:35:28,630] Trial 22 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 211, 'max_depth': 5, 'learning_rate': 0.21448797035979278}. Best is trial 8 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [18:35:31] WARNING: /workspace/src/learner.cc:740:
# ...
# [I 2024-12-28 18:51:39,612] Trial 28 finished with value: 0.7766666666666666 and parameters: {'n_estimators': 337, 'learning_rate': 0.4448731472052113}. Best is trial 18 with value: 0.87.
# [I 2024-12-28 18:52:12,108] Trial 29 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 463, 'learning_rate': 0.9262528306076172}. Best is trial 18 with value: 0.87.
# [I 2024-12-28 18:52:46,415] A new study created in memory with name: no-name-447b27c2-db31-4fc1-9e2b-292b639ba9bc
# Optimizing Neural Network...
# [I 2024-12-28 18:52:56,762] Trial 0 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 42, 'learning_rate_init': 0.08547380078919815}. Best is trial 0 with value: 0.9033333333333333.
# [I 2024-12-28 18:53:10,596] Trial 1 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 30, 'hidden_layer_2': 59, 'learning_rate_init': 0.027222675755263197}. Best is trial 0 with value: 0.9033333333333333.
# [I 2024-12-28 18:53:39,336] Trial 2 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 57, 'hidden_layer_2': 65, 'learning_rate_init': 0.04410803278966192}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:54:07,019] Trial 3 finished with value: 0.91 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 77, 'learning_rate_init': 0.04131094091134468}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:54:20,210] Trial 4 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 14, 'hidden_layer_2': 41, 'learning_rate_init': 0.0672763025529087}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:54:37,926] Trial 5 finished with value: 0.9 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 62, 'learning_rate_init': 0.006562490263844056}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:55:10,241] Trial 6 finished with value: 0.9 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 40, 'learning_rate_init': 0.09559299186372604}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:55:24,530] Trial 7 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 37, 'hidden_layer_2': 96, 'learning_rate_init': 0.05335687155870704}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:55:38,227] Trial 8 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 50, 'hidden_layer_2': 92, 'learning_rate_init': 0.035133357243654906}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:56:02,018] Trial 9 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 71, 'learning_rate_init': 0.032624085248131006}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:56:25,616] Trial 10 finished with value: 0.9 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 14, 'learning_rate_init': 0.00890528686448322}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:56:32,980] Trial 11 finished with value: 0.9 and parameters: {'hidden_layer_1': 11, 'hidden_layer_2': 32, 'learning_rate_init': 0.06239214906909274}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:56:51,144] Trial 12 finished with value: 0.91 and parameters: {'hidden_layer_1': 55, 'hidden_layer_2': 23, 'learning_rate_init': 0.07034558304026287}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:57:03,256] Trial 13 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 47, 'learning_rate_init': 0.07314098162490137}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:57:29,076] Trial 14 finished with value: 0.91 and parameters: {'hidden_layer_1': 68, 'hidden_layer_2': 72, 'learning_rate_init': 0.05094322121663704}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:57:46,847] Trial 15 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 49, 'hidden_layer_2': 51, 'learning_rate_init': 0.019886729632513436}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:57:58,283] Trial 16 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 25, 'hidden_layer_2': 84, 'learning_rate_init': 0.06187255439042532}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:58:16,529] Trial 17 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 33, 'learning_rate_init': 0.08387077903383419}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:58:25,689] Trial 18 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 64, 'learning_rate_init': 0.044705736309618896}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:58:42,493] Trial 19 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 64, 'hidden_layer_2': 52, 'learning_rate_init': 0.05757580872446591}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:59:10,797] Trial 20 finished with value: 0.9 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 25, 'learning_rate_init': 0.0739185426656408}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:59:31,011] Trial 21 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 44, 'hidden_layer_2': 47, 'learning_rate_init': 0.07206156829422165}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 18:59:48,137] Trial 22 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 42, 'learning_rate_init': 0.08238009121546286}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:00:07,102] Trial 23 finished with value: 0.91 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 56, 'learning_rate_init': 0.09968366966817788}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:00:21,359] Trial 24 finished with value: 0.9 and parameters: {'hidden_layer_1': 23, 'hidden_layer_2': 67, 'learning_rate_init': 0.06675783010435055}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:00:38,558] Trial 25 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 71, 'hidden_layer_2': 34, 'learning_rate_init': 0.0419198450172728}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:01:04,846] Trial 26 finished with value: 0.89 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 79, 'learning_rate_init': 0.07755041062161351}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:01:11,409] Trial 27 finished with value: 0.9 and parameters: {'hidden_layer_1': 16, 'hidden_layer_2': 47, 'learning_rate_init': 0.09198025367795633}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:01:21,331] Trial 28 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 13, 'learning_rate_init': 0.05796557578222654}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:01:31,944] Trial 29 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 18, 'hidden_layer_2': 23, 'learning_rate_init': 0.08864649335690292}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-28 19:01:53,209] A new study created in memory with name: no-name-fff10186-829a-406b-b3e3-4226cbff5396
# Optimizing MLP...
# [I 2024-12-28 19:02:33,766] Trial 0 finished with value: 0.9066666666666666 and parameters: {'layer_1': 122, 'layer_2': 83, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.050903786787646024}. Best is trial 0 with value: 0.9066666666666666.
# [I 2024-12-28 19:03:03,670] Trial 1 finished with value: 0.91 and parameters: {'layer_1': 129, 'layer_2': 134, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.027082986802228922}. Best is trial 1 with value: 0.91.
# [I 2024-12-28 19:03:13,077] Trial 2 finished with value: 0.5 and parameters: {'layer_1': 132, 'layer_2': 122, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.09061819555249595}. Best is trial 1 with value: 0.91.
# [I 2024-12-28 19:03:57,346] Trial 3 finished with value: 0.92 and parameters: {'layer_1': 62, 'layer_2': 95, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04087038885143787}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:04:35,753] Trial 4 finished with value: 0.8933333333333333 and parameters: {'layer_1': 96, 'layer_2': 112, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.05802823124976954}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:05:24,501] Trial 5 finished with value: 0.9133333333333333 and parameters: {'layer_1': 111, 'layer_2': 102, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.07433209397482392}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:05:32,813] Trial 6 finished with value: 0.5 and parameters: {'layer_1': 107, 'layer_2': 129, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.012842459252098159}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:06:34,998] Trial 7 finished with value: 0.9166666666666666 and parameters: {'layer_1': 119, 'layer_2': 111, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04074434440628553}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:06:42,361] Trial 8 finished with value: 0.5 and parameters: {'layer_1': 52, 'layer_2': 98, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.09855248387629802}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:07:33,334] Trial 9 finished with value: 0.8966666666666666 and parameters: {'layer_1': 85, 'layer_2': 65, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0011109586317872733}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:08:04,106] Trial 10 finished with value: 0.8966666666666666 and parameters: {'layer_1': 59, 'layer_2': 53, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.03219820968829125}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:09:19,421] Trial 11 finished with value: 0.9166666666666666 and parameters: {'layer_1': 147, 'layer_2': 86, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03681423051518516}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:10:22,067] Trial 12 finished with value: 0.9166666666666666 and parameters: {'layer_1': 74, 'layer_2': 145, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.06395725608583314}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:11:41,608] Trial 13 finished with value: 0.8766666666666667 and parameters: {'layer_1': 76, 'layer_2': 81, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03647554638295531}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:12:05,861] Trial 14 finished with value: 0.8966666666666666 and parameters: {'layer_1': 97, 'layer_2': 107, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0213499644009689}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:13:20,619] Trial 15 finished with value: 0.5433333333333333 and parameters: {'layer_1': 68, 'layer_2': 93, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04845600266386757}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:14:35,678] Trial 16 finished with value: 0.5433333333333333 and parameters: {'layer_1': 148, 'layer_2': 115, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.04299789582256954}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:15:19,958] Trial 17 finished with value: 0.9166666666666666 and parameters: {'layer_1': 88, 'layer_2': 71, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0670928158412809}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:15:48,645] Trial 18 finished with value: 0.8966666666666666 and parameters: {'layer_1': 121, 'layer_2': 147, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.01626215989661406}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:16:13,640] Trial 19 finished with value: 0.8933333333333333 and parameters: {'layer_1': 106, 'layer_2': 119, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.08328436336977382}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:17:12,071] Trial 20 finished with value: 0.91 and parameters: {'layer_1': 138, 'layer_2': 72, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0559807047439239}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:18:09,173] Trial 21 finished with value: 0.9033333333333333 and parameters: {'layer_1': 147, 'layer_2': 88, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03911679449162338}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:19:48,836] Trial 22 finished with value: 0.92 and parameters: {'layer_1': 115, 'layer_2': 99, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02828778793533636}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:20:56,465] Trial 23 finished with value: 0.9133333333333333 and parameters: {'layer_1': 116, 'layer_2': 104, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0459444083598813}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:22:30,632] Trial 24 finished with value: 0.92 and parameters: {'layer_1': 101, 'layer_2': 94, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02301608107543178}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:23:56,468] Trial 25 finished with value: 0.8866666666666667 and parameters: {'layer_1': 88, 'layer_2': 100, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.007561513514303049}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:24:08,549] Trial 26 finished with value: 0.9 and parameters: {'layer_1': 96, 'layer_2': 94, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.026584635592552093}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:25:39,727] Trial 27 finished with value: 0.91 and parameters: {'layer_1': 104, 'layer_2': 76, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.022198252501979196}. Best is trial 3 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-28 19:26:50,772] Trial 28 finished with value: 0.9166666666666666 and parameters: {'layer_1': 64, 'layer_2': 92, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.031178720630234476}. Best is trial 3 with value: 0.92.
# [I 2024-12-28 19:26:55,657] Trial 29 finished with value: 0.5 and parameters: {'layer_1': 81, 'layer_2': 80, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.014980044351983399}. Best is trial 3 with value: 0.92.
# Dataset saved successfully!

# %% [markdown]
# Class Feature Vector (CFV)

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score


# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]

# Define models with hyperparameter optimization (Optuna)
models = {
    "SVM": lambda trial: SVC(
         probability=True,
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}

# Initialize a list to store the CFV data
cfv_data = []

# Define the optimization and prediction function
def optimize_and_predict(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict_proba(X_val)[:, 1]  # Get probability for class 1 (positive)
        return accuracy_score(y_val, model.predict(X_val))

    # Perform optimization with Optuna
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Return the best model
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)
    preds = best_model.predict_proba(X_val)[:, 1]  # Using the probability for class 1 (positive)

    # Append predictions to CFV list
    return preds

# Train each model and generate predictions for CFV
for model_name, model_func in models.items():
    print(f"Training and predicting with {model_name}...")
    preds = optimize_and_predict(model_name, model_func)
    cfv_data.append(preds)

# Convert the CFV data into a DataFrame
cfv_df = pd.DataFrame(np.array(cfv_data).T, columns=models.keys())

# Optionally, add the true labels column
cfv_df["True_Label"] = y_val.values

# Save the CFV dataset to CSV
cfv_df.to_csv("CFV_CTDT.csv", index=False)
print("CFV dataset created and saved!")
# Out:
# [I 2025-01-15 06:23:49,831] A new study created in memory with name: no-name-ed2f3d97-fa22-483d-9c13-58dc246f79b6
# Training and predicting with SVM...
# [I 2025-01-15 06:24:10,268] Trial 0 finished with value: 0.88 and parameters: {'C': 5.717977577816307, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06
finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 5}. Best is trial 2 with value: 0.86.
# [I 2025-01-15 06:42:25,428] Trial 4 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 5}. Best is trial 2 with value: 0.86.
# [I 2025-01-15 06:42:26,088] Trial 5 finished with value: 0.86 and parameters: {'max_depth': 19, 'min_samples_split': 6}. Best is trial 2 with value: 0.86.
# [I 2025-01-15 06:42:26,749] Trial 6 finished with value: 0.87 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 6 with value: 0.87.
# [I 2025-01-15 06:42:27,299] Trial 7 finished with value: 0.82 and parameters: {'max_depth': 12, 'min_samples_split': 4}. Best is trial 6 with value: 0.87.
# [I 2025-01-15 06:42:27,752] Trial 8 finished with value: 0.79 and parameters: {'max_depth': 9, 'min_samples_split': 5}. Best is trial 6 with value: 0.87.
# [I 2025-01-15 06:42:28,127] Trial 9 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 7}. Best is trial 6 with value: 0.87.
# [I 2025-01-15 06:42:28,483] Trial 10 finished with value: 0.8266666666666667 and parameters: {'max_depth': 13, 'min_samples_split': 10}. Best is trial 6 with value: 0.87.
# [I 2025-01-15 06:42:28,907] Trial 11 finished with value: 0.8733333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:29,335] Trial 12 finished with value: 0.8733333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:29,759] Trial 13 finished with value: 0.87 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:30,130] Trial 14 finished with value: 0.84 and parameters: {'max_depth': 15, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:30,440] Trial 15 finished with value: 0.7866666666666666 and parameters: {'max_depth': 9, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:30,805] Trial 16 finished with value: 0.8233333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 3}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:31,216] Trial 17 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:31,605] Trial 18 finished with value: 0.8466666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 10}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:31,929] Trial 19 finished with value: 0.8066666666666666 and parameters: {'max_depth': 10, 'min_samples_split': 4}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:32,196] Trial 20 finished with value: 0.7633333333333333 and parameters: {'max_depth': 6, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:32,620] Trial 21 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:33,019] Trial 22 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:33,422] Trial 23 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:33,811] Trial 24 finished with value: 0.8533333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:34,215] Trial 25 finished with value: 0.8666666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:34,597] Trial 26 finished with value: 0.8366666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 3}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:35,022] Trial 27 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:35,418] Trial 28 finished with value: 0.8666666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:35,831] Trial 29 finished with value: 0.8633333333333333 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 11 with value: 0.8733333333333333.
# [I 2025-01-15 06:42:36,185] A new study created in memory with name: no-name-b28a4c31-8659-44e2-beb4-46b2ae7576b7
# Training and predicting with Random Forest...
# [I 2025-01-15 06:42:38,389] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 264, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:40,096] Trial 1 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 234, 'max_depth': 8, 'min_samples_split': 6}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:41,651] Trial 2 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 310, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:43,423] Trial 3 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 210, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:45,664] Trial 4 finished with value: 0.85 and parameters: {'n_estimators': 457, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:46,084] Trial 5 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 62, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:47,067] Trial 6 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 147, 'max_depth': 13, 'min_samples_split': 3}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:47,726] Trial 7 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 81, 'max_depth': 15, 'min_samples_split': 4}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:49,406] Trial 8 finished with value: 0.84 and parameters: {'n_estimators': 347, 'max_depth': 10, 'min_samples_split': 10}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:50,149] Trial 9 finished with value: 0.81 and parameters: {'n_estimators': 213, 'max_depth': 4, 'min_samples_split': 10}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:54,071] Trial 10 finished with value: 0.88 and parameters: {'n_estimators': 393, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:42:58,192] Trial 11 finished with value: 0.88 and parameters: {'n_estimators': 444, 'max_depth': 19, 'min_samples_split': 2}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:43:00,864] Trial 12 finished with value: 0.87 and parameters: {'n_estimators': 377, 'max_depth': 17, 'min_samples_split': 2}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:43:03,433] Trial 13 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 391, 'max_depth': 17, 'min_samples_split': 7}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:43:05,707] Trial 14 finished with value: 0.89 and parameters: {'n_estimators': 276, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 14 with value: 0.89.
# [I 2025-01-15 06:43:08,659] Trial 15 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 279, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 14 with value: 0.89.
# [I 2025-01-15 06:43:10,182] Trial 16 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 139, 'max_depth': 14, 'min_samples_split': 7}. Best is trial 14 with value: 0.89.
# [I 2025-01-15 06:43:12,452] Trial 17 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 291, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 14 with value: 0.89.
# [I 2025-01-15 06:43
 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 06:43:56,252] Trial 28 finished with value: 0.8866666666666667 and parameters: {'C': 9.197661609959024, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 06:43:56,616] Trial 29 finished with value: 0.8666666666666667 and parameters: {'C': 3.5148839261981664, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 06:43:56,886] A new study created in memory with name: no-name-9c80d508-8553-4b1d-9df1-e787d326250f
# Training and predicting with k-NN...
# [I 2025-01-15 06:43:57,631] Trial 0 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 0 with value: 0.8733333333333333.
# [I 2025-01-15 06:43:58,309] Trial 1 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 15}. Best is trial 0 with value: 0.8733333333333333.
# [I 2025-01-15 06:43:58,975] Trial 2 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 0 with value: 0.8733333333333333.
# [I 2025-01-15 06:43:59,649] Trial 3 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 0 with value: 0.8733333333333333.
# [I 2025-01-15 06:44:00,320] Trial 4 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:00,984] Trial 5 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:01,665] Trial 6 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:02,343] Trial 7 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:03,010] Trial 8 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:03,688] Trial 9 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:04,657] Trial 10 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:05,706] Trial 11 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:06,761] Trial 12 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:07,822] Trial 13 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:08,844] Trial 14 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:09,522] Trial 15 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:10,203] Trial 16 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:10,892] Trial 17 finished with value: 0.84 and parameters: {'n_neighbors': 18}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:11,566] Trial 18 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:12,249] Trial 19 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:12,928] Trial 20 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:13,602] Trial 21 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:14,291] Trial 22 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:14,976] Trial 23 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:15,663] Trial 24 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 4 with value: 0.88.
# [I 2025-01-15 06:44:16,353] Trial 25 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 25 with value: 0.8833333333333333.
# [I 2025-01-15 06:44:17,032] Trial 26 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 25 with value: 0.8833333333333333.
# [I 2025-01-15 06:44:17,716] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 25 with value: 0.8833333333333333.
# [I 2025-01-15 06:44:18,399] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 25 with value: 0.8833333333333333.
# [I 2025-01-15 06:44:19,267] Trial 29 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 25 with value: 0.8833333333333333.
# [I 2025-01-15 06:44:19,863] A new study created in memory with name: no-name-e0205eb2-7b52-4e14-95a0-513b13224e4e
# Training and predicting with Naive Bayes...
# [I 2025-01-15 06:44:20,432] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:20,952] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:21,478] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:22,019] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:22,578] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:23,130] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:23,623] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:24,006] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:24,405] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:24,790] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:25,182] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:25,574] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:25,958] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:26,354] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:26,743] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:27,129] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:27,527] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:27,913] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:28,314] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:28,701] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:29,080] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:29,479] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:29,867] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:30,254] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:30,645] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:31,029] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:31,429] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:31,812] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:32,195] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:32,590] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 06:44:32,902] A new study created in memory with name: no-name-a38d6bc0-8429-4a93-ba75-0396f8c5f26d
# Training and predicting with Gradient Boosting...
# [I 2025-01-15 06:45:47,131] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 247, 'learning_rate': 0.30775984742303036, 'max_depth': 16}. Best is trial 0 with value: 0.88.
# [I 2025-01-15 06:46:07,295] Trial 1 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 136, 'learning_rate': 0.027432904049019227, 'max_depth': 7}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-15 06:47:51,272] Trial 2 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 329, 'learning_rate': 0.18167984289514286, 'max_depth': 17}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:48:22,311] Trial 3 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 175, 'learning_rate': 0.37598105656849634, 'max_depth': 9}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:50:03,104] Trial 4 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 471, 'learning_rate': 0.24882049415920285, 'max_depth': 11}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:50:59,612] Trial 5 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 229, 'learning_rate': 0.08254150319021297, 'max_depth': 13}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:51:18,548] Trial 6 finished with value: 0.88 and parameters: {'n_estimators': 79, 'learning_rate': 0.4052301652095654, 'max_depth': 13}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:53:16,618] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 477, 'learning_rate': 0.16488733204819903, 'max_depth': 13}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:55:16,477] Trial 8 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 344, 'learning_rate': 0.1501054120504553, 'max_depth': 19}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:55:38,543] Trial 9 finished with value: 0.88 and parameters: {'n_estimators': 64, 'learning_rate': 0.16921372957226583, 'max_depth': 19}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:56:04,474] Trial 10 finished with value: 0.87 and parameters: {'n_estimators': 359, 'learning_rate': 0.4901723855341896, 'max_depth': 3}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:56:32,440] Trial 11 finished with value: 0.89 and parameters: {'n_estimators': 173, 'learning_rate': 0.31314120842610127, 'max_depth': 8}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:57:32,333] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 337, 'learning_rate': 0.39592898483984046, 'max_depth': 9}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 06:58:04,203] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 301, 'learning_rate': 0.27045723801426713, 'max_depth': 5}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:00:08,501] Trial 14 finished with value: 0.88 and parameters: {'n_estimators': 423, 'learning_rate': 0.3982826261917707, 'max_depth': 16}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:01:08,875] Trial 15 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 200, 'learning_rate': 0.49772164070604896, 'max_depth': 16}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:01:34,728] Trial 16 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 138, 'learning_rate': 0.23519695184503794, 'max_depth': 10}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:02:10,853] Trial 17 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 284, 'learning_rate': 0.3519677976746135, 'max_depth': 6}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:02:52,356] Trial 18 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 131, 'learning_rate': 0.20753705654598095, 'max_depth': 17}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:04:37,950] Trial 19 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 401, 'learning_rate': 0.12836683047823952, 'max_depth': 14}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:06:04,861] Trial 20 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 238, 'learning_rate': 0.4535584297719061, 'max_depth': 20}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:07:50,980] Trial 21 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 404, 'learning_rate': 0.10238483736328738, 'max_depth': 14}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:09:16,892] Trial 22 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 402, 'learning_rate': 0.12769704372377153, 'max_depth': 11}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:10:37,695] Trial 23 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 306, 'learning_rate': 0.05059267100635281, 'max_depth': 14}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:12:40,902] Trial 24 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 372, 'learning_rate': 0.20747233452965652, 'max_depth': 18}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:14:39,687] Trial 25 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 427, 'learning_rate': 0.08105229995337683, 'max_depth': 15}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:15:51,635] Trial 26 finished with value: 0.88 and parameters: {'n_estimators': 314, 'learning_rate': 0.31675046341102875, 'max_depth': 12}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:16:59,944] Trial 27 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 382, 'learning_rate': 0.20424165263749977, 'max_depth': 9}. Best is trial 2 with value: 0.8933333333333333.
# [I 2025-01-15 07:18:26,500] Trial 28 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 263, 'learning_rate': 0.13004313125998795, 'max_depth': 18}. Best is trial 28 with value: 0.8966666666666666.
# [I 2025-01-15 07:19:50,193] Trial 29 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 265, 'learning_rate': 0.27637895768809495, 'max_depth': 17}. Best is trial 28 with value: 0.8966666666666666.
# [I 2025-01-15 07:21:16,212] A new study created in memory with name: no-name-ac843d76-7a50-47d1-8a18-b8e0d4bd8e4a
# Training and predicting with XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:21:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 07:21:26,777] Trial 0 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 56, 'max_depth': 8, 'learning_rate': 0.33722822155290183}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:21:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 07:21:40,837] Trial 1 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 107, 'max_depth': 20, 'learning_rate': 0.16726219628088992}. Best is trial 1 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:21:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 07:22:00,818] Trial 2 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 210, 'max_depth': 18, 'learning_rate': 0.31042283445911345}. Best is trial 1 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07
finished with value: 0.8766666666666667 and parameters: {'n_estimators': 499, 'learning_rate': 0.9131122021421734}. Best is trial 28 with value: 0.8766666666666667.
# [I 2025-01-15 07:45:11,554] Trial 29 finished with value: 0.87 and parameters: {'n_estimators': 491, 'learning_rate': 0.9081535742974135}. Best is trial 28 with value: 0.8766666666666667.
# [I 2025-01-15 07:45:47,658] A new study created in memory with name: no-name-d4b75323-bed8-4de1-b1d1-21bdde4cb4c6
# Training and predicting with Neural Network...
# [I 2025-01-15 07:46:19,417] Trial 0 finished with value: 0.91 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 44, 'learning_rate_init': 0.037188235982632774}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 07:46:53,974] Trial 1 finished with value: 0.92 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 80, 'learning_rate_init': 0.09510061312020879}. Best is trial 1 with value: 0.92.
# [I 2025-01-15 07:47:08,201] Trial 2 finished with value: 0.9 and parameters: {'hidden_layer_1': 27, 'hidden_layer_2': 34, 'learning_rate_init': 0.015102873872363608}. Best is trial 1 with value: 0.92.
# [I 2025-01-15 07:48:10,317] Trial 3 finished with value: 0.9 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 100, 'learning_rate_init': 0.001109898117013194}. Best is trial 1 with value: 0.92.
# [I 2025-01-15 07:48:27,338] Trial 4 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 47, 'learning_rate_init': 0.04936893390563183}. Best is trial 1 with value: 0.92.
# [I 2025-01-15 07:48:52,428] Trial 5 finished with value: 0.9 and parameters: {'hidden_layer_1': 55, 'hidden_layer_2': 46, 'learning_rate_init': 0.07298921775182718}. Best is trial 1 with value: 0.92.
# [I 2025-01-15 07:49:18,579] Trial 6 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 14, 'learning_rate_init': 0.05755635693507329}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:49:38,268] Trial 7 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 54, 'learning_rate_init': 0.09700313084870059}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:49:49,739] Trial 8 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 44, 'hidden_layer_2': 11, 'learning_rate_init': 0.03131242191691575}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:50:11,032] Trial 9 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 73, 'learning_rate_init': 0.06513528426410793}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:50:41,779] Trial 10 finished with value: 0.91 and parameters: {'hidden_layer_1': 66, 'hidden_layer_2': 11, 'learning_rate_init': 0.07272467851288444}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:50:57,824] Trial 11 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 97, 'hidden_layer_2': 76, 'learning_rate_init': 0.0995788555493719}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:51:44,704] Trial 12 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 83, 'hidden_layer_2': 78, 'learning_rate_init': 0.08297201648431944}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:51:55,815] Trial 13 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 64, 'hidden_layer_2': 24, 'learning_rate_init': 0.05574013852954029}. Best is trial 6 with value: 0.9233333333333333.
# [I 2025-01-15 07:52:21,591] Trial 14 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 94, 'hidden_layer_2': 96, 'learning_rate_init': 0.08397110430916209}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:52:51,252] Trial 15 finished with value: 0.92 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 97, 'learning_rate_init': 0.08447511461752431}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:53:20,832] Trial 16 finished with value: 0.92 and parameters: {'hidden_layer_1': 46, 'hidden_layer_2': 64, 'learning_rate_init': 0.05383092120400667}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:53:46,448] Trial 17 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 70, 'hidden_layer_2': 89, 'learning_rate_init': 0.03971357266442426}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:54:07,362] Trial 18 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 30, 'learning_rate_init': 0.08250911980541113}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:54:22,651] Trial 19 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 59, 'hidden_layer_2': 63, 'learning_rate_init': 0.06531609716127895}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:55:06,109] Trial 20 finished with value: 0.91 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 20, 'learning_rate_init': 0.023757794267972247}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:55:26,490] Trial 21 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 89, 'learning_rate_init': 0.045099487566437065}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:55:38,608] Trial 22 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 72, 'hidden_layer_2': 89, 'learning_rate_init': 0.0367119562601793}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:56:09,711] Trial 23 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 81, 'hidden_layer_2': 89, 'learning_rate_init': 0.062109270795882056}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:56:38,859] Trial 24 finished with value: 0.91 and parameters: {'hidden_layer_1': 87, 'hidden_layer_2': 67, 'learning_rate_init': 0.020887758675694874}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:56:52,765] Trial 25 finished with value: 0.9 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 85, 'learning_rate_init': 0.04311871498867882}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:57:13,335] Trial 26 finished with value: 0.91 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 94, 'learning_rate_init': 0.07410201679493955}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:57:45,419] Trial 27 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 91, 'hidden_layer_2': 57, 'learning_rate_init': 0.05997841333096879}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:58:12,540] Trial 28 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 79, 'hidden_layer_2': 38, 'learning_rate_init': 0.005839811118915454}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:58:27,106] Trial 29 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 69, 'learning_rate_init': 0.03213184333582145}. Best is trial 14 with value: 0.9266666666666666.
# [I 2025-01-15 07:58:59,724] A new study created in memory with name: no-name-1e7cd054-7116-4b3b-afd8-35365a042afd
# Training and predicting with MLP...
# [I 2025-01-15 07:59:41,089] Trial 0 finished with value: 0.91 and parameters: {'layer_1': 97, 'layer_2': 97, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.035866919768500795}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:00:24,426] Trial 1 finished with value: 0.8933333333333333 and parameters: {'layer_1': 94, 'layer_2': 121, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0015212446889584451}. Best is trial 0 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-15 08:01:46,833] Trial 2 finished with value: 0.8533333333333334 and parameters: {'layer_1': 66, 'layer_2': 62, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0063328585741566175}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:02:51,435] Trial 3 finished with value: 0.9033333333333333 and parameters: {'layer_1': 140, 'layer_2': 118, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.07420068180406914}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:03:25,131] Trial 4 finished with value: 0.8866666666666667 and parameters: {'layer_1': 99, 'layer_2': 107, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.052474277311391815}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:03:42,215] Trial 5 finished with value: 0.9033333333333333 and parameters: {'layer_1': 52, 'layer_2': 117, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08334219040764859}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:04:17,959] Trial 6 finished with value: 0.9033333333333333 and parameters: {'layer_1': 79, 'layer_2': 74, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0060501150769101675}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:05:00,504] Trial 7 finished with value: 0.8933333333333333 and parameters: {'layer_1': 119, 'layer_2': 136, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08386267023604184}. Best is trial 0 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-15 08:06:44,074] Trial 8 finished with value: 0.9066666666666666 and parameters: {'layer_1': 105, 'layer_2': 133, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.010838208878706491}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:07:57,242] Trial 9 finished with value: 0.91 and parameters: {'layer_1': 118, 'layer_2': 86, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.05719960075722325}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:08:35,761] Trial 10 finished with value: 0.8866666666666667 and parameters: {'layer_1': 145, 'layer_2': 95, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.03404155667500285}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:08:43,746] Trial 11 finished with value: 0.5 and parameters: {'layer_1': 123, 'layer_2': 87, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.04505464628601449}. Best is trial 0 with value: 0.91.
# [I 2025-01-15 08:09:37,589] Trial 12 finished with value: 0.9133333333333333 and parameters: {'layer_1': 121, 'layer_2': 82, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.056394255827395295}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:10:37,561] Trial 13 finished with value: 0.91 and parameters: {'layer_1': 83, 'layer_2': 55, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.031685747411118084}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:11:29,971] Trial 14 finished with value: 0.9066666666666666 and parameters: {'layer_1': 126, 'layer_2': 74, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.06430526153403265}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:11:41,286] Trial 15 finished with value: 0.5 and parameters: {'layer_1': 108, 'layer_2': 103, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.026088816144669895}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:12:16,030] Trial 16 finished with value: 0.91 and parameters: {'layer_1': 133, 'layer_2': 74, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09647870775626555}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:12:34,926] Trial 17 finished with value: 0.9066666666666666 and parameters: {'layer_1': 89, 'layer_2': 90, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.04238535394105805}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:12:48,876] Trial 18 finished with value: 0.5 and parameters: {'layer_1': 110, 'layer_2': 80, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.019292821757881693}. Best is trial 12 with value: 0.9133333333333333.
# [I 2025-01-15 08:13:10,664] Trial 19 finished with value: 0.9166666666666666 and parameters: {'layer_1': 70, 'layer_2': 64, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06393066322925656}. Best is trial 19 with value: 0.9166666666666666.
# [I 2025-01-15 08:13:37,288] Trial 20 finished with value: 0.9166666666666666 and parameters: {'layer_1': 71, 'layer_2': 52, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0661193421715413}. Best is trial 19 with value: 0.9166666666666666.
# [I 2025-01-15 08:14:08,339] Trial 21 finished with value: 0.88 and parameters: {'layer_1': 65, 'layer_2': 50, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06557172225284795}. Best is trial 19 with value: 0.9166666666666666.
# [I 2025-01-15 08:14:38,819] Trial 22 finished with value: 0.8966666666666666 and parameters: {'layer_1': 70, 'layer_2': 64, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06336584489287352}. Best is trial 19 with value: 0.9166666666666666.
# [I 2025-01-15 08:14:55,592] Trial 23 finished with value: 0.92 and parameters: {'layer_1': 55, 'layer_2': 60, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07438882595705149}. Best is trial 23 with value: 0.92.
# [I 2025-01-15 08:15:25,736] Trial 24 finished with value: 0.9166666666666666 and parameters: {'layer_1': 51, 'layer_2': 62, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07525064475586418}. Best is trial 23 with value: 0.92.
# [I 2025-01-15 08:15:50,849] Trial 25 finished with value: 0.91 and parameters: {'layer_1': 61, 'layer_2': 150, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.09685982402704296}. Best is trial 23 with value: 0.92.
# [I 2025-01-15 08:16:08,931] Trial 26 finished with value: 0.9233333333333333 and parameters: {'layer_1': 74, 'layer_2': 50, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07429566964765091}. Best is trial 26 with value: 0.9233333333333333.
# [I 2025-01-15 08:16:36,183] Trial 27 finished with value: 0.9033333333333333 and parameters: {'layer_1': 57, 'layer_2': 59, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08609242181018245}. Best is trial 26 with value: 0.9233333333333333.
# [I 2025-01-15 08:17:14,126] Trial 28 finished with value: 0.9166666666666666 and parameters: {'layer_1': 77, 'layer_2': 70, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0774310990003607}. Best is trial 26 with value: 0.9233333333333333.
# [I 2025-01-15 08:17:41,894] Trial 29 finished with value: 0.8866666666666667 and parameters: {'layer_1': 86, 'layer_2': 68, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07097038035741376}. Best is trial 26 with value: 0.9233333333333333.
# CFV dataset created and saved!

# %% [markdown]
# CPFV (Combined Probability and Class Feature Vector)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/CTDT_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)], ignore_index=True)
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)], ignore_index=True)

# Separate features and labels
X_train = main_data.drop(columns=["label"])
y_train = main_data["label"]
X_val = validation_data.drop(columns=["label"])
y_val = validation_data["label"]

# Initialize models with their tuned hyperparameters
trained_models = {
    "SVM": SVC(C=1.0, kernel="rbf", probability=True),  # Example parameters
    "Decision Tree": DecisionTreeClassifier(max_depth=10, min_samples_split=5),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5),
    "Logistic Regression": LogisticRegression(C=1.0, solver="lbfgs"),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=10),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=10, learning_rate=0.1, use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": LGBMClassifier(n_estimators=100, max_depth=10, learning_rate=0.1),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, learning_rate=0.1),
    "Neural Network (MLPClassifier)": MLPClassifier(hidden_layer_sizes=(100, 50), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200),
    "Multilayer Perceptron (Custom MLP)": MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200)
}

# Train all models on the training dataset
for model_name, model in trained_models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)

# Function to create CPFV dataset
def create_cpfv(models, X_data, y_data):
    cpfv_data = pd.DataFrame()
    for model_name, model in models.items():
        # Add predicted class labels
        cpfv_data[f"{model_name}_Class"] = model.predict(X_data)
        # Add predicted probabilities or decision scores
        if hasattr(model, "predict_proba"):
            cpfv_data[f"{model_name}_Prob"] = model.predict_proba(X_data)[:, 1]
        elif hasattr(model, "decision_function"):
            cpfv_data[f"{model_name}_Prob"] = model.decision_function(X_data)
        else:
            cpfv_data[f"{model_name}_Prob"] = cpfv_data[f"{model_name}_Class"]
    # Add true labels
    cpfv_data["True_Label"] = y_data.reset_index(drop=True)
    return cpfv_data

# Create CPFV dataset using validation data
cpfv_dataset = create_cpfv(trained_models, X_val, y_val)

# Save CPFV dataset to CSV
cpfv_dataset.to_csv("CPFV_CTDT.csv", index=False)
# Out:
# Training SVM...
# Training Decision Tree...
# Training Random Forest...
# Training Logistic Regression...
# Training k-NN...
# Training Naive Bayes...
# Training Gradient Boosting...
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:20:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001386 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training AdaBoost...
# Training Neural Network (MLPClassifier)...
# Training Multilayer Perceptron (Custom MLP)...

# %% [markdown]
# # **parameter grids for RandomizedSearchCV**

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier # Import path for KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_negative_features.csv")


# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for RandomizedSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply random search
for model_name, model in models.items():
    print(f"Performing RandomizedSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform randomized search
    random_search = RandomizedSearchCV(model, param_grid, n_iter=10, cv=cv, scoring='accuracy', n_jobs=-1, random_state=42)
    random_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = random_search.best_params_
    best_scores.append(random_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)
# Out:
# Performing RandomizedSearchCV for SVM...
# Performing RandomizedSearchCV for Decision Tree...
# Performing RandomizedSearchCV for Random Forest...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan 0.92009768 0.92267278 0.8221881         nan        nan
#  0.8333321  0.92009398        nan 0.86169528]
#   warnings.warn(
# Performing RandomizedSearchCV for Logistic Regression...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Performing RandomizedSearchCV for k-NN...
# Performing RandomizedSearchCV for Naive Bayes...
# Performing RandomizedSearchCV for Gradient Boosting...
# Performing RandomizedSearchCV for XGBoost...
# Performing RandomizedSearchCV for LightGBM...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001764 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Performing RandomizedSearchCV for CatBoost...
# Performing RandomizedSearchCV for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing RandomizedSearchCV for Neural Network...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#                   Model  Best Score  \
# 0                   SVM    0.928681
# 1         Decision Tree    0.854791
# 2         Random Forest    0.922673
# 3   Logistic Regression    0.924401
# 4                  k-NN    0.915810
# 5           Naive Bayes    0.905531
# 6     Gradient Boosting    0.897762
# 7               XGBoost    0.892615
# 8              LightGBM    0.795549
# 9              CatBoost    0.906356
# 10             AdaBoost    0.884882
# 11       Neural Network    0.937276
#
#                                       Best Parameters
# 0    {'kernel': 'linear', 'gamma': 'scale', 'C': 100}
# 1   {'min_samples_split': 2, 'min_samples_leaf': 2...
# 2   {'n_estimators': 100, 'min_samples_split': 5, ...
# 3       {'solver': 'saga', 'penalty': 'l2', 'C': 100}
# 4   {'weights': 'distance', 'n_neighbors': 3, 'met...
# 5            {'var_smoothing': 2.782559402207126e-05}
# 6   {'n_estimators': 200, 'max_depth': 5, 'learnin...
# 7   {'n_estimators': 200, 'max_depth': 5, 'learnin...
# 8   {'n_estimators': 200, 'max_depth': 10, 'learni...
# 9   {'learning_rate': 0.2, 'iterations': 100, 'dep...
# 10        {'n_estimators': 100, 'learning_rate': 1.0}
# 11  {'model__num_units': 32, 'model__learning_rate...

# %% [markdown]
# # **Hyperparameter grids for GridSearchCV**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/CTDT/CTDT (Physicochemical Properties)/ctdt_validation_negative_features.csv")

# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for GridSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply grid search
for model_name, model in models.items():
    print(f"Performing GridSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform grid search
    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = grid_search.best_params_
    best_scores.append(grid_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)
# Out:
# Performing GridSearchCV for SVM...
# Performing GridSearchCV for Decision Tree...
# Performing GridSearchCV for Random Forest...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 135 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.83850081 0.82901806 0.83505254
#  0.81700829 0.83076809 0.83591091 0.8110071  0.82046396 0.83076439
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.86255735 0.86856963 0.86340832
#  0.85997114 0.86341202 0.86254995 0.84622984 0.85223842 0.85739603
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92010138 0.92353485 0.92096345
#  0.91409279 0.92266538 0.92267648 0.91408169 0.92266908 0.91923191]
#   warnings.warn(
# Performing GridSearchCV for Logistic Regression...
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Performing GridSearchCV for k-NN...
# Performing GridSearchCV for Naive Bayes...
# Performing GridSearchCV for Gradient Boosting...
# Performing GridSearchCV for XGBoost...
# Performing GridSearchCV for LightGBM...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001428 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Performing GridSearchCV for CatBoost...
# Performing GridSearchCV for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing GridSearchCV for Neural Network...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#                   Model  Best Score  \
# 0                   SVM    0.928681
# 1         Decision Tree    0.880590
# 2         Random Forest    0.923535
# 3   Logistic Regression    0.924401
# 4                  k-NN    0.915810
# 5           Naive Bayes    0.905531
# 6     Gradient Boosting    0.899478
# 7               XGBoost    0.894339
# 8              LightGBM    0.795549
# 9              CatBoost    0.906356
# 10             AdaBoost    0.886592
# 11       Neural Network    0.935567
#
#                                       Best Parameters
# 0    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 1   {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 2   {'max_depth': None, 'max_features': 'sqrt', 'm...
# 3       {'C': 100, 'penalty': 'l2', 'solver': 'saga'}
# 4   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...
# 5            {'var_smoothing': 2.782559402207126e-05}
# 6   {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...
# 7   {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...
# 8   {'learning_rate': 0.2, 'max_depth': 10, 'n_est...
# 9   {'depth': 6, 'iterations': 100, 'learning_rate...
# 10        {'learning_rate': 1.0, 'n_estimators': 200}
# 11  {'model__dropout_rate': 0.1, 'model__learning_...

# %% [markdown]
# PROPOSED MODEL FOR CTDT

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, classification_report,
                           confusion_matrix, matthews_corrcoef,
                           cohen_kappa_score, roc_auc_score)

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_main_positive_features (1).csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_validation_positive_features (2).csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_validation_negative_features.csv")

# Add target labels
main_p['Target'] = 1
main_n['Target'] = 0
validation_p['Target'] = 1
validation_n['Target'] = 0

# Combine and shuffle data
train_data = pd.concat([main_p, main_n]).sample(frac=1, random_state=42)
validation_data = pd.concat([validation_p, validation_n]).sample(frac=1, random_state=42)

# Check class balance
print("Class distribution in training set:")
print(train_data['Target'].value_counts())
print("\nClass distribution in validation set:")
print(validation_data['Target'].value_counts())

# Separate features and labels
X_train = train_data.drop(columns=['Target']).values
y_train = train_data['Target'].values
X_val = validation_data.drop(columns=['Target']).values
y_val = validation_data['Target'].values

# Check for NaN/inf and replace
X_train = np.nan_to_num(X_train)
X_val = np.nan_to_num(X_val)

# Normalize features carefully
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# Clip extreme values
X_train = np.clip(X_train, -5, 5)
X_val = np.clip(X_val, -5, 5)

# Build simpler and more stable model
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],),
          kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),

    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),

    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

# Compile with class weighting if imbalanced
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy',
                      tf.keras.metrics.AUC(name='auc'),
                      tf.keras.metrics.Recall(name='recall'),
                      tf.keras.metrics.Precision(name='precision')])

# Model summary
model.summary()

# Early stopping based on validation AUC
early_stop = EarlyStopping(monitor='val_auc',
                          patience=15,
                          mode='max',
                          restore_best_weights=True,
                          verbose=1)

# Train model
history = model.fit(X_train, y_train,
                   validation_data=(X_val, y_val),
                   epochs=10,
                   batch_size=64,
                   callbacks=[early_stop],
                   verbose=1)

# Evaluate model
val_probabilities = model.predict(X_val).flatten()
val_predictions = (val_probabilities > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_val, val_predictions)
tn, fp, fn, tp = confusion_matrix(y_val, val_predictions).ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
mcc = matthews_corrcoef(y_val, val_predictions)
kappa = cohen_kappa_score(y_val, val_predictions)
auc = roc_auc_score(y_val, val_probabilities)

# Print metrics
print("\nValidation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"MCC: {mcc:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")
print(f"AUC: {auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_val, val_predictions))

print("\nConfusion Matrix:")
print(confusion_matrix(y_val, val_predictions))
# Out:
# Class distribution in training set:
# Target
# 0    582
# 1    582
# Name: count, dtype: int64
#
# Class distribution in validation set:
# Target
# 0    150
# 1    150
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 256)            │     2,048,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,091,265 (7.98 MB)
#  Trainable params: 2,090,369 (7.97 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.5048 - auc: 0.4937 - loss: 1.6740 - precision: 0.5362 - recall: 0.4849 - val_accuracy: 0.5767 - val_auc: 0.5917 - val_loss: 1.1628 - val_precision: 0.6769 - val_recall: 0.2933
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5103 - auc: 0.4993 - loss: 1.3647 - precision: 0.4972 - recall: 0.5049 - val_accuracy: 0.5367 - val_auc: 0.5776 - val_loss: 1.0701 - val_precision: 0.6897 - val_recall: 0.1333
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4734 - auc: 0.5141 - loss: 1.2609 - precision: 0.4625 - recall: 0.4734 - val_accuracy: 0.5200 - val_auc: 0.5628 - val_loss: 1.0552 - val_precision: 0.7500 - val_recall: 0.0600
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4901 - auc: 0.4717 - loss: 1.2925 - precision: 0.4868 - recall: 0.4831 - val_accuracy: 0.5033 - val_auc: 0.5351 - val_loss: 1.0589 - val_precision: 0.5714 - val_recall: 0.0267
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4523 - auc: 0.4284 - loss: 1.3041 - precision: 0.4267 - recall: 0.4211 - val_accuracy: 0.5067 - val_auc: 0.5565 - val_loss: 1.0562 - val_precision: 0.6000 - val_recall: 0.0400
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4943 - auc: 0.4931 - loss: 1.2371 - precision: 0.5102 - recall: 0.4767 - val_accuracy: 0.5167 - val_auc: 0.5332 - val_loss: 1.0550 - val_precision: 0.6923 - val_recall: 0.0600
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5362 - auc: 0.5271 - loss: 1.1851 - precision: 0.5211 - recall: 0.5094 - val_accuracy: 0.5233 - val_auc: 0.5847 - val_loss: 1.0476 - val_precision: 0.7333 - val_recall: 0.0733
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5066 - auc: 0.5029 - loss: 1.1881 - precision: 0.5510 - recall: 0.4816 - val_accuracy: 0.5467 - val_auc: 0.5612 - val_loss: 1.0464 - val_precision: 0.7917 - val_recall: 0.1267
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5091 - auc: 0.4999 - loss: 1.1782 - precision: 0.5022 - recall: 0.4911 - val_accuracy: 0.5500 - val_auc: 0.5722 - val_loss: 1.0439 - val_precision: 0.7586 - val_recall: 0.1467
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5218 - auc: 0.5057 - loss: 1.1711 - precision: 0.5326 - recall: 0.5136 - val_accuracy: 0.5867 - val_auc: 0.5803 - val_loss: 1.0394 - val_precision: 0.7600 - val_recall: 0.2533
# Restoring model weights from the end of the best epoch: 1.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Validation Metrics:
# Accuracy: 0.5767
# Sensitivity (Recall): 0.2933
# Specificity: 0.8600
# MCC: 0.1861
# Cohen's Kappa: 0.1533
# AUC: 0.5912
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67       150
#            1       0.68      0.29      0.41       150
#
#     accuracy                           0.58       300
#    macro avg       0.61      0.58      0.54       300
# weighted avg       0.61      0.58      0.54       300
#
#
# Confusion Matrix:
# [[129  21]
#  [106  44]]

# %%
# cross valiation 5 fold


import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (accuracy_score, classification_report,
                           confusion_matrix, matthews_corrcoef,
                           cohen_kappa_score, roc_auc_score)

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_main_positive_features (1).csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_validation_positive_features (2).csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/5_CTDT/ctdt_validation_negative_features.csv")

# Add target labels
main_p['Target'] = 1
main_n['Target'] = 0
validation_p['Target'] = 1
validation_n['Target'] = 0

# Combine all data for cross-validation
all_data = pd.concat([main_p, main_n, validation_p, validation_n])
all_data = all_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Check class balance
print("Class distribution:")
print(all_data['Target'].value_counts())

# Check for non-numeric columns
non_numeric_cols = all_data.select_dtypes(exclude=[np.number]).columns.tolist()
if non_numeric_cols:
    print(f"\nDropping non-numeric columns: {non_numeric_cols}")
    all_data = all_data.drop(columns=non_numeric_cols)

# Separate features and labels
X = all_data.drop(columns=['Target']).values
y = all_data['Target'].values

# Initialize 5-fold cross-validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
results = []

for train_idx, val_idx in kfold.split(X, y):
    print(f'\n{"="*40}')
    print(f'Training fold {fold_no}')
    print(f'{"="*40}')

    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Handle NaN/inf and normalize with clipping
    X_train = np.nan_to_num(X_train)
    X_val = np.nan_to_num(X_val)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_train = np.clip(X_train, -5, 5)
    X_val = np.clip(X_val, -5, 5)

    # Build model with regularization
    model = Sequential([
        Dense(256, activation='relu', input_shape=(X_train.shape[1],),
              kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.5),

        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.4),

        Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(1, activation='sigmoid')
    ])

    # Compile with adjusted learning rate
    optimizer = Adam(learning_rate=0.0005)
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

    # Early stopping
    early_stop = EarlyStopping(monitor='val_auc',
                              patience=15,
                              mode='max',
                              restore_best_weights=True,
                              verbose=1)

    # Class weighting if imbalanced
    class_counts = np.bincount(y_train)
    class_weight = {0: 1/class_counts[0], 1: 1/class_counts[1]}

    # Train model
    history = model.fit(X_train, y_train,
                       validation_data=(X_val, y_val),
                       epochs=100,
                       batch_size=64,
                       callbacks=[early_stop],
                       class_weight=class_weight,
                       verbose=1)

    # Evaluate model
    val_probabilities = model.predict(X_val).flatten()
    val_predictions = (val_probabilities > 0.5).astype(int)

    # Calculate metrics
    tn, fp, fn, tp = confusion_matrix(y_val, val_predictions).ravel()
    metrics = {
        'fold': fold_no,
        'accuracy': accuracy_score(y_val, val_predictions),
        'sensitivity': tp / (tp + fn) if (tp + fn) > 0 else 0,
        'specificity': tn / (tn + fp) if (tn + fp) > 0 else 0,
        'mcc': matthews_corrcoef(y_val, val_predictions),
        'kappa': cohen_kappa_score(y_val, val_predictions),
        'auc': roc_auc_score(y_val, val_probabilities)
    }

    results.append(metrics)

    print(f'\nFold {fold_no} Results:')
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"AUC: {metrics['auc']:.4f}")
    print(f"MCC: {metrics['mcc']:.4f}")

    fold_no += 1

# Calculate and display average metrics
print('\n' + '='*50)
print('Cross-Validation Summary')
print('='*50)

avg_metrics = {
    'accuracy': np.mean([r['accuracy'] for r in results]),
    'sensitivity': np.mean([r['sensitivity'] for r in results]),
    'specificity': np.mean([r['specificity'] for r in results]),
    'mcc': np.mean([r['mcc'] for r in results]),
    'kappa': np.mean([r['kappa'] for r in results]),
    'auc': np.mean([r['auc'] for r in results])
}

print(f"\nAverage Metrics Across All Folds:")
print(f"Accuracy: {avg_metrics['accuracy']:.4f}")
print(f"Sensitivity: {avg_metrics['sensitivity']:.4f}")
print(f"Specificity: {avg_metrics['specificity']:.4f}")
print(f"MCC: {avg_metrics['mcc']:.4f}")
print(f"Cohen's Kappa: {avg_metrics['kappa']:.4f}")
print(f"AUC: {avg_metrics['auc']:.4f}")

# Train final model on all data
print("\nTraining final model on all data...")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.clip(X_scaled, -5, 5)

final_model = Sequential([
    Dense(256, activation='relu', input_shape=(X_scaled.shape[1],),
          kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),

    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),

    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

optimizer = Adam(learning_rate=0.0005)
final_model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# Final class weights
class_counts = np.bincount(y)
final_class_weight = {0: 1/class_counts[0], 1: 1/class_counts[1]}

history = final_model.fit(X_scaled, y,
               epochs=100,
               batch_size=64,
               class_weight=final_class_weight,
               verbose=1)

# Save the final model
final_model.save('ctdt_final_model.h5')
print("Final model training complete and saved!")
# Out:
# Class distribution:
# Target
# 1    732
# 0    732
# Name: count, dtype: int64
#
# ========================================
# Training fold 1
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.4724 - auc: 0.4918 - loss: 0.6403 - val_accuracy: 0.5051 - val_auc: 0.4955 - val_loss: 1.0622
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5046 - auc: 0.5014 - loss: 0.3183 - val_accuracy: 0.4915 - val_auc: 0.4867 - val_loss: 0.9056
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5451 - auc: 0.5547 - loss: 0.1896 - val_accuracy: 0.5017 - val_auc: 0.4652 - val_loss: 0.8445
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5593 - auc: 0.5902 - loss: 0.1373 - val_accuracy: 0.4983 - val_auc: 0.4319 - val_loss: 0.8144
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5360 - auc: 0.5300 - loss: 0.1078 - val_accuracy: 0.4983 - val_auc: 0.4479 - val_loss: 0.7927
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5308 - auc: 0.5499 - loss: 0.0862 - val_accuracy: 0.4983 - val_auc: 0.4675 - val_loss: 0.7752
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5394 - auc: 0.5732 - loss: 0.0690 - val_accuracy: 0.4983 - val_auc: 0.4579 - val_loss: 0.7593
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5531 - auc: 0.5873 - loss: 0.0552 - val_accuracy: 0.4983 - val_auc: 0.4814 - val_loss: 0.7477
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Fold 2 Results:
# Accuracy: 0.4881
# AUC: 0.4185
# MCC: -0.0406
#
# ========================================
# Training fold 3
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5075 - auc: 0.5161 - loss: 0.6403 - val_accuracy: 0.4949 - val_auc: 0.4749 - val_loss: 1.0616
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.4995 - auc: 0.4948 - loss: 0.3185 - val_accuracy: 0.4744 - val_auc: 0.4229 - val_loss: 0.9045
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5594 - auc: 0.5663 - loss: 0.1899 - val_accuracy: 0.4812 - val_auc: 0.4206 - val_loss: 0.8433
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5275 - auc: 0.5570 - loss: 0.1374 - val_accuracy: 0.4642 - val_auc: 0.4043 - val_loss: 0.8114
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5710 - auc: 0.5876 - loss: 0.1078 - val_accuracy: 0.4642 - val_auc: 0.4348 - val_loss: 0.7876
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.5668 - auc: 0.5843 - loss: 0.0860 - val_accuracy: 0.4744 - val_auc: 0.4191 - val_loss: 0.7701
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.5838 - auc: 0.6209 - loss: 0.0687 - val_accuracy: 0.4744 - val_auc: 0.3969 - val_loss: 0.7559
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.5727 - auc: 0.5984 - loss: 0.0550 - val_accuracy: 0.4744 - val_auc: 0.4046 - val_loss: 0.7432
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5832 - auc: 0.6304 - loss: 0.0440 - val_accuracy: 0.4471 - val_auc: 0.4161 - val_loss: 0.7330
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5514 - auc: 0.5933 - loss: 0.0353 - val_accuracy: 0.4778 - val_auc: 0.4234 - val_loss: 0.7263
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5629 - auc: 0.5899 - loss: 0.0284 - val_accuracy: 0.4642 - val_auc: 0.4220 - val_loss: 0.7192
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5637 - auc: 0.5950 - loss: 0.0230 - val_accuracy: 0.4471 - val_auc: 0.4365 - val_loss: 0.7139
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5757 - auc: 0.5901 - loss: 0.0187 - val_accuracy: 0.4642 - val_auc: 0.4361 - val_loss: 0.7109
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5816 - auc: 0.6098 - loss: 0.0151 - val_accuracy: 0.5017 - val_auc: 0.4604 - val_loss: 0.7071
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.5721 - auc: 0.6033 - loss: 0.0124 - val_accuracy: 0.5051 - val_auc: 0.4536 - val_loss: 0.7042
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.5801 - auc: 0.6060 - loss: 0.0102 - val_accuracy: 0.4676 - val_auc: 0.4421 - val_loss: 0.7027
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Fold 3 Results:
# Accuracy: 0.4949
# AUC: 0.4719
# MCC: -0.0098
#
# ========================================
# Training fold 4
# ========================================
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.5494 - auc: 0.5383 - loss: 0.6401 - val_accuracy: 0.4778 - val_auc: 0.4532 - val_loss: 1.0642
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5110 - auc: 0.5187 - loss: 0.3191 - val_accuracy: 0.4642 - val_auc: 0.4431 - val_loss: 0.9043
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5382 - auc: 0.5562 - loss: 0.1907 - val_accuracy: 0.4846 - val_auc: 0.4437 - val_loss: 0.8421
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5461 - auc: 0.5767 - loss: 0.1382 - val_accuracy: 0.5051 - val_auc: 0.4629 - val_loss: 0.8091
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5561 - auc: 0.5774 - loss: 0.1084 - val_accuracy: 0.4812 - val_auc: 0.4631 - val_loss: 0.7862
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5363 - auc: 0.5680 - loss: 0.0865 - val_accuracy: 0.4846 - val_auc: 0.4379 - val_loss: 0.7688
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5904 - auc: 0.6275 - loss: 0.0023 - val_accuracy: 0.5154 - val_auc: 0.4410 - val_loss: 0.6980
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5471 - auc: 0.5742 - loss: 0.0023 - val_accuracy: 0.5222 - val_auc: 0.4538 - val_loss: 0.7025
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5646 - auc: 0.5921 - loss: 0.0022 - val_accuracy: 0.5256 - val_auc: 0.4535 - val_loss: 0.6945
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5690 - auc: 0.5974 - loss: 0.0022 - val_accuracy: 0.5085 - val_auc: 0.4569 - val_loss: 0.7032
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5603 - auc: 0.5894 - loss: 0.0022 - val_accuracy: 0.5119 - val_auc: 0.4537 - val_loss: 0.7080
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5835 - auc: 0.6226 - loss: 0.0020 - val_accuracy: 0.4983 - val_auc: 0.4262 - val_loss: 0.7186
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6006 - auc: 0.6293 - loss: 0.0020 - val_accuracy: 0.5154 - val_auc: 0.3964 - val_loss: 0.7066
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.5883 - auc: 0.6269 - loss: 0.0020 - val_accuracy: 0.5051 - val_auc: 0.4374 - val_loss: 0.7063
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5714 - auc: 0.5959 - loss: 0.0019 - val_accuracy: 0.5256 - val_auc: 0.4380 - val_loss: 0.7221
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6023 - auc: 0.6461 - loss: 0.0018 - val_accuracy: 0.5017 - val_auc: 0.4061 - val_loss: 0.7230
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5975 - auc: 0.6366 - loss: 0.0019 - val_accuracy: 0.4983 - val_auc: 0.4273 - val_loss: 0.7105
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5663 - auc: 0.5905 - loss: 0.0019 - val_accuracy: 0.4949 - val_auc: 0.4571 - val_loss: 0.6976
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5664 - auc: 0.6153 - loss: 0.0018 - val_accuracy: 0.5051 - val_auc: 0.4327 - val_loss: 0.7038
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5841 - auc: 0.6175 - loss: 0.0019 - val_accuracy: 0.5222 - val_auc: 0.4163 - val_loss: 0.7115
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5924 - auc: 0.6167 - loss: 0.0019 - val_accuracy: 0.5017 - val_auc: 0.4252 - val_loss: 0.7212
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 31.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Fold 4 Results:
# Accuracy: 0.5051
# AUC: 0.4751
# MCC: 0.0181
#
# ========================================
# Training fold 5
# ========================================
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.5047 - auc: 0.5042 - loss: 0.6401 - val_accuracy: 0.5000 - val_auc: 0.5030 - val_loss: 1.0613
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5413 - auc: 0.5598 - loss: 0.3188 - val_accuracy: 0.4897 - val_auc: 0.4700 - val_loss: 0.9041
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5314 - auc: 0.5458 - loss: 0.1902 - val_accuracy: 0.5000 - val_auc: 0.3903 - val_loss: 0.8439
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5589 - auc: 0.5878 - loss: 0.1377 - val_accuracy: 0.5000 - val_auc: 0.3778 - val_loss: 0.8132
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5418 - auc: 0.5710 - loss: 0.1080 - val_accuracy: 0.5000 - val_auc: 0.4170 - val_loss: 0.7901
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5403 - auc: 0.5688 - loss: 0.0862 - val_accuracy: 0.5000 - val_auc: 0.4415 - val_loss: 0.7723
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5545 - auc: 0.5611 - loss: 0.0690 - val_accuracy: 0.5000 - val_auc: 0.3945 - val_loss: 0.7588
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5135 - auc: 0.5514 - loss: 0.0553 - val_accuracy: 0.5000 - val_auc: 0.3765 - val_loss: 0.7488
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5253 - auc: 0.5482 - loss: 0.0443 - val_accuracy: 0.5000 - val_auc: 0.4115 - val_loss: 0.7382
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.