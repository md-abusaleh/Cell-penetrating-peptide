# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
import os
import numpy as np
import pandas as pd
from Bio import SeqIO

# Amino acid alphabet
AminoAcids = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

# Mapping of amino acid characters to integers
aa_dict = {aa: i for i, aa in enumerate(AminoAcids)}

# Function to calculate the CTDD feature (correlation of tri-peptides)
def calculate_ctdd(sequence):
    tri_peptide_count = np.zeros((20, 20, 20))  # 3D array for counting tri-peptide frequencies
    for i in range(len(sequence) - 2):
        first_aa = sequence[i]
        second_aa = sequence[i + 1]
        third_aa = sequence[i + 2]

        if first_aa in aa_dict and second_aa in aa_dict and third_aa in aa_dict:
            tri_peptide_count[aa_dict[first_aa], aa_dict[second_aa], aa_dict[third_aa]] += 1

    total_tri_peptides = np.sum(tri_peptide_count)

    if total_tri_peptides > 0:
        tri_peptide_count = tri_peptide_count / total_tri_peptides  # Normalize by total count

    # Flatten the 3D array into a 1D feature vector
    return tri_peptide_count.flatten()

# Function to extract CTDD features from sequences in FASTA format
def extract_ctdd_features(fasta_path):
    features = []
    for record in SeqIO.parse(fasta_path, "fasta"):
        seq = str(record.seq)
        ctdd_features = calculate_ctdd(seq)
        features.append(ctdd_features)

    # Convert the list of feature vectors into a DataFrame
    df = pd.DataFrame(features)
    return df

# Define file paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_main (2) (1).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_validation (2) (1).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_validation (2) (1).fasta"

# Output directories for each file
output_dirs = {
    "main_positive": "/content/ctdd_main_positive_features.csv",
    "main_negative": "/content/ctdd_main_negative_features.csv",
    "validation_positive": "/content/ctdd_validation_positive_features.csv",
    "validation_negative": "/content/ctdd_validation_negative_features.csv"
}

# Function to ensure the directory exists
def ensure_directory_exists(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# Main workflow function
def main():
    # File paths for input FASTA files
    datasets = [
        (main_p, output_dirs["main_positive"]),
        (main_n, output_dirs["main_negative"]),
        (validation_p, output_dirs["validation_positive"]),
        (validation_n, output_dirs["validation_negative"])
    ]

    # Extract features and save to CSV
    for fasta_path, output_csv in datasets:
        print(f"Processing {fasta_path}...")

        # Ensure the directory for saving the output file exists
        ensure_directory_exists(output_csv)

        # Extract features and save to CSV
        features_df = extract_ctdd_features(fasta_path)
        features_df.to_csv(output_csv, index=False)
        print(f"CTDD features saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta...
# CTDD features saved to /content/ctdd_main_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_main (2) (1).fasta...
# CTDD features saved to /content/ctdd_main_negative_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_validation (2) (1).fasta...
# CTDD features saved to /content/ctdd_validation_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_validation (2) (1).fasta...
# CTDD features saved to /content/ctdd_validation_negative_features.csv

# %%
# !pip install pfeature
# Out:
# Requirement already satisfied: pfeature in /usr/local/lib/python3.11/dist-packages (1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pfeature) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pfeature) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pfeature) (1.17.0)

# %%
import os
import numpy as np
import pandas as pd
from Bio import SeqIO

# Amino acid alphabet
AminoAcids = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

# Mapping of amino acid characters to integers
aa_dict = {aa: i for i, aa in enumerate(AminoAcids)}

# Generate all possible tri-peptide combinations as feature names
tri_peptide_names = [f"{a1}{a2}{a3}" for a1 in AminoAcids for a2 in AminoAcids for a3 in AminoAcids]

# Function to calculate the CTDD feature (correlation of tri-peptides)
def calculate_ctdd(sequence):
    tri_peptide_count = np.zeros((20, 20, 20))  # 3D array for counting tri-peptide frequencies
    for i in range(len(sequence) - 2):
        first_aa = sequence[i]
        second_aa = sequence[i + 1]
        third_aa = sequence[i + 2]

        if first_aa in aa_dict and second_aa in aa_dict and third_aa in aa_dict:
            tri_peptide_count[aa_dict[first_aa], aa_dict[second_aa], aa_dict[third_aa]] += 1

    total_tri_peptides = np.sum(tri_peptide_count)

    if total_tri_peptides > 0:
        tri_peptide_count = tri_peptide_count / total_tri_peptides  # Normalize by total count

    # Flatten the 3D array into a 1D feature vector
    return tri_peptide_count.flatten()

# Function to extract CTDD features from sequences in FASTA format
def extract_ctdd_features(fasta_path):
    features = []
    for record in SeqIO.parse(fasta_path, "fasta"):
        seq = str(record.seq)
        ctdd_features = calculate_ctdd(seq)
        features.append(ctdd_features)

    # Convert the list of feature vectors into a DataFrame
    df = pd.DataFrame(features, columns=tri_peptide_names)
    return df

# Define file paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_main (2) (1).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_validation (2) (1).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_validation (2) (1).fasta"

# Output directories for each file
output_dirs = {
    "main_positive": "/content/ctdd_main_positive_features.csv",
    "main_negative": "/content/ctdd_main_negative_features.csv",
    "validation_positive": "/content/ctdd_validation_positive_features.csv",
    "validation_negative": "/content/ctdd_validation_negative_features.csv"
}

# Function to ensure the directory exists
def ensure_directory_exists(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# Main workflow function
def main():
    # File paths for input FASTA files
    datasets = [
        (main_p, output_dirs["main_positive"]),
        (main_n, output_dirs["main_negative"]),
        (validation_p, output_dirs["validation_positive"]),
        (validation_n, output_dirs["validation_negative"])
    ]

    # Extract features and save to CSV
    for fasta_path, output_csv in datasets:
        print(f"Processing {fasta_path}...")

        # Ensure the directory for saving the output file exists
        ensure_directory_exists(output_csv)

        # Extract features and save to CSV
        features_df = extract_ctdd_features(fasta_path)
        features_df.to_csv(output_csv, index=False)
        print(f"CTDD features saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta...
# CTDD features saved to /content/ctdd_main_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_main (2) (1).fasta...
# CTDD features saved to /content/ctdd_main_negative_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_validation (2) (1).fasta...
# CTDD features saved to /content/ctdd_validation_positive_features.csv
# Processing /content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_validation (2) (1).fasta...
# CTDD features saved to /content/ctdd_validation_negative_features.csv

# %%
# !pip show pfeature  # Check if pfeature is installed and its location
# !pip install pfeature --upgrade #Update the library incase there's an updated version that has the PyProtein class.
# Out:
# Name: pfeature
# Version: 1.4
# Summary: A tool to compute the features of protein and peptide sequences
# Home-page: https://github.com/raghavagps/pfeature
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: numpy, pandas
# Required-by:
# Requirement already satisfied: pfeature in /usr/local/lib/python3.11/dist-packages (1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pfeature) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pfeature) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pfeature) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pfeature) (1.17.0)

# %%
import pandas as pd
from pfeature import PyProtein

# Define the input file paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_main (2) (1).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_validation (2) (1).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/NEGATIVE_validation (2) (1).fasta"

# Output file paths
output_main_p = "/content/CTDD_features_positive_main.csv"
output_main_n = "/content/CTDD_features_negative_main.csv"
output_validation_p = "/content/CTDD_features_positive_validation.csv"
output_validation_n = "/content/CTDD_features_negative_validation.csv"

# Function to extract CTDD features from a FASTA file
def extract_ctdd_features(fasta_file, output_file):
    features = []
    labels = []
    with open(fasta_file, "r") as f:
        lines = f.readlines()
        for i in range(0, len(lines), 2):  # FASTA format alternates between headers and sequences
            sequence = lines[i + 1].strip()
            protein = PyProtein(sequence)
            ctdd_features = protein.GetCTDD()
            features.append(list(ctdd_features.values()))
            labels.append(lines[i].strip())  # Save header as label

    # Convert features into a DataFrame
    df = pd.DataFrame(features, columns=ctdd_features.keys())
    df.insert(0, "Sequence_ID", labels)  # Insert Sequence ID
    df.to_csv(output_file, index=False)
    print(f"CTDD features saved to {output_file}")

# Extract and save features for all datasets
extract_ctdd_features(main_p, output_main_p)
extract_ctdd_features(main_n, output_main_n)
extract_ctdd_features(validation_p, output_validation_p)
extract_ctdd_features(validation_n, output_validation_n)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-a6bcf4e5a6e7> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from pfeature import PyProtein
#       3
#       4 # Define the input file paths
#       5 main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/POSITIVE_main (2) (1).fasta"
#
# ImportError: cannot import name 'PyProtein' from 'pfeature' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # ***All Algorithm ***

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# %%
# Label the datasets
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the neural network models
models["Neural Network"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
models["MLP"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Store accuracies
results = []

# Train each model and evaluate
for name, model in models.items():
    print(f"\nTraining {name}...")

    if name in ["Neural Network", "MLP"]:
        # Neural Network training
        model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=0)
        train_pred = (model.predict(X_train) > 0.5).astype("int32")
        val_pred = (model.predict(X_val) > 0.5).astype("int32")
    else:
        # Traditional ML model training
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        val_pred = model.predict(X_val)

    # Calculate train and validation accuracy
    train_accuracy = accuracy_score(y_train, train_pred)
    val_accuracy = accuracy_score(y_val, val_pred)

    results.append({"Model": name, "Train Accuracy": train_accuracy, "Validation Accuracy": val_accuracy})
# Out:
# Training SVM...
#
# Training Decision Tree...
#
# Training Random Forest...
#
# Training Logistic Regression...
#
# Training k-NN...
#
# Training Naive Bayes...
#
# Training Gradient Boosting...
#
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:38:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001451 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Training CatBoost...
#
# Training AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training Neural Network...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Training MLP...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Convert to DataFrame and sort by Validation Accuracy and Train Accuracy in descending order
results_df = pd.DataFrame(results).sort_values(by=["Validation Accuracy", "Train Accuracy"], ascending=False).reset_index(drop=True)

# Display results
print("\nModel Accuracy Table (Descending Order of Validation Accuracy)")
print(results_df)
# Out:
# Model Accuracy Table (Descending Order of Validation Accuracy)
#                   Model  Train Accuracy  Validation Accuracy
# 0         Random Forest        0.995704             0.913333
# 1        Neural Network        0.995704             0.903333
# 2                   MLP        0.995704             0.900000
# 3              CatBoost        0.970790             0.900000
# 4               XGBoost        0.963918             0.896667
# 5         Decision Tree        0.995704             0.893333
# 6              AdaBoost        0.939863             0.890000
# 7     Gradient Boosting        0.933849             0.876667
# 8           Naive Bayes        0.959622             0.866667
# 9                  k-NN        0.928694             0.856667
# 10             LightGBM        0.887457             0.840000
# 11  Logistic Regression        0.849656             0.823333
# 12                  SVM        0.809278             0.773333

# %% [markdown]
# # **CROSS VALIDATION**

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
# Define Neural Network models
def create_neural_network(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

def create_mlp(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Cross-validation for traditional models
results = []

# For traditional ML models, we use cross_val_score
for name, model in models.items():
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Calculate cross-validation accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    mean_accuracy = np.mean(cv_scores)
    std_accuracy = np.std(cv_scores)

    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})

# Cross-validation for Neural Networks (manual implementation)
for name, create_model in [("Neural Network", create_neural_network), ("MLP", create_mlp)]:
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Custom function to calculate accuracy for neural networks
    def neural_network_cross_val(model_func, X_train, y_train):
        accuracies = []
        for train_index, val_index in cv.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = model_func(X_train.shape[1])  # Create a new model for each fold
            model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=32, verbose=0)

            y_pred = (model.predict(X_val_fold) > 0.5).astype("int32")
            accuracy = accuracy_score(y_val_fold, y_pred)
            accuracies.append(accuracy)

        return np.mean(accuracies), np.std(accuracies)

    mean_accuracy, std_accuracy = neural_network_cross_val(create_model, X_train, y_train)
    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})
# Out:
# Performing Cross-validation for SVM...
#
# Performing Cross-validation for Decision Tree...
#
# Performing Cross-validation for Random Forest...
#
# Performing Cross-validation for Logistic Regression...
#
# Performing Cross-validation for k-NN...
#
# Performing Cross-validation for Naive Bayes...
#
# Performing Cross-validation for Gradient Boosting...
#
# Performing Cross-validation for XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:47:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:47:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:47:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:47:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:47:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Performing Cross-validation for LightGBM...
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000819 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 631
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 81
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000804 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 610
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000846 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 621
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000873 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 654
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 84
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000825 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 932, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Performing Cross-validation for CatBoost...
#
# Performing Cross-validation for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing Cross-validation for Neural Network...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f8e342808b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f8e2ff9d510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Performing Cross-validation for MLP...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Convert to DataFrame and display
cv_results_df = pd.DataFrame(results).sort_values(by="Mean CV Accuracy", ascending=False).reset_index(drop=True)
print("\nCross-Validation Accuracy Table")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Table
#                   Model  Mean CV Accuracy  STD CV Accuracy
# 0                   MLP          0.927834         0.011328
# 1        Neural Network          0.927830         0.006918
# 2         Random Forest          0.920105         0.007461
# 3              CatBoost          0.898613         0.018209
# 4           Naive Bayes          0.892648         0.025944
# 5               XGBoost          0.888320         0.013813
# 6     Gradient Boosting          0.873705         0.018966
# 7         Decision Tree          0.871134         0.019762
# 8              AdaBoost          0.867704         0.015870
# 9                  k-NN          0.856504         0.022010
# 10  Logistic Regression          0.804976         0.016045
# 11             LightGBM          0.784372         0.013287
# 12                  SVM          0.766320         0.012068

# %% [markdown]
# # **Hyperparameter optimization with Optuna**

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 15.4 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 16.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]



# Define models with MLP included
models = {
    "SVM": lambda trial: SVC(
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}


results = []

def optimize_model(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        return accuracy_score(y_val, preds)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the results
    results.append({
        "Model": model_name,
        "Accuracy": study.best_value,
        "Best Params": study.best_params
    })

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model(model_name, model_func)


# Convert results to a DataFrame
results_df = pd.DataFrame(results)


# Display the DataFrame
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2024-12-27 09:44:27,427] A new study created in memory with name: no-name-4c32d2a6-ce43-40c2-afc0-1ade4c571ba1
# Optimizing SVM...
# [I 2024-12-27 09:44:37,139] Trial 0 finished with value: 0.8633333333333333 and parameters: {'C': 9.48374615820333, 'kernel': 'poly'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:44:46,433] Trial 1 finished with value: 0.8566666666666667 and parameters: {'C': 0.27425940547801, 'kernel': 'rbf'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:44:55,568] Trial 2 finished with value: 0.8633333333333333 and parameters: {'C': 9.456950246446223, 'kernel': 'poly'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:45:00,964] Trial 3 finished with value: 0.89 and parameters: {'C': 6.128819341645765, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:11,342] Trial 4 finished with value: 0.84 and parameters: {'C': 4.9571273035859695, 'kernel': 'poly'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:19,389] Trial 5 finished with value: 0.8666666666666667 and parameters: {'C': 2.228288113038584, 'kernel': 'linear'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:27,963] Trial 6 finished with value: 0.8566666666666667 and parameters: {'C': 6.244450166223419, 'kernel': 'poly'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:32,554] Trial 7 finished with value: 0.8866666666666667 and parameters: {'C': 9.239223900615372, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:41,040] Trial 8 finished with value: 0.7833333333333333 and parameters: {'C': 0.14675336868169211, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:47,448] Trial 9 finished with value: 0.89 and parameters: {'C': 7.427168945008795, 'kernel': 'linear'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:51,898] Trial 10 finished with value: 0.86 and parameters: {'C': 4.1358489356567, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 09:45:57,922] Trial 11 finished with value: 0.8933333333333333 and parameters: {'C': 7.136565647507294, 'kernel': 'linear'}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 09:46:04,492] Trial 12 finished with value: 0.8933333333333333 and parameters: {'C': 6.9666255791559, 'kernel': 'linear'}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 09:46:10,241] Trial 13 finished with value: 0.8866666666666667 and parameters: {'C': 7.622237246427578, 'kernel': 'linear'}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 09:46:17,115] Trial 14 finished with value: 0.89 and parameters: {'C': 7.465821389831225, 'kernel': 'linear'}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 09:46:25,267] Trial 15 finished with value: 0.8833333333333333 and parameters: {'C': 3.7351918246087896, 'kernel': 'linear'}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 09:46:39,229] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 6.085864540540266, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:46:48,262] Trial 17 finished with value: 0.9033333333333333 and parameters: {'C': 8.317885057345045, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:46:56,732] Trial 18 finished with value: 0.9033333333333333 and parameters: {'C': 8.41516545873808, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:05,895] Trial 19 finished with value: 0.9033333333333333 and parameters: {'C': 5.366616172506659, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:15,161] Trial 20 finished with value: 0.9033333333333333 and parameters: {'C': 2.7642625017601836, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:23,675] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 8.468245352367456, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:32,838] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 8.2981935383472, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:41,714] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 8.483487998426845, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:50,602] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 6.251667944125153, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:47:59,741] Trial 25 finished with value: 0.9033333333333333 and parameters: {'C': 9.908607993070088, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:48:08,194] Trial 26 finished with value: 0.9033333333333333 and parameters: {'C': 8.184809982512153, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:48:17,238] Trial 27 finished with value: 0.9033333333333333 and parameters: {'C': 5.344550563438068, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:48:27,346] Trial 28 finished with value: 0.9033333333333333 and parameters: {'C': 8.985033336253345, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:48:35,916] Trial 29 finished with value: 0.9033333333333333 and parameters: {'C': 9.951440433770928, 'kernel': 'rbf'}. Best is trial 16 with value: 0.9033333333333333.
# [I 2024-12-27 09:48:35,918] A new study created in memory with name: no-name-77de733a-ff23-473e-a6cb-2ef3aac1f972
# [I 2024-12-27 09:48:36,102] Trial 0 finished with value: 0.72 and parameters: {'max_depth': 4, 'min_samples_split': 10}. Best is trial 0 with value: 0.72.
# Optimizing Decision Tree...
# [I 2024-12-27 09:48:36,424] Trial 1 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 5}. Best is trial 1 with value: 0.8433333333333334.
# [I 2024-12-27 09:48:36,754] Trial 2 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 10}. Best is trial 2 with value: 0.85.
# [I 2024-12-27 09:48:37,054] Trial 3 finished with value: 0.8333333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 5}. Best is trial 2 with value: 0.85.
# [I 2024-12-27 09:48:37,363] Trial 4 finished with value: 0.8233333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 6}. Best is trial 2 with value: 0.85.
# [I 2024-12-27 09:48:37,709] Trial 5 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 10}. Best is trial 5 with value: 0.8566666666666667.
# [I 2024-12-27 09:48:38,238] Trial 6 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 6 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:38,656] Trial 7 finished with value: 0.8066666666666666 and parameters: {'max_depth': 10, 'min_samples_split': 3}. Best is trial 6 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:39,065] Trial 8 finished with value: 0.79 and parameters: {'max_depth': 9, 'min_samples_split': 7}. Best is trial 6 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:39,410] Trial 9 finished with value: 0.7633333333333333 and parameters: {'max_depth': 6, 'min_samples_split': 3}. Best is trial 6 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:40,031] Trial 10 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:40,639] Trial 11 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:41,221] Trial 12 finished with value: 0.8633333333333333 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:41,787] Trial 13 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:42,348] Trial 14 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:42,647] Trial 15 finished with value: 0.8166666666666667 and parameters: {'max_depth': 12, 'min_samples_split': 8}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:42,988] Trial 16 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:43,276] Trial 17 finished with value: 0.82 and parameters: {'max_depth': 12, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:43,635] Trial 18 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:44,000] Trial 19 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 8}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:44,249] Trial 20 finished with value: 0.7866666666666666 and parameters: {'max_depth': 8, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:44,611] Trial 21 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:44,975] Trial 22 finished with value: 0.85 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:45,347] Trial 23 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:45,668] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:46,039] Trial 25 finished with value: 0.86 and parameters: {'max_depth': 19, 'min_samples_split': 5}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:46,349] Trial 26 finished with value: 0.8233333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:46,682] Trial 27 finished with value: 0.8533333333333334 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 09:48:47,051] Trial 28 finished with value: 0.87 and parameters: {'max_depth': 19, 'min_samples_split': 3}. Best is trial 28 with value: 0.87.
# [I 2024-12-27 09:48:47,257] Trial 29 finished with value: 0.7366666666666667 and parameters: {'max_depth': 5, 'min_samples_split': 3}. Best is trial 28 with value: 0.87.
# [I 2024-12-27 09:48:47,259] A new study created in memory with name: no-name-5d41e5e2-f285-4654-9de8-df2b5e7eb7f5
# Optimizing Random Forest...
# [I 2024-12-27 09:48:49,503] Trial 0 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 402, 'max_depth': 14, 'min_samples_split': 4}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:50,011] Trial 1 finished with value: 0.7566666666666667 and parameters: {'n_estimators': 161, 'max_depth': 3, 'min_samples_split': 9}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:52,617] Trial 2 finished with value: 0.86 and parameters: {'n_estimators': 432, 'max_depth': 16, 'min_samples_split': 7}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:56,973] Trial 3 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 483, 'max_depth': 14, 'min_samples_split': 2}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:59,194] Trial 4 finished with value: 0.85 and parameters: {'n_estimators': 473, 'max_depth': 11, 'min_samples_split': 7}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:48:59,855] Trial 5 finished with value: 0.82 and parameters: {'n_estimators': 119, 'max_depth': 12, 'min_samples_split': 10}. Best is trial 0 with value: 0.8633333333333333.
# [I 2024-12-27 09:49:02,982] Trial 6 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 451, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:05,300] Trial 7 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 361, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:05,945] Trial 8 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 121, 'max_depth': 11, 'min_samples_split': 6}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:07,984] Trial 9 finished with value: 0.85 and parameters: {'n_estimators': 242, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:11,352] Trial 10 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 310, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:13,512] Trial 11 finished with value: 0.87 and parameters: {'n_estimators': 307, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 6 with value: 0.8833333333333333.
# [I 2024-12-27 09:49:15,283] Trial 12 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 245, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 12 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:16,138] Trial 13 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 212, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 12 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:17,532] Trial 14 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 205, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:18,024] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 59, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:19,429] Trial 16 finished with value: 0.87 and parameters: {'n_estimators': 196, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:20,504] Trial 17 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 277, 'max_depth': 7, 'min_samples_split': 6}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:23,336] Trial 18 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 361, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:25,852] Trial 19 finished with value: 0.88 and parameters: {'n_estimators': 233, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:26,532] Trial 20 finished with value: 0.7633333333333333 and parameters: {'n_estimators': 161, 'max_depth': 7, 'min_samples_split': 8}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:28,723] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 305, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:30,663] Trial 22 finished with value: 0.88 and parameters: {'n_estimators': 268, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:33,049] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 356, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:34,264] Trial 24 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 183, 'max_depth': 16, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:35,177] Trial 25 finished with value: 0.88 and parameters: {'n_estimators': 110, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:37,679] Trial 26 finished with value: 0.87 and parameters: {'n_estimators': 258, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:41,268] Trial 27 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 445, 'max_depth': 15, 'min_samples_split': 4}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:42,949] Trial 28 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 392, 'max_depth': 9, 'min_samples_split': 3}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:44,170] Trial 29 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 221, 'max_depth': 13, 'min_samples_split': 4}. Best is trial 14 with value: 0.8933333333333333.
# [I 2024-12-27 09:49:44,174] A new study created in memory with name: no-name-72ad456c-769a-465c-aa3f-4d0cbff8d784
# Optimizing Logistic Regression...
# [I 2024-12-27 09:49:44,548] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 5.66531771641788, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:44,785] Trial 1 finished with value: 0.8533333333333334 and parameters: {'C': 1.8817306496067852, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:45,094] Trial 2 finished with value: 0.86 and parameters: {'C': 2.9934116528700856, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:45,534] Trial 3 finished with value: 0.8633333333333333 and parameters: {'C': 3.0577018752653746, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:46,028] Trial 4 finished with value: 0.8733333333333333 and parameters: {'C': 4.222293523927825, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:46,441] Trial 5 finished with value: 0.8833333333333333 and parameters: {'C': 5.07044965951815, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:46,696] Trial 6 finished with value: 0.8866666666666667 and parameters: {'C': 8.033491347226773, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:46,960] Trial 7 finished with value: 0.8833333333333333 and parameters: {'C': 6.938677043634463, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:47,390] Trial 8 finished with value: 0.8833333333333333 and parameters: {'C': 4.786258400202145, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:47,660] Trial 9 finished with value: 0.8833333333333333 and parameters: {'C': 6.8733904497488085, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:48,105] Trial 10 finished with value: 0.7466666666666667 and parameters: {'C': 0.21742422405161133, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:48,412] Trial 11 finished with value: 0.8866666666666667 and parameters: {'C': 8.593482333034558, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:48,920] Trial 12 finished with value: 0.8866666666666667 and parameters: {'C': 8.881085282385351, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:49,209] Trial 13 finished with value: 0.8833333333333333 and parameters: {'C': 6.850039783386324, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:49,692] Trial 14 finished with value: 0.8866666666666667 and parameters: {'C': 9.518006454023586, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:49,997] Trial 15 finished with value: 0.8833333333333333 and parameters: {'C': 7.739032993069064, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:51,268] Trial 16 finished with value: 0.8866666666666667 and parameters: {'C': 5.64175107883638, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:52,170] Trial 17 finished with value: 0.8866666666666667 and parameters: {'C': 9.849855718041834, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:52,825] Trial 18 finished with value: 0.8866666666666667 and parameters: {'C': 6.305159934645025, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:53,747] Trial 19 finished with value: 0.8833333333333333 and parameters: {'C': 7.587074470429544, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:54,338] Trial 20 finished with value: 0.8866666666666667 and parameters: {'C': 8.25218622458887, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:54,707] Trial 21 finished with value: 0.8866666666666667 and parameters: {'C': 8.622860253183523, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:55,075] Trial 22 finished with value: 0.8866666666666667 and parameters: {'C': 5.935711797082627, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:55,426] Trial 23 finished with value: 0.8866666666666667 and parameters: {'C': 8.987581456629805, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:55,764] Trial 24 finished with value: 0.8833333333333333 and parameters: {'C': 7.9118571454205515, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:56,136] Trial 25 finished with value: 0.8833333333333333 and parameters: {'C': 7.221586013356149, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:56,530] Trial 26 finished with value: 0.87 and parameters: {'C': 3.8564450428186197, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:56,845] Trial 27 finished with value: 0.8866666666666667 and parameters: {'C': 9.976793601983195, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:57,264] Trial 28 finished with value: 0.8833333333333333 and parameters: {'C': 6.243931892237958, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:57,503] Trial 29 finished with value: 0.7866666666666666 and parameters: {'C': 0.5336598294248027, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 09:49:57,505] A new study created in memory with name: no-name-7f40ae23-b222-427e-a0dd-d00c3caa76a7
# Optimizing k-NN...
# [I 2024-12-27 09:49:57,993] Trial 0 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 0 with value: 0.8566666666666667.
# [I 2024-12-27 09:49:58,366] Trial 1 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 0 with value: 0.8566666666666667.
# [I 2024-12-27 09:49:58,730] Trial 2 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 2 with value: 0.86.
# [I 2024-12-27 09:49:59,105] Trial 3 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 2 with value: 0.86.
# [I 2024-12-27 09:49:59,464] Trial 4 finished with value: 0.84 and parameters: {'n_neighbors': 18}. Best is trial 2 with value: 0.86.
# [I 2024-12-27 09:49:59,824] Trial 5 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 5 with value: 0.87.
# [I 2024-12-27 09:50:00,189] Trial 6 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 5 with value: 0.87.
# [I 2024-12-27 09:50:00,543] Trial 7 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.87.
# [I 2024-12-27 09:50:00,905] Trial 8 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 8 with value: 0.8733333333333333.
# [I 2024-12-27 09:50:01,276] Trial 9 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 15}. Best is trial 8 with value: 0.8733333333333333.
# [I 2024-12-27 09:50:01,632] Trial 10 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:02,003] Trial 11 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:02,377] Trial 12 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:02,738] Trial 13 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:03,106] Trial 14 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:03,467] Trial 15 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:03,828] Trial 16 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:04,679] Trial 17 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:05,198] Trial 18 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:05,555] Trial 19 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:05,921] Trial 20 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:06,296] Trial 21 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:06,652] Trial 22 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:07,181] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 09:50:07,763] Trial 24 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:08,322] Trial 25 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:08,892] Trial 26 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:09,484] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:10,046] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:10,632] Trial 29 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 24 with value: 0.8833333333333333.
# [I 2024-12-27 09:50:10,639] A new study created in memory with name: no-name-92ca2191-5224-4c35-9300-c24f17f392d1
# Optimizing Naive Bayes...
# [I 2024-12-27 09:50:11,065] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:11,389] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:11,662] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:11,933] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:12,211] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:12,475] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:12,763] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:13,026] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:13,296] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:13,573] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:13,841] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:14,100] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:14,372] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:14,647] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:14,919] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:15,199] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:15,462] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:15,737] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:15,998] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:16,264] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:16,531] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:16,804] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:17,072] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:17,343] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:17,603] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:17,883] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:18,152] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:18,417] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:18,686] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:18,972] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 09:50:18,975] A new study created in memory with name: no-name-5407fae7-eef0-42f3-91ce-9046d8942704
# Optimizing Gradient Boosting...
# [I 2024-12-27 09:50:35,050] Trial 0 finished with value: 0.89 and parameters: {'n_estimators': 232, 'learning_rate': 0.3072125263944971, 'max_depth': 3}. Best is trial 0 with value: 0.89.
# [I 2024-12-27 09:51:56,381] Trial 1 finished with value: 0.88 and parameters: {'n_estimators': 386, 'learning_rate': 0.1838602134415169, 'max_depth': 11}. Best is trial 0 with value: 0.89.
# [I 2024-12-27 09:54:05,265] Trial 2 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 380, 'learning_rate': 0.37504103957927293, 'max_depth': 20}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:54:47,574] Trial 3 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 166, 'learning_rate': 0.11423545236477257, 'max_depth': 14}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:55:58,964] Trial 4 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 375, 'learning_rate': 0.12062385405413355, 'max_depth': 10}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:57:48,527] Trial 5 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 339, 'learning_rate': 0.46866365371413476, 'max_depth': 19}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:58:13,740] Trial 6 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 216, 'learning_rate': 0.29559929064194357, 'max_depth': 4}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:58:39,623] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 308, 'learning_rate': 0.3153648350476573, 'max_depth': 4}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:59:11,497] Trial 8 finished with value: 0.88 and parameters: {'n_estimators': 446, 'learning_rate': 0.4747561598750089, 'max_depth': 3}. Best is trial 2 with value: 0.8966666666666666.
# [I 2024-12-27 09:59:56,461] Trial 9 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 153, 'learning_rate': 0.013581588060865363, 'max_depth': 20}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:00:17,936] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 82, 'learning_rate': 0.010616538889836269, 'max_depth': 16}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:02:53,574] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 487, 'learning_rate': 0.38593164338662045, 'max_depth': 20}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:03:11,444] Trial 12 finished with value: 0.9 and parameters: {'n_estimators': 60, 'learning_rate': 0.38547830242269826, 'max_depth': 17}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:03:26,093] Trial 13 finished with value: 0.88 and parameters: {'n_estimators': 58, 'learning_rate': 0.01378207179657892, 'max_depth': 17}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:04:00,149] Trial 14 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 135, 'learning_rate': 0.21266539428789472, 'max_depth': 14}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:04:38,546] Trial 15 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 122, 'learning_rate': 0.40676630814499376, 'max_depth': 17}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:05:11,473] Trial 16 finished with value: 0.89 and parameters: {'n_estimators': 193, 'learning_rate': 0.08783141939802941, 'max_depth': 9}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:05:40,203] Trial 17 finished with value: 0.89 and parameters: {'n_estimators': 112, 'learning_rate': 0.2465124930074465, 'max_depth': 14}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:05:56,591] Trial 18 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 51, 'learning_rate': 0.16467842945861255, 'max_depth': 18}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:06:39,819] Trial 19 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 254, 'learning_rate': 0.431538286531439, 'max_depth': 8}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:07:20,709] Trial 20 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 148, 'learning_rate': 0.3390269754272989, 'max_depth': 15}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:09:09,760] Trial 21 finished with value: 0.89 and parameters: {'n_estimators': 307, 'learning_rate': 0.36435592711321996, 'max_depth': 20}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:11:45,398] Trial 22 finished with value: 0.88 and parameters: {'n_estimators': 430, 'learning_rate': 0.2606707873541807, 'max_depth': 20}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:12:16,627] Trial 23 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 97, 'learning_rate': 0.4333179480295571, 'max_depth': 18}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:12:49,141] Trial 24 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 100, 'learning_rate': 0.49987747427011686, 'max_depth': 18}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:13:42,125] Trial 25 finished with value: 0.9 and parameters: {'n_estimators': 180, 'learning_rate': 0.4278620674596072, 'max_depth': 16}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:14:00,565] Trial 26 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 88, 'learning_rate': 0.06043752054603768, 'max_depth': 12}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:14:50,042] Trial 27 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 148, 'learning_rate': 0.43381400968682954, 'max_depth': 18}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:15:06,768] Trial 28 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 76, 'learning_rate': 0.27021447457342596, 'max_depth': 12}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:16:10,576] Trial 29 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 220, 'learning_rate': 0.33953365368296784, 'max_depth': 16}. Best is trial 9 with value: 0.9033333333333333.
# [I 2024-12-27 10:16:10,579] A new study created in memory with name: no-name-14142e9f-5036-4bd9-a3c4-d0821881d5b7
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:16:37,035] Trial 0 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 354, 'max_depth': 12, 'learning_rate': 0.489615601539429}. Best is trial 0 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:16:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:17:03,715] Trial 1 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 320, 'max_depth': 20, 'learning_rate': 0.07145972604866886}. Best is trial 1 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:17:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:17:14,809] Trial 2 finished with value: 0.91 and parameters: {'n_estimators': 91, 'max_depth': 9, 'learning_rate': 0.3543502329483138}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:17:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:17:29,275] Trial 3 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 143, 'max_depth': 18, 'learning_rate': 0.4829042283271115}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:17:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:17:57,906] Trial 4 finished with value: 0.91 and parameters: {'n_estimators': 399, 'max_depth': 14, 'learning_rate': 0.0363088823537798}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:18:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:18:28,768] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 460, 'max_depth': 14, 'learning_rate': 0.22307427133661054}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:18:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:18:46,649] Trial 6 finished with value: 0.9 and parameters: {'n_estimators': 257, 'max_depth': 9, 'learning_rate': 0.30940053921716215}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:18:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:19:15,159] Trial 7 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 416, 'max_depth': 17, 'learning_rate': 0.30319624219616126}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:19:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:19:49,861] Trial 8 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 497, 'max_depth': 16, 'learning_rate': 0.4386229792530342}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:19:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:19:56,973] Trial 9 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 87, 'max_depth': 3, 'learning_rate': 0.4996153089564625}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:20:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:20:10,225] Trial 10 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 187, 'max_depth': 7, 'learning_rate': 0.18187633468778505}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:20:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:20:19,365] Trial 11 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.021591859643285874}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:20:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:20:37,053] Trial 12 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 237, 'max_depth': 12, 'learning_rate': 0.37322270161929705}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:20:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:21:01,569] Trial 13 finished with value: 0.9 and parameters: {'n_estimators': 385, 'max_depth': 6, 'learning_rate': 0.1608634700988185}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:21:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:21:15,953] Trial 14 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 166, 'max_depth': 10, 'learning_rate': 0.11050597614454867}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:21:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:21:41,143] Trial 15 finished with value: 0.91 and parameters: {'n_estimators': 321, 'max_depth': 15, 'learning_rate': 0.38542172555642246}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:21:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:21:58,406] Trial 16 finished with value: 0.91 and parameters: {'n_estimators': 222, 'max_depth': 13, 'learning_rate': 0.30090437263329006}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:22:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:22:16,912] Trial 17 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 298, 'max_depth': 7, 'learning_rate': 0.24423348721150082}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:22:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:22:27,314] Trial 18 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 114, 'max_depth': 4, 'learning_rate': 0.3608679424128571}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:22:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:22:56,571] Trial 19 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 428, 'max_depth': 10, 'learning_rate': 0.014421597356127379}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:22:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:23:25,266] Trial 20 finished with value: 0.9 and parameters: {'n_estimators': 364, 'max_depth': 19, 'learning_rate': 0.1194015471564715}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:23:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 10:23:50,272] Trial 21 finished with value: 0.9 and parameters: {'n_estimators': 306, 'max_depth': 15, 'learning_rate': 0.4015368293411382}. Best is trial 2 with value: 0.91.
# ...
# Optimizing Neural Network...
# [I 2024-12-27 10:40:22,683] Trial 0 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 48, 'learning_rate_init': 0.010208593746490243}. Best is trial 0 with value: 0.8966666666666666.
# [I 2024-12-27 10:41:01,357] Trial 1 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 89, 'learning_rate_init': 0.054178009400851226}. Best is trial 0 with value: 0.8966666666666666.
# [I 2024-12-27 10:41:40,850] Trial 2 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 96, 'hidden_layer_2': 87, 'learning_rate_init': 0.09278249388092663}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:41:58,180] Trial 3 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 91, 'hidden_layer_2': 37, 'learning_rate_init': 0.05239655816861249}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:42:15,619] Trial 4 finished with value: 0.91 and parameters: {'hidden_layer_1': 71, 'hidden_layer_2': 24, 'learning_rate_init': 0.013464613512310476}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:42:31,042] Trial 5 finished with value: 0.9 and parameters: {'hidden_layer_1': 35, 'hidden_layer_2': 32, 'learning_rate_init': 0.017334646915124072}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:42:57,298] Trial 6 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 99, 'learning_rate_init': 0.031337713307294596}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:43:03,269] Trial 7 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 15, 'hidden_layer_2': 39, 'learning_rate_init': 0.09295221084350466}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:43:18,534] Trial 8 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 80, 'learning_rate_init': 0.014076938655428813}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:43:42,413] Trial 9 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 56, 'learning_rate_init': 0.0076905162633507385}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:44:12,543] Trial 10 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 68, 'learning_rate_init': 0.0989814454209586}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:44:34,706] Trial 11 finished with value: 0.9 and parameters: {'hidden_layer_1': 79, 'hidden_layer_2': 13, 'learning_rate_init': 0.07354981845345204}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:44:52,224] Trial 12 finished with value: 0.91 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 64, 'learning_rate_init': 0.056184944207117}. Best is trial 2 with value: 0.9166666666666666.
# [I 2024-12-27 10:45:10,991] Trial 13 finished with value: 0.93 and parameters: {'hidden_layer_1': 59, 'hidden_layer_2': 76, 'learning_rate_init': 0.07531780407408123}. Best is trial 13 with value: 0.93.
# [I 2024-12-27 10:45:24,687] Trial 14 finished with value: 0.9333333333333333 and parameters: {'hidden_layer_1': 57, 'hidden_layer_2': 77, 'learning_rate_init': 0.07638910404805781}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:45:47,136] Trial 15 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 53, 'hidden_layer_2': 75, 'learning_rate_init': 0.07296266657294075}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:46:02,162] Trial 16 finished with value: 0.92 and parameters: {'hidden_layer_1': 56, 'hidden_layer_2': 59, 'learning_rate_init': 0.07556629148709611}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:46:17,539] Trial 17 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 24, 'hidden_layer_2': 99, 'learning_rate_init': 0.06524225024167178}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:46:34,100] Trial 18 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 57, 'hidden_layer_2': 73, 'learning_rate_init': 0.04015577448172077}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:46:55,969] Trial 19 finished with value: 0.92 and parameters: {'hidden_layer_1': 74, 'hidden_layer_2': 85, 'learning_rate_init': 0.0837256503325998}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:47:20,059] Trial 20 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 52, 'learning_rate_init': 0.06232198524441649}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:47:42,929] Trial 21 finished with value: 0.91 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 60, 'learning_rate_init': 0.07874157968912464}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:48:11,639] Trial 22 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 52, 'hidden_layer_2': 69, 'learning_rate_init': 0.08554637514675471}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:48:27,963] Trial 23 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 78, 'learning_rate_init': 0.06906106690584396}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:48:51,557] Trial 24 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 66, 'hidden_layer_2': 80, 'learning_rate_init': 0.0400992463658021}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:49:16,079] Trial 25 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 92, 'learning_rate_init': 0.0667519480515286}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:49:30,123] Trial 26 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 72, 'hidden_layer_2': 76, 'learning_rate_init': 0.08493068646690008}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:49:53,310] Trial 27 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 81, 'learning_rate_init': 0.06661342115763144}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:50:00,094] Trial 28 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 49, 'hidden_layer_2': 93, 'learning_rate_init': 0.04287793137138621}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:50:13,556] Trial 29 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 64, 'hidden_layer_2': 49, 'learning_rate_init': 0.06152346176056508}. Best is trial 14 with value: 0.9333333333333333.
# [I 2024-12-27 10:50:13,570] A new study created in memory with name: no-name-de46985a-d408-44c3-8e99-ca528b66ed7a
# Optimizing MLP...
# [I 2024-12-27 10:50:47,665] Trial 0 finished with value: 0.9233333333333333 and parameters: {'layer_1': 85, 'layer_2': 53, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05618522834368167}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:50:58,086] Trial 1 finished with value: 0.9 and parameters: {'layer_1': 61, 'layer_2': 132, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.03666585848227141}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:51:45,242] Trial 2 finished with value: 0.8733333333333333 and parameters: {'layer_1': 101, 'layer_2': 97, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.04009653095661493}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:52:31,166] Trial 3 finished with value: 0.9066666666666666 and parameters: {'layer_1': 142, 'layer_2': 103, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.03540527915881024}. Best is trial 0 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 10:53:46,699] Trial 4 finished with value: 0.91 and parameters: {'layer_1': 77, 'layer_2': 85, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.016961894081544377}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:53:54,826] Trial 5 finished with value: 0.5 and parameters: {'layer_1': 98, 'layer_2': 138, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.08137015392773934}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:54:24,533] Trial 6 finished with value: 0.91 and parameters: {'layer_1': 56, 'layer_2': 113, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.055264199325585496}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:55:18,195] Trial 7 finished with value: 0.9133333333333333 and parameters: {'layer_1': 85, 'layer_2': 121, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0396390555482427}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:56:00,877] Trial 8 finished with value: 0.8833333333333333 and parameters: {'layer_1': 125, 'layer_2': 71, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0650240228947288}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:56:38,613] Trial 9 finished with value: 0.89 and parameters: {'layer_1': 131, 'layer_2': 132, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06800684464677213}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:56:49,535] Trial 10 finished with value: 0.5 and parameters: {'layer_1': 119, 'layer_2': 51, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09721092360449449}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:57:13,464] Trial 11 finished with value: 0.8866666666666667 and parameters: {'layer_1': 87, 'layer_2': 51, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.004530056846736498}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:57:32,268] Trial 12 finished with value: 0.8933333333333333 and parameters: {'layer_1': 73, 'layer_2': 150, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.024371175899006982}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:58:16,357] Trial 13 finished with value: 0.9166666666666666 and parameters: {'layer_1': 107, 'layer_2': 117, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.051756925473320475}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:59:01,797] Trial 14 finished with value: 0.9166666666666666 and parameters: {'layer_1': 108, 'layer_2': 73, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05257630452987418}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 10:59:31,529] Trial 15 finished with value: 0.91 and parameters: {'layer_1': 111, 'layer_2': 90, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07603332114069278}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:00:01,675] Trial 16 finished with value: 0.8966666666666666 and parameters: {'layer_1': 150, 'layer_2': 112, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.058642364717122517}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:00:16,344] Trial 17 finished with value: 0.91 and parameters: {'layer_1': 91, 'layer_2': 66, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08817668468786158}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:00:41,561] Trial 18 finished with value: 0.9033333333333333 and parameters: {'layer_1': 70, 'layer_2': 119, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.046792528096640196}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:01:09,240] Trial 19 finished with value: 0.9066666666666666 and parameters: {'layer_1': 50, 'layer_2': 83, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.02255556545528484}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:01:44,417] Trial 20 finished with value: 0.9 and parameters: {'layer_1': 114, 'layer_2': 60, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0701853900976512}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:02:17,668] Trial 21 finished with value: 0.9133333333333333 and parameters: {'layer_1': 103, 'layer_2': 76, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05483921826936194}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:02:44,705] Trial 22 finished with value: 0.91 and parameters: {'layer_1': 111, 'layer_2': 61, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.047645550218537294}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:03:02,893] Trial 23 finished with value: 0.9 and parameters: {'layer_1': 96, 'layer_2': 74, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06259415341917038}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:03:31,617] Trial 24 finished with value: 0.9033333333333333 and parameters: {'layer_1': 81, 'layer_2': 100, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.04889922977322257}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:04:02,161] Trial 25 finished with value: 0.9033333333333333 and parameters: {'layer_1': 106, 'layer_2': 57, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.02783567225702112}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:04:32,968] Trial 26 finished with value: 0.8933333333333333 and parameters: {'layer_1': 121, 'layer_2': 79, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.07481138861464531}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:05:07,146] Trial 27 finished with value: 0.92 and parameters: {'layer_1': 130, 'layer_2': 68, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05872658044586944}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:05:30,107] Trial 28 finished with value: 0.91 and parameters: {'layer_1': 129, 'layer_2': 91, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05965954684664313}. Best is trial 0 with value: 0.9233333333333333.
# [I 2024-12-27 11:06:13,292] Trial 29 finished with value: 0.9133333333333333 and parameters: {'layer_1': 138, 'layer_2': 66, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03381022015810812}. Best is trial 0 with value: 0.9233333333333333.
#                   Model  Accuracy  \
# 0                   SVM  0.903333
# 1         Decision Tree  0.870000
# 2         Random Forest  0.893333
# 3   Logistic Regression  0.886667
# 4                  k-NN  0.883333
# 5           Naive Bayes  0.866667
# 6     Gradient Boosting  0.903333
# 7               XGBoost  0.910000
# 8              LightGBM  0.853333
# 9              AdaBoost  0.886667
# 10       Neural Network  0.933333
# 11                  MLP  0.923333
#
#                                           Best Params
# 0           {'C': 6.085864540540266, 'kernel': 'rbf'}
# 1           {'max_depth': 19, 'min_samples_split': 3}
# 2   {'n_estimators': 205, 'max_depth': 18, 'min_sa...
# 3          {'C': 5.66531771641788, 'solver': 'lbfgs'}
# 4                                  {'n_neighbors': 3}
# 5                                                  {}
# 6   {'n_estimators': 153, 'learning_rate': 0.01358...
# 7   {'n_estimators': 91, 'max_depth': 9, 'learning...
# 8   {'n_estimators': 67, 'max_depth': 17, 'learnin...
# 9   {'n_estimators': 500, 'learning_rate': 0.98962...
# 10  {'hidden_layer_1': 57, 'hidden_layer_2': 77, '...
# 11  {'layer_1': 85, 'layer_2': 53, 'activation': '...

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, cohen_kappa_score, roc_auc_score # Import confusion_matrix and other metrics

# Function to calculate metrics with model name
def calculate_metrics(y_true, y_pred, model_name=None):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    mcc = matthews_corrcoef(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "Kappa": kappa,
        "AUC": auc,
    }

# Results storage
results = []

# Optimization function
def optimize_model_with_metrics(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        trial.set_user_attr("preds", preds)
        metrics = calculate_metrics(y_val, preds, model_name=model_name)
        return metrics["Accuracy"]

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the best trial metrics
    best_trial_preds = study.best_trial.user_attrs["preds"]
    best_metrics = calculate_metrics(y_val, best_trial_preds, model_name=model_name)
    best_metrics["Best Params"] = study.best_params
    results.append(best_metrics)

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model_with_metrics(model_name, model_func)

# Store the final results with selected metrics and best parameters
final_results = []
for result in results:
    final_results.append(
        {
            "Model": result["Model"],
            "Accuracy": result["Accuracy"],
            "Sensitivity": result["Sensitivity"],
            "Specificity": result["Specificity"],
            "MCC": result["MCC"],
            "Kappa": result["Kappa"],
            "AUC": result["AUC"],
            "Best Params": result["Best Params"],
        }
    )

# Convert results to a DataFrame and display it
final_results_df = pd.DataFrame(final_results)
print(final_results_df)
# Out:
# [I 2024-12-27 11:08:25,592] A new study created in memory with name: no-name-9d2e186a-9924-42f1-a76a-c11b2f89ff83
# Optimizing SVM...
# [I 2024-12-27 11:08:34,233] Trial 0 finished with value: 0.89 and parameters: {'C': 5.528009860655345, 'kernel': 'linear'}. Best is trial 0 with value: 0.89.
# [I 2024-12-27 11:08:42,921] Trial 1 finished with value: 0.8566666666666667 and parameters: {'C': 1.882477897081928, 'kernel': 'linear'}. Best is trial 0 with value: 0.89.
# [I 2024-12-27 11:08:51,264] Trial 2 finished with value: 0.9033333333333333 and parameters: {'C': 3.8008971659568984, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:08:58,112] Trial 3 finished with value: 0.8766666666666667 and parameters: {'C': 4.204386891705302, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:05,495] Trial 4 finished with value: 0.8966666666666666 and parameters: {'C': 0.9912576605297914, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:14,271] Trial 5 finished with value: 0.75 and parameters: {'C': 1.0766126215230611, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:22,948] Trial 6 finished with value: 0.9033333333333333 and parameters: {'C': 1.720007492297749, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:31,483] Trial 7 finished with value: 0.8566666666666667 and parameters: {'C': 6.483118102417255, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:36,008] Trial 8 finished with value: 0.8733333333333333 and parameters: {'C': 3.580462116712946, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:43,546] Trial 9 finished with value: 0.8933333333333333 and parameters: {'C': 7.168698716318525, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:09:52,553] Trial 10 finished with value: 0.9033333333333333 and parameters: {'C': 9.393344340328655, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:01,612] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 3.0549578841859644, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:11,550] Trial 12 finished with value: 0.81 and parameters: {'C': 0.16624597055748236, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:20,253] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 2.723508184138693, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:24,854] Trial 14 finished with value: 0.86 and parameters: {'C': 4.845278017691838, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:33,287] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 2.1971068757051753, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:42,530] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 7.825410078787371, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:52,228] Trial 17 finished with value: 0.9033333333333333 and parameters: {'C': 3.8044316561227185, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:10:56,288] Trial 18 finished with value: 0.86 and parameters: {'C': 5.221539672500196, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:04,760] Trial 19 finished with value: 0.7766666666666666 and parameters: {'C': 1.5039964992869366, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:13,634] Trial 20 finished with value: 0.8566666666666667 and parameters: {'C': 0.2973669628769695, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:22,711] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 9.07046066137596, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:31,127] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 6.1049506234094135, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:40,460] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 9.84392475810408, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:49,506] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 8.676096786570454, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:11:58,363] Trial 25 finished with value: 0.9033333333333333 and parameters: {'C': 4.392082640865591, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:12:07,333] Trial 26 finished with value: 0.9033333333333333 and parameters: {'C': 2.6747094356348717, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:12:15,719] Trial 27 finished with value: 0.86 and parameters: {'C': 7.029077431623644, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:12:20,696] Trial 28 finished with value: 0.8733333333333333 and parameters: {'C': 3.2274127717883467, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:12:26,658] Trial 29 finished with value: 0.8933333333333333 and parameters: {'C': 5.80226855008272, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2024-12-27 11:12:26,669] A new study created in memory with name: no-name-4d941886-0eb3-4154-8ef7-4ca6c18e6c1f
# [I 2024-12-27 11:12:26,858] Trial 0 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 10}. Best is trial 0 with value: 0.7233333333333334.
# Optimizing Decision Tree...
# [I 2024-12-27 11:12:27,216] Trial 1 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 5}. Best is trial 1 with value: 0.8533333333333334.
# [I 2024-12-27 11:12:27,439] Trial 2 finished with value: 0.77 and parameters: {'max_depth': 7, 'min_samples_split': 7}. Best is trial 1 with value: 0.8533333333333334.
# [I 2024-12-27 11:12:27,718] Trial 3 finished with value: 0.83 and parameters: {'max_depth': 13, 'min_samples_split': 7}. Best is trial 1 with value: 0.8533333333333334.
# [I 2024-12-27 11:12:28,091] Trial 4 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:28,316] Trial 5 finished with value: 0.78 and parameters: {'max_depth': 7, 'min_samples_split': 5}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:28,570] Trial 6 finished with value: 0.8066666666666666 and parameters: {'max_depth': 10, 'min_samples_split': 8}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:28,851] Trial 7 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 7}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:29,368] Trial 8 finished with value: 0.8466666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 4}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:29,738] Trial 9 finished with value: 0.78 and parameters: {'max_depth': 7, 'min_samples_split': 4}. Best is trial 4 with value: 0.86.
# [I 2024-12-27 11:12:30,356] Trial 10 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2024-12-27 11:12:30,973] Trial 11 finished with value: 0.87 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:31,541] Trial 12 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:32,120] Trial 13 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:32,748] Trial 14 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:33,324] Trial 15 finished with value: 0.8633333333333333 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:33,632] Trial 16 finished with value: 0.8133333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:33,959] Trial 17 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:34,327] Trial 18 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 10}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:34,648] Trial 19 finished with value: 0.8466666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 4}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:34,922] Trial 20 finished with value: 0.81 and parameters: {'max_depth': 10, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:35,276] Trial 21 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:35,645] Trial 22 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:35,979] Trial 23 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:36,330] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:36,656] Trial 25 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:37,007] Trial 26 finished with value: 0.8633333333333333 and parameters: {'max_depth': 19, 'min_samples_split': 2}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:37,392] Trial 27 finished with value: 0.85 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:37,699] Trial 28 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 3}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:37,972] Trial 29 finished with value: 0.8166666666666667 and parameters: {'max_depth': 11, 'min_samples_split': 9}. Best is trial 11 with value: 0.87.
# [I 2024-12-27 11:12:37,985] A new study created in memory with name: no-name-7019a028-a145-491a-b8a6-3859418ab18a
# Optimizing Random Forest...
# [I 2024-12-27 11:12:39,784] Trial 0 finished with value: 0.87 and parameters: {'n_estimators': 283, 'max_depth': 19, 'min_samples_split': 8}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:41,925] Trial 1 finished with value: 0.85 and parameters: {'n_estimators': 451, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:42,491] Trial 2 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 93, 'max_depth': 13, 'min_samples_split': 7}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:44,206] Trial 3 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 270, 'max_depth': 12, 'min_samples_split': 4}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:47,757] Trial 4 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 391, 'max_depth': 16, 'min_samples_split': 7}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:49,040] Trial 5 finished with value: 0.7933333333333333 and parameters: {'n_estimators': 395, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:49,430] Trial 6 finished with value: 0.7766666666666666 and parameters: {'n_estimators': 114, 'max_depth': 3, 'min_samples_split': 6}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:50,772] Trial 7 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 389, 'max_depth': 6, 'min_samples_split': 5}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:51,146] Trial 8 finished with value: 0.7933333333333333 and parameters: {'n_estimators': 78, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:52,534] Trial 9 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 218, 'max_depth': 17, 'min_samples_split': 5}. Best is trial 0 with value: 0.87.
# [I 2024-12-27 11:12:53,921] Trial 10 finished with value: 0.88 and parameters: {'n_estimators': 204, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 11:12:55,277] Trial 11 finished with value: 0.87 and parameters: {'n_estimators': 197, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 11:12:57,261] Trial 12 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 294, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 11:12:59,922] Trial 13 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 299, 'max_depth': 16, 'min_samples_split': 10}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 11:13:01,348] Trial 14 finished with value: 0.86 and parameters: {'n_estimators': 178, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 10 with value: 0.88.
# [I 2024-12-27 11:13:03,395] Trial 15 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 310, 'max_depth': 18, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:04,438] Trial 16 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 155, 'max_depth': 18, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:05,789] Trial 17 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 241, 'max_depth': 14, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:07,179] Trial 18 finished with value: 0.83 and parameters: {'n_estimators': 324, 'max_depth': 9, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:09,065] Trial 19 finished with value: 0.86 and parameters: {'n_estimators': 346, 'max_depth': 14, 'min_samples_split': 8}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:12,851] Trial 20 finished with value: 0.87 and parameters: {'n_estimators': 490, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:15,439] Trial 21 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 245, 'max_depth': 19, 'min_samples_split': 10}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:17,898] Trial 22 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 343, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:19,945] Trial 23 finished with value: 0.88 and parameters: {'n_estimators': 308, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:20,964] Trial 24 finished with value: 0.86 and parameters: {'n_estimators': 160, 'max_depth': 16, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:22,499] Trial 25 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 243, 'max_depth': 18, 'min_samples_split': 8}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:24,535] Trial 26 finished with value: 0.85 and parameters: {'n_estimators': 364, 'max_depth': 15, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:25,375] Trial 27 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 129, 'max_depth': 17, 'min_samples_split': 9}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:27,218] Trial 28 finished with value: 0.87 and parameters: {'n_estimators': 211, 'max_depth': 19, 'min_samples_split': 8}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:29,577] Trial 29 finished with value: 0.84 and parameters: {'n_estimators': 308, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 15 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:29,592] A new study created in memory with name: no-name-8fb8181d-846e-48de-baad-6fedca116f23
# Optimizing Logistic Regression...
# [I 2024-12-27 11:13:29,904] Trial 0 finished with value: 0.79 and parameters: {'C': 0.5795293005238256, 'solver': 'liblinear'}. Best is trial 0 with value: 0.79.
# [I 2024-12-27 11:13:30,254] Trial 1 finished with value: 0.8866666666666667 and parameters: {'C': 8.34888059318696, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:30,780] Trial 2 finished with value: 0.8533333333333334 and parameters: {'C': 2.271608684536865, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:31,139] Trial 3 finished with value: 0.8266666666666667 and parameters: {'C': 1.1232680920816671, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:31,526] Trial 4 finished with value: 0.8833333333333333 and parameters: {'C': 4.622768559039366, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:31,971] Trial 5 finished with value: 0.8833333333333333 and parameters: {'C': 6.050078310129342, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:32,265] Trial 6 finished with value: 0.8866666666666667 and parameters: {'C': 4.884461641667201, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:32,679] Trial 7 finished with value: 0.8833333333333333 and parameters: {'C': 6.389938902685202, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:32,984] Trial 8 finished with value: 0.8466666666666667 and parameters: {'C': 1.811470640979911, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:33,383] Trial 9 finished with value: 0.8866666666666667 and parameters: {'C': 8.2643848375499, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:33,665] Trial 10 finished with value: 0.8866666666666667 and parameters: {'C': 9.826036010080147, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:33,914] Trial 11 finished with value: 0.8733333333333333 and parameters: {'C': 3.9838543173722627, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:34,160] Trial 12 finished with value: 0.8833333333333333 and parameters: {'C': 7.377960667125692, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:34,405] Trial 13 finished with value: 0.8666666666666667 and parameters: {'C': 3.2782616265197295, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:34,655] Trial 14 finished with value: 0.8866666666666667 and parameters: {'C': 9.740728362912906, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:34,903] Trial 15 finished with value: 0.8866666666666667 and parameters: {'C': 5.542915995840889, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:35,148] Trial 16 finished with value: 0.8833333333333333 and parameters: {'C': 7.303444795721476, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:35,386] Trial 17 finished with value: 0.8866666666666667 and parameters: {'C': 8.563325771343814, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:35,639] Trial 18 finished with value: 0.8666666666666667 and parameters: {'C': 3.599952166282976, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:35,884] Trial 19 finished with value: 0.8866666666666667 and parameters: {'C': 4.926662318974206, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:36,125] Trial 20 finished with value: 0.8833333333333333 and parameters: {'C': 6.854009109998761, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:36,534] Trial 21 finished with value: 0.8866666666666667 and parameters: {'C': 8.458931651105724, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:36,953] Trial 22 finished with value: 0.8866666666666667 and parameters: {'C': 8.441704343763769, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:37,352] Trial 23 finished with value: 0.8866666666666667 and parameters: {'C': 8.052934944922914, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:37,771] Trial 24 finished with value: 0.8866666666666667 and parameters: {'C': 9.203036705406081, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:38,012] Trial 25 finished with value: 0.8866666666666667 and parameters: {'C': 5.894590388926677, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:38,416] Trial 26 finished with value: 0.8833333333333333 and parameters: {'C': 7.772412009118415, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:38,659] Trial 27 finished with value: 0.8833333333333333 and parameters: {'C': 6.83619592997239, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:39,045] Trial 28 finished with value: 0.8666666666666667 and parameters: {'C': 2.783290068250934, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:39,290] Trial 29 finished with value: 0.8866666666666667 and parameters: {'C': 5.292372838332538, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2024-12-27 11:13:39,304] A new study created in memory with name: no-name-44f60b86-4296-4355-bde6-640fd2a1e7c6
# Optimizing k-NN...
# [I 2024-12-27 11:13:39,698] Trial 0 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:40,063] Trial 1 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:40,418] Trial 2 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:40,803] Trial 3 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:41,369] Trial 4 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:41,956] Trial 5 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:42,523] Trial 6 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 0 with value: 0.8533333333333334.
# [I 2024-12-27 11:13:43,102] Trial 7 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 15}. Best is trial 7 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:43,671] Trial 8 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 7 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:44,268] Trial 9 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 9 with value: 0.8733333333333333.
# [I 2024-12-27 11:13:44,856] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:45,421] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:45,789] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:46,165] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:46,527] Trial 14 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:46,904] Trial 15 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:47,276] Trial 16 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:47,635] Trial 17 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:48,002] Trial 18 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:48,366] Trial 19 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:48,730] Trial 20 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:49,095] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:49,483] Trial 22 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:49,845] Trial 23 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:50,216] Trial 24 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:50,575] Trial 25 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:50,936] Trial 26 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:51,305] Trial 27 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:51,675] Trial 28 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:52,036] Trial 29 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 10 with value: 0.8833333333333333.
# [I 2024-12-27 11:13:52,047] A new study created in memory with name: no-name-c70d7e8a-83fe-43a0-9489-5e2089679605
# Optimizing Naive Bayes...
# [I 2024-12-27 11:13:52,335] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:52,613] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:52,892] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:53,168] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:53,449] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:53,728] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:54,004] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:54,299] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:54,583] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:54,860] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:55,136] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:55,478] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:55,888] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:56,276] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:56,669] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:57,074] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:57,478] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:57,872] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:58,266] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:58,682] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:59,090] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:59,495] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:13:59,926] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:00,263] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:00,543] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:00,832] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:01,109] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:01,384] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:01,680] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:01,962] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 11:14:01,973] A new study created in memory with name: no-name-1e1efba6-689b-42c1-bacc-4835d97e1cde
# Optimizing Gradient Boosting...
# [I 2024-12-27 11:14:38,972] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 435, 'learning_rate': 0.04349909640361378, 'max_depth': 4}. Best is trial 0 with value: 0.88.
# [I 2024-12-27 11:15:00,063] Trial 1 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 143, 'learning_rate': 0.0494399357365585, 'max_depth': 7}. Best is trial 1 with value: 0.8833333333333333.
# [I 2024-12-27 11:16:37,544] Trial 2 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 384, 'learning_rate': 0.0414966285536507, 'max_depth': 14}. Best is trial 1 with value: 0.8833333333333333.
# [I 2024-12-27 11:18:59,723] Trial 3 finished with value: 0.89 and parameters: {'n_estimators': 457, 'learning_rate': 0.4770438123429577, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:19:39,292] Trial 4 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 206, 'learning_rate': 0.0720647048790072, 'max_depth': 10}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:20:31,342] Trial 5 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 375, 'learning_rate': 0.0947841957857717, 'max_depth': 7}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:21:03,584] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 110, 'learning_rate': 0.010895642146887975, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:21:22,569] Trial 7 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 94, 'learning_rate': 0.44143298896835137, 'max_depth': 11}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:21:41,492] Trial 8 finished with value: 0.89 and parameters: {'n_estimators': 140, 'learning_rate': 0.24260787543413678, 'max_depth': 7}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:22:09,597] Trial 9 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 135, 'learning_rate': 0.14711219704258693, 'max_depth': 11}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:24:44,485] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 495, 'learning_rate': 0.47539845276887593, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:26:18,753] Trial 11 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 264, 'learning_rate': 0.36281310900923225, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:27:51,575] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 312, 'learning_rate': 0.2950033154555762, 'max_depth': 16}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:28:09,013] Trial 13 finished with value: 0.89 and parameters: {'n_estimators': 59, 'learning_rate': 0.21749015852856962, 'max_depth': 17}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:29:27,240] Trial 14 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 254, 'learning_rate': 0.3526953359996772, 'max_depth': 17}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 11:30:52,541] Trial 15 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 328, 'learning_rate': 0.1803399105393777, 'max_depth': 14}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:33:02,786] Trial 16 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 500, 'learning_rate': 0.1488684515694224, 'max_depth': 14}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:34:29,920] Trial 17 finished with value: 0.88 and parameters: {'n_estimators': 335, 'learning_rate': 0.1829736857495276, 'max_depth': 14}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:36:51,214] Trial 18 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 430, 'learning_rate': 0.29613397396522484, 'max_depth': 18}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:38:37,397] Trial 19 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 437, 'learning_rate': 0.4198542082448461, 'max_depth': 13}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:39:13,015] Trial 20 finished with value: 0.88 and parameters: {'n_estimators': 209, 'learning_rate': 0.3650113710937639, 'max_depth': 9}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:40:16,003] Trial 21 finished with value: 0.89 and parameters: {'n_estimators': 213, 'learning_rate': 0.011295340662702102, 'max_depth': 19}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:41:47,769] Trial 22 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 318, 'learning_rate': 0.11423433755304441, 'max_depth': 16}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:43:22,136] Trial 23 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 325, 'learning_rate': 0.11671852180185002, 'max_depth': 16}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:44:55,984] Trial 24 finished with value: 0.89 and parameters: {'n_estimators': 320, 'learning_rate': 0.11508659047809683, 'max_depth': 16}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:46:38,037] Trial 25 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 369, 'learning_rate': 0.17871760992479713, 'max_depth': 15}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:47:55,491] Trial 26 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 347, 'learning_rate': 0.12273949919033583, 'max_depth': 12}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:49:19,493] Trial 27 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 285, 'learning_rate': 0.19668130258545868, 'max_depth': 16}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:50:53,959] Trial 28 finished with value: 0.89 and parameters: {'n_estimators': 292, 'learning_rate': 0.2570666252445267, 'max_depth': 18}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:51:22,159] Trial 29 finished with value: 0.89 and parameters: {'n_estimators': 406, 'learning_rate': 0.146692646578733, 'max_depth': 3}. Best is trial 15 with value: 0.8966666666666666.
# [I 2024-12-27 11:51:22,171] A new study created in memory with name: no-name-ebf2829c-2cca-492f-b8f3-9cd25630dfca
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:51:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:51:44,075] Trial 0 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 303, 'max_depth': 7, 'learning_rate': 0.3467772509100809}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:51:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:52:12,220] Trial 1 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 429, 'max_depth': 10, 'learning_rate': 0.03690306722083159}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:52:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:52:30,781] Trial 2 finished with value: 0.9 and parameters: {'n_estimators': 336, 'max_depth': 3, 'learning_rate': 0.09603889073571087}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:52:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:52:54,154] Trial 3 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 295, 'max_depth': 11, 'learning_rate': 0.022782225464979114}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:52:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:53:02,852] Trial 4 finished with value: 0.91 and parameters: {'n_estimators': 80, 'max_depth': 19, 'learning_rate': 0.15661116429235733}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:53:14,201] Trial 5 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 146, 'max_depth': 10, 'learning_rate': 0.3325504274244794}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:53:42,008] Trial 6 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 426, 'max_depth': 11, 'learning_rate': 0.2871145640733549}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:53:55,634] Trial 7 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 192, 'max_depth': 4, 'learning_rate': 0.2320094506185239}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:54:11,930] Trial 8 finished with value: 0.9 and parameters: {'n_estimators': 195, 'max_depth': 15, 'learning_rate': 0.07338850483338814}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:54:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:54:22,670] Trial 9 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 117, 'max_depth': 7, 'learning_rate': 0.11919866513609557}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:54:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:54:34,027] Trial 10 finished with value: 0.91 and parameters: {'n_estimators': 75, 'max_depth': 20, 'learning_rate': 0.18345042666582834}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:54:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:54:42,255] Trial 11 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 70, 'max_depth': 20, 'learning_rate': 0.18012256764153103}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:54:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:54:50,627] Trial 12 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 55, 'max_depth': 20, 'learning_rate': 0.45132733925238366}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:54:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:55:08,304] Trial 13 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 221, 'max_depth': 16, 'learning_rate': 0.18156504819054828}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:55:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:55:20,392] Trial 14 finished with value: 0.91 and parameters: {'n_estimators': 114, 'max_depth': 17, 'learning_rate': 0.15933180272698427}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:55:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:55:39,120] Trial 15 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 241, 'max_depth': 14, 'learning_rate': 0.2403319674378414}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:55:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:55:51,849] Trial 16 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 149, 'max_depth': 18, 'learning_rate': 0.44471199867718975}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:55:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:56:00,988] Trial 17 finished with value: 0.9 and parameters: {'n_estimators': 53, 'max_depth': 18, 'learning_rate': 0.13516425940990442}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:56:27,536] Trial 18 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 358, 'max_depth': 14, 'learning_rate': 0.29895902457756873}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:57:01,818] Trial 19 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 488, 'max_depth': 20, 'learning_rate': 0.20949662187767487}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:57:12,744] Trial 20 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 104, 'max_depth': 13, 'learning_rate': 0.3807332008203569}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:57:25,001] Trial 21 finished with value: 0.9 and parameters: {'n_estimators': 100, 'max_depth': 17, 'learning_rate': 0.15895886828953856}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 11:57:39,469] Trial 22 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 146, 'max_depth': 18, 'learning_rate': 0.07774523137421388}. Best is trial 4 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# [I 2024-12-27 12:14:11,687] Trial 8 finished with value: 0.91 and parameters: {'hidden_layer_1': 76, 'hidden_layer_2': 90, 'learning_rate_init': 0.09301814167560168}. Best is trial 1 with value: 0.9133333333333333.
# [I 2024-12-27 12:14:30,075] Trial 9 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 48, 'hidden_layer_2': 69, 'learning_rate_init': 0.04029975273138964}. Best is trial 1 with value: 0.9133333333333333.
# [I 2024-12-27 12:14:51,229] Trial 10 finished with value: 0.9 and parameters: {'hidden_layer_1': 11, 'hidden_layer_2': 26, 'learning_rate_init': 0.010188391929322561}. Best is trial 1 with value: 0.9133333333333333.
# [I 2024-12-27 12:15:08,011] Trial 11 finished with value: 0.91 and parameters: {'hidden_layer_1': 33, 'hidden_layer_2': 99, 'learning_rate_init': 0.06127149995005014}. Best is trial 1 with value: 0.9133333333333333.
# [I 2024-12-27 12:15:31,849] Trial 12 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 67, 'learning_rate_init': 0.057482761735391734}. Best is trial 1 with value: 0.9133333333333333.
# [I 2024-12-27 12:15:56,731] Trial 13 finished with value: 0.92 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 32, 'learning_rate_init': 0.06893632373261703}. Best is trial 13 with value: 0.92.
# [I 2024-12-27 12:16:27,216] Trial 14 finished with value: 0.91 and parameters: {'hidden_layer_1': 98, 'hidden_layer_2': 31, 'learning_rate_init': 0.0693144276559057}. Best is trial 13 with value: 0.92.
# [I 2024-12-27 12:16:55,107] Trial 15 finished with value: 0.92 and parameters: {'hidden_layer_1': 96, 'hidden_layer_2': 38, 'learning_rate_init': 0.0749965830610484}. Best is trial 13 with value: 0.92.
# [I 2024-12-27 12:17:08,682] Trial 16 finished with value: 0.89 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 36, 'learning_rate_init': 0.0971337568090304}. Best is trial 13 with value: 0.92.
# [I 2024-12-27 12:17:31,472] Trial 17 finished with value: 0.9 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 16, 'learning_rate_init': 0.044822907420937044}. Best is trial 13 with value: 0.92.
# [I 2024-12-27 12:17:57,644] Trial 18 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 66, 'hidden_layer_2': 11, 'learning_rate_init': 0.06885659355527395}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:18:07,191] Trial 19 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 40, 'hidden_layer_2': 13, 'learning_rate_init': 0.03242039932931979}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:18:18,597] Trial 20 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 23, 'learning_rate_init': 0.0651928512696257}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:18:46,625] Trial 21 finished with value: 0.92 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 40, 'learning_rate_init': 0.0743723542016858}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:19:17,088] Trial 22 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 93, 'hidden_layer_2': 39, 'learning_rate_init': 0.05673211080060598}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:19:36,130] Trial 23 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 10, 'learning_rate_init': 0.08484779031304934}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:19:56,497] Trial 24 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 66, 'hidden_layer_2': 20, 'learning_rate_init': 0.06624700173416763}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:20:12,786] Trial 25 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 44, 'learning_rate_init': 0.07434850494429465}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:20:33,210] Trial 26 finished with value: 0.91 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 28, 'learning_rate_init': 0.04854581963665553}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:20:48,652] Trial 27 finished with value: 0.91 and parameters: {'hidden_layer_1': 70, 'hidden_layer_2': 34, 'learning_rate_init': 0.0511633932476909}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:21:08,226] Trial 28 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 33, 'hidden_layer_2': 46, 'learning_rate_init': 0.08791270781304214}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:21:37,717] Trial 29 finished with value: 0.8733333333333333 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 45, 'learning_rate_init': 0.078437995875599}. Best is trial 18 with value: 0.9233333333333333.
# [I 2024-12-27 12:21:37,735] A new study created in memory with name: no-name-735490e0-fc71-4df0-8219-6907389ce026
# Optimizing MLP...
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:22:42,183] Trial 0 finished with value: 0.9166666666666666 and parameters: {'layer_1': 59, 'layer_2': 146, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.02849652858494237}. Best is trial 0 with value: 0.9166666666666666.
# [I 2024-12-27 12:23:30,383] Trial 1 finished with value: 0.9133333333333333 and parameters: {'layer_1': 142, 'layer_2': 86, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.08386283683949947}. Best is trial 0 with value: 0.9166666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:24:35,513] Trial 2 finished with value: 0.92 and parameters: {'layer_1': 50, 'layer_2': 122, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02018636080410494}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:24:57,369] Trial 3 finished with value: 0.9166666666666666 and parameters: {'layer_1': 55, 'layer_2': 115, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.04592974504634596}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:25:18,266] Trial 4 finished with value: 0.9166666666666666 and parameters: {'layer_1': 112, 'layer_2': 59, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.07158300536224611}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:25:45,387] Trial 5 finished with value: 0.9066666666666666 and parameters: {'layer_1': 78, 'layer_2': 103, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.03672110944919408}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:26:15,096] Trial 6 finished with value: 0.9033333333333333 and parameters: {'layer_1': 121, 'layer_2': 141, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.018644636136378994}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:26:19,363] Trial 7 finished with value: 0.5 and parameters: {'layer_1': 97, 'layer_2': 67, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.04309503056590187}. Best is trial 2 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:27:29,175] Trial 8 finished with value: 0.91 and parameters: {'layer_1': 72, 'layer_2': 84, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.025998404845184033}. Best is trial 2 with value: 0.92.
# [I 2024-12-27 12:28:06,176] Trial 9 finished with value: 0.93 and parameters: {'layer_1': 126, 'layer_2': 147, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04908420133254549}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:28:35,395] Trial 10 finished with value: 0.8866666666666667 and parameters: {'layer_1': 148, 'layer_2': 127, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06464151258747587}. Best is trial 9 with value: 0.93.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:30:12,264] Trial 11 finished with value: 0.8433333333333334 and parameters: {'layer_1': 128, 'layer_2': 129, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.005103309539516605}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:30:49,864] Trial 12 finished with value: 0.9066666666666666 and parameters: {'layer_1': 93, 'layer_2': 148, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09877873131719243}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:31:17,279] Trial 13 finished with value: 0.8933333333333333 and parameters: {'layer_1': 109, 'layer_2': 126, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.004590823899600348}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:31:48,867] Trial 14 finished with value: 0.9166666666666666 and parameters: {'layer_1': 131, 'layer_2': 111, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06137458880229574}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:32:22,553] Trial 15 finished with value: 0.9033333333333333 and parameters: {'layer_1': 82, 'layer_2': 136, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.054964216250409204}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:32:32,833] Trial 16 finished with value: 0.8966666666666666 and parameters: {'layer_1': 110, 'layer_2': 116, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.01724090037453429}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:33:19,257] Trial 17 finished with value: 0.9133333333333333 and parameters: {'layer_1': 65, 'layer_2': 92, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.03577893396937531}. Best is trial 9 with value: 0.93.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:34:39,503] Trial 18 finished with value: 0.8966666666666666 and parameters: {'layer_1': 89, 'layer_2': 150, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.012932163580590544}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:34:54,370] Trial 19 finished with value: 0.5 and parameters: {'layer_1': 133, 'layer_2': 136, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07435737994532862}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:35:23,097] Trial 20 finished with value: 0.6566666666666666 and parameters: {'layer_1': 51, 'layer_2': 106, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.05253799382340841}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:36:04,946] Trial 21 finished with value: 0.9033333333333333 and parameters: {'layer_1': 61, 'layer_2': 145, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.027189742839203942}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:36:51,909] Trial 22 finished with value: 0.9166666666666666 and parameters: {'layer_1': 70, 'layer_2': 122, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.030445235458482357}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:37:49,653] Trial 23 finished with value: 0.8833333333333333 and parameters: {'layer_1': 59, 'layer_2': 136, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.041188441275493384}. Best is trial 9 with value: 0.93.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:38:51,614] Trial 24 finished with value: 0.9233333333333333 and parameters: {'layer_1': 52, 'layer_2': 140, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.02393805394174736}. Best is trial 9 with value: 0.93.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:40:18,852] Trial 25 finished with value: 0.9033333333333333 and parameters: {'layer_1': 103, 'layer_2': 132, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.013676402446063678}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:40:34,489] Trial 26 finished with value: 0.91 and parameters: {'layer_1': 83, 'layer_2': 119, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.020304960256207514}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:40:40,061] Trial 27 finished with value: 0.5433333333333333 and parameters: {'layer_1': 51, 'layer_2': 141, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0010739466682968754}. Best is trial 9 with value: 0.93.
# [I 2024-12-27 12:41:02,971] Trial 28 finished with value: 0.9 and parameters: {'layer_1': 121, 'layer_2': 94, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0342301199083955}. Best is trial 9 with value: 0.93.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-12-27 12:42:15,406] Trial 29 finished with value: 0.92 and parameters: {'layer_1': 66, 'layer_2': 142, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02307745220433117}. Best is trial 9 with value: 0.93.
#                   Model  Accuracy  Sensitivity  Specificity       MCC  \
# 0                   SVM  0.903333     0.873333     0.933333  0.808123
# 1         Decision Tree  0.870000     0.780000     0.960000  0.752287
# 2         Random Forest  0.883333     0.813333     0.953333  0.774292
# 3   Logistic Regression  0.886667     0.853333     0.920000  0.775058
# 4                  k-NN  0.883333     0.866667     0.900000  0.767093
# 5           Naive Bayes  0.866667     0.880000     0.853333  0.733594
# 6     Gradient Boosting  0.896667     0.866667     0.926667  0.794765
# 7               XGBoost  0.910000     0.886667     0.933333  0.820894
# 8              LightGBM  0.856667     0.793333     0.920000  0.719126
# 9              AdaBoost  0.870000     0.793333     0.946667  0.748856
# 10       Neural Network  0.923333     0.946667     0.900000  0.847590
# 11                  MLP  0.930000     0.926667     0.933333  0.860019
#
#        Kappa       AUC                                        Best Params
# 0   0.806667  0.903333         {'C': 3.8008971659568984, 'kernel': 'rbf'}
# 1   0.740000  0.870000          {'max_depth': 20, 'min_samples_split': 2}
# 2   0.766667  0.883333  {'n_estimators': 310, 'max_depth': 18, 'min_sa...
# 3   0.773333  0.886667     {'C': 8.34888059318696, 'solver': 'liblinear'}
# 4   0.766667  0.883333                                 {'n_neighbors': 3}
# 5   0.733333  0.866667                                                 {}
# 6   0.793333  0.896667  {'n_estimators': 328, 'learning_rate': 0.18033...
# 7   0.820000  0.910000  {'n_estimators': 80, 'max_depth': 19, 'learnin...
# 8   0.713333  0.856667  {'n_estimators': 194, 'max_depth': 7, 'learnin...
# 9   0.740000  0.870000  {'n_estimators': 498, 'learning_rate': 0.89860...
# 10  0.846667  0.923333  {'hidden_layer_1': 66, 'hidden_layer_2': 11, '...
# 11  0.860000  0.930000  {'layer_1': 126, 'layer_2': 147, 'activation':...

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Define models
models = {
    "SVM": lambda trial: SVC(probability=True, C=trial.suggest_float("C", 0.1, 10.0), kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])),
    "Decision Tree": lambda trial: DecisionTreeClassifier(max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Random Forest": lambda trial: RandomForestClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Logistic Regression": lambda trial: LogisticRegression(C=trial.suggest_float("C", 0.1, 10.0), solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])),
    "k-NN": lambda trial: KNeighborsClassifier(n_neighbors=trial.suggest_int("n_neighbors", 3, 20)),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), max_depth=trial.suggest_int("max_depth", 3, 20)),
    "XGBoost": lambda trial: XGBClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": lambda trial: LGBMClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)),
    "AdaBoost": lambda trial: AdaBoostClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)),
    "Neural Network": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("hidden_layer_1", 10, 100), trial.suggest_int("hidden_layer_2", 10, 100)), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200),
    "MLP": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("layer_1", 50, 150), trial.suggest_int("layer_2", 50, 150)), activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]), solver=trial.suggest_categorical("solver", ["adam", "sgd"]), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200, random_state=42)
}

# Prepare a dictionary to store model probabilities horizontally
probabilities = {"Target": y_val}  # Starting with the target column (y_val)

# Run optimization and compute probabilities for each model
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    study = optuna.create_study(direction="maximize")

    # Objective function for Optuna
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        return accuracy_score(y_val, model.predict(X_val))

    study.optimize(objective, n_trials=30)

    # Train the best model using the best hyperparameters
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)

    # Get predicted probabilities for the positive class (class 1)
    probs = best_model.predict_proba(X_val)[:, 1]

    # Add to the probabilities dictionary
    probabilities[model_name] = probs

# Convert the probabilities dictionary to a DataFrame
probability_df = pd.DataFrame(probabilities)

# Save the probability dataset to a CSV file
probability_df.to_csv("N_CTDD_OPTUNA_probability_predictions.csv", index=False)

print("Dataset saved successfully!")
# Out:
# [I 2024-12-27 12:42:15,487] A new study created in memory with name: no-name-dbb6ed62-df20-4645-9bda-74467a25d832
# Optimizing SVM...
# [I 2024-12-27 12:42:33,051] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 6.522197047368653, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 12:43:06,665] Trial 1 finished with value: 0.8166666666666667 and parameters: {'C': 2.8208025533999015, 'kernel': 'poly'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 12:43:24,502] Trial 2 finished with value: 0.88 and parameters: {'C': 9.488685047879896, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 12:44:01,434] Trial 3 finished with value: 0.7133333333333334 and parameters: {'C': 0.7049368695613077, 'kernel': 'poly'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 12:44:39,589] Trial 4 finished with value: 0.9033333333333333 and parameters: {'C': 3.115673376766238, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:44:58,993] Trial 5 finished with value: 0.87 and parameters: {'C': 4.202704842679156, 'kernel': 'sigmoid'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:45:33,851] Trial 6 finished with value: 0.9 and parameters: {'C': 0.9562422289281978, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:45:58,811] Trial 7 finished with value: 0.8833333333333333 and parameters: {'C': 8.990153171965764, 'kernel': 'linear'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:46:35,422] Trial 8 finished with value: 0.86 and parameters: {'C': 8.154351336731251, 'kernel': 'poly'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:47:10,803] Trial 9 finished with value: 0.8533333333333334 and parameters: {'C': 5.878085959471668, 'kernel': 'poly'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:47:48,542] Trial 10 finished with value: 0.9033333333333333 and parameters: {'C': 2.911896494832446, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:48:27,042] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 3.1973498013086363, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:49:04,900] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 2.449383899924862, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:49:43,392] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 4.491457762524439, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:50:21,474] Trial 14 finished with value: 0.9033333333333333 and parameters: {'C': 1.7639561286381906, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:50:50,716] Trial 15 finished with value: 0.8833333333333333 and parameters: {'C': 3.7776794062539922, 'kernel': 'linear'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:51:27,878] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 6.639386230204282, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:52:06,165] Trial 17 finished with value: 0.9033333333333333 and parameters: {'C': 5.002298184641639, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:52:43,681] Trial 18 finished with value: 0.9033333333333333 and parameters: {'C': 1.7238323185326063, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:53:23,669] Trial 19 finished with value: 0.6466666666666666 and parameters: {'C': 0.3404191794012146, 'kernel': 'linear'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:54:01,802] Trial 20 finished with value: 0.9033333333333333 and parameters: {'C': 2.1387170854620594, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:54:39,385] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 3.4982081956592075, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:55:16,809] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 3.0832619154234497, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:55:54,917] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 5.416572795290348, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:56:32,376] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 3.5718208912502103, 'kernel': 'rbf'}. Best is trial 4 with value: 0.9033333333333333.
# [I 2024-12-27 12:57:10,352] Trial 25 finished with value: 0.9066666666666666 and parameters: {'C': 1.5136941817456755, 'kernel': 'rbf'}. Best is trial 25 with value: 0.9066666666666666.
# [I 2024-12-27 12:57:48,185] Trial 26 finished with value: 0.9066666666666666 and parameters: {'C': 1.5542388284370399, 'kernel': 'rbf'}. Best is trial 25 with value: 0.9066666666666666.
# [I 2024-12-27 12:58:23,754] Trial 27 finished with value: 0.8366666666666667 and parameters: {'C': 1.4144312481977657, 'kernel': 'linear'}. Best is trial 25 with value: 0.9066666666666666.
# [I 2024-12-27 12:59:02,643] Trial 28 finished with value: 0.7466666666666667 and parameters: {'C': 0.11424586798256309, 'kernel': 'sigmoid'}. Best is trial 25 with value: 0.9066666666666666.
# [I 2024-12-27 12:59:27,389] Trial 29 finished with value: 0.8833333333333333 and parameters: {'C': 1.1512197418011145, 'kernel': 'sigmoid'}. Best is trial 25 with value: 0.9066666666666666.
# [I 2024-12-27 13:00:07,168] A new study created in memory with name: no-name-05885417-3940-4e8c-bcc8-91f2708e9c0d
# Optimizing Decision Tree...
# [I 2024-12-27 13:00:07,505] Trial 0 finished with value: 0.8466666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 0 with value: 0.8466666666666667.
# [I 2024-12-27 13:00:07,914] Trial 1 finished with value: 0.85 and parameters: {'max_depth': 19, 'min_samples_split': 10}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:08,092] Trial 2 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:08,413] Trial 3 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 6}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:08,590] Trial 4 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:08,878] Trial 5 finished with value: 0.7866666666666666 and parameters: {'max_depth': 8, 'min_samples_split': 8}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:09,124] Trial 6 finished with value: 0.7833333333333333 and parameters: {'max_depth': 8, 'min_samples_split': 10}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:09,421] Trial 7 finished with value: 0.8333333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 5}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:09,635] Trial 8 finished with value: 0.7533333333333333 and parameters: {'max_depth': 6, 'min_samples_split': 8}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:09,978] Trial 9 finished with value: 0.8266666666666667 and parameters: {'max_depth': 14, 'min_samples_split': 6}. Best is trial 1 with value: 0.85.
# [I 2024-12-27 13:00:10,349] Trial 10 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:10,859] Trial 11 finished with value: 0.85 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:11,481] Trial 12 finished with value: 0.85 and parameters: {'max_depth': 20, 'min_samples_split': 8}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:12,088] Trial 13 finished with value: 0.8433333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 9}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:12,674] Trial 14 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 10}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:13,263] Trial 15 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 9}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:13,761] Trial 16 finished with value: 0.82 and parameters: {'max_depth': 12, 'min_samples_split': 7}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:14,228] Trial 17 finished with value: 0.8066666666666666 and parameters: {'max_depth': 10, 'min_samples_split': 5}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:14,815] Trial 18 finished with value: 0.8533333333333334 and parameters: {'max_depth': 17, 'min_samples_split': 9}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:15,407] Trial 19 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 7}. Best is trial 10 with value: 0.86.
# [I 2024-12-27 13:00:15,814] Trial 20 finished with value: 0.87 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:16,212] Trial 21 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:16,590] Trial 22 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:16,953] Trial 23 finished with value: 0.8533333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 2}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:17,347] Trial 24 finished with value: 0.85 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:17,686] Trial 25 finished with value: 0.8466666666666667 and parameters: {'max_depth': 15, 'min_samples_split': 2}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:18,106] Trial 26 finished with value: 0.8633333333333333 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:18,471] Trial 27 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:18,767] Trial 28 finished with value: 0.82 and parameters: {'max_depth': 11, 'min_samples_split': 4}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:19,139] Trial 29 finished with value: 0.8533333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 20 with value: 0.87.
# [I 2024-12-27 13:00:19,515] A new study created in memory with name: no-name-1bcc7b27-1395-4f5d-a941-489feae86de6
# Optimizing Random Forest...
# [I 2024-12-27 13:00:22,525] Trial 0 finished with value: 0.86 and parameters: {'n_estimators': 496, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 0 with value: 0.86.
# [I 2024-12-27 13:00:25,824] Trial 1 finished with value: 0.88 and parameters: {'n_estimators': 444, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 1 with value: 0.88.
# [I 2024-12-27 13:00:29,635] Trial 2 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 370, 'max_depth': 18, 'min_samples_split': 7}. Best is trial 1 with value: 0.88.
# [I 2024-12-27 13:00:31,320] Trial 3 finished with value: 0.85 and parameters: {'n_estimators': 316, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 1 with value: 0.88.
# [I 2024-12-27 13:00:32,072] Trial 4 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 256, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.88.
# [I 2024-12-27 13:00:33,420] Trial 5 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 286, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 1 with value: 0.88.
# [I 2024-12-27 13:00:36,693] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 447, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:38,142] Trial 7 finished with value: 0.85 and parameters: {'n_estimators': 317, 'max_depth': 10, 'min_samples_split': 7}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:42,023] Trial 8 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 495, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:43,387] Trial 9 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 245, 'max_depth': 5, 'min_samples_split': 9}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:44,543] Trial 10 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 116, 'max_depth': 14, 'min_samples_split': 10}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:47,391] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 412, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:50,235] Trial 12 finished with value: 0.87 and parameters: {'n_estimators': 421, 'max_depth': 20, 'min_samples_split': 8}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:51,384] Trial 13 finished with value: 0.83 and parameters: {'n_estimators': 167, 'max_depth': 17, 'min_samples_split': 5}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:54,289] Trial 14 finished with value: 0.88 and parameters: {'n_estimators': 416, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:00:58,545] Trial 15 finished with value: 0.85 and parameters: {'n_estimators': 457, 'max_depth': 14, 'min_samples_split': 2}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:01,086] Trial 16 finished with value: 0.85 and parameters: {'n_estimators': 362, 'max_depth': 18, 'min_samples_split': 8}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:02,345] Trial 17 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 198, 'max_depth': 16, 'min_samples_split': 4}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:03,765] Trial 18 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 364, 'max_depth': 7, 'min_samples_split': 6}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:04,266] Trial 19 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 76, 'max_depth': 12, 'min_samples_split': 10}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:07,295] Trial 20 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 449, 'max_depth': 18, 'min_samples_split': 5}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:10,656] Trial 21 finished with value: 0.87 and parameters: {'n_estimators': 403, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:14,894] Trial 22 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 457, 'max_depth': 20, 'min_samples_split': 8}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:17,421] Trial 23 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 384, 'max_depth': 18, 'min_samples_split': 6}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:19,511] Trial 24 finished with value: 0.86 and parameters: {'n_estimators': 329, 'max_depth': 16, 'min_samples_split': 4}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:22,489] Trial 25 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 445, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:26,469] Trial 26 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 500, 'max_depth': 15, 'min_samples_split': 3}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:29,377] Trial 27 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 430, 'max_depth': 12, 'min_samples_split': 7}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:32,585] Trial 28 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 471, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:34,838] Trial 29 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 397, 'max_depth': 14, 'min_samples_split': 6}. Best is trial 6 with value: 0.89.
# [I 2024-12-27 13:01:38,066] A new study created in memory with name: no-name-51ac6e7e-1c60-455c-b6e8-790347923c5f
# Optimizing Logistic Regression...
# [I 2024-12-27 13:01:38,455] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 8.519156777583722, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:39,035] Trial 1 finished with value: 0.8866666666666667 and parameters: {'C': 8.368781280885706, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:39,383] Trial 2 finished with value: 0.83 and parameters: {'C': 1.2252468319554448, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:39,697] Trial 3 finished with value: 0.78 and parameters: {'C': 0.45914246425044736, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:40,064] Trial 4 finished with value: 0.8866666666666667 and parameters: {'C': 9.88962285952172, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:40,410] Trial 5 finished with value: 0.8866666666666667 and parameters: {'C': 5.835514495009268, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:40,957] Trial 6 finished with value: 0.87 and parameters: {'C': 3.974582620175448, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:41,303] Trial 7 finished with value: 0.8533333333333334 and parameters: {'C': 1.928294580613932, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:41,623] Trial 8 finished with value: 0.8766666666666667 and parameters: {'C': 4.43770683516316, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:42,219] Trial 9 finished with value: 0.8833333333333333 and parameters: {'C': 6.195859679740456, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:42,852] Trial 10 finished with value: 0.8866666666666667 and parameters: {'C': 7.83769188349106, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:43,418] Trial 11 finished with value: 0.8866666666666667 and parameters: {'C': 9.54368649440236, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:44,037] Trial 12 finished with value: 0.8833333333333333 and parameters: {'C': 7.815185105253169, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:44,494] Trial 13 finished with value: 0.8833333333333333 and parameters: {'C': 7.624515780978118, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:44,927] Trial 14 finished with value: 0.8866666666666667 and parameters: {'C': 8.546925681693086, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:45,341] Trial 15 finished with value: 0.8833333333333333 and parameters: {'C': 6.4751836070873985, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:45,711] Trial 16 finished with value: 0.8633333333333333 and parameters: {'C': 2.951637156358444, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:46,161] Trial 17 finished with value: 0.8866666666666667 and parameters: {'C': 8.965879635434128, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:46,593] Trial 18 finished with value: 0.8833333333333333 and parameters: {'C': 6.847661879432282, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:47,001] Trial 19 finished with value: 0.8833333333333333 and parameters: {'C': 5.070669354748415, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:47,420] Trial 20 finished with value: 0.8866666666666667 and parameters: {'C': 8.664309262572655, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:47,676] Trial 21 finished with value: 0.8866666666666667 and parameters: {'C': 9.805345074768137, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:47,929] Trial 22 finished with value: 0.8866666666666667 and parameters: {'C': 9.945890894168732, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:48,186] Trial 23 finished with value: 0.8833333333333333 and parameters: {'C': 7.324071445822012, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:48,432] Trial 24 finished with value: 0.8866666666666667 and parameters: {'C': 8.999659544874477, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:48,861] Trial 25 finished with value: 0.8866666666666667 and parameters: {'C': 8.369491618179067, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:49,117] Trial 26 finished with value: 0.8866666666666667 and parameters: {'C': 9.242431300302512, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:49,509] Trial 27 finished with value: 0.8866666666666667 and parameters: {'C': 5.547910988275384, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:49,770] Trial 28 finished with value: 0.8833333333333333 and parameters: {'C': 7.078499691100325, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:50,016] Trial 29 finished with value: 0.8866666666666667 and parameters: {'C': 8.214831776464628, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2024-12-27 13:01:50,420] A new study created in memory with name: no-name-8b019184-6d37-4b3d-b90e-59952cc6478c
# Optimizing k-NN...
# [I 2024-12-27 13:01:50,866] Trial 0 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 0 with value: 0.8566666666666667.
# [I 2024-12-27 13:01:51,225] Trial 1 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 1 with value: 0.8733333333333333.
# [I 2024-12-27 13:01:51,582] Trial 2 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 1 with value: 0.8733333333333333.
# [I 2024-12-27 13:01:51,962] Trial 3 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 1 with value: 0.8733333333333333.
# [I 2024-12-27 13:01:52,318] Trial 4 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 1 with value: 0.8733333333333333.
# [I 2024-12-27 13:01:52,675] Trial 5 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:53,054] Trial 6 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:53,413] Trial 7 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:53,783] Trial 8 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:54,194] Trial 9 finished with value: 0.84 and parameters: {'n_neighbors': 16}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:54,768] Trial 10 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:55,341] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:55,921] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:56,503] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:57,098] Trial 14 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:57,696] Trial 15 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:58,352] Trial 16 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:58,943] Trial 17 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:59,326] Trial 18 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 17}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:01:59,685] Trial 19 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:00,057] Trial 20 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:00,434] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:00,807] Trial 22 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:01,190] Trial 23 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:01,547] Trial 24 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:01,930] Trial 25 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:02,317] Trial 26 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:02,671] Trial 27 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:03,051] Trial 28 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:03,430] Trial 29 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2024-12-27 13:02:03,784] A new study created in memory with name: no-name-0faa1599-eb5c-49b1-97bc-3f29f80a65f1
# Optimizing Naive Bayes...
# [I 2024-12-27 13:02:04,068] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:04,347] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:04,610] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:04,886] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:05,155] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:05,432] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:05,699] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:05,974] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:06,248] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:06,541] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:06,815] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:07,088] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:07,374] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:07,639] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:07,915] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:08,190] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:08,467] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:08,743] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:09,047] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:09,437] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:09,810] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:10,175] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:10,556] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:10,930] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:11,306] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:11,678] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:12,069] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:12,458] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:12,864] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:13,248] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2024-12-27 13:02:13,659] A new study created in memory with name: no-name-7042afcb-b877-43c9-b386-83e3fba84337
# Optimizing Gradient Boosting...
# [I 2024-12-27 13:03:43,135] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 406, 'learning_rate': 0.012814936522365638, 'max_depth': 12}. Best is trial 0 with value: 0.88.
# [I 2024-12-27 13:04:35,009] Trial 1 finished with value: 0.88 and parameters: {'n_estimators': 424, 'learning_rate': 0.4087957233124397, 'max_depth': 6}. Best is trial 0 with value: 0.88.
# [I 2024-12-27 13:05:18,863] Trial 2 finished with value: 0.88 and parameters: {'n_estimators': 354, 'learning_rate': 0.28794746172113833, 'max_depth': 6}. Best is trial 0 with value: 0.88.
# [I 2024-12-27 13:07:27,260] Trial 3 finished with value: 0.89 and parameters: {'n_estimators': 455, 'learning_rate': 0.31593965942704205, 'max_depth': 15}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:08:14,345] Trial 4 finished with value: 0.88 and parameters: {'n_estimators': 298, 'learning_rate': 0.4250822505634833, 'max_depth': 8}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:08:40,926] Trial 5 finished with value: 0.89 and parameters: {'n_estimators': 163, 'learning_rate': 0.12398061058971567, 'max_depth': 8}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:09:15,839] Trial 6 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 180, 'learning_rate': 0.06827281940053868, 'max_depth': 10}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:09:40,461] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 158, 'learning_rate': 0.4523432763018886, 'max_depth': 8}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:10:33,789] Trial 8 finished with value: 0.87 and parameters: {'n_estimators': 497, 'learning_rate': 0.3535952658165291, 'max_depth': 5}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:11:46,276] Trial 9 finished with value: 0.89 and parameters: {'n_estimators': 242, 'learning_rate': 0.33061855726790423, 'max_depth': 16}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:12:14,437] Trial 10 finished with value: 0.89 and parameters: {'n_estimators': 78, 'learning_rate': 0.1956161351809457, 'max_depth': 20}. Best is trial 3 with value: 0.89.
# [I 2024-12-27 13:12:28,607] Trial 11 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 54, 'learning_rate': 0.1968326715207478, 'max_depth': 14}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:12:49,199] Trial 12 finished with value: 0.89 and parameters: {'n_estimators': 78, 'learning_rate': 0.19994961675635914, 'max_depth': 15}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:15:20,660] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 497, 'learning_rate': 0.22701441613498727, 'max_depth': 15}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:17:19,412] Trial 14 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 297, 'learning_rate': 0.14250738482234263, 'max_depth': 18}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:18:10,337] Trial 15 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 220, 'learning_rate': 0.27715077768945867, 'max_depth': 12}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:19:42,356] Trial 16 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 352, 'learning_rate': 0.49223045549802424, 'max_depth': 14}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:20:16,716] Trial 17 finished with value: 0.89 and parameters: {'n_estimators': 113, 'learning_rate': 0.3577545560560247, 'max_depth': 17}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:20:46,435] Trial 18 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 425, 'learning_rate': 0.15816407565134366, 'max_depth': 3}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:22:14,596] Trial 19 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 360, 'learning_rate': 0.25637422962227413, 'max_depth': 13}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:23:43,440] Trial 20 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 256, 'learning_rate': 0.3227377432870696, 'max_depth': 19}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:24:04,963] Trial 21 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 134, 'learning_rate': 0.1118118179365554, 'max_depth': 8}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:24:14,649] Trial 22 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 50, 'learning_rate': 0.07897784166469513, 'max_depth': 10}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:24:48,031] Trial 23 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 175, 'learning_rate': 0.16823712971331836, 'max_depth': 10}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:25:16,578] Trial 24 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 110, 'learning_rate': 0.22588590102808154, 'max_depth': 14}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:25:43,875] Trial 25 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 104, 'learning_rate': 0.22468854330126306, 'max_depth': 14}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:26:47,739] Trial 26 finished with value: 0.89 and parameters: {'n_estimators': 208, 'learning_rate': 0.29137073233196786, 'max_depth': 17}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:27:01,999] Trial 27 finished with value: 0.89 and parameters: {'n_estimators': 59, 'learning_rate': 0.22618208766700573, 'max_depth': 13}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:29:08,484] Trial 28 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 460, 'learning_rate': 0.3819946840756272, 'max_depth': 15}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:29:29,323] Trial 29 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 112, 'learning_rate': 0.012857819081439154, 'max_depth': 11}. Best is trial 11 with value: 0.8933333333333333.
# [I 2024-12-27 13:29:44,589] A new study created in memory with name: no-name-5089edbc-a086-4c2b-87d1-275c02b4fddc
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:29:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:30:22,192] Trial 0 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 491, 'max_depth': 18, 'learning_rate': 0.12871272012978754}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:30:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:30:34,360] Trial 1 finished with value: 0.89 and parameters: {'n_estimators': 98, 'max_depth': 18, 'learning_rate': 0.4341950696763331}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:30:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:30:53,299] Trial 2 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 326, 'max_depth': 5, 'learning_rate': 0.09887981231758973}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:30:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:31:26,933] Trial 3 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 494, 'max_depth': 14, 'learning_rate': 0.35590242045097137}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:31:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:31:52,677] Trial 4 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 444, 'max_depth': 8, 'learning_rate': 0.04132559010619621}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:31:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:32:23,419] Trial 5 finished with value: 0.91 and parameters: {'n_estimators': 435, 'max_depth': 20, 'learning_rate': 0.33500674741559877}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:32:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:32:33,775] Trial 6 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 114, 'max_depth': 11, 'learning_rate': 0.38710075149207546}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:32:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:32:48,847] Trial 7 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 187, 'max_depth': 10, 'learning_rate': 0.07403629860220391}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:32:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:33:15,905] Trial 8 finished with value: 0.91 and parameters: {'n_estimators': 391, 'max_depth': 12, 'learning_rate': 0.2573684366520122}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:33:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:33:43,850] Trial 9 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 376, 'max_depth': 17, 'learning_rate': 0.21768427811568145}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:33:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:34:06,519] Trial 10 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 250, 'max_depth': 20, 'learning_rate': 0.2947701387245042}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:34:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:34:34,655] Trial 11 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 383, 'max_depth': 14, 'learning_rate': 0.22172743174087992}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:34:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:34:55,796] Trial 12 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 391, 'max_depth': 5, 'learning_rate': 0.48322894405106703}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:35:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:35:18,217] Trial 13 finished with value: 0.9 and parameters: {'n_estimators': 291, 'max_depth': 14, 'learning_rate': 0.3271729083851143}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:35:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:35:45,614] Trial 14 finished with value: 0.9 and parameters: {'n_estimators': 431, 'max_depth': 8, 'learning_rate': 0.1633190869140974}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:35:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:36:04,466] Trial 15 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 340, 'max_depth': 3, 'learning_rate': 0.28405033651402223}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:36:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:36:26,244] Trial 16 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 232, 'max_depth': 20, 'learning_rate': 0.2402850936342317}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:36:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:36:56,858] Trial 17 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 431, 'max_depth': 16, 'learning_rate': 0.4033013721113132}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:36:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:37:21,681] Trial 18 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 317, 'max_depth': 13, 'learning_rate': 0.17319128536152495}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:37:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:37:35,980] Trial 19 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 179, 'max_depth': 9, 'learning_rate': 0.3204705798083802}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:37:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:38:07,779] Trial 20 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 459, 'max_depth': 16, 'learning_rate': 0.4990709933459247}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:38:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:38:45,829] Trial 21 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 494, 'max_depth': 19, 'learning_rate': 0.1454028047764223}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:38:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:39:15,725] Trial 22 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 404, 'max_depth': 18, 'learning_rate': 0.2670440774552853}. Best is trial 5 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:39:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-27 13:39:48,143] Trial 23 finished with value: 0.9 and parameters: {'n_estimators': 466, 'max_depth': 16, 'learning_rate': 0.1188536173943145}. Best is trial 5 with value: 0.91.
# ...
# [I 2024-12-27 13:52:24,683] Trial 22 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 358, 'learning_rate': 0.9765188723193865}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:52:57,651] Trial 23 finished with value: 0.86 and parameters: {'n_estimators': 459, 'learning_rate': 0.8267757736831789}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:53:25,289] Trial 24 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 402, 'learning_rate': 0.7175001866032188}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:53:43,806] Trial 25 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 262, 'learning_rate': 0.8618464973605735}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:54:05,757] Trial 26 finished with value: 0.7933333333333333 and parameters: {'n_estimators': 323, 'learning_rate': 0.6649604562675315}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:54:32,388] Trial 27 finished with value: 0.79 and parameters: {'n_estimators': 374, 'learning_rate': 0.5078436048515445}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:55:01,542] Trial 28 finished with value: 0.85 and parameters: {'n_estimators': 415, 'learning_rate': 0.795333284570925}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:55:24,758] Trial 29 finished with value: 0.79 and parameters: {'n_estimators': 321, 'learning_rate': 0.527984776771565}. Best is trial 7 with value: 0.87.
# [I 2024-12-27 13:55:56,901] A new study created in memory with name: no-name-75cd3c5d-d7ad-479f-9617-3b6c201a942a
# Optimizing Neural Network...
# [I 2024-12-27 13:56:11,840] Trial 0 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 52, 'learning_rate_init': 0.0854995331262163}. Best is trial 0 with value: 0.9133333333333333.
# [I 2024-12-27 13:56:32,265] Trial 1 finished with value: 0.92 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 65, 'learning_rate_init': 0.053156026165303315}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:56:50,967] Trial 2 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 16, 'learning_rate_init': 0.009201654591059066}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:57:15,230] Trial 3 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 95, 'learning_rate_init': 0.03672685483015423}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:57:26,452] Trial 4 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 25, 'learning_rate_init': 0.051555911936076844}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:57:54,491] Trial 5 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 97, 'learning_rate_init': 0.06302856344369304}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:58:22,871] Trial 6 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 54, 'hidden_layer_2': 66, 'learning_rate_init': 0.09164662210243792}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:58:37,977] Trial 7 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 17, 'learning_rate_init': 0.03153623962052394}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:58:57,634] Trial 8 finished with value: 0.91 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 55, 'learning_rate_init': 0.02590208591335725}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:59:16,081] Trial 9 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 24, 'hidden_layer_2': 29, 'learning_rate_init': 0.009614638344484422}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 13:59:41,018] Trial 10 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 98, 'hidden_layer_2': 74, 'learning_rate_init': 0.07084362770337321}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:00:09,205] Trial 11 finished with value: 0.92 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 74, 'learning_rate_init': 0.06953633704029123}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:00:30,094] Trial 12 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 78, 'learning_rate_init': 0.0712324554944869}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:00:53,769] Trial 13 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 45, 'hidden_layer_2': 43, 'learning_rate_init': 0.05028221269708248}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:01:23,287] Trial 14 finished with value: 0.91 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 82, 'learning_rate_init': 0.051213672120338324}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:01:45,447] Trial 15 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 65, 'learning_rate_init': 0.08105421803941135}. Best is trial 1 with value: 0.92.
# [I 2024-12-27 14:02:19,163] Trial 16 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 42, 'learning_rate_init': 0.062071947608992484}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:02:50,909] Trial 17 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 41, 'learning_rate_init': 0.09903555831705686}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:03:12,821] Trial 18 finished with value: 0.9 and parameters: {'hidden_layer_1': 63, 'hidden_layer_2': 38, 'learning_rate_init': 0.041692753700733734}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:03:31,285] Trial 19 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 49, 'learning_rate_init': 0.022063795309451534}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:03:47,106] Trial 20 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 56, 'hidden_layer_2': 62, 'learning_rate_init': 0.06209652771530795}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:04:13,472] Trial 21 finished with value: 0.9 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 86, 'learning_rate_init': 0.06211254424080308}. Best is trial 16 with value: 0.9233333333333333.
# [I 2024-12-27 14:04:35,061] Trial 22 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 68, 'learning_rate_init': 0.07296907254594057}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:05:01,214] Trial 23 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 57, 'learning_rate_init': 0.08010552871423904}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:05:20,768] Trial 24 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 58, 'learning_rate_init': 0.07996359282211035}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:05:40,444] Trial 25 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 71, 'hidden_layer_2': 33, 'learning_rate_init': 0.07790250050199705}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:06:02,299] Trial 26 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 81, 'hidden_layer_2': 46, 'learning_rate_init': 0.09304524657033653}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:06:15,195] Trial 27 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 55, 'hidden_layer_2': 72, 'learning_rate_init': 0.0871042701057774}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:06:41,102] Trial 28 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 58, 'learning_rate_init': 0.07395570139365311}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:07:03,672] Trial 29 finished with value: 0.9 and parameters: {'hidden_layer_1': 70, 'hidden_layer_2': 51, 'learning_rate_init': 0.0865900221655696}. Best is trial 22 with value: 0.9266666666666666.
# [I 2024-12-27 14:07:28,888] A new study created in memory with name: no-name-add18bc2-06ce-4f8e-92c7-61dce8856e16
# Optimizing MLP...
# [I 2024-12-27 14:08:05,909] Trial 0 finished with value: 0.9 and parameters: {'layer_1': 147, 'layer_2': 130, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.07026376160387535}. Best is trial 0 with value: 0.9.
# [I 2024-12-27 14:08:45,301] Trial 1 finished with value: 0.89 and parameters: {'layer_1': 148, 'layer_2': 91, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06551448739697524}. Best is trial 0 with value: 0.9.
# [I 2024-12-27 14:09:33,937] Trial 2 finished with value: 0.9133333333333333 and parameters: {'layer_1': 125, 'layer_2': 54, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.05472908060290152}. Best is trial 2 with value: 0.9133333333333333.
# [I 2024-12-27 14:09:59,973] Trial 3 finished with value: 0.9066666666666666 and parameters: {'layer_1': 59, 'layer_2': 149, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.055146588458306355}. Best is trial 2 with value: 0.9133333333333333.
# [I 2024-12-27 14:10:28,554] Trial 4 finished with value: 0.9166666666666666 and parameters: {'layer_1': 105, 'layer_2': 128, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05792493558601818}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:11:07,243] Trial 5 finished with value: 0.7 and parameters: {'layer_1': 140, 'layer_2': 145, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.07809496669522402}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:12:01,090] Trial 6 finished with value: 0.9033333333333333 and parameters: {'layer_1': 146, 'layer_2': 54, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.027859077649705574}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:12:55,849] Trial 7 finished with value: 0.8933333333333333 and parameters: {'layer_1': 133, 'layer_2': 51, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.001149953040077311}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:13:32,940] Trial 8 finished with value: 0.91 and parameters: {'layer_1': 56, 'layer_2': 99, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.07953226170521689}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:13:37,994] Trial 9 finished with value: 0.5 and parameters: {'layer_1': 97, 'layer_2': 126, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.0902742764459909}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:14:08,307] Trial 10 finished with value: 0.9033333333333333 and parameters: {'layer_1': 97, 'layer_2': 118, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0323044214605554}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:14:20,228] Trial 11 finished with value: 0.5 and parameters: {'layer_1': 117, 'layer_2': 77, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.04194914804822846}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:14:59,474] Trial 12 finished with value: 0.86 and parameters: {'layer_1': 115, 'layer_2': 72, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.05305291762837246}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:15:32,841] Trial 13 finished with value: 0.9033333333333333 and parameters: {'layer_1': 78, 'layer_2': 113, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.01752166067244163}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:16:01,395] Trial 14 finished with value: 0.8933333333333333 and parameters: {'layer_1': 118, 'layer_2': 80, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.04311092060311211}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:16:26,514] Trial 15 finished with value: 0.9 and parameters: {'layer_1': 81, 'layer_2': 107, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.09479611730145446}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:16:39,603] Trial 16 finished with value: 0.5 and parameters: {'layer_1': 129, 'layer_2': 136, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.06168588326592326}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:17:13,616] Trial 17 finished with value: 0.9133333333333333 and parameters: {'layer_1': 85, 'layer_2': 61, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04401344610543371}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:17:35,009] Trial 18 finished with value: 0.8833333333333333 and parameters: {'layer_1': 107, 'layer_2': 92, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07356699694220405}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:18:37,101] Trial 19 finished with value: 0.9033333333333333 and parameters: {'layer_1': 128, 'layer_2': 65, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.031727500311071716}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:18:47,417] Trial 20 finished with value: 0.5 and parameters: {'layer_1': 105, 'layer_2': 122, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.06093173305412845}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:19:20,053] Trial 21 finished with value: 0.9066666666666666 and parameters: {'layer_1': 85, 'layer_2': 59, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.045242829553366615}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:19:48,235] Trial 22 finished with value: 0.9066666666666666 and parameters: {'layer_1': 68, 'layer_2': 65, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.049389029798995225}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:20:04,462] Trial 23 finished with value: 0.9033333333333333 and parameters: {'layer_1': 87, 'layer_2': 66, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03762101188564395}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:20:35,136] Trial 24 finished with value: 0.91 and parameters: {'layer_1': 91, 'layer_2': 85, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.020143475591251653}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:20:48,067] Trial 25 finished with value: 0.9033333333333333 and parameters: {'layer_1': 75, 'layer_2': 104, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.058359334969360535}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-12-27 14:21:26,525] Trial 26 finished with value: 0.9233333333333333 and parameters: {'layer_1': 122, 'layer_2': 58, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06702986252499685}. Best is trial 26 with value: 0.9233333333333333.
# [I 2024-12-27 14:22:11,368] Trial 27 finished with value: 0.9 and parameters: {'layer_1': 122, 'layer_2': 139, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08753167935307961}. Best is trial 26 with value: 0.9233333333333333.
# [I 2024-12-27 14:22:56,980] Trial 28 finished with value: 0.9133333333333333 and parameters: {'layer_1': 108, 'layer_2': 73, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.06774397981997615}. Best is trial 26 with value: 0.9233333333333333.
# [I 2024-12-27 14:23:08,800] Trial 29 finished with value: 0.5 and parameters: {'layer_1': 135, 'layer_2': 134, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.07290587195171333}. Best is trial 26 with value: 0.9233333333333333.
# Dataset saved successfully!

# %% [markdown]
# Class Feature Vector (CFV)

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]

# Define models with hyperparameter optimization (Optuna)
models = {
    "SVM": lambda trial: SVC(
         probability=True,
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}

# Initialize a list to store the CFV data
cfv_data = []

# Define the optimization and prediction function
def optimize_and_predict(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict_proba(X_val)[:, 1]  # Get probability for class 1 (positive)
        return accuracy_score(y_val, model.predict(X_val))

    # Perform optimization with Optuna
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Return the best model
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)
    preds = best_model.predict_proba(X_val)[:, 1]  # Using the probability for class 1 (positive)

    # Append predictions to CFV list
    return preds

# Train each model and generate predictions for CFV
for model_name, model_func in models.items():
    print(f"Training and predicting with {model_name}...")
    preds = optimize_and_predict(model_name, model_func)
    cfv_data.append(preds)

# Convert the CFV data into a DataFrame
cfv_df = pd.DataFrame(np.array(cfv_data).T, columns=models.keys())

# Optionally, add the true labels column
cfv_df["True_Label"] = y_val.values

# Save the CFV dataset to CSV
cfv_df.to_csv("CFV_CTDD.csv", index=False)
print("CFV dataset created and saved!")
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2025-01-15 12:03:24,608] A new study created in memory with name: no-name-6990331d-0838-4aa2-8fb8-8c2ed1c3b1c4
# Training and predicting with SVM...
# [I 2025-01-15 12:03:53,296] Trial 0 finished with value: 0.8833333333333333 and parameters: {'C': 8.63059532325755, 'kernel': 'linear'}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-15 12:04:28,222] Trial 1 finished with value: 0.8833333333333333 and parameters: {'C': 0.5434157206769458, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-15 12:05:11,592] Trial 2 finished with value: 0.9033333333333333 and parameters: {'C': 3.6730715107125906, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:05:53,994] Trial 3 finished with value: 0.9033333333333333 and parameters: {'C': 6.5165850420915294, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:06:36,620] Trial 4 finished with value: 0.9033333333333333 and parameters: {'C': 2.657868985539425, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:07:10,040] Trial 5 finished with value: 0.8833333333333333 and parameters: {'C': 3.617115671067177, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:07:50,638] Trial 6 finished with value: 0.75 and parameters: {'C': 1.0968259152544073, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:08:10,358] Trial 7 finished with value: 0.8833333333333333 and parameters: {'C': 9.585541457326633, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:08:31,735] Trial 8 finished with value: 0.89 and parameters: {'C': 6.198313435732, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:09:13,725] Trial 9 finished with value: 0.9033333333333333 and parameters: {'C': 2.728169197776858, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:09:51,438] Trial 10 finished with value: 0.8366666666666667 and parameters: {'C': 4.671505859073425, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:10:34,534] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 6.783580114569327, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:11:17,058] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 7.1146870201467225, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:11:59,743] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 5.1169825956449415, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:12:42,300] Trial 14 finished with value: 0.9033333333333333 and parameters: {'C': 5.131299161801886, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:13:24,477] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 7.967506796047202, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:14:06,681] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 3.7399331644482965, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:14:43,845] Trial 17 finished with value: 0.8566666666666667 and parameters: {'C': 1.9185277683889739, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:15:25,173] Trial 18 finished with value: 0.8566666666666667 and parameters: {'C': 6.015590549767193, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:16:07,541] Trial 19 finished with value: 0.9033333333333333 and parameters: {'C': 3.879871023992022, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:16:49,934] Trial 20 finished with value: 0.9033333333333333 and parameters: {'C': 7.810802307746737, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:17:32,342] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 2.5770517055125817, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:18:14,631] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 1.9708939947508868, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:18:56,889] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 4.404002429566759, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:19:39,386] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 3.0329663283183823, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:20:21,760] Trial 25 finished with value: 0.9033333333333333 and parameters: {'C': 5.822117615387499, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:20:48,988] Trial 26 finished with value: 0.8833333333333333 and parameters: {'C': 1.5008172746266668, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:21:32,528] Trial 27 finished with value: 0.64 and parameters: {'C': 0.33681391362426094, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:22:06,333] Trial 28 finished with value: 0.8833333333333333 and parameters: {'C': 3.3096117783039785, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:22:34,935] Trial 29 finished with value: 0.8833333333333333 and parameters: {'C': 9.30527754751773, 'kernel': 'linear'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-15 12:23:15,065] A new study created in memory with name: no-name-e184039d-7442-4d74-a647-15c49c102c23
# Training and predicting with Decision Tree...
# [I 2025-01-15 12:23:15,302] Trial 0 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 4}. Best is trial 0 with value: 0.7233333333333334.
# [I 2025-01-15 12:23:15,583] Trial 1 finished with value: 0.78 and parameters: {'max_depth': 8, 'min_samples_split': 4}. Best is trial 1 with value: 0.78.
# [I 2025-01-15 12:23:16,008] Trial 2 finished with value: 0.8533333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:16,323] Trial 3 finished with value: 0.7933333333333333 and parameters: {'max_depth': 9, 'min_samples_split': 7}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:16,577] Trial 4 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 10}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:16,917] Trial 5 finished with value: 0.78 and parameters: {'max_depth': 7, 'min_samples_split': 7}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:17,694] Trial 6 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 8}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:18,395] Trial 7 finished with value: 0.8366666666666667 and parameters: {'max_depth': 14, 'min_samples_split': 4}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:18,860] Trial 8 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 10}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:19,470] Trial 9 finished with value: 0.7933333333333333 and parameters: {'max_depth': 9, 'min_samples_split': 9}. Best is trial 2 with value: 0.8533333333333334.
# [I 2025-01-15 12:23:20,279] Trial 10 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-15 12:23:20,970] Trial 11 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-15 12:23:21,612] Trial 12 finished with value: 0.8433333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 2}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-15 12:23:22,220] Trial 13 finished with value: 0.87 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:22,609] Trial 14 finished with value: 0.8466666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 6}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:23,004] Trial 15 finished with value: 0.8566666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:23,365] Trial 16 finished with value: 0.8333333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 6}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:23,769] Trial 17 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 5}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:24,128] Trial 18 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 3}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:24,464] Trial 19 finished with value: 0.82 and parameters: {'max_depth': 11, 'min_samples_split': 8}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:24,865] Trial 20 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 5}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:25,271] Trial 21 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 2}. Best is trial 13 with value: 0.87.
# [I 2025-01-15 12:23:25,702] Trial 22 finished with value: 0.8733333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 2}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:26,082] Trial 23 finished with value: 0.8566666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:26,510] Trial 24 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:26,912] Trial 25 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 2}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:27,275] Trial 26 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 4}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:27,678] Trial 27 finished with value: 0.8466666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 7}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:28,022] Trial 28 finished with value: 0.8166666666666667 and parameters: {'max_depth': 12, 'min_samples_split': 3}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:28,450] Trial 29 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 22 with value: 0.8733333333333333.
# [I 2025-01-15 12:23:28,811] A new study created in memory with name: no-name-7b785d58-c53f-4389-b156-d4b62d429efa
# Training and predicting with Random Forest...
# [I 2025-01-15 12:23:29,911] Trial 0 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 133, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:30,422] Trial 1 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 67, 'max_depth': 13, 'min_samples_split': 7}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:31,598] Trial 2 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 388, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:32,553] Trial 3 finished with value: 0.8033333333333333 and parameters: {'n_estimators': 238, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:33,347] Trial 4 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 86, 'max_depth': 7, 'min_samples_split': 10}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:36,640] Trial 5 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 453, 'max_depth': 9, 'min_samples_split': 8}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:37,462] Trial 6 finished with value: 0.8033333333333333 and parameters: {'n_estimators': 178, 'max_depth': 7, 'min_samples_split': 6}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:40,656] Trial 7 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 466, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:41,919] Trial 8 finished with value: 0.87 and parameters: {'n_estimators': 173, 'max_depth': 18, 'min_samples_split': 7}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:43,152] Trial 9 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 236, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:45,294] Trial 10 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 330, 'max_depth': 15, 'min_samples_split': 3}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:46,601] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 154, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:48,403] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 133, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:49,928] Trial 13 finished with value: 0.84 and parameters: {'n_estimators': 117, 'max_depth': 17, 'min_samples_split': 2}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:52,288] Trial 14 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 305, 'max_depth': 15, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:52,808] Trial 15 finished with value: 0.87 and parameters: {'n_estimators': 54, 'max_depth': 16, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:54,700] Trial 16 finished with value: 0.88 and parameters: {'n_estimators': 225, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:55,576] Trial 17 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 134, 'max_depth': 13, 'min_samples_split': 6}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:57,144] Trial 18 finished with value: 0.86 and parameters: {'n_estimators': 208, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:58,833] Trial 19 finished with value: 0.85 and parameters: {'n_estimators': 281, 'max_depth': 13, 'min_samples_split': 6}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:23:59,814] Trial 20 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 110, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:01,894] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 203, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:04,176] Trial 22 finished with value: 0.88 and parameters: {'n_estimators': 179, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:05,370] Trial 23 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 114, 'max_depth': 17, 'min_samples_split': 3}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:07,008] Trial 24 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 203, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:08,051] Trial 25 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 148, 'max_depth': 15, 'min_samples_split': 5}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:10,129] Trial 26 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 261, 'max_depth': 19, 'min_samples_split': 2}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:10,976] Trial 27 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 100, 'max_depth': 17, 'min_samples_split': 3}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:13,625] Trial 28 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 372, 'max_depth': 19, 'min_samples_split': 7}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:14,214] Trial 29 finished with value: 0.84 and parameters: {'n_estimators': 82, 'max_depth': 11, 'min_samples_split': 4}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:15,405] A new study created in memory with name: no-name-3397178e-cdc2-4820-86e8-c5651719ffab
# Training and predicting with Logistic Regression...
# [I 2025-01-15 12:24:15,979] Trial 0 finished with value: 0.86 and parameters: {'C': 2.369984250079421, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.86.
# [I 2025-01-15 12:24:16,471] Trial 1 finished with value: 0.8866666666666667 and parameters: {'C': 5.031442743941689, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:16,933] Trial 2 finished with value: 0.8833333333333333 and parameters: {'C': 7.334113223963511, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:17,391] Trial 3 finished with value: 0.8366666666666667 and parameters: {'C': 1.4154594267286449, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:17,853] Trial 4 finished with value: 0.8266666666666667 and parameters: {'C': 1.1438467278077997, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:18,637] Trial 5 finished with value: 0.8866666666666667 and parameters: {'C': 8.494119396900318, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:19,127] Trial 6 finished with value: 0.8833333333333333 and parameters: {'C': 7.693052318971082, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:19,616] Trial 7 finished with value: 0.8866666666666667 and parameters: {'C': 9.983407382608231, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:19,984] Trial 8 finished with value: 0.8566666666666667 and parameters: {'C': 2.271142935068914, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:20,298] Trial 9 finished with value: 0.8833333333333333 and parameters: {'C': 6.59782945848596, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:20,786] Trial 10 finished with value: 0.88 and parameters: {'C': 4.458921623936203, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:21,248] Trial 11 finished with value: 0.8733333333333333 and parameters: {'C': 4.40779257226481, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:21,805] Trial 12 finished with value: 0.8866666666666667 and parameters: {'C': 9.826393810978947, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:22,304] Trial 13 finished with value: 0.8866666666666667 and parameters: {'C': 5.887930428817102, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:22,823] Trial 14 finished with value: 0.8866666666666667 and parameters: {'C': 8.42217447276553, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:23,281] Trial 15 finished with value: 0.87 and parameters: {'C': 3.515522531616769, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:23,602] Trial 16 finished with value: 0.8866666666666667 and parameters: {'C': 5.5361186309297326, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:24,108] Trial 17 finished with value: 0.8866666666666667 and parameters: {'C': 8.675190695836905, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:24,578] Trial 18 finished with value: 0.8633333333333333 and parameters: {'C': 3.23792419279445, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:24,923] Trial 19 finished with value: 0.8833333333333333 and parameters: {'C': 6.449624382352818, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:25,371] Trial 20 finished with value: 0.88 and parameters: {'C': 4.55540868695395, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:25,698] Trial 21 finished with value: 0.8866666666666667 and parameters: {'C': 9.939098024647095, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:26,030] Trial 22 finished with value: 0.8866666666666667 and parameters: {'C': 9.052978855910004, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:26,346] Trial 23 finished with value: 0.8833333333333333 and parameters: {'C': 7.684711449649551, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:26,665] Trial 24 finished with value: 0.8866666666666667 and parameters: {'C': 9.276558935239139, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:27,004] Trial 25 finished with value: 0.8866666666666667 and parameters: {'C': 8.285247805161722, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:27,320] Trial 26 finished with value: 0.8833333333333333 and parameters: {'C': 7.0081012707035075, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:27,644] Trial 27 finished with value: 0.8866666666666667 and parameters: {'C': 6.072040065392382, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:28,154] Trial 28 finished with value: 0.8866666666666667 and parameters: {'C': 8.108472200971645, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:28,625] Trial 29 finished with value: 0.8833333333333333 and parameters: {'C': 5.190794751564333, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-15 12:24:28,871] A new study created in memory with name: no-name-44777953-bbed-44fd-a811-b60a12a03675
# Training and predicting with k-NN...
# [I 2025-01-15 12:24:29,582] Trial 0 finished with value: 0.84 and parameters: {'n_neighbors': 18}. Best is trial 0 with value: 0.84.
# [I 2025-01-15 12:24:30,457] Trial 1 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 1 with value: 0.87.
# [I 2025-01-15 12:24:31,423] Trial 2 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 2 with value: 0.88.
# [I 2025-01-15 12:24:32,535] Trial 3 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 15}. Best is trial 2 with value: 0.88.
# [I 2025-01-15 12:24:33,708] Trial 4 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 2 with value: 0.88.
# [I 2025-01-15 12:24:35,071] Trial 5 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:36,052] Trial 6 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:36,826] Trial 7 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:37,573] Trial 8 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:38,319] Trial 9 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 17}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:39,830] Trial 10 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:40,777] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:41,404] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:42,033] Trial 13 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:42,636] Trial 14 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:43,264] Trial 15 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:43,908] Trial 16 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 20}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:44,513] Trial 17 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:45,130] Trial 18 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:45,800] Trial 19 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:46,805] Trial 20 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:47,782] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:48,782] Trial 22 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:49,769] Trial 23 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:50,721] Trial 24 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 6}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:51,340] Trial 25 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:51,976] Trial 26 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:52,589] Trial 27 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:53,203] Trial 28 finished with value: 0.8566666666666667 and parameters: {'n_neighbors': 5}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:53,824] Trial 29 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 5 with value: 0.8833333333333333.
# [I 2025-01-15 12:24:54,159] A new study created in memory with name: no-name-5ec12afc-bbed-468c-b1b1-155efa047bd1
# Training and predicting with Naive Bayes...
# [I 2025-01-15 12:24:54,544] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:54,891] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:55,237] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:55,585] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:55,931] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:56,273] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:56,623] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:56,963] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:57,306] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:57,656] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:58,010] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:58,350] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:58,713] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:59,055] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:59,397] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:24:59,757] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:00,103] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:00,456] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:00,911] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:01,401] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:01,898] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:02,401] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:02,902] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:03,371] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:03,872] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:04,377] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:04,885] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:05,379] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:05,743] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:06,093] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-15 12:25:06,367] A new study created in memory with name: no-name-91d41250-3c47-4290-a42b-5173cad8b410
# Training and predicting with Gradient Boosting...
# [I 2025-01-15 12:25:49,856] Trial 0 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 144, 'learning_rate': 0.4787747769126398, 'max_depth': 16}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-15 12:25:56,310] Trial 1 finished with value: 0.9 and parameters: {'n_estimators': 51, 'learning_rate': 0.10572701535835176, 'max_depth': 7}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:26:26,185] Trial 2 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 335, 'learning_rate': 0.49953541920024247, 'max_depth': 4}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:26:39,247] Trial 3 finished with value: 0.89 and parameters: {'n_estimators': 60, 'learning_rate': 0.3975353660484763, 'max_depth': 11}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:28:18,410] Trial 4 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 268, 'learning_rate': 0.23813951876138856, 'max_depth': 20}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:28:55,002] Trial 5 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 350, 'learning_rate': 0.1319874596736404, 'max_depth': 5}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:29:25,459] Trial 6 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 91, 'learning_rate': 0.40959381958473307, 'max_depth': 18}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:30:30,119] Trial 7 finished with value: 0.89 and parameters: {'n_estimators': 324, 'learning_rate': 0.20992422659241022, 'max_depth': 10}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:30:51,821] Trial 8 finished with value: 0.88 and parameters: {'n_estimators': 116, 'learning_rate': 0.1350301361982473, 'max_depth': 10}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:33:45,990] Trial 9 finished with value: 0.88 and parameters: {'n_estimators': 471, 'learning_rate': 0.2122339083188948, 'max_depth': 20}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:34:14,405] Trial 10 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 201, 'learning_rate': 0.017313948967330697, 'max_depth': 7}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:35:20,036] Trial 11 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 230, 'learning_rate': 0.3017936411399027, 'max_depth': 15}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:36:24,380] Trial 12 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 450, 'learning_rate': 0.05223250816797337, 'max_depth': 7}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:37:16,092] Trial 13 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 196, 'learning_rate': 0.3059703068358056, 'max_depth': 14}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:37:54,674] Trial 14 finished with value: 0.89 and parameters: {'n_estimators': 269, 'learning_rate': 0.11221123266203491, 'max_depth': 7}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:40:21,400] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 398, 'learning_rate': 0.21464909655629752, 'max_depth': 20}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:40:58,175] Trial 16 finished with value: 0.89 and parameters: {'n_estimators': 156, 'learning_rate': 0.2816541861797153, 'max_depth': 12}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:41:01,911] Trial 17 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 52, 'learning_rate': 0.07933937476081104, 'max_depth': 3}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:42:09,424] Trial 18 finished with value: 0.89 and parameters: {'n_estimators': 272, 'learning_rate': 0.1772042888525529, 'max_depth': 13}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:44:19,564] Trial 19 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 418, 'learning_rate': 0.34878172258205353, 'max_depth': 17}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:45:00,048] Trial 20 finished with value: 0.89 and parameters: {'n_estimators': 234, 'learning_rate': 0.16245696511835245, 'max_depth': 9}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:45:33,862] Trial 21 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 99, 'learning_rate': 0.3839501541615002, 'max_depth': 18}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:46:09,948] Trial 22 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 112, 'learning_rate': 0.4412535235211439, 'max_depth': 18}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:46:38,524] Trial 23 finished with value: 0.89 and parameters: {'n_estimators': 83, 'learning_rate': 0.2552667393721509, 'max_depth': 19}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:47:32,717] Trial 24 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 171, 'learning_rate': 0.34111991363580785, 'max_depth': 17}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:48:19,769] Trial 25 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 131, 'learning_rate': 0.42694852858058296, 'max_depth': 20}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:48:42,104] Trial 26 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 82, 'learning_rate': 0.24972599222022945, 'max_depth': 14}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:51:09,697] Trial 27 finished with value: 0.89 and parameters: {'n_estimators': 500, 'learning_rate': 0.07714777307017667, 'max_depth': 16}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:53:16,307] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 375, 'learning_rate': 0.33863459691139547, 'max_depth': 18}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:54:45,783] Trial 29 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 303, 'learning_rate': 0.4508547621515759, 'max_depth': 16}. Best is trial 1 with value: 0.9.
# [I 2025-01-15 12:54:53,639] A new study created in memory with name: no-name-b41bc576-6397-4fc8-b908-11d3685197e5
# Training and predicting with XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:54:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:55:11,440] Trial 0 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 165, 'max_depth': 8, 'learning_rate': 0.02496536066505519}. Best is trial 0 with value: 0.8466666666666667.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:55:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:55:39,993] Trial 1 finished with value: 0.91 and parameters: {'n_estimators': 399, 'max_depth': 12, 'learning_rate': 0.34408487653655345}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:55:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:55:54,794] Trial 2 finished with value: 0.9 and parameters: {'n_estimators': 163, 'max_depth': 8, 'learning_rate': 0.10553230482031642}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:55:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:56:17,352] Trial 3 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 330, 'max_depth': 6, 'learning_rate': 0.20291030427563742}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:56:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:56:51,236] Trial 4 finished with value: 0.91 and parameters: {'n_estimators': 487, 'max_depth': 16, 'learning_rate': 0.2188502302758039}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:56:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:57:16,144] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 330, 'max_depth': 10, 'learning_rate': 0.3314999217115794}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:57:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:57:42,999] Trial 6 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 335, 'max_depth': 15, 'learning_rate': 0.3107395071861719}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:57:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:57:51,864] Trial 7 finished with value: 0.89 and parameters: {'n_estimators': 56, 'max_depth': 12, 'learning_rate': 0.12711488454028627}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:57:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:58:03,281] Trial 8 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 115, 'max_depth': 13, 'learning_rate': 0.1266413623421125}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:58:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:58:25,979] Trial 9 finished with value: 0.91 and parameters: {'n_estimators': 267, 'max_depth': 14, 'learning_rate': 0.36340070139613506}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:58:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:59:00,026] Trial 10 finished with value: 0.9 and parameters: {'n_estimators': 483, 'max_depth': 20, 'learning_rate': 0.4964342239180868}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:59:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 12:59:36,046] Trial 11 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 485, 'max_depth': 18, 'learning_rate': 0.4318871848899657}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:59:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:00:07,450] Trial 12 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 419, 'max_depth': 17, 'learning_rate': 0.22535074085504878}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:00:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:00:36,377] Trial 13 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 387, 'max_depth': 16, 'learning_rate': 0.25770754999305373}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:00:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:01:01,816] Trial 14 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 436, 'max_depth': 4, 'learning_rate': 0.4063591499787294}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:01:23,634] Trial 15 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 270, 'max_depth': 10, 'learning_rate': 0.2786337971053102}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:01:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:01:54,816] Trial 16 finished with value: 0.91 and parameters: {'n_estimators': 389, 'max_depth': 20, 'learning_rate': 0.17449010993951175}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:01:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:02:27,455] Trial 17 finished with value: 0.91 and parameters: {'n_estimators': 496, 'max_depth': 11, 'learning_rate': 0.3985116179701871}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:02:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:02:59,745] Trial 18 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 436, 'max_depth': 18, 'learning_rate': 0.4961200835113839}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:03:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:03:25,965] Trial 19 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 367, 'max_depth': 14, 'learning_rate': 0.29107130843169066}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:03:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:03:41,807] Trial 20 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 227, 'max_depth': 3, 'learning_rate': 0.028147939271796818}. Best is trial 1 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:03:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-15 13:04:03,062] Trial 21 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 266, 'max_depth': 14, 'learning_rate': 0.3615911596668578}. Best is trial 1 with value: 0.91.
# ...
# [I 2025-01-15 13:09:00,323] Trial 2 finished with value: 0.7866666666666666 and parameters: {'n_estimators': 387, 'learning_rate': 0.4449350663873341}. Best is trial 2 with value: 0.7866666666666666.
# [I 2025-01-15 13:09:24,632] Trial 3 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 296, 'learning_rate': 0.8904237576448794}. Best is trial 3 with value: 0.8433333333333334.
# [I 2025-01-15 13:09:40,707] Trial 4 finished with value: 0.79 and parameters: {'n_estimators': 201, 'learning_rate': 0.8287700266510682}. Best is trial 3 with value: 0.8433333333333334.
# [I 2025-01-15 13:10:19,936] Trial 5 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 487, 'learning_rate': 0.7288687781248427}. Best is trial 3 with value: 0.8433333333333334.
# [I 2025-01-15 13:10:41,282] Trial 6 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 277, 'learning_rate': 0.8943688663387757}. Best is trial 3 with value: 0.8433333333333334.
# [I 2025-01-15 13:11:09,664] Trial 7 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 374, 'learning_rate': 0.9201947893094605}. Best is trial 7 with value: 0.8633333333333333.
# [I 2025-01-15 13:11:34,756] Trial 8 finished with value: 0.7733333333333333 and parameters: {'n_estimators': 328, 'learning_rate': 0.40058643453269954}. Best is trial 7 with value: 0.8633333333333333.
# [I 2025-01-15 13:11:50,447] Trial 9 finished with value: 0.69 and parameters: {'n_estimators': 211, 'learning_rate': 0.13455264844668477}. Best is trial 7 with value: 0.8633333333333333.
# [I 2025-01-15 13:12:26,911] Trial 10 finished with value: 0.83 and parameters: {'n_estimators': 489, 'learning_rate': 0.6490939125043913}. Best is trial 7 with value: 0.8633333333333333.
# [I 2025-01-15 13:12:55,735] Trial 11 finished with value: 0.87 and parameters: {'n_estimators': 386, 'learning_rate': 0.9609946644784475}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:13:26,107] Trial 12 finished with value: 0.8 and parameters: {'n_estimators': 403, 'learning_rate': 0.6284246114179597}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:13:56,180] Trial 13 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 400, 'learning_rate': 0.9933945326947665}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:14:27,680] Trial 14 finished with value: 0.86 and parameters: {'n_estimators': 425, 'learning_rate': 0.9998273562085683}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:14:53,419] Trial 15 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 342, 'learning_rate': 0.9980939797867299}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:15:26,070] Trial 16 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 439, 'learning_rate': 0.7216459220436116}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:16:03,275] Trial 17 finished with value: 0.8 and parameters: {'n_estimators': 445, 'learning_rate': 0.5587086338120542}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:16:33,466] Trial 18 finished with value: 0.7733333333333333 and parameters: {'n_estimators': 344, 'learning_rate': 0.3444187702914352}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:16:55,405] Trial 19 finished with value: 0.8033333333333333 and parameters: {'n_estimators': 250, 'learning_rate': 0.7702539274582434}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:17:06,590] Trial 20 finished with value: 0.7433333333333333 and parameters: {'n_estimators': 132, 'learning_rate': 0.5599330801794717}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:17:38,245] Trial 21 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 364, 'learning_rate': 0.9222238066526832}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:18:11,547] Trial 22 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 384, 'learning_rate': 0.9431795686961439}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:18:38,801] Trial 23 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 306, 'learning_rate': 0.9843958310221695}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:19:11,727] Trial 24 finished with value: 0.85 and parameters: {'n_estimators': 404, 'learning_rate': 0.8226758747864057}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:19:46,529] Trial 25 finished with value: 0.83 and parameters: {'n_estimators': 460, 'learning_rate': 0.6706114730003999}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:20:05,792] Trial 26 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 256, 'learning_rate': 0.866144173452901}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:20:37,054] Trial 27 finished with value: 0.84 and parameters: {'n_estimators': 420, 'learning_rate': 0.7696066537923112}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:21:11,755] Trial 28 finished with value: 0.87 and parameters: {'n_estimators': 465, 'learning_rate': 0.9388486912611066}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:21:47,396] Trial 29 finished with value: 0.6633333333333333 and parameters: {'n_estimators': 467, 'learning_rate': 0.03844582956330611}. Best is trial 11 with value: 0.87.
# [I 2025-01-15 13:22:14,864] A new study created in memory with name: no-name-d21a7751-ce99-46e1-b14a-d1174e9ec8c2
# Training and predicting with Neural Network...
# [I 2025-01-15 13:22:30,920] Trial 0 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 52, 'hidden_layer_2': 18, 'learning_rate_init': 0.016588702168304912}. Best is trial 0 with value: 0.8966666666666666.
# [I 2025-01-15 13:22:46,237] Trial 1 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 40, 'learning_rate_init': 0.07247407292591374}. Best is trial 1 with value: 0.9133333333333333.
# [I 2025-01-15 13:23:15,969] Trial 2 finished with value: 0.8833333333333333 and parameters: {'hidden_layer_1': 94, 'hidden_layer_2': 72, 'learning_rate_init': 0.05607440893373081}. Best is trial 1 with value: 0.9133333333333333.
# [I 2025-01-15 13:23:33,457] Trial 3 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 76, 'hidden_layer_2': 74, 'learning_rate_init': 0.061624666064036916}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:23:41,223] Trial 4 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 18, 'hidden_layer_2': 99, 'learning_rate_init': 0.09517202749210808}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:24:22,249] Trial 5 finished with value: 0.9 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 42, 'learning_rate_init': 0.0019154359729592232}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:24:33,268] Trial 6 finished with value: 0.91 and parameters: {'hidden_layer_1': 28, 'hidden_layer_2': 23, 'learning_rate_init': 0.0864768156318773}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:25:01,206] Trial 7 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 59, 'learning_rate_init': 0.006997400298617676}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:25:25,295] Trial 8 finished with value: 0.9 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 52, 'learning_rate_init': 0.026994684965114327}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:25:53,301] Trial 9 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 52, 'learning_rate_init': 0.08946006015930949}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-15 13:26:25,785] Trial 10 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 87, 'learning_rate_init': 0.04082217985783844}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:26:39,749] Trial 11 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 98, 'hidden_layer_2': 87, 'learning_rate_init': 0.03857305166193829}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:27:04,243] Trial 12 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 78, 'learning_rate_init': 0.05727746582078671}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:27:22,470] Trial 13 finished with value: 0.9 and parameters: {'hidden_layer_1': 59, 'hidden_layer_2': 98, 'learning_rate_init': 0.04232963362498318}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:27:50,281] Trial 14 finished with value: 0.9 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 73, 'learning_rate_init': 0.071879753370639}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:28:14,519] Trial 15 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 86, 'learning_rate_init': 0.031513002291958}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:28:32,006] Trial 16 finished with value: 0.9 and parameters: {'hidden_layer_1': 45, 'hidden_layer_2': 62, 'learning_rate_init': 0.06700649490372958}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:28:54,203] Trial 17 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 86, 'learning_rate_init': 0.04834625368843559}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:29:12,458] Trial 18 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 67, 'learning_rate_init': 0.061460637656844355}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:29:26,676] Trial 19 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 70, 'hidden_layer_2': 90, 'learning_rate_init': 0.021869402789470537}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:29:55,249] Trial 20 finished with value: 0.91 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 80, 'learning_rate_init': 0.0807348644520872}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:30:12,190] Trial 21 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 67, 'learning_rate_init': 0.0626732814447298}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:30:30,364] Trial 22 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 66, 'learning_rate_init': 0.04776728950700684}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:30:58,139] Trial 23 finished with value: 0.91 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 76, 'learning_rate_init': 0.03824324941594967}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:31:14,674] Trial 24 finished with value: 0.9 and parameters: {'hidden_layer_1': 68, 'hidden_layer_2': 40, 'learning_rate_init': 0.055656391232555696}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:31:39,178] Trial 25 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 51, 'hidden_layer_2': 92, 'learning_rate_init': 0.08004457427408446}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:32:03,595] Trial 26 finished with value: 0.92 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 81, 'learning_rate_init': 0.06250876198682728}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:32:40,643] Trial 27 finished with value: 0.9 and parameters: {'hidden_layer_1': 95, 'hidden_layer_2': 80, 'learning_rate_init': 0.04918673955189133}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:33:13,033] Trial 28 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 94, 'learning_rate_init': 0.07071604897866754}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:33:42,627] Trial 29 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 83, 'learning_rate_init': 0.03151001376083813}. Best is trial 10 with value: 0.9233333333333333.
# [I 2025-01-15 13:34:10,863] A new study created in memory with name: no-name-67f0113d-407a-41e4-9b8d-a4bffd1a4fd4
# Training and predicting with MLP...
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-15 13:35:19,046] Trial 0 finished with value: 0.9133333333333333 and parameters: {'layer_1': 61, 'layer_2': 133, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.02569048255583432}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:36:13,922] Trial 1 finished with value: 0.8666666666666667 and parameters: {'layer_1': 148, 'layer_2': 51, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.05298967473630021}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:36:33,630] Trial 2 finished with value: 0.89 and parameters: {'layer_1': 115, 'layer_2': 100, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.00833720816874194}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:37:09,887] Trial 3 finished with value: 0.9033333333333333 and parameters: {'layer_1': 145, 'layer_2': 110, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08389354522460025}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:37:47,230] Trial 4 finished with value: 0.9066666666666666 and parameters: {'layer_1': 150, 'layer_2': 85, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.049094615527938854}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:38:42,970] Trial 5 finished with value: 0.91 and parameters: {'layer_1': 93, 'layer_2': 57, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.030363215181894446}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:39:01,347] Trial 6 finished with value: 0.8966666666666666 and parameters: {'layer_1': 115, 'layer_2': 79, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04513406961374981}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:39:11,327] Trial 7 finished with value: 0.5 and parameters: {'layer_1': 97, 'layer_2': 104, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.08268439580503831}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:39:29,182] Trial 8 finished with value: 0.5 and parameters: {'layer_1': 150, 'layer_2': 135, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.08034747364512616}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:40:21,368] Trial 9 finished with value: 0.8866666666666667 and parameters: {'layer_1': 135, 'layer_2': 54, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06486307439370458}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:40:24,995] Trial 10 finished with value: 0.48 and parameters: {'layer_1': 53, 'layer_2': 147, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0018775441585200253}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-15 13:41:18,204] Trial 11 finished with value: 0.92 and parameters: {'layer_1': 65, 'layer_2': 128, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.026147337637614315}. Best is trial 11 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-15 13:42:26,946] Trial 12 finished with value: 0.9233333333333333 and parameters: {'layer_1': 58, 'layer_2': 129, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.023577443387368214}. Best is trial 12 with value: 0.9233333333333333.

# %% [markdown]
# CPFV (Combined Probability and Class Feature Vector)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)], ignore_index=True)
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)], ignore_index=True)

# Separate features and labels
X_train = main_data.drop(columns=["label"])
y_train = main_data["label"]
X_val = validation_data.drop(columns=["label"])
y_val = validation_data["label"]

# Initialize models with their tuned hyperparameters
trained_models = {
    "SVM": SVC(C=1.0, kernel="rbf", probability=True),  # Example parameters
    "Decision Tree": DecisionTreeClassifier(max_depth=10, min_samples_split=5),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5),
    "Logistic Regression": LogisticRegression(C=1.0, solver="lbfgs"),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=10),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=10, learning_rate=0.1, use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": LGBMClassifier(n_estimators=100, max_depth=10, learning_rate=0.1),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, learning_rate=0.1),
    "Neural Network (MLPClassifier)": MLPClassifier(hidden_layer_sizes=(100, 50), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200),
    "Multilayer Perceptron (Custom MLP)": MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200)
}

# Train all models on the training dataset
for model_name, model in trained_models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)

# Function to create CPFV dataset
def create_cpfv(models, X_data, y_data):
    cpfv_data = pd.DataFrame()
    for model_name, model in models.items():
        # Add predicted class labels
        cpfv_data[f"{model_name}_Class"] = model.predict(X_data)
        # Add predicted probabilities or decision scores
        if hasattr(model, "predict_proba"):
            cpfv_data[f"{model_name}_Prob"] = model.predict_proba(X_data)[:, 1]
        elif hasattr(model, "decision_function"):
            cpfv_data[f"{model_name}_Prob"] = model.decision_function(X_data)
        else:
            cpfv_data[f"{model_name}_Prob"] = cpfv_data[f"{model_name}_Class"]
    # Add true labels
    cpfv_data["True_Label"] = y_data.reset_index(drop=True)
    return cpfv_data

# Create CPFV dataset using validation data
cpfv_dataset = create_cpfv(trained_models, X_val, y_val)

# Save CPFV dataset to CSV
cpfv_dataset.to_csv("CPFV_CTDD.csv", index=False)
# Out:
# Training SVM...
# Training Decision Tree...
# Training Random Forest...
# Training Logistic Regression...
# Training k-NN...
# Training Naive Bayes...
# Training Gradient Boosting...
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:20:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001713 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training AdaBoost...
# Training Neural Network (MLPClassifier)...
# Training Multilayer Perceptron (Custom MLP)...

# %% [markdown]
# # **Hyperparameter grids for RandomizedSearchCV**

# %%
#import optuna
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier # Import path for KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for RandomizedSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply random search
for model_name, model in models.items():
    print(f"Performing RandomizedSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform randomized search
    random_search = RandomizedSearchCV(model, param_grid, n_iter=10, cv=cv, scoring='accuracy', n_jobs=-1, random_state=42)
    random_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = random_search.best_params_
    best_scores.append(random_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-46013dd8be16> in <cell line: 1>()
# ----> 1 import optuna
#       2 import pandas as pd
#       3 import numpy as np
#       4 from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
#       5 from sklearn.svm import SVC
#
# ModuleNotFoundError: No module named 'optuna'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Storage for predictions and target column
probability_datasets = pd.DataFrame(y_train, columns=['Target'])

# Loop through models, perform random search, and save probabilities
for model_name, model in models.items():
    print(f"Performing RandomizedSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform randomized search
    random_search = RandomizedSearchCV(model,
                                       param_grid,
                                       n_iter=10,
                                       cv=cv,
                                       scoring='accuracy',
                                       n_jobs=-1,
                                       random_state=42)

    random_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = random_search.best_params_
    best_scores.append(random_search.best_score_)



    # Get probability predictions (if supported)
    if hasattr(random_search.best_estimator_, "predict_proba"):
        probabilities = random_search.best_estimator_.predict_proba(X_train)[:, 1]  # Probability for the positive class
        probability_datasets[f"{model_name}_Probabilities"] = probabilities
    else:
        # Fallback if probability prediction isn't supported
        predictions = random_search.best_estimator_.predict(X_train)
        probability_datasets[f"{model_name}_Predictions"] = predictions



# Display final dataset with probabilities
print(probability_datasets.head())

# Save the probability dataset to a CSV file
probability_datasets.to_csv("CTDD_Randomsearch .csv", index=False)
print("Probability dataset saved to 'CTDD_Randomsearch.csv'.")

# %% [markdown]
# # **Hyperparameter grids for GridSearchCV**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_main_positive_features.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ CTDD_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/CTDD_validation_negative_features.csv")

# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for GridSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply grid search
for model_name, model in models.items():
    print(f"Performing GridSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform grid search
    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = grid_search.best_params_
    best_scores.append(grid_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)

# %%
# Prepare the final dataset with probabilities and target
all_probabilities = []
all_targets = []

# Loop through models and apply grid search
for model_name, model in models.items():
    print(f"Performing GridSearchCV for {model_name}...")

    # Special handling for SVC: enable probability estimation
    if model_name == "SVM":
        model.probability = True  # Enable probability for SVC

    # Get the parameter grid for the current model
    param_grid = param_grids[model_name]

    # Perform grid search
    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = grid_search.best_params_
    best_scores.append(grid_search.best_score_)

    # Predict probabilities using the best estimator
    best_model = grid_search.best_estimator_
    if hasattr(best_model, "predict_proba"):
        probabilities = best_model.predict_proba(X_train)[:, 1]  # Positive class probabilities
    else:
        # Fallback for models without predict_proba (e.g., SVM with linear kernel)
        probabilities = best_model.decision_function(X_train)
        probabilities = (probabilities - probabilities.min()) / (probabilities.max() - probabilities.min())

    # Append probabilities and targets for this model
    all_probabilities.append(probabilities)
    all_targets.append(y_train)

    # Combine probabilities, features, and target into a DataFrame
    model_data = pd.DataFrame(X_train, columns=main_p.columns)  # Ensure column consistency
    model_data[f"{model_name}_probability"] = probabilities
    model_data['target'] = y_train

    # Save to CSV
    output_path = f"/content/{model_name}_probabilities.csv"
    model_data.to_csv(output_path, index=False)
    print(f"Saved probabilities for {model_name} to {output_path}")

# Combine all model probabilities into a single DataFrame (optional)
final_dataset = pd.DataFrame({'target': y_train})
for idx, model_name in enumerate(models.keys()):
    final_dataset[f"{model_name}_probability"] = all_probabilities[idx]

# Save the combined dataset
final_output_path = "/content/combined_probabilities CTDD_GridSearchCV.csv"
final_dataset.to_csv(final_output_path, index=False)
print(f"Saved combined dataset to {final_output_path}")

# %% [markdown]
# proposed model for CTDD

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix,
                            matthews_corrcoef, cohen_kappa_score, roc_auc_score)

# Load all datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_positive_features (3).csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_negative_features.csv")

# Add target labels (1 for positive, 0 for negative)
main_p['Target'] = 1
main_n['Target'] = 0
validation_p['Target'] = 1
validation_n['Target'] = 0

# Combine main datasets for training and validation datasets for testing
train_data = pd.concat([main_p, main_n], axis=0)
validation_data = pd.concat([validation_p, validation_n], axis=0)

# Shuffle the datasets
train_data = train_data.sample(frac=1, random_state=42).reset_index(drop=True)
validation_data = validation_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Check for non-numeric columns and remove them
non_numeric_cols = train_data.select_dtypes(exclude=[np.number]).columns.tolist()
if non_numeric_cols:
    print(f"Dropping non-numeric columns: {non_numeric_cols}")
    train_data = train_data.drop(columns=non_numeric_cols)
    validation_data = validation_data.drop(columns=non_numeric_cols)

# Separate features and labels
X_train = train_data.drop(columns=['Target']).values
y_train = train_data['Target'].values
X_val = validation_data.drop(columns=['Target']).values
y_val = validation_data['Target'].values

# Check for NaN or infinite values
print(f"NaN in X_train: {np.isnan(X_train).any()}")
print(f"Inf in X_train: {np.isinf(X_train).any()}")
print(f"NaN in X_val: {np.isnan(X_val).any()}")
print(f"Inf in X_val: {np.isinf(X_val).any()}")

# Replace any NaN or infinite values
X_train = np.nan_to_num(X_train)
X_val = np.nan_to_num(X_val)

# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# Reshape data for Conv1D input
X_train = X_train[..., np.newaxis]
X_val = X_val[..., np.newaxis]

# Model Architecture with improvements
model = Sequential()

# First Conv1D layer with input specification
model.add(Conv1D(filters=32, kernel_size=3, activation='relu',
                input_shape=(X_train.shape[1], 1),
                kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))

# Second Conv1D layer
model.add(Conv1D(filters=64, kernel_size=3, activation='relu',
                kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Third Conv1D layer
model.add(Conv1D(filters=128, kernel_size=3, activation='relu',
                kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

# LSTM layer with tanh activation (more stable than relu for RNNs)
model.add(LSTM(32, return_sequences=False, activation='tanh'))

# Dense layers with reduced complexity
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compile with lower learning rate and gradient clipping
optimizer = Adam(learning_rate=0.0001, clipvalue=0.5)
model.compile(optimizer=optimizer,
             loss='binary_crossentropy',
             metrics=['accuracy'])

# Model Summary
model.summary()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss',
                             patience=10,
                             restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train,
                   validation_data=(X_val, y_val),
                   epochs=10,
                   batch_size=32,
                   verbose=1,
                   callbacks=[early_stopping])

# Evaluate the model
val_probabilities = model.predict(X_val).flatten()
val_predictions = (val_probabilities > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_val, val_predictions)
tn, fp, fn, tp = confusion_matrix(y_val, val_predictions).ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
mcc = matthews_corrcoef(y_val, val_predictions)
kappa = cohen_kappa_score(y_val, val_predictions)
auc = roc_auc_score(y_val, val_probabilities)

# Print metrics
print("\nValidation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Matthews Correlation Coefficient (MCC): {mcc:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")
print(f"Area Under Curve (AUC): {auc:.4f}")

# Classification report
print("\nClassification Report:\n", classification_report(y_val, val_predictions))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, val_predictions))
# Out:
# NaN in X_train: False
# Inf in X_train: False
# NaN in X_val: False
# Inf in X_val: False
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 7998, 32)       │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7998, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 3999, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 3999, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 3997, 64)       │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3997, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 3997, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3995, 128)      │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3995, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 1997, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 1997, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,769 (221.75 KB)
#  Trainable params: 56,321 (220.00 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 125s 3s/step - accuracy: 0.5247 - loss: 0.9081 - val_accuracy: 0.5000 - val_loss: 0.9064
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.4895 - loss: 0.9068 - val_accuracy: 0.5000 - val_loss: 0.9025
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 117s 3s/step - accuracy: 0.5241 - loss: 0.9002 - val_accuracy: 0.5000 - val_loss: 0.8989
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.4911 - loss: 0.8988 - val_accuracy: 0.5000 - val_loss: 0.8953
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.4740 - loss: 0.8966 - val_accuracy: 0.5033 - val_loss: 0.8918
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.4838 - loss: 0.8927 - val_accuracy: 0.5033 - val_loss: 0.8882
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.5093 - loss: 0.8865 - val_accuracy: 0.4967 - val_loss: 0.8847
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.4992 - loss: 0.8847 - val_accuracy: 0.4967 - val_loss: 0.8812
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 137s 3s/step - accuracy: 0.5097 - loss: 0.8814 - val_accuracy: 0.4967 - val_loss: 0.8780
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 123s 3s/step - accuracy: 0.4960 - loss: 0.8776 - val_accuracy: 0.4967 - val_loss: 0.8745
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 549ms/step
#
# Validation Metrics:
# Accuracy: 0.4967
# Sensitivity (Recall): 0.9867
# Specificity: 0.0067
# Matthews Correlation Coefficient (MCC): -0.0335
# Cohen's Kappa: -0.0067
# Area Under Curve (AUC): 0.4727
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.01      0.01       150
#            1       0.50      0.99      0.66       150
#
#     accuracy                           0.50       300
#    macro avg       0.42      0.50      0.34       300
# weighted avg       0.42      0.50      0.34       300
#
#
# Confusion Matrix:
# [[  1 149]
#  [  2 148]]

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, classification_report,
                           confusion_matrix, matthews_corrcoef,
                           cohen_kappa_score, roc_auc_score)

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_positive_features (3).csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_negative_features.csv")

# Add target labels
main_p['Target'] = 1
main_n['Target'] = 0
validation_p['Target'] = 1
validation_n['Target'] = 0

# Combine and shuffle data
train_data = pd.concat([main_p, main_n]).sample(frac=1, random_state=42)
validation_data = pd.concat([validation_p, validation_n]).sample(frac=1, random_state=42)

# Check class balance
print("Class distribution in training set:")
print(train_data['Target'].value_counts())
print("\nClass distribution in validation set:")
print(validation_data['Target'].value_counts())

# Drop non-numeric columns
non_numeric_cols = train_data.select_dtypes(exclude=[np.number]).columns.tolist()
if non_numeric_cols:
    print(f"Dropping non-numeric columns: {non_numeric_cols}")
    train_data = train_data.drop(columns=non_numeric_cols)
    validation_data = validation_data.drop(columns=non_numeric_cols)

# Separate features and labels
X_train = train_data.drop(columns=['Target']).values
y_train = train_data['Target'].values
X_val = validation_data.drop(columns=['Target']).values
y_val = validation_data['Target'].values

# Handle NaN/inf
X_train = np.nan_to_num(X_train)
X_val = np.nan_to_num(X_val)

# Normalize with clipping
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_train = np.clip(X_train, -5, 5)
X_val = np.clip(X_val, -5, 5)

# Build Dense network (appropriate for CTDD features)
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(1, activation='sigmoid'))

# Compile with class weighting if imbalanced
optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy',
                      tf.keras.metrics.AUC(name='auc'),
                      tf.keras.metrics.Recall(name='recall'),
                      tf.keras.metrics.Precision(name='precision')])

# Model summary
model.summary()

# Early stopping
early_stop = EarlyStopping(monitor='val_auc',
                          patience=15,
                          mode='max',
                          restore_best_weights=True)

# Train model
history = model.fit(X_train, y_train,
                   validation_data=(X_val, y_val),
                   epochs=10,
                   batch_size=64,
                   callbacks=[early_stop],
                   verbose=1)

# Evaluate
val_probabilities = model.predict(X_val).flatten()
val_predictions = (val_probabilities > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_val, val_predictions)
tn, fp, fn, tp = confusion_matrix(y_val, val_predictions).ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
mcc = matthews_corrcoef(y_val, val_predictions)
kappa = cohen_kappa_score(y_val, val_predictions)
auc = roc_auc_score(y_val, val_probabilities)

# Print metrics
print("\nValidation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"MCC: {mcc:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")
print(f"AUC: {auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_val, val_predictions))

print("\nConfusion Matrix:")
print(confusion_matrix(y_val, val_predictions))
# Out:
# Class distribution in training set:
# Target
# 0    582
# 1    582
# Name: count, dtype: int64
#
# Class distribution in validation set:
# Target
# 0    150
# 1    150
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 256)            │     2,048,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,091,265 (7.98 MB)
#  Trainable params: 2,090,369 (7.97 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - accuracy: 0.5528 - auc: 0.5932 - loss: 0.8716 - precision: 0.5551 - recall: 0.5175 - val_accuracy: 0.7700 - val_auc: 0.8686 - val_loss: 0.6276 - val_precision: 0.8240 - val_recall: 0.6867
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.7365 - auc: 0.8269 - loss: 0.5164 - precision: 0.7563 - recall: 0.6960 - val_accuracy: 0.8600 - val_auc: 0.9293 - val_loss: 0.5431 - val_precision: 0.8375 - val_recall: 0.8933
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8575 - auc: 0.9306 - loss: 0.3509 - precision: 0.8687 - recall: 0.8593 - val_accuracy: 0.8667 - val_auc: 0.9431 - val_loss: 0.4753 - val_precision: 0.8571 - val_recall: 0.8800
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8964 - auc: 0.9626 - loss: 0.2597 - precision: 0.8960 - recall: 0.8949 - val_accuracy: 0.8767 - val_auc: 0.9491 - val_loss: 0.4134 - val_precision: 0.8742 - val_recall: 0.8800
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9179 - auc: 0.9740 - loss: 0.2164 - precision: 0.9231 - recall: 0.9081 - val_accuracy: 0.8800 - val_auc: 0.9552 - val_loss: 0.3580 - val_precision: 0.8750 - val_recall: 0.8867
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9446 - auc: 0.9837 - loss: 0.1673 - precision: 0.9568 - recall: 0.9326 - val_accuracy: 0.8700 - val_auc: 0.9564 - val_loss: 0.3334 - val_precision: 0.9111 - val_recall: 0.8200
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9609 - auc: 0.9940 - loss: 0.1195 - precision: 0.9527 - recall: 0.9640 - val_accuracy: 0.8767 - val_auc: 0.9572 - val_loss: 0.3104 - val_precision: 0.9185 - val_recall: 0.8267
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9629 - auc: 0.9919 - loss: 0.1152 - precision: 0.9675 - recall: 0.9583 - val_accuracy: 0.8867 - val_auc: 0.9562 - val_loss: 0.2894 - val_precision: 0.9028 - val_recall: 0.8667
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9761 - auc: 0.9942 - loss: 0.0958 - precision: 0.9762 - recall: 0.9737 - val_accuracy: 0.8867 - val_auc: 0.9613 - val_loss: 0.2669 - val_precision: 0.8973 - val_recall: 0.8733
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9644 - auc: 0.9942 - loss: 0.1051 - precision: 0.9797 - recall: 0.9503 - val_accuracy: 0.8933 - val_auc: 0.9653 - val_loss: 0.2582 - val_precision: 0.8986 - val_recall: 0.8867
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Validation Metrics:
# Accuracy: 0.8933
# Sensitivity (Recall): 0.8867
# Specificity: 0.9000
# MCC: 0.7867
# Cohen's Kappa: 0.7867
# AUC: 0.9653
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       150
#            1       0.90      0.89      0.89       150
#
#     accuracy                           0.89       300
#    macro avg       0.89      0.89      0.89       300
# weighted avg       0.89      0.89      0.89       300
#
#
# Confusion Matrix:
# [[135  15]
#  [ 17 133]]

# %%
#cross validation 5 fold

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (accuracy_score, classification_report,
                           confusion_matrix, matthews_corrcoef,
                           cohen_kappa_score, roc_auc_score)

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_positive_features (3).csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_main_negative_features.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_positive_features.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_2/4_CTDD/ctdd_validation_negative_features.csv")

# Add target labels
main_p['Target'] = 1
main_n['Target'] = 0
validation_p['Target'] = 1
validation_n['Target'] = 0

# Combine all data for cross-validation
all_data = pd.concat([main_p, main_n, validation_p, validation_n])
all_data = all_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Check class balance
print("Class distribution:")
print(all_data['Target'].value_counts())

# Drop non-numeric columns
non_numeric_cols = all_data.select_dtypes(exclude=[np.number]).columns.tolist()
if non_numeric_cols:
    print(f"\nDropping non-numeric columns: {non_numeric_cols}")
    all_data = all_data.drop(columns=non_numeric_cols)

# Separate features and labels
X = all_data.drop(columns=['Target']).values
y = all_data['Target'].values

# Initialize 5-fold cross-validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
results = []

for train_idx, val_idx in kfold.split(X, y):
    print(f'\n{"="*40}')
    print(f'Training fold {fold_no}')
    print(f'{"="*40}')

    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Handle NaN/inf and normalize with clipping
    X_train = np.nan_to_num(X_train)
    X_val = np.nan_to_num(X_val)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_train = np.clip(X_train, -5, 5)
    X_val = np.clip(X_val, -5, 5)

    # Build model with regularization
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],),
                    kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))

    # Compile with adjusted learning rate
    optimizer = Adam(learning_rate=0.0005)
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

    # Early stopping
    early_stop = EarlyStopping(monitor='val_auc',
                              patience=15,
                              mode='max',
                              restore_best_weights=True,
                              verbose=1)

    # Class weighting if imbalanced
    class_counts = np.bincount(y_train)
    class_weight = {0: 1/class_counts[0], 1: 1/class_counts[1]}

    # Train model
    history = model.fit(X_train, y_train,
                       validation_data=(X_val, y_val),
                       epochs=100,
                       batch_size=64,
                       callbacks=[early_stop],
                       class_weight=class_weight,
                       verbose=1)

    # Evaluate model
    val_probabilities = model.predict(X_val).flatten()
    val_predictions = (val_probabilities > 0.5).astype(int)

    # Calculate metrics
    tn, fp, fn, tp = confusion_matrix(y_val, val_predictions).ravel()
    metrics = {
        'fold': fold_no,
        'accuracy': accuracy_score(y_val, val_predictions),
        'sensitivity': tp / (tp + fn) if (tp + fn) > 0 else 0,
        'specificity': tn / (tn + fp) if (tn + fp) > 0 else 0,
        'mcc': matthews_corrcoef(y_val, val_predictions),
        'kappa': cohen_kappa_score(y_val, val_predictions),
        'auc': roc_auc_score(y_val, val_probabilities)
    }

    results.append(metrics)

    print(f'\nFold {fold_no} Results:')
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"AUC: {metrics['auc']:.4f}")
    print(f"MCC: {metrics['mcc']:.4f}")

    fold_no += 1

# Calculate and display average metrics
print('\n' + '='*50)
print('Cross-Validation Summary')
print('='*50)

avg_metrics = {
    'accuracy': np.mean([r['accuracy'] for r in results]),
    'sensitivity': np.mean([r['sensitivity'] for r in results]),
    'specificity': np.mean([r['specificity'] for r in results]),
    'mcc': np.mean([r['mcc'] for r in results]),
    'kappa': np.mean([r['kappa'] for r in results]),
    'auc': np.mean([r['auc'] for r in results])
}

print(f"\nAverage Metrics Across All Folds:")
print(f"Accuracy: {avg_metrics['accuracy']:.4f}")
print(f"Sensitivity: {avg_metrics['sensitivity']:.4f}")
print(f"Specificity: {avg_metrics['specificity']:.4f}")
print(f"MCC: {avg_metrics['mcc']:.4f}")
print(f"Cohen's Kappa: {avg_metrics['kappa']:.4f}")
print(f"AUC: {avg_metrics['auc']:.4f}")

# Train final model on all data
print("\nTraining final model on all data...")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.clip(X_scaled, -5, 5)

final_model = Sequential()
final_model.add(Dense(256, activation='relu', input_shape=(X_scaled.shape[1],),
                     kernel_regularizer=l2(0.001)))
final_model.add(BatchNormalization())
final_model.add(Dropout(0.5))

final_model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
final_model.add(BatchNormalization())
final_model.add(Dropout(0.4))

final_model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
final_model.add(BatchNormalization())
final_model.add(Dropout(0.3))

final_model.add(Dense(1, activation='sigmoid'))

optimizer = Adam(learning_rate=0.0005)
final_model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# Final class weights
class_counts = np.bincount(y)
final_class_weight = {0: 1/class_counts[0], 1: 1/class_counts[1]}

history = final_model.fit(X_scaled, y,
               epochs=100,
               batch_size=64,
               class_weight=final_class_weight,
               verbose=1)

# Save the final model
final_model.save('ctdd_final_model.h5')
print("Final model training complete and saved!")
# Out:
# Class distribution:
# Target
# 1    732
# 0    732
# Name: count, dtype: int64
#
# ========================================
# Training fold 1
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.5512 - auc: 0.5443 - loss: 0.6409 - val_accuracy: 0.8157 - val_auc: 0.9065 - val_loss: 1.0238
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7637 - auc: 0.8372 - loss: 0.3200 - val_accuracy: 0.8771 - val_auc: 0.9575 - val_loss: 0.8549
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.8376 - auc: 0.9231 - loss: 0.1900 - val_accuracy: 0.9078 - val_auc: 0.9672 - val_loss: 0.7846
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8659 - auc: 0.9489 - loss: 0.1365 - val_accuracy: 0.8908 - val_auc: 0.9680 - val_loss: 0.7480
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9024 - auc: 0.9681 - loss: 0.1064 - val_accuracy: 0.8976 - val_auc: 0.9671 - val_loss: 0.7214
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9087 - auc: 0.9695 - loss: 0.0845 - val_accuracy: 0.9010 - val_auc: 0.9681 - val_loss: 0.6947
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9434 - auc: 0.9820 - loss: 0.0672 - val_accuracy: 0.8840 - val_auc: 0.9710 - val_loss: 0.6694
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9538 - auc: 0.9905 - loss: 0.0535 - val_accuracy: 0.8328 - val_auc: 0.9658 - val_loss: 0.6567
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9534 - auc: 0.9902 - loss: 0.0425 - val_accuracy: 0.8942 - val_auc: 0.9663 - val_loss: 0.6360
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9334 - auc: 0.9841 - loss: 0.0340 - val_accuracy: 0.8430 - val_auc: 0.9715 - val_loss: 0.6141
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9562 - auc: 0.9894 - loss: 0.0273 - val_accuracy: 0.8942 - val_auc: 0.9709 - val_loss: 0.5939
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9593 - auc: 0.9932 - loss: 0.0217 - val_accuracy: 0.8737 - val_auc: 0.9701 - val_loss: 0.5829
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9573 - auc: 0.9904 - loss: 0.0172 - val_accuracy: 0.8942 - val_auc: 0.9649 - val_loss: 0.5667
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9490 - auc: 0.9868 - loss: 0.0139 - val_accuracy: 0.8669 - val_auc: 0.9717 - val_loss: 0.5514
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9672 - auc: 0.9958 - loss: 0.0112 - val_accuracy: 0.9010 - val_auc: 0.9732 - val_loss: 0.5268
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9757 - auc: 0.9949 - loss: 0.0089 - val_accuracy: 0.8737 - val_auc: 0.9684 - val_loss: 0.5373
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9580 - auc: 0.9898 - loss: 0.0073 - val_accuracy: 0.8567 - val_auc: 0.9583 - val_loss: 0.5097
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9587 - auc: 0.9872 - loss: 0.0063 - val_accuracy: 0.8362 - val_auc: 0.9525 - val_loss: 0.4976
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9372 - auc: 0.9792 - loss: 0.0056 - val_accuracy: 0.8976 - val_auc: 0.9563 - val_loss: 0.4688
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9550 - auc: 0.9929 - loss: 0.0049 - val_accuracy: 0.8840 - val_auc: 0.9650 - val_loss: 0.4581
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9625 - auc: 0.9943 - loss: 0.0041 - val_accuracy: 0.8976 - val_auc: 0.9607 - val_loss: 0.4180
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9598 - auc: 0.9927 - loss: 0.0035 - val_accuracy: 0.8294 - val_auc: 0.9601 - val_loss: 0.4257
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9336 - auc: 0.9816 - loss: 0.0034 - val_accuracy: 0.8805 - val_auc: 0.9584 - val_loss: 0.3904
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9641 - auc: 0.9865 - loss: 0.0032 - val_accuracy: 0.8908 - val_auc: 0.9646 - val_loss: 0.3597
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9555 - auc: 0.9928 - loss: 0.0027 - val_accuracy: 0.9078 - val_auc: 0.9634 - val_loss: 0.3591
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9724 - auc: 0.9942 - loss: 0.0022 - val_accuracy: 0.8840 - val_auc: 0.9604 - val_loss: 0.3476
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9418 - auc: 0.9832 - loss: 0.0023 - val_accuracy: 0.8942 - val_auc: 0.9618 - val_loss: 0.3153
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9501 - auc: 0.9825 - loss: 0.0028 - val_accuracy: 0.9215 - val_auc: 0.9656 - val_loss: 0.2840
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9569 - auc: 0.9923 - loss: 0.0027 - val_accuracy: 0.8840 - val_auc: 0.9672 - val_loss: 0.2705
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9611 - auc: 0.9939 - loss: 0.0023 - val_accuracy: 0.9147 - val_auc: 0.9692 - val_loss: 0.2430
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Fold 1 Results:
# Accuracy: 0.9010
# AUC: 0.9733
# MCC: 0.8076
#
# ========================================
# Training fold 2
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5109 - auc: 0.5312 - loss: 0.6389 - val_accuracy: 0.7235 - val_auc: 0.8369 - val_loss: 1.0160
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7048 - auc: 0.7722 - loss: 0.3191 - val_accuracy: 0.6212 - val_auc: 0.9562 - val_loss: 0.8482
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8315 - auc: 0.9123 - loss: 0.1893 - val_accuracy: 0.5358 - val_auc: 0.9699 - val_loss: 0.7971
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8817 - auc: 0.9555 - loss: 0.1356 - val_accuracy: 0.4983 - val_auc: 0.9705 - val_loss: 0.7810
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9034 - auc: 0.9648 - loss: 0.1054 - val_accuracy: 0.4983 - val_auc: 0.9675 - val_loss: 0.7624
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9392 - auc: 0.9888 - loss: 0.0835 - val_accuracy: 0.4983 - val_auc: 0.9711 - val_loss: 0.7488
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9322 - auc: 0.9840 - loss: 0.0664 - val_accuracy: 0.4983 - val_auc: 0.9767 - val_loss: 0.7359
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9361 - auc: 0.9861 - loss: 0.0528 - val_accuracy: 0.4983 - val_auc: 0.9749 - val_loss: 0.7155
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9574 - auc: 0.9878 - loss: 0.0419 - val_accuracy: 0.4983 - val_auc: 0.9712 - val_loss: 0.7065
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9603 - auc: 0.9911 - loss: 0.0334 - val_accuracy: 0.4983 - val_auc: 0.9700 - val_loss: 0.6834
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9401 - auc: 0.9820 - loss: 0.0268 - val_accuracy: 0.5017 - val_auc: 0.9709 - val_loss: 0.6710
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9617 - auc: 0.9923 - loss: 0.0213 - val_accuracy: 0.4983 - val_auc: 0.9665 - val_loss: 0.6631
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9494 - auc: 0.9898 - loss: 0.0168 - val_accuracy: 0.5154 - val_auc: 0.9633 - val_loss: 0.6296
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9685 - auc: 0.9918 - loss: 0.0135 - val_accuracy: 0.5802 - val_auc: 0.9642 - val_loss: 0.6051
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9493 - auc: 0.9908 - loss: 0.0109 - val_accuracy: 0.6928 - val_auc: 0.9633 - val_loss: 0.5710
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9435 - auc: 0.9863 - loss: 0.0090 - val_accuracy: 0.7747 - val_auc: 0.9651 - val_loss: 0.5454
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9572 - auc: 0.9897 - loss: 0.0077 - val_accuracy: 0.7679 - val_auc: 0.9807 - val_loss: 0.5179
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9495 - auc: 0.9924 - loss: 0.0065 - val_accuracy: 0.8362 - val_auc: 0.9681 - val_loss: 0.5001
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9705 - auc: 0.9913 - loss: 0.0054 - val_accuracy: 0.8498 - val_auc: 0.9726 - val_loss: 0.4827
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9559 - auc: 0.9925 - loss: 0.0045 - val_accuracy: 0.8635 - val_auc: 0.9691 - val_loss: 0.4533
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9431 - auc: 0.9851 - loss: 0.0042 - val_accuracy: 0.9078 - val_auc: 0.9711 - val_loss: 0.4164
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9611 - auc: 0.9935 - loss: 0.0036 - val_accuracy: 0.9044 - val_auc: 0.9687 - val_loss: 0.4010
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9572 - auc: 0.9879 - loss: 0.0031 - val_accuracy: 0.8874 - val_auc: 0.9585 - val_loss: 0.4081
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9600 - auc: 0.9923 - loss: 0.0030 - val_accuracy: 0.9078 - val_auc: 0.9653 - val_loss: 0.3693
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9530 - auc: 0.9834 - loss: 0.0029 - val_accuracy: 0.9010 - val_auc: 0.9627 - val_loss: 0.3570
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9529 - auc: 0.9915 - loss: 0.0026 - val_accuracy: 0.8874 - val_auc: 0.9670 - val_loss: 0.3459
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9574 - auc: 0.9912 - loss: 0.0024 - val_accuracy: 0.8874 - val_auc: 0.9616 - val_loss: 0.3502
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9427 - auc: 0.9844 - loss: 0.0024 - val_accuracy: 0.9181 - val_auc: 0.9752 - val_loss: 0.2847
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9602 - auc: 0.9934 - loss: 0.0025 - val_accuracy: 0.8976 - val_auc: 0.9747 - val_loss: 0.2537
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9661 - auc: 0.9944 - loss: 0.0020 - val_accuracy: 0.9044 - val_auc: 0.9588 - val_loss: 0.3039
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9359 - auc: 0.9855 - loss: 0.0021 - val_accuracy: 0.8976 - val_auc: 0.9570 - val_loss: 0.3168
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9564 - auc: 0.9903 - loss: 0.0023 - val_accuracy: 0.8976 - val_auc: 0.9687 - val_loss: 0.2532
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Fold 2 Results:
# Accuracy: 0.7679
# AUC: 0.9809
# MCC: 0.6055
#
# ========================================
# Training fold 3
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.4767 - auc: 0.4909 - loss: 0.6402 - val_accuracy: 0.7031 - val_auc: 0.8951 - val_loss: 1.0265
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7166 - auc: 0.7891 - loss: 0.3201 - val_accuracy: 0.5700 - val_auc: 0.9308 - val_loss: 0.8678
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8224 - auc: 0.9062 - loss: 0.1901 - val_accuracy: 0.5017 - val_auc: 0.9491 - val_loss: 0.8110
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8612 - auc: 0.9370 - loss: 0.1363 - val_accuracy: 0.5017 - val_auc: 0.9553 - val_loss: 0.7859
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9114 - auc: 0.9682 - loss: 0.1060 - val_accuracy: 0.5017 - val_auc: 0.9591 - val_loss: 0.7686
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9245 - auc: 0.9754 - loss: 0.0841 - val_accuracy: 0.5017 - val_auc: 0.9583 - val_loss: 0.7539
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9225 - auc: 0.9791 - loss: 0.0668 - val_accuracy: 0.5017 - val_auc: 0.9627 - val_loss: 0.7373
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9497 - auc: 0.9856 - loss: 0.0531 - val_accuracy: 0.5017 - val_auc: 0.9596 - val_loss: 0.7317
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9464 - auc: 0.9872 - loss: 0.0423 - val_accuracy: 0.5017 - val_auc: 0.9619 - val_loss: 0.7238
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9477 - auc: 0.9857 - loss: 0.0337 - val_accuracy: 0.5017 - val_auc: 0.9624 - val_loss: 0.7063
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9704 - auc: 0.9951 - loss: 0.0267 - val_accuracy: 0.5017 - val_auc: 0.9633 - val_loss: 0.7050
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9741 - auc: 0.9935 - loss: 0.0212 - val_accuracy: 0.5017 - val_auc: 0.9603 - val_loss: 0.6876
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9602 - auc: 0.9901 - loss: 0.0169 - val_accuracy: 0.5017 - val_auc: 0.9582 - val_loss: 0.6537
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9476 - auc: 0.9895 - loss: 0.0136 - val_accuracy: 0.5017 - val_auc: 0.9620 - val_loss: 0.6438
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9617 - auc: 0.9890 - loss: 0.0111 - val_accuracy: 0.5529 - val_auc: 0.9615 - val_loss: 0.5881
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9459 - auc: 0.9896 - loss: 0.0092 - val_accuracy: 0.6519 - val_auc: 0.9532 - val_loss: 0.5621
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9527 - auc: 0.9872 - loss: 0.0075 - val_accuracy: 0.6246 - val_auc: 0.9562 - val_loss: 0.5659
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9538 - auc: 0.9863 - loss: 0.0064 - val_accuracy: 0.7270 - val_auc: 0.9589 - val_loss: 0.5254
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9728 - auc: 0.9954 - loss: 0.0053 - val_accuracy: 0.8123 - val_auc: 0.9573 - val_loss: 0.5011
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9494 - auc: 0.9853 - loss: 0.0045 - val_accuracy: 0.7031 - val_auc: 0.9559 - val_loss: 0.5167
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9612 - auc: 0.9912 - loss: 0.0039 - val_accuracy: 0.8123 - val_auc: 0.9481 - val_loss: 0.4782
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9527 - auc: 0.9785 - loss: 0.0039 - val_accuracy: 0.8942 - val_auc: 0.9489 - val_loss: 0.4252
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9336 - auc: 0.9799 - loss: 0.0037 - val_accuracy: 0.8874 - val_auc: 0.9460 - val_loss: 0.4092
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9564 - auc: 0.9899 - loss: 0.0033 - val_accuracy: 0.9044 - val_auc: 0.9528 - val_loss: 0.3818
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9577 - auc: 0.9875 - loss: 0.0031 - val_accuracy: 0.8874 - val_auc: 0.9540 - val_loss: 0.3461
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9668 - auc: 0.9942 - loss: 0.0028 - val_accuracy: 0.8976 - val_auc: 0.9473 - val_loss: 0.3357
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Fold 3 Results:
# Accuracy: 0.5017
# AUC: 0.9637
# MCC: 0.0000
#
# ========================================
# Training fold 4
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.5316 - auc: 0.5452 - loss: 0.6411 - val_accuracy: 0.6246 - val_auc: 0.9128 - val_loss: 1.0253
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7405 - auc: 0.8202 - loss: 0.3205 - val_accuracy: 0.5870 - val_auc: 0.9609 - val_loss: 0.8570
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8491 - auc: 0.9303 - loss: 0.1904 - val_accuracy: 0.6553 - val_auc: 0.9722 - val_loss: 0.7913
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8747 - auc: 0.9471 - loss: 0.1366 - val_accuracy: 0.6621 - val_auc: 0.9746 - val_loss: 0.7551
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9209 - auc: 0.9715 - loss: 0.1063 - val_accuracy: 0.7133 - val_auc: 0.9734 - val_loss: 0.7301
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9333 - auc: 0.9816 - loss: 0.0843 - val_accuracy: 0.7679 - val_auc: 0.9775 - val_loss: 0.7066
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9289 - auc: 0.9769 - loss: 0.0671 - val_accuracy: 0.8464 - val_auc: 0.9822 - val_loss: 0.6798
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9292 - auc: 0.9833 - loss: 0.0535 - val_accuracy: 0.8089 - val_auc: 0.9761 - val_loss: 0.6576
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9573 - auc: 0.9887 - loss: 0.0426 - val_accuracy: 0.8771 - val_auc: 0.9762 - val_loss: 0.6401
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9697 - auc: 0.9876 - loss: 0.0339 - val_accuracy: 0.8874 - val_auc: 0.9718 - val_loss: 0.6220
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9533 - auc: 0.9906 - loss: 0.0268 - val_accuracy: 0.9283 - val_auc: 0.9803 - val_loss: 0.6032
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9481 - auc: 0.9879 - loss: 0.0214 - val_accuracy: 0.8635 - val_auc: 0.9794 - val_loss: 0.5838
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9482 - auc: 0.9870 - loss: 0.0172 - val_accuracy: 0.9078 - val_auc: 0.9746 - val_loss: 0.5759
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9472 - auc: 0.9881 - loss: 0.0137 - val_accuracy: 0.9147 - val_auc: 0.9778 - val_loss: 0.5529
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9525 - auc: 0.9889 - loss: 0.0111 - val_accuracy: 0.8942 - val_auc: 0.9721 - val_loss: 0.5267
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9646 - auc: 0.9887 - loss: 0.0093 - val_accuracy: 0.8908 - val_auc: 0.9796 - val_loss: 0.5149
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9547 - auc: 0.9905 - loss: 0.0076 - val_accuracy: 0.8635 - val_auc: 0.9729 - val_loss: 0.5108
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9525 - auc: 0.9908 - loss: 0.0067 - val_accuracy: 0.9078 - val_auc: 0.9743 - val_loss: 0.4726
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9647 - auc: 0.9918 - loss: 0.0057 - val_accuracy: 0.9181 - val_auc: 0.9767 - val_loss: 0.4584
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9608 - auc: 0.9892 - loss: 0.0046 - val_accuracy: 0.8703 - val_auc: 0.9620 - val_loss: 0.4450
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9276 - auc: 0.9746 - loss: 0.0043 - val_accuracy: 0.9010 - val_auc: 0.9715 - val_loss: 0.4291
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9445 - auc: 0.9898 - loss: 0.0040 - val_accuracy: 0.8805 - val_auc: 0.9731 - val_loss: 0.3923
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Fold 4 Results:
# Accuracy: 0.8464
# AUC: 0.9822
# MCC: 0.7190
#
# ========================================
# Training fold 5
# ========================================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.4931 - auc: 0.5018 - loss: 0.6424 - val_accuracy: 0.5925 - val_auc: 0.8956 - val_loss: 1.0305
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7393 - auc: 0.8134 - loss: 0.3215 - val_accuracy: 0.5034 - val_auc: 0.9442 - val_loss: 0.8790
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8225 - auc: 0.9076 - loss: 0.1912 - val_accuracy: 0.5000 - val_auc: 0.9590 - val_loss: 0.8239
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8805 - auc: 0.9526 - loss: 0.1373 - val_accuracy: 0.5000 - val_auc: 0.9593 - val_loss: 0.7940
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9235 - auc: 0.9746 - loss: 0.1070 - val_accuracy: 0.5000 - val_auc: 0.9630 - val_loss: 0.7703
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9267 - auc: 0.9759 - loss: 0.0850 - val_accuracy: 0.5000 - val_auc: 0.9664 - val_loss: 0.7438
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9358 - auc: 0.9722 - loss: 0.0677 - val_accuracy: 0.5000 - val_auc: 0.9650 - val_loss: 0.7256
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9391 - auc: 0.9792 - loss: 0.0539 - val_accuracy: 0.5000 - val_auc: 0.9683 - val_loss: 0.7095
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9439 - auc: 0.9867 - loss: 0.0429 - val_accuracy: 0.5000 - val_auc: 0.9655 - val_loss: 0.6898
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9505 - auc: 0.9867 - loss: 0.0343 - val_accuracy: 0.5000 - val_auc: 0.9723 - val_loss: 0.6749
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9610 - auc: 0.9908 - loss: 0.0272 - val_accuracy: 0.5000 - val_auc: 0.9721 - val_loss: 0.6506
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9453 - auc: 0.9869 - loss: 0.0217 - val_accuracy: 0.5274 - val_auc: 0.9698 - val_loss: 0.6260
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9538 - auc: 0.9887 - loss: 0.0174 - val_accuracy: 0.6541 - val_auc: 0.9685 - val_loss: 0.5999
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9654 - auc: 0.9940 - loss: 0.0140 - val_accuracy: 0.6438 - val_auc: 0.9614 - val_loss: 0.5865
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9629 - auc: 0.9922 - loss: 0.0112 - val_accuracy: 0.7705 - val_auc: 0.9652 - val_loss: 0.5599
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9634 - auc: 0.9913 - loss: 0.0090 - val_accuracy: 0.8253 - val_auc: 0.9571 - val_loss: 0.5435
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9483 - auc: 0.9909 - loss: 0.0074 - val_accuracy: 0.8938 - val_auc: 0.9609 - val_loss: 0.5171
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9509 - auc: 0.9846 - loss: 0.0064 - val_accuracy: 0.8938 - val_auc: 0.9600 - val_loss: 0.4708
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9700 - auc: 0.9915 - loss: 0.0056 - val_accuracy: 0.9041 - val_auc: 0.9710 - val_loss: 0.4528
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9700 - auc: 0.9925 - loss: 0.0046 - val_accuracy: 0.8664 - val_auc: 0.9651 - val_loss: 0.4465
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9764 - auc: 0.9965 - loss: 0.0037 - val_accuracy: 0.9144 - val_auc: 0.9598 - val_loss: 0.4356
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9593 - auc: 0.9905 - loss: 0.0032 - val_accuracy: 0.9041 - val_auc: 0.9636 - val_loss: 0.4298
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9400 - auc: 0.9877 - loss: 0.0031 - val_accuracy: 0.9075 - val_auc: 0.9548 - val_loss: 0.4104
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9493 - auc: 0.9864 - loss: 0.0031 - val_accuracy: 0.8733 - val_auc: 0.9512 - val_loss: 0.3741
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9262 - auc: 0.9756 - loss: 0.0032 - val_accuracy: 0.9110 - val_auc: 0.9583 - val_loss: 0.3208
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Fold 5 Results:
# Accuracy: 0.5000
# AUC: 0.9721
# MCC: 0.0000
#
# ==================================================
# Cross-Validation Summary
# ==================================================
#
# Average Metrics Across All Folds:
# Accuracy: 0.7034
# Sensitivity: 0.6721
# Specificity: 0.7346
# MCC: 0.4264
# Cohen's Kappa: 0.4064
# AUC: 0.9744
#
# Training final model on all data...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5451 - auc: 0.5593 - loss: 0.6206
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7471 - auc: 0.8233 - loss: 0.2723
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8132 - auc: 0.9057 - loss: 0.1584
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8822 - auc: 0.9479 - loss: 0.1140
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9002 - auc: 0.9558 - loss: 0.0864
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9175 - auc: 0.9704 - loss: 0.0656
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9364 - auc: 0.9790 - loss: 0.0498
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9442 - auc: 0.9863 - loss: 0.0377
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9467 - auc: 0.9867 - loss: 0.0285
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9431 - auc: 0.9835 - loss: 0.0217
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9647 - auc: 0.9911 - loss: 0.0165
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9665 - auc: 0.9910 - loss: 0.0123
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9495 - auc: 0.9853 - loss: 0.0095
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9487 - auc: 0.9858 - loss: 0.0075
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9369 - auc: 0.9851 - loss: 0.0060
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9648 - auc: 0.9950 - loss: 0.0048
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9648 - auc: 0.9882 - loss: 0.0037
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9471 - auc: 0.9860 - loss: 0.0032
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9584 - auc: 0.9827 - loss: 0.0031
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9498 - auc: 0.9887 - loss: 0.0028
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9467 - auc: 0.9909 - loss: 0.0025
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9591 - auc: 0.9906 - loss: 0.0019
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9486 - auc: 0.9849 - loss: 0.0021
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9602 - auc: 0.9877 - loss: 0.0020
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9447 - auc: 0.9860 - loss: 0.0018
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9569 - auc: 0.9894 - loss: 0.0020
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9645 - auc: 0.9921 - loss: 0.0018
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9374 - auc: 0.9853 - loss: 0.0016
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9432 - auc: 0.9804 - loss: 0.0016
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9627 - auc: 0.9883 - loss: 0.0015
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9539 - auc: 0.9899 - loss: 0.0012
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9521 - auc: 0.9908 - loss: 0.0012
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9327 - auc: 0.9836 - loss: 0.0015
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9631 - auc: 0.9952 - loss: 0.0015
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9564 - auc: 0.9930 - loss: 0.0013
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9472 - auc: 0.9904 - loss: 0.0013
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9509 - auc: 0.9891 - loss: 0.0013
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9537 - auc: 0.9923 - loss: 0.0013
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9483 - auc: 0.9900 - loss: 0.0012
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9594 - auc: 0.9924 - loss: 0.0012
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9468 - auc: 0.9873 - loss: 0.0013
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9716 - auc: 0.9921 - loss: 0.0012
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9524 - auc: 0.9871 - loss: 0.0012
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9533 - auc: 0.9903 - loss: 0.0014
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9640 - auc: 0.9954 - loss: 0.0012
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9525 - auc: 0.9901 - loss: 0.0011
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9628 - auc: 0.9913 - loss: 0.0011
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9595 - auc: 0.9917 - loss: 0.0011
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9657 - auc: 0.9957 - loss: 9.7816e-04
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9611 - auc: 0.9918 - loss: 0.0010
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9607 - auc: 0.9913 - loss: 0.0012
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9609 - auc: 0.9860 - loss: 0.0013
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9592 - auc: 0.9916 - loss: 0.0011
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9664 - auc: 0.9955 - loss: 0.0011
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9644 - auc: 0.9882 - loss: 0.0010
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9571 - auc: 0.9911 - loss: 0.0012
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9646 - auc: 0.9929 - loss: 0.0012
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9553 - auc: 0.9929 - loss: 0.0011
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9585 - auc: 0.9925 - loss: 0.0010
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9483 - auc: 0.9900 - loss: 0.0011
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9512 - auc: 0.9871 - loss: 0.0011
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9569 - auc: 0.9940 - loss: 9.9376e-04
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9686 - auc: 0.9929 - loss: 9.7399e-04
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9577 - auc: 0.9907 - loss: 0.0010
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9597 - auc: 0.9890 - loss: 9.8864e-04
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9561 - auc: 0.9902 - loss: 9.0856e-04
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9573 - auc: 0.9903 - loss: 9.2278e-04
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9462 - auc: 0.9871 - loss: 0.0011
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9531 - auc: 0.9896 - loss: 0.0011
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9773 - auc: 0.9948 - loss: 0.0011
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9485 - auc: 0.9888 - loss: 9.6480e-04
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9687 - auc: 0.9932 - loss: 9.3127e-04
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9655 - auc: 0.9933 - loss: 9.0668e-04
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9719 - auc: 0.9933 - loss: 8.7094e-04
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9514 - auc: 0.9922 - loss: 9.4138e-04
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9565 - auc: 0.9914 - loss: 0.0011
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9592 - auc: 0.9918 - loss: 9.2780e-04
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9503 - auc: 0.9822 - loss: 0.0010
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9610 - auc: 0.9934 - loss: 9.5521e-04
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9675 - auc: 0.9944 - loss: 7.6543e-04
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9680 - auc: 0.9931 - loss: 7.1476e-04
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9592 - auc: 0.9911 - loss: 8.1550e-04
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9509 - auc: 0.9929 - loss: 9.8721e-04
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9720 - auc: 0.9934 - loss: 8.6414e-04
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9580 - auc: 0.9907 - loss: 7.7232e-04
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9743 - auc: 0.9955 - loss: 7.4987e-04
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9678 - auc: 0.9948 - loss: 7.5231e-04
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9707 - auc: 0.9962 - loss: 6.8070e-04
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9647 - auc: 0.9937 - loss: 6.8550e-04
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9615 - auc: 0.9916 - loss: 7.5805e-04
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9605 - auc: 0.9886 - loss: 9.0526e-04
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9569 - auc: 0.9914 - loss: 9.0601e-04
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9585 - auc: 0.9929 - loss: 8.5985e-04
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9623 - auc: 0.9920 - loss: 8.0685e-04
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9591 - auc: 0.9915 - loss: 8.0935e-04
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9785 - auc: 0.9947 - loss: 6.9433e-04
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9608 - auc: 0.9910 - loss: 6.8797e-04
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9576 - auc: 0.9925 - loss: 8.3972e-04
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9672 - auc: 0.9936 - loss: 8.3052e-04
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9683 - auc: 0.9941 - loss: 7.4244e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final model training complete and saved!
