# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.84

# %%
from itertools import product
from Bio import SeqIO
import pandas as pd

# Define a function to compute TPC
def compute_tpc(sequence):
    tripeptides = [''.join(p) for p in product("ACDEFGHIKLMNPQRSTVWY", repeat=3)]
    tpc_counts = {tripeptide: 0 for tripeptide in tripeptides}

    for i in range(len(sequence) - 2):
        tripeptide = sequence[i:i+3]
        if tripeptide in tpc_counts:
            tpc_counts[tripeptide] += 1

    total_tripeptides = sum(tpc_counts.values())
    if total_tripeptides > 0:
        tpc_counts = {key: val / total_tripeptides for key, val in tpc_counts.items()}

    return tpc_counts

# Process FASTA files
def process_fasta(input_path, output_path):
    data = []
    for record in SeqIO.parse(input_path, "fasta"):
        tpc_features = compute_tpc(str(record.seq))
        data.append(tpc_features)  # Only append TPC features, no IDs

    df = pd.DataFrame(data)
    df.to_csv(output_path, index=False)

# Paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/POSITIVE_main (2) (1).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/NEGATIVE_main (2) (1).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/POSITIVE_validation (2) (1).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/NEGATIVE_validation (2) (1).fasta"

# Output paths
output_main_p = "/content/positive_main_tpc.csv"
output_main_n = "/content/negative_main_tpc.csv"
output_validation_p = "/content/positive_validation_tpc.csv"
output_validation_n = "/content/negative_validation_tpc.csv"

# Process and save
process_fasta(main_p, output_main_p)
process_fasta(main_n, output_main_n)
process_fasta(validation_p, output_validation_p)
process_fasta(validation_n, output_validation_n)

# %% [markdown]
# # **All Model **

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/positive_main_tpc.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/negative_main_tpc (1).csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/positive_validation_tpc.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/10_TPC (Tripeptide Composition)/negative_validation_tpc.csv")

# %%
# Label the datasets
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the neural network models
models["Neural Network"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
models["MLP"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Store accuracies
results = []

# Train each model and evaluate
for name, model in models.items():
    print(f"\nTraining {name}...")

    if name in ["Neural Network", "MLP"]:
        # Neural Network training
        model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=0)
        train_pred = (model.predict(X_train) > 0.5).astype("int32")
        val_pred = (model.predict(X_val) > 0.5).astype("int32")
    else:
        # Traditional ML model training
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        val_pred = model.predict(X_val)

    # Calculate train and validation accuracy
    train_accuracy = accuracy_score(y_train, train_pred)
    val_accuracy = accuracy_score(y_val, val_pred)

    results.append({"Model": name, "Train Accuracy": train_accuracy, "Validation Accuracy": val_accuracy})
# Out:
# Training SVM...
#
# Training Decision Tree...
#
# Training Random Forest...
#
# Training Logistic Regression...
#
# Training k-NN...
#
# Training Naive Bayes...
#
# Training Gradient Boosting...
#
# Training XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:59:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Training CatBoost...
#
# Training AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training Neural Network...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Training MLP...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Convert to DataFrame and sort by Validation Accuracy and Train Accuracy in descending order
results_df = pd.DataFrame(results).sort_values(by=["Validation Accuracy", "Train Accuracy"], ascending=False).reset_index(drop=True)

# Display results
print("\nModel Accuracy Table (Descending Order of Validation Accuracy)")
print(results_df)
# Out:
# Model Accuracy Table (Descending Order of Validation Accuracy)
#                   Model  Train Accuracy  Validation Accuracy
# 0         Random Forest        0.995704             0.926667
# 1         Decision Tree        0.995704             0.913333
# 2        Neural Network        0.995704             0.906667
# 3                   MLP        0.995704             0.903333
# 4              CatBoost        0.970790             0.900000
# 5               XGBoost        0.963918             0.896667
# 6              AdaBoost        0.939863             0.890000
# 7     Gradient Boosting        0.939863             0.876667
# 8           Naive Bayes        0.959622             0.866667
# 9                  k-NN        0.928694             0.856667
# 10             LightGBM        0.887457             0.840000
# 11  Logistic Regression        0.849656             0.823333
# 12                  SVM        0.809278             0.773333

# %% [markdown]
# # **CROSS VALIDATION**

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
# Define Neural Network models
def create_neural_network(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

def create_mlp(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Cross-validation for traditional models
results = []

# For traditional ML models, we use cross_val_score
for name, model in models.items():
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Calculate cross-validation accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    mean_accuracy = np.mean(cv_scores)
    std_accuracy = np.std(cv_scores)

    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})

# Cross-validation for Neural Networks (manual implementation)
for name, create_model in [("Neural Network", create_neural_network), ("MLP", create_mlp)]:
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Custom function to calculate accuracy for neural networks
    def neural_network_cross_val(model_func, X_train, y_train):
        accuracies = []
        for train_index, val_index in cv.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = model_func(X_train.shape[1])  # Create a new model for each fold
            model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=32, verbose=0)

            y_pred = (model.predict(X_val_fold) > 0.5).astype("int32")
            accuracy = accuracy_score(y_val_fold, y_pred)
            accuracies.append(accuracy)

        return np.mean(accuracies), np.std(accuracies)

    mean_accuracy, std_accuracy = neural_network_cross_val(create_model, X_train, y_train)
    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})
# Out:
# Performing Cross-validation for SVM...
#
# Performing Cross-validation for Decision Tree...
#
# Performing Cross-validation for Random Forest...
#
# Performing Cross-validation for Logistic Regression...
#
# Performing Cross-validation for k-NN...
#
# Performing Cross-validation for Naive Bayes...
#
# Performing Cross-validation for Gradient Boosting...
#
# Performing Cross-validation for XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:06:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:06:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:07:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:07:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:07:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Performing Cross-validation for LightGBM...
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 631
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 81
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000955 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 610
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000982 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 621
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 77
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001043 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 654
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 84
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 466
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 603
# [LightGBM] [Info] Number of data points in the train set: 932, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Performing Cross-validation for CatBoost...
#
# Performing Cross-validation for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing Cross-validation for Neural Network...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7809b1a48670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7809b1a312d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Performing Cross-validation for MLP...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Convert to DataFrame and display
cv_results_df = pd.DataFrame(results).sort_values(by="Mean CV Accuracy", ascending=False).reset_index(drop=True)
print("\nCross-Validation Accuracy Table")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Table
#                   Model  Mean CV Accuracy  STD CV Accuracy
# 0                   MLP          0.932992         0.004345
# 1        Neural Network          0.925259         0.008398
# 2         Random Forest          0.919239         0.011677
# 3              CatBoost          0.898613         0.018209
# 4           Naive Bayes          0.892648         0.025944
# 5               XGBoost          0.888320         0.013813
# 6         Decision Tree          0.869406         0.018605
# 7     Gradient Boosting          0.868555         0.017520
# 8              AdaBoost          0.866845         0.015296
# 9                  k-NN          0.856504         0.022010
# 10  Logistic Regression          0.804976         0.016045
# 11             LightGBM          0.784372         0.013287
# 12                  SVM          0.766320         0.012068

# %% [markdown]
# # **Hyperparameter optimization with Optuna**

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 13.7 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 10.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_main_tpc.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_main_tpc (1).csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_validation_tpc.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_validation_tpc.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]



# Define models with MLP included
models = {
    "SVM": lambda trial: SVC(
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}


results = []

def optimize_model(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        return accuracy_score(y_val, preds)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the results
    results.append({
        "Model": model_name,
        "Accuracy": study.best_value,
        "Best Params": study.best_params
    })

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model(model_name, model_func)


# Convert results to a DataFrame
results_df = pd.DataFrame(results)


# Display the DataFrame
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2025-01-09 12:44:45,792] A new study created in memory with name: no-name-ae6c1430-21bc-496f-a97e-12f78d739c7b
# Optimizing SVM...
# [I 2025-01-09 12:44:56,357] Trial 0 finished with value: 0.9033333333333333 and parameters: {'C': 5.157137305824213, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:01,139] Trial 1 finished with value: 0.8766666666666667 and parameters: {'C': 5.440333510640703, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:08,342] Trial 2 finished with value: 0.8966666666666666 and parameters: {'C': 6.586790435439739, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:17,761] Trial 3 finished with value: 0.9033333333333333 and parameters: {'C': 2.568006909352526, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:22,999] Trial 4 finished with value: 0.8866666666666667 and parameters: {'C': 6.06768284122189, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:27,593] Trial 5 finished with value: 0.8866666666666667 and parameters: {'C': 6.357632173664195, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:37,232] Trial 6 finished with value: 0.8333333333333334 and parameters: {'C': 4.318703504934361, 'kernel': 'poly'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:44,304] Trial 7 finished with value: 0.8833333333333333 and parameters: {'C': 3.7275093271339768, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 12:45:54,233] Trial 8 finished with value: 0.9066666666666666 and parameters: {'C': 1.4844504033388803, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:03,688] Trial 9 finished with value: 0.8566666666666667 and parameters: {'C': 5.954631879472954, 'kernel': 'poly'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:13,232] Trial 10 finished with value: 0.8833333333333333 and parameters: {'C': 0.41928587907614157, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:29,064] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 9.44137618859141, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:40,098] Trial 12 finished with value: 0.8 and parameters: {'C': 0.14735974557362974, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:49,710] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 2.2952691741283986, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:46:59,553] Trial 14 finished with value: 0.9033333333333333 and parameters: {'C': 8.003886815410494, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:47:09,588] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 1.919249716095853, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12:47:18,944] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 3.593790273474066, 'kernel': 'rbf'}. Best is trial 8 with value: 0.9066666666666666.
# [I 2025-01-09 12
# [I 2025-01-09 12:49:21,272] Trial 9 finished with value: 0.7933333333333333 and parameters: {'max_depth': 9, 'min_samples_split': 5}. Best is trial 8 with value: 0.8633333333333333.
# [I 2025-01-09 12:49:21,870] Trial 10 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 7}. Best is trial 8 with value: 0.8633333333333333.
# [I 2025-01-09 12:49:22,492] Trial 11 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 7}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:23,113] Trial 12 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 7}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:23,668] Trial 13 finished with value: 0.8466666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 9}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:24,097] Trial 14 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 6}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:24,420] Trial 15 finished with value: 0.82 and parameters: {'max_depth': 14, 'min_samples_split': 8}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:24,794] Trial 16 finished with value: 0.8466666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 5}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:25,202] Trial 17 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:25,539] Trial 18 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 6}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:25,820] Trial 19 finished with value: 0.81 and parameters: {'max_depth': 11, 'min_samples_split': 5}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:26,196] Trial 20 finished with value: 0.8466666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 8}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:26,561] Trial 21 finished with value: 0.8666666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:26,935] Trial 22 finished with value: 0.8666666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:27,267] Trial 23 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:27,651] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:28,015] Trial 25 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:28,199] Trial 26 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 7}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:28,528] Trial 27 finished with value: 0.83 and parameters: {'max_depth': 15, 'min_samples_split': 5}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:28,902] Trial 28 finished with value: 0.86 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:29,250] Trial 29 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 8}. Best is trial 11 with value: 0.8666666666666667.
# [I 2025-01-09 12:49:29,252] A new study created in memory with name: no-name-db8eb711-fcaa-44a9-9773-600d03abeebe
# Optimizing Random Forest...
# [I 2025-01-09 12:49:30,305] Trial 0 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 262, 'max_depth': 6, 'min_samples_split': 2}. Best is trial 0 with value: 0.8166666666666667.
# [I 2025-01-09 12:49:31,396] Trial 1 finished with value: 0.86 and parameters: {'n_estimators': 178, 'max_depth': 14, 'min_samples_split': 8}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:32,033] Trial 2 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 88, 'max_depth': 15, 'min_samples_split': 6}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:34,292] Trial 3 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 399, 'max_depth': 11, 'min_samples_split': 3}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:36,556] Trial 4 finished with value: 0.83 and parameters: {'n_estimators': 367, 'max_depth': 6, 'min_samples_split': 10}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:38,416] Trial 5 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 268, 'max_depth': 8, 'min_samples_split': 3}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:38,907] Trial 6 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 69, 'max_depth': 14, 'min_samples_split': 10}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:40,324] Trial 7 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 493, 'max_depth': 3, 'min_samples_split': 7}. Best is trial 1 with value: 0.86.
# [I 2025-01-09 12:49:41,364] Trial 8 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 177, 'max_depth': 13, 'min_samples_split': 9}. Best is trial 8 with value: 0.8733333333333333.
# [I 2025-01-09 12:49:41,918] Trial 9 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 61, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:43,171] Trial 10 finished with value: 0.87 and parameters: {'n_estimators': 157, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:44,553] Trial 11 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 176, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:45,405] Trial 12 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 115, 'max_depth': 17, 'min_samples_split': 8}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:46,659] Trial 13 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 215, 'max_depth': 11, 'min_samples_split': 4}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:47,101] Trial 14 finished with value: 0.87 and parameters: {'n_estimators': 52, 'max_depth': 17, 'min_samples_split': 9}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:48,035] Trial 15 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 129, 'max_depth': 17, 'min_samples_split': 6}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:51,008] Trial 16 finished with value: 0.84 and parameters: {'n_estimators': 333, 'max_depth': 9, 'min_samples_split': 2}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:53,089] Trial 17 finished with value: 0.84 and parameters: {'n_estimators': 225, 'max_depth': 13, 'min_samples_split': 8}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:54,063] Trial 18 finished with value: 0.87 and parameters: {'n_estimators': 118, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:55,120] Trial 19 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 213, 'max_depth': 9, 'min_samples_split': 7}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:57,284] Trial 20 finished with value: 0.86 and parameters: {'n_estimators': 297, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:58,654] Trial 21 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 184, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:49:59,793] Trial 22 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 137, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:00,556] Trial 23 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 100, 'max_depth': 16, 'min_samples_split': 5}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:02,076] Trial 24 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 187, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:02,482] Trial 25 finished with value: 0.85 and parameters: {'n_estimators': 50, 'max_depth': 13, 'min_samples_split': 3}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:04,949] Trial 26 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 243, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:08,284] Trial 27 finished with value: 0.87 and parameters: {'n_estimators': 297, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:11,464] Trial 28 finished with value: 0.87 and parameters: {'n_estimators': 436, 'max_depth': 19, 'min_samples_split': 3}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:13,167] Trial 29 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 242, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 9 with value: 0.8933333333333333.
# [I 2025-01-09 12:50:13,171] A new study created in memory with name: no-name-2ff24165-ff0c-4e29-9e46-bab180a68a1a
# Optimizing Logistic Regression...
# [I 2025-01-09 12:50:13,372] Trial 0 finished with value: 0.8833333333333333 and parameters: {'C': 6.533464638260647, 'solver': 'liblinear'}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-09 12:50:13,801] Trial 1 finished with value: 0.8866666666666667 and parameters: {'C': 9.913998897787232, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-09 12:50:14,035] Trial 2 finished with value: 0.8766666666666667 and parameters: {'C': 4.34884549798885, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-09 12:50:14,272] Trial 3 finished with value: 0.8666666666666667 and parameters: {'C': 2.6469067717233514, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8866666666666667.
# [I 2025-01-09 12:50
finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:35,583] Trial 12 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:35,990] Trial 13 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:36,394] Trial 14 finished with value: 0.87 and parameters: {'n_neighbors': 13}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:36,800] Trial 15 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:37,220] Trial 16 finished with value: 0.8733333333333333 and parameters: {'n_neighbors': 8}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:37,809] Trial 17 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 14}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:38,451] Trial 18 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 17}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:39,082] Trial 19 finished with value: 0.87 and parameters: {'n_neighbors': 10}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:39,694] Trial 20 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:40,315] Trial 21 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:40,918] Trial 22 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:41,548] Trial 23 finished with value: 0.88 and parameters: {'n_neighbors': 9}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:42,183] Trial 24 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 12}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:42,799] Trial 25 finished with value: 0.8433333333333334 and parameters: {'n_neighbors': 7}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:43,197] Trial 26 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 11}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:50:43,595] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-09 12:50:43,984] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_neighbors': 3}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-09 12:50:44,386] Trial 29 finished with value: 0.86 and parameters: {'n_neighbors': 4}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-09 12:50:44,388] A new study created in memory with name: no-name-9aac05b5-ef99-49e9-903b-928c06fb50db
# Optimizing Naive Bayes...
# [I 2025-01-09 12:50:44,705] Trial 0 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:44,988] Trial 1 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:45,263] Trial 2 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:45,562] Trial 3 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:45,849] Trial 4 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:46,126] Trial 5 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:46,409] Trial 6 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:46,688] Trial 7 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:46,963] Trial 8 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:47,239] Trial 9 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:47,518] Trial 10 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:47,794] Trial 11 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:48,073] Trial 12 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:48,353] Trial 13 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:48,647] Trial 14 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:48,927] Trial 15 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:49,204] Trial 16 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:49,496] Trial 17 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:49,777] Trial 18 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:50,056] Trial 19 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:50,336] Trial 20 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:50,629] Trial 21 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:50,910] Trial 22 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:51,186] Trial 23 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:51,476] Trial 24 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:51,782] Trial 25 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:52,059] Trial 26 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:52,358] Trial 27 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:52,648] Trial 28 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:52,970] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-09 12:50:52,976] A new study created in memory with name: no-name-4d8c58aa-2270-494c-8353-6a93a4caa452
# Optimizing Gradient Boosting...
# [I 2025-01-09 12:51:14,969] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 289, 'learning_rate': 0.3842903994135972, 'max_depth': 3}. Best is trial 0 with value: 0.88.
# [I 2025-01-09 12:51:58,484] Trial 1 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 340, 'learning_rate': 0.15524974744822628, 'max_depth': 6}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:52:12,837] Trial 2 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 157, 'learning_rate': 0.34192793462483645, 'max_depth': 4}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:53:54,219] Trial 3 finished with value: 0.88 and parameters: {'n_estimators': 282, 'learning_rate': 0.4910033291185185, 'max_depth': 20}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:54:37,522] Trial 4 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 300, 'learning_rate': 0.4154426626754472, 'max_depth': 7}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:55:45,344] Trial 5 finished with value: 0.89 and parameters: {'n_estimators': 192, 'learning_rate': 0.0767590887177093, 'max_depth': 19}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:56:53,938] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 464, 'learning_rate': 0.15682922271862448, 'max_depth': 7}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:57:32,484] Trial 7 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 210, 'learning_rate': 0.21549042299181426, 'max_depth': 9}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:58:03,532] Trial 8 finished with value: 0.88 and parameters: {'n_estimators': 345, 'learning_rate': 0.4767981732411316, 'max_depth': 4}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-09 12:58:53,216] Trial 9 finished with value: 0.8766666666666667 and parameters: {'n_estimators':
. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:17:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:18:00,082] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 359, 'max_depth': 6, 'learning_rate': 0.29965597835048163}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:18:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:18:21,119] Trial 6 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 320, 'max_depth': 7, 'learning_rate': 0.10031212588993577}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:18:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:18:47,780] Trial 7 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 386, 'max_depth': 9, 'learning_rate': 0.2616679333063808}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:18:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:19:04,407] Trial 8 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 240, 'max_depth': 7, 'learning_rate': 0.40723545371728975}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:19:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:19:13,930] Trial 9 finished with value: 0.9 and parameters: {'n_estimators': 106, 'max_depth': 4, 'learning_rate': 0.49298159084460014}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:19:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:19:27,353] Trial 10 finished with value: 0.89 and parameters: {'n_estimators': 164, 'max_depth': 13, 'learning_rate': 0.034351759721283265}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:19:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:19:45,502] Trial 11 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 213, 'max_depth': 13, 'learning_rate': 0.3742830172300473}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:19:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:20:02,449] Trial 12 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 213, 'max_depth': 12, 'learning_rate': 0.3867543276003511}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:20:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:20:09,420] Trial 13 finished with value: 0.91 and parameters: {'n_estimators': 51, 'max_depth': 14, 'learning_rate': 0.48626089393663596}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:20:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:20:18,017] Trial 14 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 51, 'max_depth': 15, 'learning_rate': 0.4980672643750595}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:20:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:20:32,482] Trial 15 finished with value: 0.91 and parameters: {'n_estimators': 135, 'max_depth': 20, 'learning_rate': 0.17316875974120732}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:20:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:20:39,874] Trial 16 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 58, 'max_depth': 9, 'learning_rate': 0.4415355790946761}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:20:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:21:14,184] Trial 17 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 499, 'max_depth': 11, 'learning_rate': 0.36033412121756203}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:21:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:21:45,900] Trial 18 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 408, 'max_depth': 10, 'learning_rate': 0.4459803249551322}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:21:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:22:01,234] Trial 19 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 167, 'max_depth': 15, 'learning_rate': 0.15070378843287968}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:22:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:22:13,790] Trial 20 finished with value: 0.91 and parameters: {'n_estimators': 105, 'max_depth': 14, 'learning_rate': 0.346823643929266}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:22:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 13:22:27,500] Trial 21 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 124, 'max_depth': 20, 'learning_rate': 0.1992242436500372}. Best is trial 2 with value: 0.9133333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [13:22:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# [I 2025-01-09 13:36:17,752] Trial 28 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 417, 'learning_rate': 0.010347827769388251}. Best is trial 18 with value: 0.8866666666666667.
# [I 2025-01-09 13:36:53,176] Trial 29 finished with value: 0.79 and parameters: {'n_estimators': 478, 'learning_rate': 0.43457267019603263}. Best is trial 18 with value: 0.8866666666666667.
# [I 2025-01-09 13:36:53,179] A new study created in memory with name: no-name-ceaaffaa-ccb3-4e37-86a0-25c06faa7ca6
# Optimizing Neural Network...
# [I 2025-01-09 13:37:14,582] Trial 0 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 90, 'learning_rate_init': 0.010882835768780751}. Best is trial 0 with value: 0.8966666666666666.
# [I 2025-01-09 13:37:29,317] Trial 1 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 11, 'hidden_layer_2': 36, 'learning_rate_init': 0.0597010622485078}. Best is trial 1 with value: 0.9033333333333333.
# [I 2025-01-09 13:37:50,023] Trial 2 finished with value: 0.9 and parameters: {'hidden_layer_1': 51, 'hidden_layer_2': 54, 'learning_rate_init': 0.07957555377787122}. Best is trial 1 with value: 0.9033333333333333.
# [I 2025-01-09 13:38:05,934] Trial 3 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 49, 'hidden_layer_2': 27, 'learning_rate_init': 0.04404997770702086}. Best is trial 3 with value: 0.9066666666666666.
# [I 2025-01-09 13:38:30,090] Trial 4 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 83, 'hidden_layer_2': 75, 'learning_rate_init': 0.045047190112573306}. Best is trial 3 with value: 0.9066666666666666.
# [I 2025-01-09 13:39:04,122] Trial 5 finished with value: 0.92 and parameters: {'hidden_layer_1': 93, 'hidden_layer_2': 86, 'learning_rate_init': 0.06858199456122811}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:39:15,117] Trial 6 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 27, 'hidden_layer_2': 13, 'learning_rate_init': 0.0519050698289236}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:39:22,660] Trial 7 finished with value: 0.89 and parameters: {'hidden_layer_1': 23, 'hidden_layer_2': 26, 'learning_rate_init': 0.025813426722128812}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:39:50,452] Trial 8 finished with value: 0.91 and parameters: {'hidden_layer_1': 76, 'hidden_layer_2': 85, 'learning_rate_init': 0.0035767086705679836}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:40:18,099] Trial 9 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 31, 'learning_rate_init': 0.09071282472915326}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:40:39,658] Trial 10 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 60, 'learning_rate_init': 0.07339362695581235}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:40:56,550] Trial 11 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 72, 'hidden_layer_2': 97, 'learning_rate_init': 0.0141023700982041}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:41:57,562] Trial 12 finished with value: 0.9 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 81, 'learning_rate_init': 0.0011872399761094499}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:42:24,977] Trial 13 finished with value: 0.9 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 68, 'learning_rate_init': 0.03188438793355268}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:42:52,313] Trial 14 finished with value: 0.91 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 87, 'learning_rate_init': 0.09824345492793675}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:43:25,592] Trial 15 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 98, 'learning_rate_init': 0.07189164669103112}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:44:04,924] Trial 16 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 51, 'learning_rate_init': 0.05927679451038659}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:44:18,723] Trial 17 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 71, 'learning_rate_init': 0.03188343801447493}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:45:00,429] Trial 18 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 79, 'hidden_layer_2': 81, 'learning_rate_init': 0.08428062118585178}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:45:20,921] Trial 19 finished with value: 0.92 and parameters: {'hidden_layer_1': 58, 'hidden_layer_2': 63, 'learning_rate_init': 0.08759229652531766}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:45:42,714] Trial 20 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 44, 'learning_rate_init': 0.0660651024745656}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:45:58,779] Trial 21 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 66, 'learning_rate_init': 0.08454043063102332}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:46:26,727] Trial 22 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 77, 'learning_rate_init': 0.09649639005430909}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:46:50,787] Trial 23 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 63, 'learning_rate_init': 0.08612334652400704}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:47:09,967] Trial 24 finished with value: 0.9 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 93, 'learning_rate_init': 0.07658394407274385}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:47:27,650] Trial 25 finished with value: 0.91 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 81, 'learning_rate_init': 0.06530846275092755}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:47:48,144] Trial 26 finished with value: 0.92 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 72, 'learning_rate_init': 0.08987401346746549}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:48:07,438] Trial 27 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 47, 'learning_rate_init': 0.09380989861598756}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:48:30,537] Trial 28 finished with value: 0.89 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 73, 'learning_rate_init': 0.09957792033588353}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:48:46,862] Trial 29 finished with value: 0.9 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 58, 'learning_rate_init': 0.08887001312542468}. Best is trial 5 with value: 0.92.
# [I 2025-01-09 13:48:46,868] A new study created in memory with name: no-name-ab220188-9873-474b-a2bb-1d9ba068964d
# Optimizing MLP...
# [I 2025-01-09 13:49:22,019] Trial 0 finished with value: 0.9166666666666666 and parameters: {'layer_1': 51, 'layer_2': 58, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09490444687482802}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:49:29,030] Trial 1 finished with value: 0.5 and parameters: {'layer_1': 92, 'layer_2': 140, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.015123139097679233}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:49:43,129] Trial 2 finished with value: 0.5 and parameters: {'layer_1': 142, 'layer_2': 50, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.06833250810577617}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:49:52,621] Trial 3 finished with value: 0.5 and parameters: {'layer_1': 87, 'layer_2': 58, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.08128143091345429}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:50:18,364] Trial 4 finished with value: 0.9066666666666666 and parameters: {'layer_1': 100, 'layer_2': 130, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0819020149355856}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:51:41,993] Trial 5 finished with value: 0.9133333333333333 and parameters: {'layer_1': 123, 'layer_2': 87, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.023287767412870756}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:52:20,719] Trial 6 finished with value: 0.8966666666666666 and parameters: {'layer_1': 93, 'layer_2': 87, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.09879357172714051}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:53:17,915] Trial 7 finished with value: 0.9 and parameters: {'layer_1': 55, 'layer_2': 80, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.025814206303297116}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 13:53:34,139] Trial 8 finished with value: 0.8733333333333333 and parameters: {'layer_1': 66, 'layer_2': 86, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.08440590666138648}. Best is trial 0 with value: 0.9166666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 13:54:50,100] Trial 9 finished with value: 0.92 and parameters: {'layer_1': 67, 'layer_2': 61, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.015163409326701589}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:55:03,712] Trial 10 finished with value: 0.92 and parameters: {'layer_1': 75, 'layer_2': 117, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04380603641741177}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:55:26,568] Trial 11 finished with value: 0.9066666666666666 and parameters: {'layer_1': 74, 'layer_2': 114, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04282132308521482}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:56:15,042] Trial 12 finished with value: 0.9 and parameters: {'layer_1': 75, 'layer_2': 115, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0013028892889503513}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:56:46,441] Trial 13 finished with value: 0.92 and parameters: {'layer_1': 116, 'layer_2': 110, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0479205505164052}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:57:01,469] Trial 14 finished with value: 0.91 and parameters: {'layer_1': 67, 'layer_2': 70, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03586004415554855}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:57:18,728] Trial 15 finished with value: 0.9066666666666666 and parameters: {'layer_1': 81, 'layer_2': 102, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05911880761273905}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:57:40,779] Trial 16 finished with value: 0.8933333333333333 and parameters: {'layer_1': 110, 'layer_2': 127, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.007379652374015937}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:57:52,446] Trial 17 finished with value: 0.9 and parameters: {'layer_1': 62, 'layer_2': 146, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.035602474539816804}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:58:25,488] Trial 18 finished with value: 0.9133333333333333 and parameters: {'layer_1': 79, 'layer_2': 100, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.06133835409964887}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:58:32,656] Trial 19 finished with value: 0.5 and parameters: {'layer_1': 59, 'layer_2': 128, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.020538606213610932}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 13:59:58,601] Trial 20 finished with value: 0.82 and parameters: {'layer_1': 150, 'layer_2': 73, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.03452012420871961}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:00:24,737] Trial 21 finished with value: 0.9133333333333333 and parameters: {'layer_1': 121, 'layer_2': 104, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04838267274673889}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:00:43,368] Trial 22 finished with value: 0.9166666666666666 and parameters: {'layer_1': 109, 'layer_2': 115, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.052701927916099484}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:01:13,211] Trial 23 finished with value: 0.92 and parameters: {'layer_1': 128, 'layer_2': 96, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04340024540333656}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:01:43,847] Trial 24 finished with value: 0.9133333333333333 and parameters: {'layer_1': 103, 'layer_2': 111, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06758720876650874}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:02:02,355] Trial 25 finished with value: 0.9066666666666666 and parameters: {'layer_1': 132, 'layer_2': 122, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.028662635797280647}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:02:21,739] Trial 26 finished with value: 0.9033333333333333 and parameters: {'layer_1': 112, 'layer_2': 93, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.017332457407891577}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:02:48,026] Trial 27 finished with value: 0.91 and parameters: {'layer_1': 70, 'layer_2': 138, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05343091495735551}. Best is trial 9 with value: 0.92.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 14:04:17,924] Trial 28 finished with value: 0.9033333333333333 and parameters: {'layer_1': 84, 'layer_2': 109, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.010481502729736952}. Best is trial 9 with value: 0.92.
# [I 2025-01-09 14:04:23,745] Trial 29 finished with value: 0.5 and parameters: {'layer_1': 50, 'layer_2': 122, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.07291529406583604}. Best is trial 9 with value: 0.92.
#                   Model  Accuracy  \
# 0                   SVM  0.906667
# 1         Decision Tree  0.866667
# 2         Random Forest  0.893333
# 3   Logistic Regression  0.893333
# 4                  k-NN  0.883333
# 5           Naive Bayes  0.866667
# 6     Gradient Boosting  0.900000
# 7               XGBoost  0.913333
# 8              LightGBM  0.853333
# 9              AdaBoost  0.886667
# 10       Neural Network  0.920000
# 11                  MLP  0.920000
#
#                                           Best Params
# 0          {'C': 1.4844504033388803, 'kernel': 'rbf'}
# 1           {'max_depth': 20, 'min_samples_split': 7}
# 2   {'n_estimators': 61, 'max_depth': 20, 'min_sam...
# 3         {'C': 9.988533805424675, 'solver': 'lbfgs'}
# 4                                  {'n_neighbors': 3}
# 5                                                  {}
# 6   {'n_estimators': 96, 'learning_rate': 0.263784...
# 7   {'n_estimators': 255, 'max_depth': 11, 'learni...
# 8   {'n_estimators': 229, 'max_depth': 17, 'learni...
# 9   {'n_estimators': 488, 'learning_rate': 0.99099...
# 10  {'hidden_layer_1': 93, 'hidden_layer_2': 86, '...
# 11  {'layer_1': 67, 'layer_2': 61, 'activation': '...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, cohen_kappa_score, roc_auc_score # Import confusion_matrix and other metrics

# Function to calculate metrics with model name
def calculate_metrics(y_true, y_pred, model_name=None):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    mcc = matthews_corrcoef(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "Kappa": kappa,
        "AUC": auc,
    }

# Results storage
results = []

# Optimization function
def optimize_model_with_metrics(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        trial.set_user_attr("preds", preds)
        metrics = calculate_metrics(y_val, preds, model_name=model_name)
        return metrics["Accuracy"]

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the best trial metrics
    best_trial_preds = study.best_trial.user_attrs["preds"]
    best_metrics = calculate_metrics(y_val, best_trial_preds, model_name=model_name)
    best_metrics["Best Params"] = study.best_params
    results.append(best_metrics)

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model_with_metrics(model_name, model_func)

# Store the final results with selected metrics and best parameters
final_results = []
for result in results:
    final_results.append(
        {
            "Model": result["Model"],
            "Accuracy": result["Accuracy"],
            "Sensitivity": result["Sensitivity"],
            "Specificity": result["Specificity"],
            "MCC": result["MCC"],
            "Kappa": result["Kappa"],
            "AUC": result["AUC"],
            "Best Params": result["Best Params"],
        }
    )

# Convert results to a DataFrame and display it
final_results_df = pd.DataFrame(final_results)
print(final_results_df)
# Out:
# [I 2025-01-09 14:04:56,893] A new study created in memory with name: no-name-7bea2d43-44d0-4544-aa68-4641afb0ce71
# Optimizing SVM...
# [I 2025-01-09 14:05:02,800] Trial 0 finished with value: 0.8633333333333333 and parameters: {'C': 3.464289084451455, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2025-01-09 14:05:11,647] Trial 1 finished with value: 0.8366666666666667 and parameters: {'C': 1.4412721924465302, 'kernel': 'linear'}. Best is trial 0 with value: 0.8633333333333333.
# [I 2025-01-09 14:05:21,775] Trial 2 finished with value: 0.9033333333333333 and parameters: {'C': 6.703779296188013, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:05:26,697] Trial 3 finished with value: 0.8666666666666667 and parameters: {'C': 4.364403984502521, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:05:36,266] Trial 4 finished with value: 0.79 and parameters: {'C': 1.9154649505584882, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:05:42,417] Trial 5 finished with value: 0.8833333333333333 and parameters: {'C': 1.1547235943098157, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:05:53,486] Trial 6 finished with value: 0.7966666666666666 and parameters: {'C': 0.16109750049938254, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:05:58,455] Trial 7 finished with value: 0.88 and parameters: {'C': 5.65625115308645, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:03,966] Trial 8 finished with value: 0.8733333333333333 and parameters: {'C': 4.260702734933998, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:08,708] Trial 9 finished with value: 0.8866666666666667 and parameters: {'C': 6.549347876466768, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:18,763] Trial 10 finished with value: 0.9033333333333333 and parameters: {'C': 9.32614702929045, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:28,498] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 9.51607202340876, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:38,436] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 8.532577836320797, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:48,585] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 7.892814118370428, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:06:58,290] Trial 14 finished with value: 0.9033333333333333 and parameters: {'C': 7.258208194995156, 'kernel': 'rbf'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14:07:08,228] Trial 15 finished with value: 0.8633333333333333 and parameters: {'C': 9.815813229832603, 'kernel': 'poly'}. Best is trial 2 with value: 0.9033333333333333.
# [I 2025-01-09 14
and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 11 with value: 0.86.
# [I 2025-01-09 14:09:24,972] Trial 13 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:25,178] Trial 14 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 4}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:25,518] Trial 15 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 3}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:25,869] Trial 16 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 5}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:26,228] Trial 17 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 6}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:26,737] Trial 18 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:27,284] Trial 19 finished with value: 0.84 and parameters: {'max_depth': 15, 'min_samples_split': 8}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:28,005] Trial 20 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 4}. Best is trial 13 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:29,944] Trial 21 finished with value: 0.8733333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:32,074] Trial 22 finished with value: 0.85 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:32,868] Trial 23 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:33,626] Trial 24 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:34,463] Trial 25 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 5}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:34,829] Trial 26 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:35,191] Trial 27 finished with value: 0.8433333333333334 and parameters: {'max_depth': 17, 'min_samples_split': 4}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:35,569] Trial 28 finished with value: 0.8533333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 5}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:35,908] Trial 29 finished with value: 0.8433333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 5}. Best is trial 21 with value: 0.8733333333333333.
# [I 2025-01-09 14:09:35,919] A new study created in memory with name: no-name-f7e03cba-e9f5-4e68-94d8-5b84b6fd210b
# Optimizing Random Forest...
# [I 2025-01-09 14:09:37,945] Trial 0 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 423, 'max_depth': 9, 'min_samples_split': 3}. Best is trial 0 with value: 0.8466666666666667.
# [I 2025-01-09 14:09:40,733] Trial 1 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 426, 'max_depth': 17, 'min_samples_split': 10}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:44,672] Trial 2 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 473, 'max_depth': 16, 'min_samples_split': 7}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:47,824] Trial 3 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 377, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:50,387] Trial 4 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 355, 'max_depth': 17, 'min_samples_split': 2}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:52,250] Trial 5 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 279, 'max_depth': 17, 'min_samples_split': 10}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:53,767] Trial 6 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 232, 'max_depth': 16, 'min_samples_split': 7}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:55,662] Trial 7 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 364, 'max_depth': 11, 'min_samples_split': 7}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:56,793] Trial 8 finished with value: 0.84 and parameters: {'n_estimators': 164, 'max_depth': 11, 'min_samples_split': 7}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:58,419] Trial 9 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 201, 'max_depth': 10, 'min_samples_split': 10}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:09:58,898] Trial 10 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 1 with value: 0.8666666666666667.
# [I 2025-01-09 14:10:02,077] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 325, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 11 with value: 0.8766666666666667.
# [I 2025-01-09 14:10:05,703] Trial 12 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 498, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 11 with value: 0.8766666666666667.
# [I 2025-01-09 14:10:08,259] Trial 13 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 331, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:10,569] Trial 14 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 298, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:13,641] Trial 15 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 319, 'max_depth': 14, 'min_samples_split': 4}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:15,193] Trial 16 finished with value: 0.88 and parameters: {'n_estimators': 120, 'max_depth': 20, 'min_samples_split': 5}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:15,919] Trial 17 finished with value: 0.86 and parameters: {'n_estimators': 109, 'max_depth': 13, 'min_samples_split': 6}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:16,646] Trial 18 finished with value: 0.7966666666666666 and parameters: {'n_estimators': 142, 'max_depth': 8, 'min_samples_split': 5}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:16,962] Trial 19 finished with value: 0.81 and parameters: {'n_estimators': 58, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:17,914] Trial 20 finished with value: 0.8266666666666667 and parameters: {'n_estimators': 237, 'max_depth': 6, 'min_samples_split': 8}. Best is trial 13 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:20,406] Trial 21 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 328, 'max_depth': 20, 'min_samples_split': 4}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:22,378] Trial 22 finished with value: 0.88 and parameters: {'n_estimators': 258, 'max_depth': 19, 'min_samples_split': 3}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:23,812] Trial 23 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 193, 'max_depth': 19, 'min_samples_split': 6}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:27,165] Trial 24 finished with value: 0.86 and parameters: {'n_estimators': 431, 'max_depth': 14, 'min_samples_split': 4}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:30,808] Trial 25 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 392, 'max_depth': 18, 'min_samples_split': 5}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:33,499] Trial 26 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 376, 'max_depth': 18, 'min_samples_split': 3}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:35,867] Trial 27 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 398, 'max_depth': 14, 'min_samples_split': 6}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:38,323] Trial 28 finished with value: 0.86 and parameters: {'n_estimators': 342, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:43,680] Trial 29 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 446, 'max_depth': 18, 'min_samples_split': 2}. Best is trial 21 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:43,697] A new study created in memory with name: no-name-e80aafc1-8115-4f0b-83c2-93327ef30107
# Optimizing Logistic Regression...
# [I 2025-01-09 14:10:44,121] Trial 0 finished with value: 0.8033333333333333 and parameters: {'C': 0.6760164239856044, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8033333333333333.
# [I 2025-01-09 14:10:44,359] Trial 1 finished with value: 0.8833333333333333 and parameters: {'C': 6.653849573298111, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:44,765] Trial 2 finished with value: 0.83 and parameters: {'C': 1.2563829756465896, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:45,241] Trial 3 finished with value: 0.8833333333333333 and parameters: {'C': 6.242116469922569, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:45,662] Trial 4 finished with value: 0.8633333333333333 and parameters: {'C': 2.514827590362242, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:46,094] Trial 5 finished with value: 0.8133333333333334 and parameters: {'C': 0.820801550526398, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8833333333333333.
# [I 2025-01-09 14:10:46,371] Trial 6 finished with value: 0.8866666666666667 and parameters: {'C': 5.032151799251192, 'solver': 'liblinear'}. Best is trial 6 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:46,624] Trial 7 finished with value: 0.8866666666666667 and parameters: {'C': 5.385683401099813, 'solver': 'liblinear'}. Best is trial 6 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:47,069] Trial 8 finished with value: 0.8866666666666667 and parameters: {'C': 8.019174150262376, 'solver': 'lbfgs'}. Best is trial 6 with value: 0.8866666666666667.
# [I 2025-01-09 14:10:47,440] Trial 9 finished with value: 0.8666666666666667 and parameters: {'C': 2.8030725334136153, 'solver': 'lbfgs'}. Best is trial 6 with value: 0.8866666666666667.
# [I 2025-01-09 14:10
. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:56:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:56:52,668] Trial 12 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 413, 'max_depth': 15, 'learning_rate': 0.1616707882403143}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:56:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:57:05,223] Trial 13 finished with value: 0.9 and parameters: {'n_estimators': 53, 'max_depth': 16, 'learning_rate': 0.15170977896557516}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:57:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:57:21,673] Trial 14 finished with value: 0.9 and parameters: {'n_estimators': 244, 'max_depth': 6, 'learning_rate': 0.09230262099026412}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:57:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:57:35,525] Trial 15 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 141, 'max_depth': 12, 'learning_rate': 0.24073979852587243}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:57:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:58:05,385] Trial 16 finished with value: 0.9 and parameters: {'n_estimators': 400, 'max_depth': 17, 'learning_rate': 0.1970164084228008}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:58:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:58:18,659] Trial 17 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 151, 'max_depth': 6, 'learning_rate': 0.08643331707956822}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:58:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:58:42,657] Trial 18 finished with value: 0.9 and parameters: {'n_estimators': 278, 'max_depth': 18, 'learning_rate': 0.32958849004270696}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:58:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:59:12,214] Trial 19 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 412, 'max_depth': 14, 'learning_rate': 0.09905511568922579}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:59:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 14:59:20,351] Trial 20 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 93, 'max_depth': 9, 'learning_rate': 0.21483207261816403}. Best is trial 2 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:59:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# [I 2025-01-09 15:16:59,873] Trial 11 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 31, 'learning_rate_init': 0.06906653736009738}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:17:25,945] Trial 12 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 33, 'learning_rate_init': 0.06827458223633796}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:18:10,173] Trial 13 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 37, 'learning_rate_init': 0.0017206240515224708}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:18:42,945] Trial 14 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 62, 'learning_rate_init': 0.05867589899159284}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:19:02,548] Trial 15 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 53, 'hidden_layer_2': 13, 'learning_rate_init': 0.07926400112305956}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:19:35,105] Trial 16 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 26, 'learning_rate_init': 0.03675307293806594}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:20:16,592] Trial 17 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 41, 'learning_rate_init': 0.08274566317964296}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:20:51,622] Trial 18 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 53, 'learning_rate_init': 0.0593704714950745}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:21:09,345] Trial 19 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 79, 'learning_rate_init': 0.03497451184779721}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:21:24,871] Trial 20 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 50, 'hidden_layer_2': 20, 'learning_rate_init': 0.08357422846107052}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:21:55,599] Trial 21 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 63, 'learning_rate_init': 0.056829299143696894}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:22:23,534] Trial 22 finished with value: 0.9 and parameters: {'hidden_layer_1': 81, 'hidden_layer_2': 63, 'learning_rate_init': 0.05259081044417814}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:22:47,130] Trial 23 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 73, 'learning_rate_init': 0.06487336109409134}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:23:11,124] Trial 24 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 94, 'hidden_layer_2': 76, 'learning_rate_init': 0.06520574658219226}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:23:40,791] Trial 25 finished with value: 0.91 and parameters: {'hidden_layer_1': 83, 'hidden_layer_2': 88, 'learning_rate_init': 0.08026726520545971}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:24:04,747] Trial 26 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 93, 'hidden_layer_2': 69, 'learning_rate_init': 0.06159915723420127}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:24:40,495] Trial 27 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 84, 'learning_rate_init': 0.07482315928993774}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:25:13,193] Trial 28 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 97, 'learning_rate_init': 0.05399843332716792}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:25:54,012] Trial 29 finished with value: 0.92 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 57, 'learning_rate_init': 0.08657074312969953}. Best is trial 11 with value: 0.9266666666666666.
# [I 2025-01-09 15:25:54,033] A new study created in memory with name: no-name-9e6036dc-d5fa-4a07-8891-f67b666aae1c
# Optimizing MLP...
# [I 2025-01-09 15:26:03,005] Trial 0 finished with value: 0.5 and parameters: {'layer_1': 138, 'layer_2': 76, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.0745826634625593}. Best is trial 0 with value: 0.5.
# [I 2025-01-09 15:26:45,165] Trial 1 finished with value: 0.9233333333333333 and parameters: {'layer_1': 74, 'layer_2': 135, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08909100795993583}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:28:29,774] Trial 2 finished with value: 0.9066666666666666 and parameters: {'layer_1': 116, 'layer_2': 139, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.011411535215905957}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:28:35,128] Trial 3 finished with value: 0.5 and parameters: {'layer_1': 54, 'layer_2': 67, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.08357682460346604}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:29:25,722] Trial 4 finished with value: 0.91 and parameters: {'layer_1': 109, 'layer_2': 63, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0696029738801186}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:30:02,136] Trial 5 finished with value: 0.9 and parameters: {'layer_1': 109, 'layer_2': 133, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.062019977020971284}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:30:25,478] Trial 6 finished with value: 0.9033333333333333 and parameters: {'layer_1': 81, 'layer_2': 71, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.09889757870166234}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:30:54,923] Trial 7 finished with value: 0.91 and parameters: {'layer_1': 133, 'layer_2': 85, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04204158607504361}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:31:12,487] Trial 8 finished with value: 0.9 and parameters: {'layer_1': 56, 'layer_2': 72, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06587611527526382}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:31:45,793] Trial 9 finished with value: 0.8766666666666667 and parameters: {'layer_1': 97, 'layer_2': 135, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.08990221755925905}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:32:18,458] Trial 10 finished with value: 0.9033333333333333 and parameters: {'layer_1': 78, 'layer_2': 110, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.038665956127145566}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:33:25,330] Trial 11 finished with value: 0.9166666666666666 and parameters: {'layer_1': 85, 'layer_2': 53, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.05759981545186644}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:34:49,365] Trial 12 finished with value: 0.92 and parameters: {'layer_1': 75, 'layer_2': 110, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.025031033937222676}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:36:11,969] Trial 13 finished with value: 0.9133333333333333 and parameters: {'layer_1': 70, 'layer_2': 111, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.017826407351598614}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:37:32,053] Trial 14 finished with value: 0.9233333333333333 and parameters: {'layer_1': 65, 'layer_2': 148, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.024748071566015516}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:38:17,460] Trial 15 finished with value: 0.8966666666666666 and parameters: {'layer_1': 63, 'layer_2': 150, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0011475980407895728}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:39:22,597] Trial 16 finished with value: 0.5866666666666667 and parameters: {'layer_1': 94, 'layer_2': 125, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.036317653835078165}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:39:43,069] Trial 17 finished with value: 0.91 and parameters: {'layer_1': 65, 'layer_2': 149, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05110283701522232}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:41:12,522] Trial 18 finished with value: 0.9233333333333333 and parameters: {'layer_1': 90, 'layer_2': 123, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.027808417063990565}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:41:37,935] Trial 19 finished with value: 0.9166666666666666 and parameters: {'layer_1': 53, 'layer_2': 98, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.080067317369804}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:42:15,974] Trial 20 finished with value: 0.9033333333333333 and parameters: {'layer_1': 68, 'layer_2': 122, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.051596358229609944}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:43:48,072] Trial 21 finished with value: 0.9133333333333333 and parameters: {'layer_1': 89, 'layer_2': 141, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.025924289906706685}. Best is trial 1 with value: 0.9233333333333333.
# [I 2025-01-09 15:44:37,391] Trial 22 finished with value: 0.91 and parameters: {'layer_1': 83, 'layer_2': 126, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.02627293095925061}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:46:00,239] Trial 23 finished with value: 0.91 and parameters: {'layer_1': 73, 'layer_2': 117, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.011196790457806772}. Best is trial 1 with value: 0.9233333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:47:41,095] Trial 24 finished with value: 0.9266666666666666 and parameters: {'layer_1': 101, 'layer_2': 98, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.033703521284529254}. Best is trial 24 with value: 0.9266666666666666.
# [I 2025-01-09 15:49:17,008] Trial 25 finished with value: 0.92 and parameters: {'layer_1': 124, 'layer_2': 96, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.044630336619291534}. Best is trial 24 with value: 0.9266666666666666.
# [I 2025-01-09 15:50:04,557] Trial 26 finished with value: 0.91 and parameters: {'layer_1': 150, 'layer_2': 94, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.03304487587191331}. Best is trial 24 with value: 0.9266666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 15:51:44,350] Trial 27 finished with value: 0.92 and parameters: {'layer_1': 105, 'layer_2': 85, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.01904496974460841}. Best is trial 24 with value: 0.9266666666666666.
# [I 2025-01-09 15:52:27,448] Trial 28 finished with value: 0.9066666666666666 and parameters: {'layer_1': 103, 'layer_2': 144, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.09712535510140083}. Best is trial 24 with value: 0.9266666666666666.
# [I 2025-01-09 15:52:51,483] Trial 29 finished with value: 0.5866666666666667 and parameters: {'layer_1': 120, 'layer_2': 106, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0011999042699264752}. Best is trial 24 with value: 0.9266666666666666.
#                   Model  Accuracy  Sensitivity  Specificity       MCC  \
# 0                   SVM  0.903333     0.873333     0.933333  0.808123
# 1         Decision Tree  0.873333     0.780000     0.966667  0.760025
# 2         Random Forest  0.886667     0.820000     0.953333  0.780300
# 3   Logistic Regression  0.893333     0.853333     0.933333  0.789196
# 4                  k-NN  0.883333     0.866667     0.900000  0.767093
# 5           Naive Bayes  0.866667     0.880000     0.853333  0.733594
# 6     Gradient Boosting  0.893333     0.873333     0.913333  0.787297
# 7               XGBoost  0.910000     0.886667     0.933333  0.820894
# 8              LightGBM  0.856667     0.786667     0.926667  0.720428
# 9              AdaBoost  0.860000     0.760000     0.960000  0.734847
# 10       Neural Network  0.926667     0.940000     0.913333  0.853637
# 11                  MLP  0.926667     0.933333     0.920000  0.853409
#
#        Kappa       AUC                                        Best Params
# 0   0.806667  0.903333          {'C': 6.703779296188013, 'kernel': 'rbf'}
# 1   0.746667  0.873333          {'max_depth': 20, 'min_samples_split': 4}
# 2   0.773333  0.886667  {'n_estimators': 328, 'max_depth': 20, 'min_sa...
# 3   0.786667  0.893333        {'C': 9.972622630862766, 'solver': 'lbfgs'}
# 4   0.766667  0.883333                                 {'n_neighbors': 3}
# 5   0.733333  0.866667                                                 {}
# 6   0.786667  0.893333  {'n_estimators': 387, 'learning_rate': 0.39619...
# 7   0.820000  0.910000  {'n_estimators': 97, 'max_depth': 19, 'learnin...
# 8   0.713333  0.856667  {'n_estimators': 247, 'max_depth': 10, 'learni...
# 9   0.720000  0.860000  {'n_estimators': 382, 'learning_rate': 0.84395...
# 10  0.853333  0.926667  {'hidden_layer_1': 89, 'hidden_layer_2': 31, '...
# 11  0.853333  0.926667  {'layer_1': 101, 'layer_2': 98, 'activation': ...

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Define models
models = {
    "SVM": lambda trial: SVC(probability=True, C=trial.suggest_float("C", 0.1, 10.0), kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])),
    "Decision Tree": lambda trial: DecisionTreeClassifier(max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Random Forest": lambda trial: RandomForestClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Logistic Regression": lambda trial: LogisticRegression(C=trial.suggest_float("C", 0.1, 10.0), solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])),
    "k-NN": lambda trial: KNeighborsClassifier(n_neighbors=trial.suggest_int("n_neighbors", 3, 20)),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), max_depth=trial.suggest_int("max_depth", 3, 20)),
    "XGBoost": lambda trial: XGBClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": lambda trial: LGBMClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)),
    "AdaBoost": lambda trial: AdaBoostClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)),
    "Neural Network": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("hidden_layer_1", 10, 100), trial.suggest_int("hidden_layer_2", 10, 100)), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200),
    "MLP": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("layer_1", 50, 150), trial.suggest_int("layer_2", 50, 150)), activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]), solver=trial.suggest_categorical("solver", ["adam", "sgd"]), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200, random_state=42)
}

# Prepare a dictionary to store model probabilities horizontally
probabilities = {"Target": y_val}  # Starting with the target column (y_val)

# Run optimization and compute probabilities for each model
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    study = optuna.create_study(direction="maximize")

    # Objective function for Optuna
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        return accuracy_score(y_val, model.predict(X_val))

    study.optimize(objective, n_trials=30)

    # Train the best model using the best hyperparameters
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)

    # Get predicted probabilities for the positive class (class 1)
    probs = best_model.predict_proba(X_val)[:, 1]

    # Add to the probabilities dictionary
    probabilities[model_name] = probs

# Convert the probabilities dictionary to a DataFrame
probability_df = pd.DataFrame(probabilities)

# Save the probability dataset to a CSV file
probability_df.to_csv("N_TPC_OPTUNA_probability_predictions.csv", index=False)

print("Dataset saved successfully!")
# Out:
# [I 2025-01-09 16:05:36,845] A new study created in memory with name: no-name-20a35274-ccab-43e0-b457-6b7d89e52530
# Optimizing SVM...
# [I 2025-01-09 16:06:19,886] Trial 0 finished with value: 0.9033333333333333 and parameters: {'C': 6.4235074464357504, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:06:40,211] Trial 1 finished with value: 0.8833333333333333 and parameters: {'C': 7.668764259807423, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:07:18,772] Trial 2 finished with value: 0.83 and parameters: {'C': 3.7360319976837792, 'kernel': 'poly'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:07:49,754] Trial 3 finished with value: 0.8933333333333333 and parameters: {'C': 6.92146927782229, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:08:25,719] Trial 4 finished with value: 0.87 and parameters: {'C': 2.5342611510835513, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:09:05,330] Trial 5 finished with value: 0.8433333333333334 and parameters: {'C': 1.544822401670653, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:09:40,166] Trial 6 finished with value: 0.8833333333333333 and parameters: {'C': 3.6637841680478576, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:10:23,113] Trial 7 finished with value: 0.6933333333333334 and parameters: {'C': 0.5955861910125639, 'kernel': 'poly'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:11:02,470] Trial 8 finished with value: 0.8966666666666666 and parameters: {'C': 0.9885640691680782, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:11:45,547] Trial 9 finished with value: 0.9033333333333333 and parameters: {'C': 8.701695536889114, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:12:28,615] Trial 10 finished with value: 0.9033333333333333 and parameters: {'C': 5.619700747535665, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:13:11,883] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 9.615926191414502, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:13:57,543] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 9.916053462147133, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:14:40,879] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 7.963917226307386, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:15:02,608] Trial 14 finished with value: 0.8833333333333333 and parameters: {'C': 5.957712914588548, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:15:45,730] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 8.584811268064643, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16:16:28,982] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 6.768607931672855, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-09 16
666666667 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:48,314] Trial 11 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:48,934] Trial 12 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:49,485] Trial 13 finished with value: 0.84 and parameters: {'max_depth': 15, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:49,922] Trial 14 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:50,305] Trial 15 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:50,576] Trial 16 finished with value: 0.8033333333333333 and parameters: {'max_depth': 10, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:50,925] Trial 17 finished with value: 0.8566666666666667 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:51,228] Trial 18 finished with value: 0.8133333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 5}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:51,594] Trial 19 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 8}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:51,970] Trial 20 finished with value: 0.8533333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 10}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:52,351] Trial 21 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8666666666666667.
# [I 2025-01-09 16:25:52,704] Trial 22 finished with value: 0.8766666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 4}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:53,064] Trial 23 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:53,410] Trial 24 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 5}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:53,763] Trial 25 finished with value: 0.8533333333333334 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:54,100] Trial 26 finished with value: 0.8566666666666667 and parameters: {'max_depth': 16, 'min_samples_split': 4}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:54,471] Trial 27 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 7}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:54,787] Trial 28 finished with value: 0.8233333333333334 and parameters: {'max_depth': 14, 'min_samples_split': 2}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:55,054] Trial 29 finished with value: 0.7933333333333333 and parameters: {'max_depth': 9, 'min_samples_split': 5}. Best is trial 22 with value: 0.8766666666666667.
# [I 2025-01-09 16:25:55,403] A new study created in memory with name: no-name-fd76e2db-55a0-4263-88ba-c90ffae5691f
# Optimizing Random Forest...
# [I 2025-01-09 16:25:56,733] Trial 0 finished with value: 0.77 and parameters: {'n_estimators': 457, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 0 with value: 0.77.
# [I 2025-01-09 16:25:57,185] Trial 1 finished with value: 0.82 and parameters: {'n_estimators': 87, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 1 with value: 0.82.
# [I 2025-01-09 16:25:58,196] Trial 2 finished with value: 0.8166666666666667 and parameters: {'n_estimators': 253, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.82.
# [I 2025-01-09 16:26:02,695] Trial 3 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 482, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 3 with value: 0.8733333333333333.
# [I 2025-01-09 16:26:04,681] Trial 4 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 437, 'max_depth': 4, 'min_samples_split': 10}. Best is trial 3 with value: 0.8733333333333333.
# [I 2025-01-09 16:26:05,229] Trial 5 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 71, 'max_depth': 15, 'min_samples_split': 7}. Best is trial 3 with value: 0.8733333333333333.
# [I 2025-01-09 16:26:06,328] Trial 6 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 330, 'max_depth': 4, 'min_samples_split': 6}. Best is trial 3 with value: 0.8733333333333333.
# [I 2025-01-09 16:26:09,482] Trial 7 finished with value: 0.87 and parameters: {'n_estimators': 437, 'max_depth': 20, 'min_samples_split': 8}. Best is trial 3 with value: 0.8733333333333333.
# [I 2025-01-09 16:26:12,403] Trial 8 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 413, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 8 with value: 0.8766666666666667.
# [I 2025-01-09 16:26:14,698] Trial 9 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 362, 'max_depth': 13, 'min_samples_split': 5}. Best is trial 8 with value: 0.8766666666666667.
# [I 2025-01-09 16:26:16,894] Trial 10 finished with value: 0.86 and parameters: {'n_estimators': 202, 'max_depth': 16, 'min_samples_split': 3}. Best is trial 8 with value: 0.8766666666666667.
# [I 2025-01-09 16:26:20,196] Trial 11 finished with value: 0.88 and parameters: {'n_estimators': 369, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:22,558] Trial 12 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 362, 'max_depth': 17, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:24,064] Trial 13 finished with value: 0.84 and parameters: {'n_estimators': 303, 'max_depth': 10, 'min_samples_split': 8}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:26,634] Trial 14 finished with value: 0.87 and parameters: {'n_estimators': 380, 'max_depth': 18, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:27,973] Trial 15 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 229, 'max_depth': 13, 'min_samples_split': 8}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:29,612] Trial 16 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 171, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:32,664] Trial 17 finished with value: 0.84 and parameters: {'n_estimators': 391, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:34,821] Trial 18 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 294, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:38,278] Trial 19 finished with value: 0.86 and parameters: {'n_estimators': 499, 'max_depth': 18, 'min_samples_split': 7}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:40,602] Trial 20 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 417, 'max_depth': 13, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:44,606] Trial 21 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 484, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:48,431] Trial 22 finished with value: 0.87 and parameters: {'n_estimators': 410, 'max_depth': 20, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:51,590] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 466, 'max_depth': 18, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:53,698] Trial 24 finished with value: 0.86 and parameters: {'n_estimators': 330, 'max_depth': 16, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:26:56,092] Trial 25 finished with value: 0.87 and parameters: {'n_estimators': 339, 'max_depth': 19, 'min_samples_split': 8}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:27:00,644] Trial 26 finished with value: 0.86 and parameters: {'n_estimators': 499, 'max_depth': 17, 'min_samples_split': 7}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:27:03,959] Trial 27 finished with value: 0.87 and parameters: {'n_estimators': 436, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:27:07,163] Trial 28 finished with value: 0.85 and parameters: {'n_estimators': 391, 'max_depth': 15, 'min_samples_split': 9}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:27:11,174] Trial 29 finished with value: 0.88 and parameters: {'n_estimators': 455, 'max_depth': 19, 'min_samples_split': 8}. Best is trial 11 with value: 0.88.
# [I 2025-01-09 16:27:15,179] A new study created in memory with name: no-name-29d644e0-fff2-482d-98d4-65f404346e93
# Optimizing Logistic Regression...
# [I 2025-01-09 16:27:15,655] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 5.904372620431427, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-09 16:27
finished with value: 0.8866666666666667 and parameters: {'n_estimators': 271, 'learning_rate': 0.22561651751199419, 'max_depth': 10}. Best is trial 14 with value: 0.8933333333333333.
# [I 2025-01-09 17:06:59,636] A new study created in memory with name: no-name-69568129-0836-42e4-b542-233152daf608
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:07:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:07:33,099] Trial 0 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 429, 'max_depth': 18, 'learning_rate': 0.35366691709110454}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:07:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:07:39,670] Trial 1 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 68, 'max_depth': 4, 'learning_rate': 0.49781225654953903}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:07:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:08:11,582] Trial 2 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 438, 'max_depth': 19, 'learning_rate': 0.2562903273755281}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:08:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:08:34,412] Trial 3 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 290, 'max_depth': 18, 'learning_rate': 0.18351425840021776}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:08:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:09:04,093] Trial 4 finished with value: 0.9 and parameters: {'n_estimators': 484, 'max_depth': 7, 'learning_rate': 0.22730628272680073}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:09:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:09:31,400] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 337, 'max_depth': 19, 'learning_rate': 0.2687462048371979}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:09:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:09:58,134] Trial 6 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.48509279201098116}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:10:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:10:17,634] Trial 7 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 244, 'max_depth': 18, 'learning_rate': 0.48637724360166695}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:10:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:10:35,641] Trial 8 finished with value: 0.9 and parameters: {'n_estimators': 258, 'max_depth': 8, 'learning_rate': 0.1842842427460637}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:10:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:11:04,162] Trial 9 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 412, 'max_depth': 15, 'learning_rate': 0.26634586783074}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:11:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:11:16,975] Trial 10 finished with value: 0.9 and parameters: {'n_estimators': 159, 'max_depth': 13, 'learning_rate': 0.3932015421275491}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:11:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:11:41,858] Trial 11 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 324, 'max_depth': 15, 'learning_rate': 0.054689325006962525}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:11:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:11:58,898] Trial 12 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 196, 'max_depth': 16, 'learning_rate': 0.11389772035968893}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:12:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:12:23,650] Trial 13 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 330, 'max_depth': 12, 'learning_rate': 0.36173287269732907}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:12:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:12:58,530] Trial 14 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 482, 'max_depth': 20, 'learning_rate': 0.350586990169831}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:13:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:13:25,136] Trial 15 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 368, 'max_depth': 16, 'learning_rate': 0.14836933371537162}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:13:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:13:37,798] Trial 16 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 116, 'max_depth': 17, 'learning_rate': 0.31929943647152914}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:13:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:14:02,601] Trial 17 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 284, 'max_depth': 13, 'learning_rate': 0.010018388481572271}. Best is trial 0 with value: 0.9066666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:14:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:14:18,970] Trial 18 finished with value: 0.91 and parameters: {'n_estimators': 207, 'max_depth': 10, 'learning_rate': 0.4143906649254487}. Best is trial 18 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:14:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:14:35,654] Trial 19 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 207, 'max_depth': 11, 'learning_rate': 0.4047829154975063}. Best is trial 18 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:14:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:14:48,133] Trial 20 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 143, 'max_depth': 4, 'learning_rate': 0.4458621957449037}. Best is trial 18 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:14:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-09 17:15:09,039] Trial 21 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 285, 'max_depth': 11, 'learning_rate': 0.33400550554589303}. Best is trial 18 with value: 0.91.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [17:15:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# [I 2025-01-09 17:29:09,575] Trial 24 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 438, 'learning_rate': 0.95283197813576}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:29:45,474] Trial 25 finished with value: 0.87 and parameters: {'n_estimators': 458, 'learning_rate': 0.9210129394706073}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:30:22,290] Trial 26 finished with value: 0.85 and parameters: {'n_estimators': 490, 'learning_rate': 0.6786303770635169}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:30:58,315] Trial 27 finished with value: 0.8466666666666667 and parameters: {'n_estimators': 463, 'learning_rate': 0.7897906417188101}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:31:32,827] Trial 28 finished with value: 0.87 and parameters: {'n_estimators': 453, 'learning_rate': 0.9168779707815747}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:31:57,177] Trial 29 finished with value: 0.6333333333333333 and parameters: {'n_estimators': 334, 'learning_rate': 0.018219579488719884}. Best is trial 23 with value: 0.8833333333333333.
# [I 2025-01-09 17:32:32,159] A new study created in memory with name: no-name-54184460-2b08-4c2e-99ab-abecd3829363
# Optimizing Neural Network...
# [I 2025-01-09 17:32:47,533] Trial 0 finished with value: 0.92 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 22, 'learning_rate_init': 0.04766872956542842}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:33:08,891] Trial 1 finished with value: 0.92 and parameters: {'hidden_layer_1': 74, 'hidden_layer_2': 59, 'learning_rate_init': 0.09105616871960961}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:33:57,652] Trial 2 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 54, 'hidden_layer_2': 76, 'learning_rate_init': 0.0015010942069476935}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:34:14,579] Trial 3 finished with value: 0.91 and parameters: {'hidden_layer_1': 46, 'hidden_layer_2': 50, 'learning_rate_init': 0.06044859810453942}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:34:32,583] Trial 4 finished with value: 0.91 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 30, 'learning_rate_init': 0.07056557670290124}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:34:55,006] Trial 5 finished with value: 0.91 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 83, 'learning_rate_init': 0.06812851961611761}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:35:09,245] Trial 6 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 54, 'hidden_layer_2': 54, 'learning_rate_init': 0.021220161136268113}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:35:37,986] Trial 7 finished with value: 0.91 and parameters: {'hidden_layer_1': 32, 'hidden_layer_2': 83, 'learning_rate_init': 0.07621795164319357}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:36:06,385] Trial 8 finished with value: 0.92 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 36, 'learning_rate_init': 0.06329244007662609}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:36:31,880] Trial 9 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 10, 'learning_rate_init': 0.008344161306829925}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:36:49,280] Trial 10 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 98, 'hidden_layer_2': 13, 'learning_rate_init': 0.03843582957392591}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:37:18,452] Trial 11 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 79, 'hidden_layer_2': 65, 'learning_rate_init': 0.0945337509218903}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:37:41,738] Trial 12 finished with value: 0.9 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 100, 'learning_rate_init': 0.039720809528903785}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:38:13,313] Trial 13 finished with value: 0.91 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 38, 'learning_rate_init': 0.08924771923296028}. Best is trial 0 with value: 0.92.
# [I 2025-01-09 17:38:42,128] Trial 14 finished with value: 0.9233333333333333 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 23, 'learning_rate_init': 0.04439854519426251}. Best is trial 14 with value: 0.9233333333333333.
# [I 2025-01-09 17:39:15,814] Trial 15 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 22, 'learning_rate_init': 0.044814896205555774}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:39:30,820] Trial 16 finished with value: 0.9 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 22, 'learning_rate_init': 0.027576292331406235}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:40:00,722] Trial 17 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 88, 'hidden_layer_2': 44, 'learning_rate_init': 0.05203241761986802}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:40:12,582] Trial 18 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 90, 'hidden_layer_2': 25, 'learning_rate_init': 0.028984859061085874}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:40:32,411] Trial 19 finished with value: 0.91 and parameters: {'hidden_layer_1': 88, 'hidden_layer_2': 14, 'learning_rate_init': 0.0502082318695849}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:40:46,142] Trial 20 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 40, 'hidden_layer_2': 32, 'learning_rate_init': 0.03884675631117143}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:41:14,132] Trial 21 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 64, 'hidden_layer_2': 20, 'learning_rate_init': 0.04941097776180108}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:41:29,296] Trial 22 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 13, 'hidden_layer_2': 42, 'learning_rate_init': 0.0538916478864159}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:41:56,267] Trial 23 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 27, 'learning_rate_init': 0.045900668556481825}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:42:12,379] Trial 24 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 67, 'hidden_layer_2': 20, 'learning_rate_init': 0.029377428552688722}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:42:35,282] Trial 25 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 46, 'learning_rate_init': 0.017360449123678835}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:42:56,912] Trial 26 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 93, 'hidden_layer_2': 17, 'learning_rate_init': 0.07816299340528574}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:43:18,106] Trial 27 finished with value: 0.91 and parameters: {'hidden_layer_1': 82, 'hidden_layer_2': 33, 'learning_rate_init': 0.0415741129868987}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:43:39,652] Trial 28 finished with value: 0.88 and parameters: {'hidden_layer_1': 48, 'hidden_layer_2': 24, 'learning_rate_init': 0.06069499929247765}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:44:05,860] Trial 29 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 60, 'learning_rate_init': 0.03576284227188902}. Best is trial 15 with value: 0.9266666666666666.
# [I 2025-01-09 17:44:40,826] A new study created in memory with name: no-name-38fae461-88c9-4bd9-ba64-214f0b8aa4a1
# Optimizing MLP...
# [I 2025-01-09 17:45:19,724] Trial 0 finished with value: 0.9166666666666666 and parameters: {'layer_1': 129, 'layer_2': 81, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06404304420935956}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:46:02,487] Trial 1 finished with value: 0.91 and parameters: {'layer_1': 109, 'layer_2': 129, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.054499384177819056}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:46:15,226] Trial 2 finished with value: 0.88 and parameters: {'layer_1': 76, 'layer_2': 79, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09932092910554714}. Best is trial 0 with value: 0.9166666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-09 17:47:36,379] Trial 3 finished with value: 0.9066666666666666 and parameters: {'layer_1': 75, 'layer_2': 50, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00996740257579267}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:47:46,269] Trial 4 finished with value: 0.5 and parameters: {'layer_1': 78, 'layer_2': 125, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.09089133369010452}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:48:05,520] Trial 5 finished with value: 0.5 and parameters: {'layer_1': 127, 'layer_2': 64, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.0644376373839857}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:48:10,868] Trial 6 finished with value: 0.5 and parameters: {'layer_1': 120, 'layer_2': 80, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.056394222415200985}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:48:18,009] Trial 7 finished with value: 0.5 and parameters: {'layer_1': 53, 'layer_2': 62, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.05550443231764463}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:48:38,316] Trial 8 finished with value: 0.9066666666666666 and parameters: {'layer_1': 76, 'layer_2': 88, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.04833099743470411}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:49:14,626] Trial 9 finished with value: 0.9166666666666666 and parameters: {'layer_1': 148, 'layer_2': 125, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0550166519773145}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:49:59,115] Trial 10 finished with value: 0.91 and parameters: {'layer_1': 146, 'layer_2': 106, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.029578349905690516}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:50:42,508] Trial 11 finished with value: 0.9033333333333333 and parameters: {'layer_1': 147, 'layer_2': 104, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07740890348089154}. Best is trial 0 with value: 0.9166666666666666.
# [I 2025-01-09 17:51:22,907] Trial 12 finished with value: 0.9233333333333333 and parameters: {'layer_1': 131, 'layer_2': 149, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07299043197798874}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:52:04,222] Trial 13 finished with value: 0.9 and parameters: {'layer_1': 129, 'layer_2': 148, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07609454064758576}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:52:31,690] Trial 14 finished with value: 0.9233333333333333 and parameters: {'layer_1': 98, 'layer_2': 149, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03942845608468837}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:52:59,673] Trial 15 finished with value: 0.91 and parameters: {'layer_1': 96, 'layer_2': 147, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.034745695796098}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:53:33,523] Trial 16 finished with value: 0.92 and parameters: {'layer_1': 98, 'layer_2': 137, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.035834392514471305}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:53:50,622] Trial 17 finished with value: 0.9033333333333333 and parameters: {'layer_1': 109, 'layer_2': 112, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.01598144022597023}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:54:35,281] Trial 18 finished with value: 0.8966666666666666 and parameters: {'layer_1': 86, 'layer_2': 138, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0010211083139345448}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:54:50,528] Trial 19 finished with value: 0.9066666666666666 and parameters: {'layer_1': 55, 'layer_2': 117, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07825807990849287}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:55:17,961] Trial 20 finished with value: 0.9 and parameters: {'layer_1': 114, 'layer_2': 138, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0444439458749919}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:55:45,764] Trial 21 finished with value: 0.9 and parameters: {'layer_1': 97, 'layer_2': 138, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03339615138273918}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:56:13,789] Trial 22 finished with value: 0.9133333333333333 and parameters: {'layer_1': 89, 'layer_2': 149, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04073833670215121}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:56:39,503] Trial 23 finished with value: 0.9066666666666666 and parameters: {'layer_1': 104, 'layer_2': 133, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.02192791527920042}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:56:52,247] Trial 24 finished with value: 0.9033333333333333 and parameters: {'layer_1': 66, 'layer_2': 143, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.026262994965689304}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:57:37,578] Trial 25 finished with value: 0.9166666666666666 and parameters: {'layer_1': 139, 'layer_2': 119, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.04230078351094804}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:58:05,095] Trial 26 finished with value: 0.9166666666666666 and parameters: {'layer_1': 88, 'layer_2': 133, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06496337951036074}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:58:52,985] Trial 27 finished with value: 0.8933333333333333 and parameters: {'layer_1': 101, 'layer_2': 143, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03891872748232579}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:59:22,300] Trial 28 finished with value: 0.9066666666666666 and parameters: {'layer_1': 118, 'layer_2': 150, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08467479506454252}. Best is trial 12 with value: 0.9233333333333333.
# [I 2025-01-09 17:59:53,326] Trial 29 finished with value: 0.9233333333333333 and parameters: {'layer_1': 136, 'layer_2': 90, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06781650868440678}. Best is trial 12 with value: 0.9233333333333333.
# Dataset saved successfully!

# %% [markdown]
# Class Feature Vector (CFV)

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_main_tpc.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_main_tpc (1).csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_validation_tpc.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_validation_tpc.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]

# Define models with hyperparameter optimization (Optuna)
models = {
    "SVM": lambda trial: SVC(
         probability=True,
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}

# Initialize a list to store the CFV data
cfv_data = []

# Define the optimization and prediction function
def optimize_and_predict(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict_proba(X_val)[:, 1]  # Get probability for class 1 (positive)
        return accuracy_score(y_val, model.predict(X_val))

    # Perform optimization with Optuna
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Return the best model
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)
    preds = best_model.predict_proba(X_val)[:, 1]  # Using the probability for class 1 (positive)

    # Append predictions to CFV list
    return preds

# Train each model and generate predictions for CFV
for model_name, model_func in models.items():
    print(f"Training and predicting with {model_name}...")
    preds = optimize_and_predict(model_name, model_func)
    cfv_data.append(preds)

# Convert the CFV data into a DataFrame
cfv_df = pd.DataFrame(np.array(cfv_data).T, columns=models.keys())

# Optionally, add the true labels column
cfv_df["True_Label"] = y_val.values

# Save the CFV dataset to CSV
cfv_df.to_csv("CFV_TPC.csv", index=False)
print("CFV dataset created and saved!")
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2025-01-16 13:55:11,762] A new study created in memory with name: no-name-d98548f2-1d11-452d-830b-a1fd9464f393
# Training and predicting with SVM...
# [I 2025-01-16 13:55:47,867] Trial 0 finished with value: 0.81 and parameters: {'C': 2.576322755143849, 'kernel': 'poly'}. Best is trial 0 with value: 0.81.
# [I 2025-01-16 13:56:24,424] Trial 1 finished with value: 0.8333333333333334 and parameters: {'C': 4.346971155793399, 'kernel': 'poly'}. Best is trial 1 with value: 0.8333333333333334.
# [I 2025-01-16 13:56:53,976] Trial 2 finished with value: 0.8833333333333333 and parameters: {'C': 4.706341750295366, 'kernel': 'linear'}. Best is trial 2 with value: 0.8833333333333333.
# [I 2025-01-16 13:57:33,057] Trial 3 finished with value: 0.9033333333333333 and parameters: {'C': 8.446869128095893, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 13:58:11,215] Trial 4 finished with value: 0.86 and parameters: {'C': 7.022367754624726, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 13:58:51,146] Trial 5 finished with value: 0.9033333333333333 and parameters: {'C': 4.739543195512678, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 13:59:27,950] Trial 6 finished with value: 0.7766666666666666 and parameters: {'C': 1.4385897445509572, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:00:00,760] Trial 7 finished with value: 0.87 and parameters: {'C': 2.7517223177187193, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:00:40,269] Trial 8 finished with value: 0.9033333333333333 and parameters: {'C': 4.139099081019251, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:01:00,380] Trial 9 finished with value: 0.88 and parameters: {'C': 7.175347834716735, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:01:39,229] Trial 10 finished with value: 0.9033333333333333 and parameters: {'C': 9.90125153117048, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:02:18,764] Trial 11 finished with value: 0.9033333333333333 and parameters: {'C': 6.952171704933917, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:02:58,676] Trial 12 finished with value: 0.9033333333333333 and parameters: {'C': 9.501866445298685, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:03:38,756] Trial 13 finished with value: 0.9033333333333333 and parameters: {'C': 6.371929785925765, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:03:57,349] Trial 14 finished with value: 0.8833333333333333 and parameters: {'C': 8.544193687946219, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:04:38,616] Trial 15 finished with value: 0.9033333333333333 and parameters: {'C': 5.857862599770705, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:05:18,334] Trial 16 finished with value: 0.9033333333333333 and parameters: {'C': 8.331351157200046, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:06:04,211] Trial 17 finished with value: 0.7866666666666666 and parameters: {'C': 0.14086778942421585, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:06:36,096] Trial 18 finished with value: 0.8733333333333333 and parameters: {'C': 3.0553495717783603, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:06:55,914] Trial 19 finished with value: 0.88 and parameters: {'C': 5.362940733408878, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:07:35,705] Trial 20 finished with value: 0.9033333333333333 and parameters: {'C': 8.409983865282289, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:08:15,873] Trial 21 finished with value: 0.9033333333333333 and parameters: {'C': 3.946449894957216, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:08:55,562] Trial 22 finished with value: 0.9033333333333333 and parameters: {'C': 3.644141590448912, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:09:35,365] Trial 23 finished with value: 0.9033333333333333 and parameters: {'C': 5.257546302115358, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:10:14,987] Trial 24 finished with value: 0.9033333333333333 and parameters: {'C': 1.863445360315212, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:10:55,246] Trial 25 finished with value: 0.9033333333333333 and parameters: {'C': 6.1424589439230655, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:11:34,891] Trial 26 finished with value: 0.9033333333333333 and parameters: {'C': 3.5695778128847495, 'kernel': 'rbf'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:11:55,482] Trial 27 finished with value: 0.8633333333333333 and parameters: {'C': 4.74028303343705, 'kernel': 'sigmoid'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:12:22,918] Trial 28 finished with value: 0.8866666666666667 and parameters: {'C': 7.820381729215444, 'kernel': 'linear'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:13:00,066] Trial 29 finished with value: 0.8533333333333334 and parameters: {'C': 5.690298062637494, 'kernel': 'poly'}. Best is trial 3 with value: 0.9033333333333333.
# [I 2025-01-16 14:13:37,915] A new study created in memory with name: no-name-aa98f412-f4be-46fd-b846-68437125ea13
# Training and predicting with Decision Tree...
# [I 2025-01-16 14:13:38,150] Trial 0 finished with value: 0.7633333333333333 and parameters: {'max_depth': 6, 'min_samples_split': 9}. Best is trial 0 with value: 0.7633333333333333.
# [I 2025-01-16 14:13:38,405] Trial 1 finished with value: 0.7866666666666666 and parameters: {'max_depth': 8, 'min_samples_split': 10}. Best is trial 1 with value: 0.7866666666666666.
# [I 2025-01-16 14:13:38,646] Trial 2 finished with value: 0.77 and parameters: {'max_depth': 7, 'min_samples_split': 6}. Best is trial 1 with value: 0.7866666666666666.
# [I 2025-01-16 14:13:38,855] Trial 3 finished with value: 0.71 and parameters: {'max_depth': 3, 'min_samples_split': 9}. Best is trial 1 with value: 0.7866666666666666.
# [I 2025-01-16 14:13:39,107] Trial 4 finished with value: 0.7866666666666666 and parameters: {'max_depth': 8, 'min_samples_split': 9}. Best is trial 1 with value: 0.7866666666666666.
# [I 2025-01-16 14:13:39,418] Trial 5 finished with value: 0.8166666666666667 and parameters: {'max_depth': 13, 'min_samples_split': 7}. Best is trial 5 with value: 0.8166666666666667.
# [I 2025-01-16 14:13:39,778] Trial 6 finished with value: 0.86 and parameters: {'max_depth': 17, 'min_samples_split': 2}. Best is trial 6 with value: 0.86.
# [I 2025-01-16 14:13:39,988] Trial 7 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 3}. Best is trial 6 with value: 0.86.
# [I 2025-01-16 14:13:40,232] Trial 8 finished with value: 0.77 and parameters: {'max_depth': 7, 'min_samples_split': 9}. Best is trial 6 with value: 0.86.
# [I 2025-01-16 14:13:40,444] Trial 9 finished with value: 0.7233333333333334 and parameters: {'max_depth': 4, 'min_samples_split': 2}. Best is trial 6 with value: 0.86.
# [I 2025-01-16 14:13:40,836] Trial 10 finished with value: 0.8633333333333333 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:41,211] Trial 11 finished with value: 0.8566666666666667 and parameters: {'max_depth': 19, 'min_samples_split': 4}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:41,594] Trial 12 finished with value: 0.86 and parameters: {'max_depth': 20, 'min_samples_split': 4}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:41,959] Trial 13 finished with value: 0.8533333333333334 and parameters: {'max_depth': 16, 'min_samples_split': 2}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:42,307] Trial 14 finished with value: 0.85 and parameters: {'max_depth': 16, 'min_samples_split': 5}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:42,664] Trial 15 finished with value: 0.85 and parameters: {'max_depth': 17, 'min_samples_split': 3}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:43,006] Trial 16 finished with value: 0.8266666666666667 and parameters: {'max_depth': 13, 'min_samples_split': 5}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:43,465] Trial 17 finished with value: 0.86 and parameters: {'max_depth': 18, 'min_samples_split': 3}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:44,026] Trial 18 finished with value: 0.83 and parameters: {'max_depth': 14, 'min_samples_split': 2}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-16 14:13:44,661] Trial 19 finished with value: 0.8666666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 7}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:45,124] Trial 20 finished with value: 0.81 and parameters: {'max_depth': 10, 'min_samples_split': 7}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:45,759] Trial 21 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 7}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:46,376] Trial 22 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 6}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:46,935] Trial 23 finished with value: 0.8433333333333334 and parameters: {'max_depth': 15, 'min_samples_split': 4}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:47,558] Trial 24 finished with value: 0.8566666666666667 and parameters: {'max_depth': 18, 'min_samples_split': 5}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:48,119] Trial 25 finished with value: 0.8633333333333333 and parameters: {'max_depth': 20, 'min_samples_split': 8}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:48,502] Trial 26 finished with value: 0.8566666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 8}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:48,798] Trial 27 finished with value: 0.8033333333333333 and parameters: {'max_depth': 11, 'min_samples_split': 8}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:49,189] Trial 28 finished with value: 0.8533333333333334 and parameters: {'max_depth': 19, 'min_samples_split': 6}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:49,568] Trial 29 finished with value: 0.85 and parameters: {'max_depth': 19, 'min_samples_split': 8}. Best is trial 19 with value: 0.8666666666666667.
# [I 2025-01-16 14:13:49,928] A new study created in memory with name: no-name-cbdc0b88-6770-43ae-af89-91694702da94
# Training and predicting with Random Forest...
# [I 2025-01-16 14:13:51,060] Trial 0 finished with value: 0.8033333333333333 and parameters: {'n_estimators': 417, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 0 with value: 0.8033333333333333.
# [I 2025-01-16 14:13:52,970] Trial 1 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 323, 'max_depth': 16, 'min_samples_split': 10}. Best is trial 1 with value: 0.8533333333333334.
# [I 2025-01-16 14:13:54,810] Trial 2 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 460, 'max_depth': 8, 'min_samples_split': 9}. Best is trial 1 with value: 0.8533333333333334.
# [I 2025-01-16 14:13:57,851] Trial 3 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 478, 'max_depth': 17, 'min_samples_split': 4}. Best is trial 3 with value: 0.8766666666666667.
# [I 2025-01-16 14:13:59,536] Trial 4 finished with value: 0.8066666666666666 and parameters: {'n_estimators': 363, 'max_depth': 4, 'min_samples_split': 5}. Best is trial 3 with value: 0.8766666666666667.
# [I 2025-01-16 14:14:00,360] Trial 5 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 140, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 3 with value: 0.8766666666666667.
# [I 2025-01-16 14:14:04,211] Trial 6 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 473, 'max_depth': 18, 'min_samples_split': 5}. Best is trial 3 with value: 0.8766666666666667.
# [I 2025-01-16 14:14:06,126] Trial 7 finished with value: 0.86 and parameters: {'n_estimators': 326, 'max_depth': 15, 'min_samples_split': 5}. Best is trial 3 with value: 0.8766666666666667.
# [I 2025-01-16 14:14:07,756] Trial 8 finished with value: 0.88 and parameters: {'n_estimators': 230, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:11,235] Trial 9 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 468, 'max_depth': 18, 'min_samples_split': 4}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:15,296] Trial 10 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 182, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:19,231] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 209, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:19,807] Trial 12 finished with value: 0.87 and parameters: {'n_estimators': 57, 'max_depth': 20, 'min_samples_split': 2}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:21,225] Trial 13 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 252, 'max_depth': 13, 'min_samples_split': 7}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:22,952] Trial 14 finished with value: 0.85 and parameters: {'n_estimators': 268, 'max_depth': 16, 'min_samples_split': 3}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:23,646] Trial 15 finished with value: 0.84 and parameters: {'n_estimators': 133, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:26,140] Trial 16 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 382, 'max_depth': 18, 'min_samples_split': 6}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:28,095] Trial 17 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 308, 'max_depth': 15, 'min_samples_split': 4}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:29,797] Trial 18 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 216, 'max_depth': 10, 'min_samples_split': 7}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:30,738] Trial 19 finished with value: 0.87 and parameters: {'n_estimators': 64, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:33,628] Trial 20 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 409, 'max_depth': 14, 'min_samples_split': 8}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:35,144] Trial 21 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 211, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:36,237] Trial 22 finished with value: 0.86 and parameters: {'n_estimators': 157, 'max_depth': 18, 'min_samples_split': 8}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:37,772] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 233, 'max_depth': 17, 'min_samples_split': 6}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:39,795] Trial 24 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 290, 'max_depth': 20, 'min_samples_split': 6}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:40,629] Trial 25 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 108, 'max_depth': 19, 'min_samples_split': 5}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:41,844] Trial 26 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 182, 'max_depth': 17, 'min_samples_split': 7}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:45,231] Trial 27 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 358, 'max_depth': 19, 'min_samples_split': 9}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:46,559] Trial 28 finished with value: 0.8233333333333334 and parameters: {'n_estimators': 188, 'max_depth': 7, 'min_samples_split': 3}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:49,379] Trial 29 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 425, 'max_depth': 16, 'min_samples_split': 2}. Best is trial 8 with value: 0.88.
# [I 2025-01-16 14:14:51,020] A new study created in memory with name: no-name-1eeb0fe5-3d7f-478a-8063-625620705068
# Training and predicting with Logistic Regression...
# [I 2025-01-16 14:14:51,446] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 5.815936362145891, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-16 14:14
finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-16 14:15:35,016] Trial 29 finished with value: 0.8666666666666667 and parameters: {}. Best is trial 0 with value: 0.8666666666666667.
# [I 2025-01-16 14:15:35,264] A new study created in memory with name: no-name-93d298b5-e108-450b-8dff-e94904b109ae
# Training and predicting with Gradient Boosting...
# [I 2025-01-16 14:16:11,835] Trial 0 finished with value: 0.89 and parameters: {'n_estimators': 295, 'learning_rate': 0.21803013102337818, 'max_depth': 6}. Best is trial 0 with value: 0.89.
# [I 2025-01-16 14:16:32,233] Trial 1 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 282, 'learning_rate': 0.3847723219325019, 'max_depth': 3}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:17:24,492] Trial 2 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 276, 'learning_rate': 0.3595763375324751, 'max_depth': 10}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:17:39,536] Trial 3 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 121, 'learning_rate': 0.4307860767469923, 'max_depth': 6}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:18:18,358] Trial 4 finished with value: 0.88 and parameters: {'n_estimators': 160, 'learning_rate': 0.3230232833232413, 'max_depth': 13}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:20:27,911] Trial 5 finished with value: 0.89 and parameters: {'n_estimators': 416, 'learning_rate': 0.4319979100982847, 'max_depth': 19}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:20:33,101] Trial 6 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 66, 'learning_rate': 0.04939786352430064, 'max_depth': 4}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:21:31,592] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 260, 'learning_rate': 0.11708915724862129, 'max_depth': 12}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:23:31,097] Trial 8 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 475, 'learning_rate': 0.47739698690246685, 'max_depth': 14}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:23:39,527] Trial 9 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 130, 'learning_rate': 0.07190955457046573, 'max_depth': 3}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:25:47,682] Trial 10 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 372, 'learning_rate': 0.21687075187767593, 'max_depth': 19}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:26:14,820] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 192, 'learning_rate': 0.3852266791104681, 'max_depth': 7}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:26:48,407] Trial 12 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 217, 'learning_rate': 0.30406765981228645, 'max_depth': 8}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:26:51,837] Trial 13 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 51, 'learning_rate': 0.4959558784537734, 'max_depth': 3}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:27:33,819] Trial 14 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 344, 'learning_rate': 0.42978971129638394, 'max_depth': 6}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:27:57,724] Trial 15 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 133, 'learning_rate': 0.278221338130191, 'max_depth': 9}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:29:04,507] Trial 16 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 228, 'learning_rate': 0.26343921823329125, 'max_depth': 16}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:30:11,048] Trial 17 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 348, 'learning_rate': 0.1573607941185062, 'max_depth': 10}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:31:04,784] Trial 18 finished with value: 0.88 and parameters: {'n_estimators': 304, 'learning_rate': 0.27714778707917453, 'max_depth': 9}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:31:54,765] Trial 19 finished with value: 0.89 and parameters: {'n_estimators': 174, 'learning_rate': 0.3508552705280927, 'max_depth': 16}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:32:04,405] Trial 20 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 101, 'learning_rate': 0.21216864771195504, 'max_depth': 4}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:32:17,588] Trial 21 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 123, 'learning_rate': 0.40684009018152595, 'max_depth': 5}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:32:53,649] Trial 22 finished with value: 0.88 and parameters: {'n_estimators': 235, 'learning_rate': 0.47059428510307677, 'max_depth': 8}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:33:05,823] Trial 23 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 96, 'learning_rate': 0.3384122210130742, 'max_depth': 6}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:33:34,302] Trial 24 finished with value: 0.89 and parameters: {'n_estimators': 148, 'learning_rate': 0.39078982998218065, 'max_depth': 10}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:33:54,211] Trial 25 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 193, 'learning_rate': 0.44312564209085775, 'max_depth': 5}. Best is trial 1 with value: 0.8966666666666666.
# [I 2025-01-16 14:34:09,795] Trial 26 finished with value: 0.9 and parameters: {'n_estimators': 97, 'learning_rate': 0.29524376794070817, 'max_depth': 8}. Best is trial 26 with value: 0.9.
# [I 2025-01-16 14:34:27,504] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 81, 'learning_rate': 0.29316910864168594, 'max_depth': 11}. Best is trial 26 with value: 0.9.
# [I 2025-01-16 14:35:06,673] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 257, 'learning_rate': 0.2487052496476696, 'max_depth': 8}. Best is trial 26 with value: 0.9.
# [I 2025-01-16 14:36:29,958] Trial 29 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 319, 'learning_rate': 0.19072403182853068, 'max_depth': 14}. Best is trial 26 with value: 0.9.
# [I 2025-01-16 14:36:45,235] A new study created in memory with name: no-name-11287ecb-0fdd-469d-a042-24e783d91151
# Training and predicting with XGBoost...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:36:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:37:10,150] Trial 0 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 314, 'max_depth': 16, 'learning_rate': 0.18311037236566277}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:37:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:37:26,160] Trial 1 finished with value: 0.9 and parameters: {'n_estimators': 211, 'max_depth': 12, 'learning_rate': 0.04604450143115096}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:37:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:37:55,699] Trial 2 finished with value: 0.9 and parameters: {'n_estimators': 473, 'max_depth': 15, 'learning_rate': 0.21551971670470874}. Best is trial 0 with value: 0.9033333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:37:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:38:18,977] Trial 3 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 275, 'max_depth': 19, 'learning_rate': 0.052878517481328935}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:38:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:38:35,319] Trial 4 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 282, 'max_depth': 5, 'learning_rate': 0.1039608710893421}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:38:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:38:51,870] Trial 5 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 203, 'max_depth': 18, 'learning_rate': 0.15018200374664928}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:38:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:39:17,069] Trial 6 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 382, 'max_depth': 13, 'learning_rate': 0.40963254271858524}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:39:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:39:38,781] Trial 7 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 341, 'max_depth': 11, 'learning_rate': 0.4624267545275174}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:39:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:39:46,775] Trial 8 finished with value: 0.9 and parameters: {'n_estimators': 67, 'max_depth': 13, 'learning_rate': 0.1327478062202381}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:39:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:40:11,178] Trial 9 finished with value: 0.91 and parameters: {'n_estimators': 341, 'max_depth': 14, 'learning_rate': 0.40945446683135245}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:40:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:40:21,528] Trial 10 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 83, 'max_depth': 20, 'learning_rate': 0.29448918994083867}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:40:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:40:44,149] Trial 11 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 445, 'max_depth': 7, 'learning_rate': 0.3182869618379781}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:40:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:40:58,736] Trial 12 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 194, 'max_depth': 9, 'learning_rate': 0.4895308359944698}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:41:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:41:23,223] Trial 13 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 374, 'max_depth': 9, 'learning_rate': 0.013534979945093263}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:41:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:41:38,006] Trial 14 finished with value: 0.9 and parameters: {'n_estimators': 245, 'max_depth': 3, 'learning_rate': 0.35918588390235684}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:41:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:42:04,341] Trial 15 finished with value: 0.9066666666666666 and parameters: {'n_estimators': 426, 'max_depth': 10, 'learning_rate': 0.4484773766173873}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:42:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:42:18,307] Trial 16 finished with value: 0.9 and parameters: {'n_estimators': 144, 'max_depth': 17, 'learning_rate': 0.2399155408937819}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:42:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:42:38,535] Trial 17 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 275, 'max_depth': 20, 'learning_rate': 0.28573856770757544}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:42:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:43:00,583] Trial 18 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 338, 'max_depth': 11, 'learning_rate': 0.06926819609032321}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:43:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:43:22,147] Trial 19 finished with value: 0.9 and parameters: {'n_estimators': 405, 'max_depth': 7, 'learning_rate': 0.3537120413477911}. Best is trial 3 with value: 0.9133333333333333.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:43:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 14:43:35,110] Trial 20 finished with value: 0.9033333333333333 and parameters: {'n_estimators': 155, 'max_depth': 18, 'learning_rate': 0.19826316734018404}. Best is trial 3 with value: 0.9133333333333333.
# ...
# [I 2025-01-16 14:56:54,351] Trial 22 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 458, 'learning_rate': 0.8357569079149685}. Best is trial 11 with value: 0.88.
# [I 2025-01-16 14:57:23,913] Trial 23 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 407, 'learning_rate': 0.9643575253467542}. Best is trial 11 with value: 0.88.
# [I 2025-01-16 14:58:00,121] Trial 24 finished with value: 0.84 and parameters: {'n_estimators': 498, 'learning_rate': 0.696597139366822}. Best is trial 11 with value: 0.88.
# [I 2025-01-16 14:58:28,961] Trial 25 finished with value: 0.84 and parameters: {'n_estimators': 398, 'learning_rate': 0.8134983125088678}. Best is trial 11 with value: 0.88.
# [I 2025-01-16 14:58:53,184] Trial 26 finished with value: 0.86 and parameters: {'n_estimators': 331, 'learning_rate': 0.9295135601677468}. Best is trial 11 with value: 0.88.
# [I 2025-01-16 14:59:26,359] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 461, 'learning_rate': 0.9996956260201393}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-16 14:59:44,300] Trial 28 finished with value: 0.8133333333333334 and parameters: {'n_estimators': 251, 'learning_rate': 0.8339833276090357}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-16 15:00:17,367] Trial 29 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 455, 'learning_rate': 0.6871389965863733}. Best is trial 27 with value: 0.8833333333333333.
# [I 2025-01-16 15:00:49,642] A new study created in memory with name: no-name-fe909683-8725-4370-99f6-ff34407869fb
# Training and predicting with Neural Network...
# [I 2025-01-16 15:01:11,482] Trial 0 finished with value: 0.9 and parameters: {'hidden_layer_1': 96, 'hidden_layer_2': 95, 'learning_rate_init': 0.011396815284265085}. Best is trial 0 with value: 0.9.
# [I 2025-01-16 15:01:22,796] Trial 1 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 50, 'hidden_layer_2': 27, 'learning_rate_init': 0.04772385042498817}. Best is trial 0 with value: 0.9.
# [I 2025-01-16 15:01:54,194] Trial 2 finished with value: 0.91 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 71, 'learning_rate_init': 0.055484974533201836}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:02:15,520] Trial 3 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 61, 'learning_rate_init': 0.02563372781870428}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:02:30,928] Trial 4 finished with value: 0.91 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 99, 'learning_rate_init': 0.07560629746956768}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:02:44,921] Trial 5 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 69, 'learning_rate_init': 0.07106893676438923}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:03:11,366] Trial 6 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 71, 'hidden_layer_2': 94, 'learning_rate_init': 0.002263555549598811}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:03:35,079] Trial 7 finished with value: 0.91 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 76, 'learning_rate_init': 0.04314961621888606}. Best is trial 2 with value: 0.91.
# [I 2025-01-16 15:03:57,111] Trial 8 finished with value: 0.9166666666666666 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 86, 'learning_rate_init': 0.09020160899876264}. Best is trial 8 with value: 0.9166666666666666.
# [I 2025-01-16 15:04:40,483] Trial 9 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 18, 'learning_rate_init': 0.0015155147259203181}. Best is trial 8 with value: 0.9166666666666666.
# [I 2025-01-16 15:04:53,102] Trial 10 finished with value: 0.91 and parameters: {'hidden_layer_1': 19, 'hidden_layer_2': 42, 'learning_rate_init': 0.0995549993089122}. Best is trial 8 with value: 0.9166666666666666.
# [I 2025-01-16 15:05:12,330] Trial 11 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 79, 'learning_rate_init': 0.0989651380445506}. Best is trial 8 with value: 0.9166666666666666.
# [I 2025-01-16 15:05:26,193] Trial 12 finished with value: 0.9266666666666666 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 47, 'learning_rate_init': 0.07144753215966887}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:05:45,082] Trial 13 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 48, 'learning_rate_init': 0.0794392763460767}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:05:50,638] Trial 14 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 33, 'learning_rate_init': 0.08419410896273863}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:06:07,488] Trial 15 finished with value: 0.9 and parameters: {'hidden_layer_1': 52, 'hidden_layer_2': 57, 'learning_rate_init': 0.06169312297430891}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:06:22,133] Trial 16 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 27, 'hidden_layer_2': 10, 'learning_rate_init': 0.08806937162372419}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:06:44,604] Trial 17 finished with value: 0.9 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 44, 'learning_rate_init': 0.063214420617363}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:07:10,435] Trial 18 finished with value: 0.9 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 83, 'learning_rate_init': 0.09119673018693855}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:07:20,985] Trial 19 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 62, 'learning_rate_init': 0.03646294254254423}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:07:42,745] Trial 20 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 45, 'hidden_layer_2': 87, 'learning_rate_init': 0.07017172617285199}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:07:56,566] Trial 21 finished with value: 0.9033333333333333 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 10, 'learning_rate_init': 0.08773591798420455}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:08:13,927] Trial 22 finished with value: 0.9133333333333333 and parameters: {'hidden_layer_1': 33, 'hidden_layer_2': 31, 'learning_rate_init': 0.09360469273625899}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:08:31,625] Trial 23 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 20, 'hidden_layer_2': 11, 'learning_rate_init': 0.08131068941593399}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:08:42,000] Trial 24 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 27, 'hidden_layer_2': 25, 'learning_rate_init': 0.06612025260499371}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:08:57,453] Trial 25 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 38, 'hidden_layer_2': 38, 'learning_rate_init': 0.0872297547309385}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:09:23,041] Trial 26 finished with value: 0.9066666666666666 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 19, 'learning_rate_init': 0.07587927237004394}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:09:30,775] Trial 27 finished with value: 0.91 and parameters: {'hidden_layer_1': 58, 'hidden_layer_2': 50, 'learning_rate_init': 0.054643394563527195}. Best is trial 12 with value: 0.9266666666666666.
# [I 2025-01-16 15:09:53,650] Trial 28 finished with value: 0.93 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 67, 'learning_rate_init': 0.09343490972219408}. Best is trial 28 with value: 0.93.
# [I 2025-01-16 15:10:20,972] Trial 29 finished with value: 0.8966666666666666 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 88, 'learning_rate_init': 0.09694578032053001}. Best is trial 28 with value: 0.93.
# [I 2025-01-16 15:10:41,994] A new study created in memory with name: no-name-8a59bfe9-7a85-4f62-b3e4-3a2c70fa6c16
# Training and predicting with MLP...
# [I 2025-01-16 15:11:09,796] Trial 0 finished with value: 0.9133333333333333 and parameters: {'layer_1': 112, 'layer_2': 113, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.058958334853773935}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-16 15:11:18,777] Trial 1 finished with value: 0.5 and parameters: {'layer_1': 145, 'layer_2': 66, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.020216416881694073}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-16 15:11:45,071] Trial 2 finished with value: 0.89 and parameters: {'layer_1': 93, 'layer_2': 91, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09172591324497353}. Best is trial 0 with value: 0.9133333333333333.
# [I 2025-01-16 15:12:35,806] Trial 3 finished with value: 0.9166666666666666 and parameters: {'layer_1': 107, 'layer_2': 113, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.08274676664271781}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-16 15:13:11,978] Trial 4 finished with value: 0.9033333333333333 and parameters: {'layer_1': 118, 'layer_2': 98, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.08190638063546372}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-16 15:13:57,986] Trial 5 finished with value: 0.8566666666666667 and parameters: {'layer_1': 120, 'layer_2': 68, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.07730959080132255}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-16 15:14:16,069] Trial 6 finished with value: 0.9 and parameters: {'layer_1': 93, 'layer_2': 87, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.026645967559700195}. Best is trial 3 with value: 0.9166666666666666.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 15:15:35,156] Trial 7 finished with value: 0.6766666666666666 and parameters: {'layer_1': 82, 'layer_2': 101, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0023914398550236773}. Best is trial 3 with value: 0.9166666666666666.
# [I 2025-01-16 15:15:58,646] Trial 8 finished with value: 0.92 and parameters: {'layer_1': 71, 'layer_2': 130, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07064806135707077}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:16:39,814] Trial 9 finished with value: 0.76 and parameters: {'layer_1': 111, 'layer_2': 112, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.061312584950251776}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:16:54,563] Trial 10 finished with value: 0.9166666666666666 and parameters: {'layer_1': 50, 'layer_2': 149, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04162156133437803}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:17:13,590] Trial 11 finished with value: 0.9 and parameters: {'layer_1': 68, 'layer_2': 138, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0989066530843023}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:17:31,219] Trial 12 finished with value: 0.9133333333333333 and parameters: {'layer_1': 71, 'layer_2': 128, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.07538464491255978}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:18:11,407] Trial 13 finished with value: 0.91 and parameters: {'layer_1': 136, 'layer_2': 125, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.06572266157962933}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:18:17,417] Trial 14 finished with value: 0.5 and parameters: {'layer_1': 71, 'layer_2': 120, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.045790290248565325}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:18:42,739] Trial 15 finished with value: 0.8966666666666666 and parameters: {'layer_1': 50, 'layer_2': 141, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08759912637229847}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:19:41,715] Trial 16 finished with value: 0.9166666666666666 and parameters: {'layer_1': 98, 'layer_2': 78, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0709723149526344}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:20:03,641] Trial 17 finished with value: 0.9 and parameters: {'layer_1': 81, 'layer_2': 132, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05254174018336072}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:20:36,907] Trial 18 finished with value: 0.8966666666666666 and parameters: {'layer_1': 83, 'layer_2': 111, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.09714286098899562}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:20:49,131] Trial 19 finished with value: 0.5 and parameters: {'layer_1': 130, 'layer_2': 50, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.08327836987385921}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:21:15,558] Trial 20 finished with value: 0.9033333333333333 and parameters: {'layer_1': 61, 'layer_2': 104, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.035262009625176664}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:21:27,801] Trial 21 finished with value: 0.9166666666666666 and parameters: {'layer_1': 54, 'layer_2': 150, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04371954392945452}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:21:49,604] Trial 22 finished with value: 0.9166666666666666 and parameters: {'layer_1': 59, 'layer_2': 148, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05197824380211963}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:22:21,229] Trial 23 finished with value: 0.8966666666666666 and parameters: {'layer_1': 103, 'layer_2': 140, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.0701257303959523}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:22:42,235] Trial 24 finished with value: 0.9066666666666666 and parameters: {'layer_1': 62, 'layer_2': 122, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.032045539939636825}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:23:06,881] Trial 25 finished with value: 0.8933333333333333 and parameters: {'layer_1': 76, 'layer_2': 135, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.012698090076656489}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:23:28,760] Trial 26 finished with value: 0.8266666666666667 and parameters: {'layer_1': 50, 'layer_2': 145, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.058096722412723366}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:24:04,715] Trial 27 finished with value: 0.9166666666666666 and parameters: {'layer_1': 102, 'layer_2': 118, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.039616085160418625}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:24:10,739] Trial 28 finished with value: 0.5 and parameters: {'layer_1': 91, 'layer_2': 133, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.06708536359942131}. Best is trial 8 with value: 0.92.
# [I 2025-01-16 15:24:34,888] Trial 29 finished with value: 0.9133333333333333 and parameters: {'layer_1': 111, 'layer_2': 109, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05885704833438221}. Best is trial 8 with value: 0.92.
# CFV dataset created and saved!

# %% [markdown]
# CPFV (Combined Probability and Class Feature Vector)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# Load datasets
# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_main_tpc.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_main_tpc (1).csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/positive_validation_tpc.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/10_TPC (Tripeptide Composition)/negative_validation_tpc.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)], ignore_index=True)
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)], ignore_index=True)

# Separate features and labels
X_train = main_data.drop(columns=["label"])
y_train = main_data["label"]
X_val = validation_data.drop(columns=["label"])
y_val = validation_data["label"]

# Initialize models with their tuned hyperparameters
trained_models = {
    "SVM": SVC(C=1.0, kernel="rbf", probability=True),  # Example parameters
    "Decision Tree": DecisionTreeClassifier(max_depth=10, min_samples_split=5),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5),
    "Logistic Regression": LogisticRegression(C=1.0, solver="lbfgs"),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=10),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=10, learning_rate=0.1, use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": LGBMClassifier(n_estimators=100, max_depth=10, learning_rate=0.1),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, learning_rate=0.1),
    "Neural Network (MLPClassifier)": MLPClassifier(hidden_layer_sizes=(100, 50), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200),
    "Multilayer Perceptron (Custom MLP)": MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200)
}

# Train all models on the training dataset
for model_name, model in trained_models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)

# Function to create CPFV dataset
def create_cpfv(models, X_data, y_data):
    cpfv_data = pd.DataFrame()
    for model_name, model in models.items():
        # Add predicted class labels
        cpfv_data[f"{model_name}_Class"] = model.predict(X_data)
        # Add predicted probabilities or decision scores
        if hasattr(model, "predict_proba"):
            cpfv_data[f"{model_name}_Prob"] = model.predict_proba(X_data)[:, 1]
        elif hasattr(model, "decision_function"):
            cpfv_data[f"{model_name}_Prob"] = model.decision_function(X_data)
        else:
            cpfv_data[f"{model_name}_Prob"] = cpfv_data[f"{model_name}_Class"]
    # Add true labels
    cpfv_data["True_Label"] = y_data.reset_index(drop=True)
    return cpfv_data

# Create CPFV dataset using validation data
cpfv_dataset = create_cpfv(trained_models, X_val, y_val)

# Save CPFV dataset to CSV
cpfv_dataset.to_csv("CPFV_TPC.csv", index=False)
# Out:
# Training SVM...
# Training Decision Tree...
# Training Random Forest...
# Training Logistic Regression...
# Training k-NN...
# Training Naive Bayes...
# Training Gradient Boosting...
# Training XGBoost...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:25:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001353 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 116
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training AdaBoost...
# Training Neural Network (MLPClassifier)...
# Training Multilayer Perceptron (Custom MLP)...
