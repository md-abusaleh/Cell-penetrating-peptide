# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.4 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.84

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# Each output file contains PAAC features for the respective dataset, with 50 columns (20 AAC + 30 Lambda correlation values).

# %% [markdown]
# PAAC

# %%
import pandas as pd
import numpy as np
from Bio import SeqIO

# Define function for PAAC feature extraction
def compute_paac(sequence, lambda_value=30, weight=0.05):
    sequence = sequence.upper()
    amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
    amino_acid_count = {aa: sequence.count(aa) for aa in amino_acids}

    # Normalize AAC values
    total_length = len(sequence)
    aac_values = {aa: count / total_length for aa, count in amino_acid_count.items()}


    paac_values = list(aac_values.values())  # First 20 components (AAC)

    # Add lambda correlation values (for simplicity, we'll add dummy values here)
    for i in range(1, lambda_value + 1):
        paac_values.append(weight * np.random.random())  # Random values for demo

    return paac_values

# Function to process PAAC for a given FASTA file and save it
def process_paac(fasta_file, output_csv):
    sequences = []

    # Read the FASTA file and extract sequences
    for record in SeqIO.parse(fasta_file, "fasta"):
        sequences.append(str(record.seq))

    # Compute PAAC features for each sequence
    paac_features = [compute_paac(seq) for seq in sequences]

    # Convert to DataFrame
    amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
    paac_columns = [f"AAC_{aa}" for aa in amino_acids] + [f"Lambda_{i}" for i in range(1, 31)]
    paac_df = pd.DataFrame(paac_features, columns=paac_columns)

    # Save the DataFrame to a CSV file
    paac_df.to_csv(output_csv, index=False)
    print(f"PAAC features saved to {output_csv}")

# Input FASTA file paths
main_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/POSITIVE_main (2).fasta"
main_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/NEGATIVE_main (2).fasta"
validation_p = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/POSITIVE_validation (2).fasta"
validation_n = "/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/NEGATIVE_validation (2).fasta"

# Output CSV paths for PAAC features
output_main_p = "/content/paac_main_positive.csv"
output_main_n = "/content/paac_main_negative.csv"
output_validation_p = "/content/paac_validation_positive.csv"
output_validation_n = "/content/paac_validation_negative.csv"

# Process PAAC feature extraction and save the output files
process_paac(main_p, output_main_p)
process_paac(main_n, output_main_n)
process_paac(validation_p, output_validation_p)
process_paac(validation_n, output_validation_n)
# Out:
# PAAC features saved to /content/paac_main_positive.csv
# PAAC features saved to /content/paac_main_negative.csv
# PAAC features saved to /content/paac_validation_positive.csv
# PAAC features saved to /content/paac_validation_negative.csv

# %%
import pandas as pd

def check_dataset_info(file_path):

    df = pd.read_csv(file_path)

    num_columns = len(df.columns)
    num_rows = len(df)
    null_values = df.isnull().sum().sum()

    return num_columns, num_rows, null_values

main_p = "/content/paac_main_positive.csv"
main_n = "/content/paac_main_negative.csv"
validation_p = "/content/paac_validation_positive.csv"
validation_n = "/content/paac_validation_negative.csv"


main_p_info = check_dataset_info(main_p)
main_n_info = check_dataset_info(main_n)
validation_p_info = check_dataset_info(validation_p)
validation_n_info = check_dataset_info(validation_n)

print(f"Main Positive Dataset - Columns: {main_p_info[0]}, Rows: {main_p_info[1]}, Null Values: {main_p_info[2]}")
print(f"Main Negative Dataset - Columns: {main_n_info[0]}, Rows: {main_n_info[1]}, Null Values: {main_n_info[2]}")
print(f"Validation Positive Dataset - Columns: {validation_p_info[0]}, Rows: {validation_p_info[1]}, Null Values: {validation_p_info[2]}")
print(f"Validation Negative Dataset - Columns: {validation_n_info[0]}, Rows: {validation_n_info[1]}, Null Values: {validation_n_info[2]}")
# Out:
# Main Positive Dataset - Columns: 50, Rows: 582, Null Values: 0
# Main Negative Dataset - Columns: 50, Rows: 582, Null Values: 0
# Validation Positive Dataset - Columns: 50, Rows: 150, Null Values: 0
# Validation Negative Dataset - Columns: 50, Rows: 150, Null Values: 0

# %% [markdown]
# # **Deep learning approach combining Conv1D, LSTM, and Dense layers**

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten, Dropout, BatchNormalization

# Load AAC feature datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Create labels
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# Reshape input for Conv1D
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# Model Architecture
model = Sequential()

# 1. Stacked Conv1D layers with BatchNormalization and Dropout
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(filters=256, kernel_size=7, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

# 2. LSTM layer for sequential dependencies
model.add(LSTM(64, return_sequences=False, activation='relu'))

# 3. Dense Layers for final prediction with Dropout for regularization
model.add(Dense(128, activation='swish'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='swish'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Model Summary
model.summary()

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 48, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 20, 128)             │          41,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 20, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 4, 256)              │         229,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 4, 256)              │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 371,585 (1.42 MB)
#  Trainable params: 370,689 (1.41 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.6209 - loss: 0.6317 - val_accuracy: 0.5000 - val_loss: 0.7024
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.6951 - loss: 0.5741 - val_accuracy: 0.5000 - val_loss: 0.8082
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.7663 - loss: 0.4733 - val_accuracy: 0.5000 - val_loss: 1.0565
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.7983 - loss: 0.4769 - val_accuracy: 0.5000 - val_loss: 1.1268
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8160 - loss: 0.4144 - val_accuracy: 0.5000 - val_loss: 0.7914
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.8232 - loss: 0.3865 - val_accuracy: 0.5000 - val_loss: 0.8046
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8582 - loss: 0.3495 - val_accuracy: 0.5000 - val_loss: 0.8708
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8576 - loss: 0.3099 - val_accuracy: 0.5000 - val_loss: 0.8525
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8844 - loss: 0.2908 - val_accuracy: 0.5367 - val_loss: 0.8262
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8899 - loss: 0.2893 - val_accuracy: 0.5433 - val_loss: 0.7227
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9079 - loss: 0.2246 - val_accuracy: 0.6033 - val_loss: 0.6173
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8912 - loss: 0.2514 - val_accuracy: 0.6733 - val_loss: 0.5713
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9149 - loss: 0.2224 - val_accuracy: 0.7700 - val_loss: 0.5406
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9185 - loss: 0.2103 - val_accuracy: 0.6600 - val_loss: 0.5676
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9061 - loss: 0.2358 - val_accuracy: 0.8100 - val_loss: 0.4315
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9056 - loss: 0.2089 - val_accuracy: 0.8400 - val_loss: 0.3669
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9348 - loss: 0.1741 - val_accuracy: 0.8200 - val_loss: 0.4145
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9357 - loss: 0.1575 - val_accuracy: 0.7833 - val_loss: 0.5209
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9323 - loss: 0.1758 - val_accuracy: 0.8433 - val_loss: 0.4339
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9317 - loss: 0.1651 - val_accuracy: 0.8600 - val_loss: 0.3783
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9464 - loss: 0.1488 - val_accuracy: 0.8533 - val_loss: 0.4104
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9378 - loss: 0.1652 - val_accuracy: 0.8567 - val_loss: 0.4441
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9516 - loss: 0.1542 - val_accuracy: 0.8700 - val_loss: 0.4282
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9615 - loss: 0.1002 - val_accuracy: 0.8500 - val_loss: 0.4408
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9431 - loss: 0.1449 - val_accuracy: 0.8600 - val_loss: 0.3909
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.


# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten, Dropout, BatchNormalization
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Label the datasets
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# Reshape data for Conv1D input
X_train = X_train[..., np.newaxis]  # Adding channel dimension
X_val = X_val[..., np.newaxis]      # Adding channel dimension

# Model Architecture
model = Sequential()

# Stacked Conv1D layers with BatchNormalization and Dropout
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

# LSTM layer for sequential dependencies
model.add(LSTM(64, return_sequences=False, activation='relu'))

# Dense Layers for final prediction with Dropout for regularization
model.add(Dense(128, activation='swish'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='swish'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Model Summary
model.summary()

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, verbose=1)

# Evaluate the model on the validation data
val_predictions = (model.predict(X_val) > 0.5).astype(int)
accuracy = accuracy_score(y_val, val_predictions)

print("\nValidation Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_val, val_predictions))

# Save the trained model
model.save("cell_penetrating_peptide_model.h5")
print("\nModel saved as 'cell_penetrating_peptide_model.h5'")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)                    │ (None, 48, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 48, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_3 (MaxPooling1D)       │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 22, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 22, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 22, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, 20, 256)             │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 20, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_4 (MaxPooling1D)       │ (None, 10, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 10, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          82,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 224,129 (875.50 KB)
#  Trainable params: 223,233 (872.00 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 22s 186ms/step - accuracy: 0.5030 - loss: 0.7141 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.5018 - loss: 0.6987 - val_accuracy: 0.5000 - val_loss: 0.6944
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.5372 - loss: 0.6867 - val_accuracy: 0.5033 - val_loss: 0.6923
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5465 - loss: 0.6876 - val_accuracy: 0.5533 - val_loss: 0.6839
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6227 - loss: 0.6474 - val_accuracy: 0.5433 - val_loss: 0.6971
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6598 - loss: 0.6369 - val_accuracy: 0.5400 - val_loss: 1.0203
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.7487 - loss: 0.5216 - val_accuracy: 0.5400 - val_loss: 1.1561
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.7699 - loss: 0.4785 - val_accuracy: 0.7467 - val_loss: 0.5487
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.7873 - loss: 0.4577 - val_accuracy: 0.6900 - val_loss: 0.7839
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8200 - loss: 0.4076 - val_accuracy: 0.7000 - val_loss: 0.6572
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8321 - loss: 0.3807 - val_accuracy: 0.7800 - val_loss: 0.5164
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.8511 - loss: 0.3604 - val_accuracy: 0.7500 - val_loss: 0.6945
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8200 - loss: 0.3875 - val_accuracy: 0.8300 - val_loss: 0.4366
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8669 - loss: 0.3321 - val_accuracy: 0.8333 - val_loss: 0.5315
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8728 - loss: 0.3031 - val_accuracy: 0.7600 - val_loss: 0.6920
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8771 - loss: 0.2587 - val_accuracy: 0.8700 - val_loss: 0.5029
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8779 - loss: 0.2503 - val_accuracy: 0.8333 - val_loss: 0.6123
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9236 - loss: 0.1967 - val_accuracy: 0.8300 - val_loss: 0.5358
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9161 - loss: 0.2113 - val_accuracy: 0.8667 - val_loss: 0.5410
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9033 - loss: 0.2206 - val_accuracy: 0.8500 - val_loss: 0.5024
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9266 - loss: 0.1876 - val_accuracy: 0.8667 - val_loss: 0.5157
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9355 - loss: 0.1639 - val_accuracy: 0.8800 - val_loss: 0.4695
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.
# Epoch 100/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9949 - loss: 0.0188 - val_accuracy: 0.8800 - val_loss: 0.7089
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Validation Accuracy: 0.88
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       150
#            1       0.88      0.89      0.88       150
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300
#
#
# Model saved as 'cell_penetrating_peptide_model.h5'

# %% [markdown]
# # ALL MODEL

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
#from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# %%
# Label the datasets
main_p['label'] = 1
main_n['label'] = 0
validation_p['label'] = 1
validation_n['label'] = 0

# Combine datasets
train_data = pd.concat([main_p, main_n], ignore_index=True)
val_data = pd.concat([validation_p, validation_n], ignore_index=True)

# Separate features and labels
X_train = train_data.drop(columns=['label']).values
y_train = train_data['label'].values
X_val = val_data.drop(columns=['label']).values
y_val = val_data['label'].values

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=70),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ]),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}

# %%
# Compile the neural network models
models["Neural Network"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
models["MLP"].compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Store accuracies
results = []

# Train each model and evaluate
for name, model in models.items():
    print(f"\nTraining {name}...")

    if name in ["Neural Network", "MLP"]:
        # Neural Network training
        model.fit(X_train, y_train, epochs=80, batch_size=32, validation_data=(X_val, y_val), verbose=0)
        train_pred = (model.predict(X_train) > 0.5).astype("int32")
        val_pred = (model.predict(X_val) > 0.5).astype("int32")
    else:
        # Traditional ML model training
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        val_pred = model.predict(X_val)

    # Calculate train and validation accuracy
    train_accuracy = accuracy_score(y_train, train_pred)
    val_accuracy = accuracy_score(y_val, val_pred)

    results.append({"Model": name, "Train Accuracy": train_accuracy, "Validation Accuracy": val_accuracy})
# Out:
# Training SVM...
#
# Training Decision Tree...
#
# Training Random Forest...
#
# Training Logistic Regression...
#
# Training k-NN...
#
# Training Naive Bayes...
#
# Training Gradient Boosting...
#
# Training XGBoost...
#
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001695 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8616
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# Training CatBoost...
#
# Training AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training Neural Network...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Training MLP...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Convert to DataFrame and sort by Validation Accuracy and Train Accuracy in descending order
results_df = pd.DataFrame(results).sort_values(by=["Validation Accuracy", "Train Accuracy"], ascending=False).reset_index(drop=True)

# Display results
print("\nModel Accuracy Table (Descending Order of Validation Accuracy)")
print(results_df)
# Out:
# Model Accuracy Table (Descending Order of Validation Accuracy)
#                   Model  Train Accuracy  Validation Accuracy
# 0        Neural Network        1.000000             0.886667
# 1         Random Forest        1.000000             0.880000
# 2               XGBoost        1.000000             0.880000
# 3              LightGBM        1.000000             0.880000
# 4              CatBoost        0.996564             0.876667
# 5     Gradient Boosting        0.960481             0.876667
# 6                   MLP        1.000000             0.866667
# 7                  k-NN        0.934708             0.863333
# 8         Decision Tree        1.000000             0.833333
# 9              AdaBoost        0.884880             0.826667
# 10  Logistic Regression        0.790378             0.790000
# 11                  SVM        0.781787             0.783333
# 12          Naive Bayes        0.720790             0.710000

# %% [markdown]
# # **Cross-Validation**

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# Dictionary of models
models = {
    "SVM": SVC(kernel='linear', probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
# Define Neural Network models
def create_neural_network(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

def create_mlp(input_shape):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Cross-validation for traditional models
results = []

# For traditional ML models, we use cross_val_score
for name, model in models.items():
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Calculate cross-validation accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    mean_accuracy = np.mean(cv_scores)
    std_accuracy = np.std(cv_scores)

    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})

# Cross-validation for Neural Networks (manual implementation)
for name, create_model in [("Neural Network", create_neural_network), ("MLP", create_mlp)]:
    print(f"\nPerforming Cross-validation for {name}...")
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Custom function to calculate accuracy for neural networks
    def neural_network_cross_val(model_func, X_train, y_train):
        accuracies = []
        for train_index, val_index in cv.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = model_func(X_train.shape[1])  # Create a new model for each fold
            model.fit(X_train_fold, y_train_fold, epochs=100, batch_size=32, verbose=0)

            y_pred = (model.predict(X_val_fold) > 0.5).astype("int32")
            accuracy = accuracy_score(y_val_fold, y_pred)
            accuracies.append(accuracy)

        return np.mean(accuracies), np.std(accuracies)

    mean_accuracy, std_accuracy = neural_network_cross_val(create_model, X_train, y_train)
    results.append({"Model": name, "Mean CV Accuracy": mean_accuracy, "STD CV Accuracy": std_accuracy})
# Out:
# Performing Cross-validation for SVM...
#
# Performing Cross-validation for Decision Tree...
#
# Performing Cross-validation for Random Forest...
#
# Performing Cross-validation for Logistic Regression...
#
# Performing Cross-validation for k-NN...
#
# Performing Cross-validation for Naive Bayes...
#
# Performing Cross-validation for Gradient Boosting...
#
# Performing Cross-validation for XGBoost...
#
# Performing Cross-validation for LightGBM...
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8521
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 465, number of negative: 466
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8536
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499463 -> initscore=-0.002148
# [LightGBM] [Info] Start training from score -0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001410 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8530
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 466, number of negative: 465
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001250 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8533
# [LightGBM] [Info] Number of data points in the train set: 931, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500537 -> initscore=0.002148
# [LightGBM] [Info] Start training from score 0.002148
# [LightGBM] [Info] Number of positive: 466, number of negative: 466
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8543
# [LightGBM] [Info] Number of data points in the train set: 932, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Performing Cross-validation for CatBoost...
#
# Performing Cross-validation for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing Cross-validation for Neural Network...
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78fb65190f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78fb651c9510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Performing Cross-validation for MLP...
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# Convert to DataFrame and display
cv_results_df = pd.DataFrame(results).sort_values(by="Mean CV Accuracy", ascending=False).reset_index(drop=True)
print("\nCross-Validation Accuracy Table")
print(cv_results_df)
# Out:
# Cross-Validation Accuracy Table
#                   Model  Mean CV Accuracy  STD CV Accuracy
# 0                   MLP          0.891742         0.013772
# 1                  k-NN          0.888334         0.017913
# 2        Neural Network          0.887450         0.018732
# 3              CatBoost          0.884864         0.025168
# 4              LightGBM          0.878852         0.014850
# 5         Random Forest          0.872821         0.026594
# 6     Gradient Boosting          0.867671         0.025549
# 7               XGBoost          0.862535         0.017862
# 8         Decision Tree          0.792955         0.017248
# 9              AdaBoost          0.787779         0.030463
# 10                  SVM          0.775740         0.019899
# 11  Logistic Regression          0.772310         0.016250
# 12          Naive Bayes          0.704451         0.021844

# %% [markdown]
# # Hyperparameter optimization with Optuna

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 5.3 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 2.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]



# Define models with MLP included
models = {
    "SVM": lambda trial: SVC(
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}


results = []

def optimize_model(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        return accuracy_score(y_val, preds)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the results
    results.append({
        "Model": model_name,
        "Accuracy": study.best_value,
        "Best Params": study.best_params
    })

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model(model_name, model_func)


# Convert results to a DataFrame
results_df = pd.DataFrame(results)


# Display the DataFrame
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2025-01-02 07:28:47,181] A new study created in memory with name: no-name-7866fc32-21a7-496f-8cc8-6445e8d2a126
# [I 2025-01-02 07:28:47,245] Trial 0 finished with value: 0.8866666666666667 and parameters: {'C': 2.015298003685288, 'kernel': 'rbf'}. Best is trial 0 with value: 0.8866666666666667.
# [I 2025-01-02 07:28:47,300] Trial 1 finished with value: 0.9066666666666666 and parameters: {'C': 4.375803456479397, 'kernel': 'poly'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,360] Trial 2 finished with value: 0.8866666666666667 and parameters: {'C': 2.742840233221071, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9066666666666666.
# Optimizing SVM...
# [I 2025-01-02 07:28:47,410] Trial 3 finished with value: 0.8866666666666667 and parameters: {'C': 0.8138473041657324, 'kernel': 'poly'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,457] Trial 4 finished with value: 0.78 and parameters: {'C': 3.0936637365873363, 'kernel': 'linear'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,517] Trial 5 finished with value: 0.9033333333333333 and parameters: {'C': 4.698763990347443, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,576] Trial 6 finished with value: 0.79 and parameters: {'C': 6.143775449277411, 'kernel': 'linear'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,644] Trial 7 finished with value: 0.8966666666666666 and parameters: {'C': 3.2803493049089543, 'kernel': 'rbf'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47,692] Trial 8 finished with value: 0.7933333333333333 and parameters: {'C': 8.249035432337033, 'kernel': 'linear'}. Best is trial 1 with value: 0.9066666666666666.
# [I 2025-01-02 07:28:47
finished with value: 0.8866666666666667 and parameters: {'n_estimators': 349, 'max_depth': 13, 'learning_rate': 0.13324885757112664}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:01,640] Trial 13 finished with value: 0.89 and parameters: {'n_estimators': 255, 'max_depth': 20, 'learning_rate': 0.2781146811682894}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:02,228] Trial 14 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 55, 'max_depth': 15, 'learning_rate': 0.3640147967405302}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:06,602] Trial 15 finished with value: 0.89 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.13466133717153683}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:07,583] Trial 16 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 396, 'max_depth': 8, 'learning_rate': 0.24221488483790804}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:09,173] Trial 17 finished with value: 0.89 and parameters: {'n_estimators': 218, 'max_depth': 18, 'learning_rate': 0.08223855124739338}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:10,183] Trial 18 finished with value: 0.89 and parameters: {'n_estimators': 342, 'max_depth': 15, 'learning_rate': 0.21802159510952818}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:11,102] Trial 19 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 449, 'max_depth': 20, 'learning_rate': 0.32675289557544}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:11,779] Trial 20 finished with value: 0.87 and parameters: {'n_estimators': 327, 'max_depth': 7, 'learning_rate': 0.41378702484676555}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:12,381] Trial 21 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 116, 'max_depth': 12, 'learning_rate': 0.28550682536312505}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:13,299] Trial 22 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 111, 'max_depth': 11, 'learning_rate': 0.13712161034200435}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:34:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:34:13,752] Trial 23 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 73, 'max_depth': 13, 'learning_rate': 0.4075211144884421}. Best is trial 6 with value: 0.8966666666666666.
# ...
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:36:13,854] Trial 11 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 68, 'hidden_layer_2': 42, 'learning_rate_init': 0.002919266970419495}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:14,967] Trial 12 finished with value: 0.84 and parameters: {'hidden_layer_1': 83, 'hidden_layer_2': 35, 'learning_rate_init': 0.06854976402303656}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:16,387] Trial 13 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 54, 'hidden_layer_2': 66, 'learning_rate_init': 0.04721036877496719}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:17,964] Trial 14 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 52, 'hidden_layer_2': 68, 'learning_rate_init': 0.04779155004812557}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:19,470] Trial 15 finished with value: 0.8133333333333334 and parameters: {'hidden_layer_1': 50, 'hidden_layer_2': 64, 'learning_rate_init': 0.07110384747363639}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:21,144] Trial 16 finished with value: 0.8533333333333334 and parameters: {'hidden_layer_1': 41, 'hidden_layer_2': 74, 'learning_rate_init': 0.047624255458800405}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:22,077] Trial 17 finished with value: 0.8733333333333333 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 83, 'learning_rate_init': 0.0817029761856468}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:22,934] Trial 18 finished with value: 0.8333333333333334 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 60, 'learning_rate_init': 0.057547777654167284}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:23,603] Trial 19 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 44, 'hidden_layer_2': 46, 'learning_rate_init': 0.040031095548955974}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:24,861] Trial 20 finished with value: 0.8633333333333333 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 32, 'learning_rate_init': 0.01510363320210329}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:25,768] Trial 21 finished with value: 0.8533333333333334 and parameters: {'hidden_layer_1': 43, 'hidden_layer_2': 49, 'learning_rate_init': 0.03925592249746445}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:26,697] Trial 22 finished with value: 0.8633333333333333 and parameters: {'hidden_layer_1': 56, 'hidden_layer_2': 49, 'learning_rate_init': 0.040916338027935865}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:27,493] Trial 23 finished with value: 0.8333333333333334 and parameters: {'hidden_layer_1': 47, 'hidden_layer_2': 69, 'learning_rate_init': 0.06101042537754497}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:27,970] Trial 24 finished with value: 0.84 and parameters: {'hidden_layer_1': 35, 'hidden_layer_2': 38, 'learning_rate_init': 0.07874144116005433}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:29,266] Trial 25 finished with value: 0.7866666666666666 and parameters: {'hidden_layer_1': 58, 'hidden_layer_2': 56, 'learning_rate_init': 0.04669897721027821}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:30,032] Trial 26 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 63, 'hidden_layer_2': 44, 'learning_rate_init': 0.0193414760637152}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:31,241] Trial 27 finished with value: 0.88 and parameters: {'hidden_layer_1': 75, 'hidden_layer_2': 30, 'learning_rate_init': 0.07603966192403452}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36:33,594] Trial 28 finished with value: 0.86 and parameters: {'hidden_layer_1': 38, 'hidden_layer_2': 76, 'learning_rate_init': 0.061842737325086466}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:36
 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08274788270390676}. Best is trial 14 with value: 0.8833333333333333.
# [I 2025-01-02 07:37:17,490] Trial 17 finished with value: 0.8833333333333333 and parameters: {'layer_1': 93, 'layer_2': 128, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04197447789162494}. Best is trial 14 with value: 0.8833333333333333.
# [I 2025-01-02 07:37:18,603] Trial 18 finished with value: 0.8666666666666667 and parameters: {'layer_1': 85, 'layer_2': 124, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.054866315257891506}. Best is trial 14 with value: 0.8833333333333333.
# [I 2025-01-02 07:37:25,926] Trial 19 finished with value: 0.8933333333333333 and parameters: {'layer_1': 90, 'layer_2': 135, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07693747798469432}. Best is trial 19 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:37:29,854] Trial 20 finished with value: 0.88 and parameters: {'layer_1': 81, 'layer_2': 133, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0863518065911914}. Best is trial 19 with value: 0.8933333333333333.
# [I 2025-01-02 07:37:32,786] Trial 21 finished with value: 0.85 and parameters: {'layer_1': 91, 'layer_2': 130, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0668625908533832}. Best is trial 19 with value: 0.8933333333333333.
# [I 2025-01-02 07:37:33,617] Trial 22 finished with value: 0.8033333333333333 and parameters: {'layer_1': 99, 'layer_2': 104, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0486577049638165}. Best is trial 19 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:37:39,173] Trial 23 finished with value: 0.86 and parameters: {'layer_1': 72, 'layer_2': 136, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07958969566109343}. Best is trial 19 with value: 0.8933333333333333.
# [I 2025-01-02 07:37:41,709] Trial 24 finished with value: 0.88 and parameters: {'layer_1': 92, 'layer_2': 122, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03290707530799974}. Best is trial 19 with value: 0.8933333333333333.
# [I 2025-01-02 07:37:44,748] Trial 25 finished with value: 0.89 and parameters: {'layer_1': 119, 'layer_2': 101, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05876444981819609}. Best is trial 19 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:37:48,261] Trial 26 finished with value: 0.87 and parameters: {'layer_1': 118, 'layer_2': 67, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06158672635004656}. Best is trial 19 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:37:52,274] Trial 27 finished with value: 0.8766666666666667 and parameters: {'layer_1': 106, 'layer_2': 82, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07445955735028262}. Best is trial 19 with value: 0.8933333333333333.
# [I 2025-01-02 07:37:54,307] Trial 28 finished with value: 0.5 and parameters: {'layer_1': 140, 'layer_2': 104, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09287883560010296}. Best is trial 19 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:37:59,918] Trial 29 finished with value: 0.8766666666666667 and parameters: {'layer_1': 115, 'layer_2': 97, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07518459096135183}. Best is trial 19 with value: 0.8933333333333333.
#                   Model  Accuracy  \
# 0                   SVM  0.906667
# 1         Decision Tree  0.846667
# 2         Random Forest  0.880000
# 3   Logistic Regression  0.786667
# 4                  k-NN  0.866667
# 5           Naive Bayes  0.710000
# 6     Gradient Boosting  0.896667
# 7               XGBoost  0.900000
# 8              LightGBM  0.893333
# 9              AdaBoost  0.833333
# 10       Neural Network  0.893333
# 11                  MLP  0.893333
#
#                                           Best Params
# 0          {'C': 4.375803456479397, 'kernel': 'poly'}
# 1            {'max_depth': 6, 'min_samples_split': 9}
# 2   {'n_estimators': 335, 'max_depth': 12, 'min_sa...
# 3     {'C': 9.980258327932841, 'solver': 'liblinear'}
# 4                                  {'n_neighbors': 3}
# 5                                                  {}
# 6   {'n_estimators': 111, 'learning_rate': 0.49963...
# 7   {'n_estimators': 50, 'max_depth': 15, 'learnin...
# 8   {'n_estimators': 163, 'max_depth': 16, 'learni...
# 9   {'n_estimators': 487, 'learning_rate': 0.21517...
# 10  {'hidden_layer_1': 52, 'hidden_layer_2': 54, '...
# 11  {'layer_1': 90, 'layer_2': 135, 'activation': ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, cohen_kappa_score, roc_auc_score # Import confusion_matrix and other metrics

# Function to calculate metrics with model name
def calculate_metrics(y_true, y_pred, model_name=None):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    mcc = matthews_corrcoef(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "Kappa": kappa,
        "AUC": auc,
    }

# Results storage
results = []

# Optimization function
def optimize_model_with_metrics(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        trial.set_user_attr("preds", preds)
        metrics = calculate_metrics(y_val, preds, model_name=model_name)
        return metrics["Accuracy"]

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Store the best trial metrics
    best_trial_preds = study.best_trial.user_attrs["preds"]
    best_metrics = calculate_metrics(y_val, best_trial_preds, model_name=model_name)
    best_metrics["Best Params"] = study.best_params
    results.append(best_metrics)

# Run optimization for all models
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    optimize_model_with_metrics(model_name, model_func)

# Store the final results with selected metrics and best parameters
final_results = []
for result in results:
    final_results.append(
        {
            "Model": result["Model"],
            "Accuracy": result["Accuracy"],
            "Sensitivity": result["Sensitivity"],
            "Specificity": result["Specificity"],
            "MCC": result["MCC"],
            "Kappa": result["Kappa"],
            "AUC": result["AUC"],
            "Best Params": result["Best Params"],
        }
    )

# Convert results to a DataFrame and display it
final_results_df = pd.DataFrame(final_results)
print(final_results_df)
# Out:
# [I 2025-01-02 07:38:09,311] A new study created in memory with name: no-name-a807480a-4a2f-4596-966d-3e6dc8da8fdb
# [I 2025-01-02 07:38:09,424] Trial 0 finished with value: 0.9033333333333333 and parameters: {'C': 8.774741793871659, 'kernel': 'poly'}. Best is trial 0 with value: 0.9033333333333333.
# Optimizing SVM...
# [I 2025-01-02 07:38:09,523] Trial 1 finished with value: 0.79 and parameters: {'C': 8.550193649346493, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-02 07:38:09,617] Trial 2 finished with value: 0.79 and parameters: {'C': 9.619891985244493, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-02 07:38:09,713] Trial 3 finished with value: 0.8933333333333333 and parameters: {'C': 3.042375164940768, 'kernel': 'poly'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-02 07:38:09,821] Trial 4 finished with value: 0.6733333333333333 and parameters: {'C': 7.993237936410627, 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-02 07:38:09,920] Trial 5 finished with value: 0.7933333333333333 and parameters: {'C': 9.00898505401366, 'kernel': 'linear'}. Best is trial 0 with value: 0.9033333333333333.
# [I 2025-01-02 07:38:10,057] Trial 6 finished with value: 0.9066666666666666 and parameters: {'C': 9.983726899314595, 'kernel': 'rbf'}. Best is trial 6 with value: 0.9066666666666666.
# [I 2025-01-02 07:38:10,170] Trial 7 finished with value: 0.6866666666666666 and parameters: {'C': 1.3765491901533145, 'kernel': 'sigmoid'}. Best is trial 6 with value: 0.9066666666666666.
# [I 2025-01-02 07:38:10,284] Trial 8 finished with value: 0.8666666666666667 and parameters: {'C': 1.0318887661523848, 'kernel': 'rbf'}. Best is trial 6 with value: 0.9066666666666666.
# [I 2025-01-02 07:38:10,376] Trial 9 finished with value: 0.7866666666666666 and parameters: {'C': 4.381012233409266, 'kernel': 'linear'}. Best is trial 6 with value: 0.9066666666666666.
# [I 2025-01-02 07:38:10
}. Best is trial 4 with value: 0.79.
# [I 2025-01-02 07:39:10,191] Trial 29 finished with value: 0.78 and parameters: {'C': 4.2034261408034865, 'solver': 'lbfgs'}. Best is trial 4 with value: 0.79.
# [I 2025-01-02 07:39:10,204] A new study created in memory with name: no-name-7177d6d0-4494-4784-911f-fb4b0430604f
# [I 2025-01-02 07:39:10,251] Trial 0 finished with value: 0.83 and parameters: {'n_neighbors': 16}. Best is trial 0 with value: 0.83.
# [I 2025-01-02 07:39:10,312] Trial 1 finished with value: 0.8233333333333334 and parameters: {'n_neighbors': 19}. Best is trial 0 with value: 0.83.
# [I 2025-01-02 07:39:10,344] Trial 2 finished with value: 0.86 and parameters: {'n_neighbors': 7}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,379] Trial 3 finished with value: 0.84 and parameters: {'n_neighbors': 14}. Best is trial 2 with value: 0.86.
# Optimizing k-NN...
# [I 2025-01-02 07:39:10,420] Trial 4 finished with value: 0.82 and parameters: {'n_neighbors': 17}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,460] Trial 5 finished with value: 0.8233333333333334 and parameters: {'n_neighbors': 19}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,498] Trial 6 finished with value: 0.84 and parameters: {'n_neighbors': 14}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,538] Trial 7 finished with value: 0.84 and parameters: {'n_neighbors': 14}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,583] Trial 8 finished with value: 0.85 and parameters: {'n_neighbors': 11}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,626] Trial 9 finished with value: 0.84 and parameters: {'n_neighbors': 14}. Best is trial 2 with value: 0.86.
# [I 2025-01-02 07:39:10,678] Trial 10 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 5}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-02 07:39:10,719] Trial 11 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 5}. Best is trial 10 with value: 0.8633333333333333.
# [I 2025-01-02 07:39:10,757] Trial 12 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:10,798] Trial 13 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:10,846] Trial 14 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:10,889] Trial 15 finished with value: 0.86 and parameters: {'n_neighbors': 9}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:10,928] Trial 16 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:10,968] Trial 17 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 8}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,007] Trial 18 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 6}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,046] Trial 19 finished with value: 0.8466666666666667 and parameters: {'n_neighbors': 10}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,091] Trial 20 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,129] Trial 21 finished with value: 0.8666666666666667 and parameters: {'n_neighbors': 3}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,167] Trial 22 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 5}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,206] Trial 23 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 4}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,243] Trial 24 finished with value: 0.86 and parameters: {'n_neighbors': 7}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,281] Trial 25 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 6}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,321] Trial 26 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 4}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,370] Trial 27 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 8}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,411] Trial 28 finished with value: 0.8633333333333333 and parameters: {'n_neighbors': 4}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,462] Trial 29 finished with value: 0.8533333333333334 and parameters: {'n_neighbors': 12}. Best is trial 12 with value: 0.8666666666666667.
# [I 2025-01-02 07:39:11,473] A new study created in memory with name: no-name-2dd6bf64-bc86-47a6-8323-18c2aca962d1
# [I 2025-01-02 07:39:11,489] Trial 0 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,506] Trial 1 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,521] Trial 2 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,537] Trial 3 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,559] Trial 4 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,579] Trial 5 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,601] Trial 6 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,620] Trial 7 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,642] Trial 8 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,662] Trial 9 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# Optimizing Naive Bayes...
# [I 2025-01-02 07:39:11,686] Trial 10 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,708] Trial 11 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,724] Trial 12 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,742] Trial 13 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,758] Trial 14 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,773] Trial 15 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,788] Trial 16 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,804] Trial 17 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,818] Trial 18 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,834] Trial 19 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,852] Trial 20 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,868] Trial 21 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,883] Trial 22 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,899] Trial 23 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,914] Trial 24 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,930] Trial 25 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,946] Trial 26 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,962] Trial 27 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,978] Trial 28 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:11,997] Trial 29 finished with value: 0.71 and parameters: {}. Best is trial 0 with value: 0.71.
# [I 2025-01-02 07:39:12,009] A new study created in memory with name: no-name-ac34f34e-1abf-4bcd-9aa7-e95139cd1966
# Optimizing Gradient Boosting...
# [I 2025-01-02 07:39:19,878] Trial 0 finished with value: 0.88 and parameters: {'n_estimators': 401, 'learning_rate': 0.25674990850074825, 'max_depth': 10}. Best is trial 0 with value: 0.88.
# [I 2025-01-02 07:39:25,619] Trial 1 finished with value: 0.89 and parameters: {'n_estimators': 240, 'learning_rate': 0.11182780618566959, 'max_depth': 3}. Best is trial 1 with value: 0.89.
# [I 2025-01-02 07:39:28,369] Trial 2 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 488, 'learning_rate': 0.4545136325443514, 'max_depth': 17}. Best is trial 1 with value: 0.89.
# [I 2025-01-02 07:39:35,910] Trial 3 finished with value: 0.9 and parameters: {'n_estimators': 159, 'learning_rate': 0.1251340389269347, 'max_depth': 7}. Best is trial 3 with value: 0.9.
# [I 2025-01-02 07:39:45,433] Trial 4 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 284, 'learning_rate': 0.4017028219819577, 'max_depth': 7}. Best is trial 3 with value: 0.9.
# [I 2025-01-02 07:39:58,498] Trial 5 finished with value: 0.88 and parameters: {'n_estimators': 482, 'learning_rate': 0.163262899127362, 'max_depth': 9}. Best is trial 3 with value: 0.9.
# [I 2025-01-02 07:40:14,103] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 226, 'learning_rate': 0.09982777102582746, 'max_depth': 10}. Best is trial 3 with value: 0.9.
# [I 2025-01-02 07:40
. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:20,110] Trial 5 finished with value: 0.88 and parameters: {'n_estimators': 406, 'max_depth': 14, 'learning_rate': 0.4067597086285099}. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:20,869] Trial 6 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 310, 'max_depth': 5, 'learning_rate': 0.2638834703940812}. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:23,621] Trial 7 finished with value: 0.89 and parameters: {'n_estimators': 227, 'max_depth': 18, 'learning_rate': 0.0325561699914003}. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:25,088] Trial 8 finished with value: 0.89 and parameters: {'n_estimators': 124, 'max_depth': 18, 'learning_rate': 0.06616015075006698}. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:25,883] Trial 9 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 315, 'max_depth': 7, 'learning_rate': 0.2863966605329679}. Best is trial 2 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:26,975] Trial 10 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 223, 'max_depth': 10, 'learning_rate': 0.14972733848637582}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:28,082] Trial 11 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 220, 'max_depth': 10, 'learning_rate': 0.14300395943280778}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:32,169] Trial 12 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 369, 'max_depth': 10, 'learning_rate': 0.12505659503721703}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:34,346] Trial 13 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 65, 'max_depth': 13, 'learning_rate': 0.010324064532022253}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:35,055] Trial 14 finished with value: 0.88 and parameters: {'n_estimators': 236, 'max_depth': 9, 'learning_rate': 0.32546811580067614}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:36,188] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 362, 'max_depth': 15, 'learning_rate': 0.19587100253691334}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:36,553] Trial 16 finished with value: 0.8566666666666667 and parameters: {'n_estimators': 167, 'max_depth': 3, 'learning_rate': 0.4779418249747418}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:38,024] Trial 17 finished with value: 0.89 and parameters: {'n_estimators': 304, 'max_depth': 8, 'learning_rate': 0.10270046166171937}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:39,211] Trial 18 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 484, 'max_depth': 16, 'learning_rate': 0.22658220028940745}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:40,519] Trial 19 finished with value: 0.89 and parameters: {'n_estimators': 360, 'max_depth': 11, 'learning_rate': 0.14556000205250455}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:42,618] Trial 20 finished with value: 0.89 and parameters: {'n_estimators': 265, 'max_depth': 20, 'learning_rate': 0.05793892020471105}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:49,665] Trial 21 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 199, 'max_depth': 17, 'learning_rate': 0.012628078622544725}. Best is trial 10 with value: 0.8933333333333333.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:51,968] Trial 22 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 264, 'max_depth': 20, 'learning_rate': 0.050315667945491624}. Best is trial 22 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:53,824] Trial 23 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 271, 'max_depth': 12, 'learning_rate': 0.0717024512151757}. Best is trial 22 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:55,739] Trial 24 finished with value: 0.9 and parameters: {'n_estimators': 262, 'max_depth': 12, 'learning_rate': 0.06647828911908599}. Best is trial 24 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:44:57,970] Trial 25 finished with value: 0.9 and parameters: {'n_estimators': 271, 'max_depth': 20, 'learning_rate': 0.06476323919304403}. Best is trial 24 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:44:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:45:03,552] Trial 26 finished with value: 0.9 and parameters: {'n_estimators': 331, 'max_depth': 20, 'learning_rate': 0.05047841148243453}. Best is trial 24 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:45:03] WARNING: /workspace/src/learner.cc:740:
# ...
# [I 2025-01-02 07:47:22,190] Trial 9 finished with value: 0.8166666666666667 and parameters: {'hidden_layer_1': 13, 'hidden_layer_2': 89, 'learning_rate_init': 0.04628128166545762}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:47:24,075] Trial 10 finished with value: 0.88 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 40, 'learning_rate_init': 0.005860208894558211}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:47:27,178] Trial 11 finished with value: 0.8566666666666667 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 41, 'learning_rate_init': 0.0030558452964954963}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:47:31,835] Trial 12 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 100, 'hidden_layer_2': 38, 'learning_rate_init': 0.005417537966480759}. Best is trial 1 with value: 0.8933333333333333.
# [I 2025-01-02 07:47:32,837] Trial 13 finished with value: 0.91 and parameters: {'hidden_layer_1': 81, 'hidden_layer_2': 100, 'learning_rate_init': 0.025747372569217844}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:34,049] Trial 14 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 98, 'learning_rate_init': 0.027224680910332113}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:34,854] Trial 15 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 85, 'hidden_layer_2': 77, 'learning_rate_init': 0.034512597375357106}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:35,851] Trial 16 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 100, 'learning_rate_init': 0.021198151845105605}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:36,850] Trial 17 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 74, 'learning_rate_init': 0.03754668696238659}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:37,941] Trial 18 finished with value: 0.8633333333333333 and parameters: {'hidden_layer_1': 74, 'hidden_layer_2': 68, 'learning_rate_init': 0.01792930733970862}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:38,947] Trial 19 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 93, 'learning_rate_init': 0.04066637293273686}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:40,107] Trial 20 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 91, 'hidden_layer_2': 81, 'learning_rate_init': 0.012263353939016897}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:41,177] Trial 21 finished with value: 0.89 and parameters: {'hidden_layer_1': 77, 'hidden_layer_2': 96, 'learning_rate_init': 0.024485978736913692}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:42,816] Trial 22 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 76, 'hidden_layer_2': 100, 'learning_rate_init': 0.027168781272495415}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:45,953] Trial 23 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 89, 'learning_rate_init': 0.012812528369418593}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:48,062] Trial 24 finished with value: 0.86 and parameters: {'hidden_layer_1': 42, 'hidden_layer_2': 52, 'learning_rate_init': 0.02905904782037378}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:49,323] Trial 25 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 80, 'hidden_layer_2': 93, 'learning_rate_init': 0.05559626658914825}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:50,382] Trial 26 finished with value: 0.89 and parameters: {'hidden_layer_1': 69, 'hidden_layer_2': 76, 'learning_rate_init': 0.04206936469638152}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:51,659] Trial 27 finished with value: 0.87 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 68, 'learning_rate_init': 0.011772050890615822}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:52,326] Trial 28 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 82, 'learning_rate_init': 0.03446141778633376}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:53,517] Trial 29 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 81, 'hidden_layer_2': 62, 'learning_rate_init': 0.020736343945145393}. Best is trial 13 with value: 0.91.
# [I 2025-01-02 07:47:53,531] A new study created in memory with name: no-name-7a91de49-d8fe-4fcf-b087-e12fdf057114
# Optimizing MLP...
# [I 2025-01-02 07:47:56,958] Trial 0 finished with value: 0.8833333333333333 and parameters: {'layer_1': 148, 'layer_2': 129, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.04951794528228063}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:47:57,842] Trial 1 finished with value: 0.5 and parameters: {'layer_1': 116, 'layer_2': 108, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08613417191121342}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:01,311] Trial 2 finished with value: 0.7866666666666666 and parameters: {'layer_1': 94, 'layer_2': 83, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.009694453685212968}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:01,998] Trial 3 finished with value: 0.5 and parameters: {'layer_1': 84, 'layer_2': 134, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0805462087555347}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:06,127] Trial 4 finished with value: 0.8666666666666667 and parameters: {'layer_1': 80, 'layer_2': 94, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05444002627801692}. Best is trial 0 with value: 0.8833333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:09,706] Trial 5 finished with value: 0.8266666666666667 and parameters: {'layer_1': 131, 'layer_2': 119, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.01788921257297226}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:10,803] Trial 6 finished with value: 0.88 and parameters: {'layer_1': 57, 'layer_2': 86, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.02527156362506155}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:13,522] Trial 7 finished with value: 0.8666666666666667 and parameters: {'layer_1': 141, 'layer_2': 57, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05345826807169135}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:17,201] Trial 8 finished with value: 0.7966666666666666 and parameters: {'layer_1': 69, 'layer_2': 55, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.020626613781494243}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-02 07:48:20,584] Trial 9 finished with value: 0.8966666666666666 and parameters: {'layer_1': 90, 'layer_2': 60, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06866134822532109}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:22,531] Trial 10 finished with value: 0.8666666666666667 and parameters: {'layer_1': 111, 'layer_2': 149, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.09726926810456528}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:24,834] Trial 11 finished with value: 0.88 and parameters: {'layer_1': 106, 'layer_2': 72, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06824763489638358}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:28,717] Trial 12 finished with value: 0.8766666666666667 and parameters: {'layer_1': 148, 'layer_2': 124, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0374857546055994}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:34,336] Trial 13 finished with value: 0.87 and parameters: {'layer_1': 123, 'layer_2': 107, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06563382481513108}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:38,532] Trial 14 finished with value: 0.8733333333333333 and parameters: {'layer_1': 94, 'layer_2': 146, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.041796092229389556}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:40,614] Trial 15 finished with value: 0.8866666666666667 and parameters: {'layer_1': 53, 'layer_2': 69, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0690576866721132}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:40,861] Trial 16 finished with value: 0.5 and parameters: {'layer_1': 54, 'layer_2': 69, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.07085155033740954}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:41,976] Trial 17 finished with value: 0.87 and parameters: {'layer_1': 66, 'layer_2': 69, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.08858223383369286}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:44,049] Trial 18 finished with value: 0.8533333333333334 and parameters: {'layer_1': 78, 'layer_2': 50, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0760445170397533}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:44,280] Trial 19 finished with value: 0.5 and parameters: {'layer_1': 68, 'layer_2': 79, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.060337165938411985}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:48:47,009] Trial 20 finished with value: 0.85 and parameters: {'layer_1': 52, 'layer_2': 66, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.03656434833171393}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:53,191] Trial 21 finished with value: 0.8733333333333333 and parameters: {'layer_1': 132, 'layer_2': 98, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.046193112241000714}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:55,187] Trial 22 finished with value: 0.87 and parameters: {'layer_1': 98, 'layer_2': 62, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06003165992651093}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:48:57,741] Trial 23 finished with value: 0.8566666666666667 and parameters: {'layer_1': 84, 'layer_2': 128, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.07708471467399}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:49:01,146] Trial 24 finished with value: 0.8933333333333333 and parameters: {'layer_1': 121, 'layer_2': 110, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.04907820806340925}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:49:07,430] Trial 25 finished with value: 0.8633333333333333 and parameters: {'layer_1': 118, 'layer_2': 110, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.06253304345041277}. Best is trial 9 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:49:10,963] Trial 26 finished with value: 0.8566666666666667 and parameters: {'layer_1': 103, 'layer_2': 90, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0306266768402728}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:49:12,732] Trial 27 finished with value: 0.8666666666666667 and parameters: {'layer_1': 128, 'layer_2': 77, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.09793739486249733}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:49:13,320] Trial 28 finished with value: 0.5 and parameters: {'layer_1': 138, 'layer_2': 104, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.07107497381436355}. Best is trial 9 with value: 0.8966666666666666.
# [I 2025-01-02 07:49:15,811] Trial 29 finished with value: 0.79 and parameters: {'layer_1': 61, 'layer_2': 114, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04511644814783024}. Best is trial 9 with value: 0.8966666666666666.
#                   Model  Accuracy  Sensitivity  Specificity       MCC  \
# 0                   SVM  0.910000     0.933333     0.886667  0.820894
# 1         Decision Tree  0.853333     0.893333     0.813333  0.708939
# 2         Random Forest  0.883333     0.913333     0.853333  0.768050
# 3   Logistic Regression  0.790000     0.806667     0.773333  0.580322
# 4                  k-NN  0.866667     0.920000     0.813333  0.737541
# 5           Naive Bayes  0.710000     0.726667     0.693333  0.420234
# 6     Gradient Boosting  0.900000     0.933333     0.866667  0.801784
# 7               XGBoost  0.903333     0.933333     0.873333  0.808123
# 8              LightGBM  0.890000     0.926667     0.853333  0.782106
# 9              AdaBoost  0.833333     0.900000     0.766667  0.672673
# 10       Neural Network  0.910000     0.933333     0.886667  0.820894
# 11                  MLP  0.896667     0.940000     0.853333  0.796330
#
#        Kappa       AUC                                        Best Params
# 0   0.820000  0.910000          {'C': 9.737063172951672, 'kernel': 'rbf'}
# 1   0.706667  0.853333           {'max_depth': 7, 'min_samples_split': 8}
# 2   0.766667  0.883333  {'n_estimators': 151, 'max_depth': 20, 'min_sa...
# 3   0.580000  0.790000   {'C': 0.9727353195162445, 'solver': 'liblinear'}
# 4   0.733333  0.866667                                 {'n_neighbors': 3}
# 5   0.420000  0.710000                                                 {}
# 6   0.800000  0.900000  {'n_estimators': 159, 'learning_rate': 0.12513...
# 7   0.806667  0.903333  {'n_estimators': 175, 'max_depth': 18, 'learni...
# 8   0.780000  0.890000  {'n_estimators': 295, 'max_depth': 20, 'learni...
# 9   0.666667  0.833333  {'n_estimators': 304, 'learning_rate': 0.31170...
# 10  0.820000  0.910000  {'hidden_layer_1': 81, 'hidden_layer_2': 100, ...
# 11  0.793333  0.896667  {'layer_1': 90, 'layer_2': 60, 'activation': '...

# %%
import pandas as pd
import optuna
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Define models
models = {
    "SVM": lambda trial: SVC(probability=True, C=trial.suggest_float("C", 0.1, 10.0), kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])),
    "Decision Tree": lambda trial: DecisionTreeClassifier(max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Random Forest": lambda trial: RandomForestClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), min_samples_split=trial.suggest_int("min_samples_split", 2, 10)),
    "Logistic Regression": lambda trial: LogisticRegression(C=trial.suggest_float("C", 0.1, 10.0), solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])),
    "k-NN": lambda trial: KNeighborsClassifier(n_neighbors=trial.suggest_int("n_neighbors", 3, 20)),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), max_depth=trial.suggest_int("max_depth", 3, 20)),
    "XGBoost": lambda trial: XGBClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5), use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": lambda trial: LGBMClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), max_depth=trial.suggest_int("max_depth", 3, 20), learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)),
    "AdaBoost": lambda trial: AdaBoostClassifier(n_estimators=trial.suggest_int("n_estimators", 50, 500), learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)),
    "Neural Network": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("hidden_layer_1", 10, 100), trial.suggest_int("hidden_layer_2", 10, 100)), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200),
    "MLP": lambda trial: MLPClassifier(hidden_layer_sizes=(trial.suggest_int("layer_1", 50, 150), trial.suggest_int("layer_2", 50, 150)), activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]), solver=trial.suggest_categorical("solver", ["adam", "sgd"]), learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1), max_iter=200, random_state=42)
}

# Prepare a dictionary to store model probabilities horizontally
probabilities = {"Target": y_val}  # Starting with the target column (y_val)

# Run optimization and compute probabilities for each model
for model_name, model_func in models.items():
    print(f"Optimizing {model_name}...")
    study = optuna.create_study(direction="maximize")

    # Objective function for Optuna
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        return accuracy_score(y_val, model.predict(X_val))

    study.optimize(objective, n_trials=30)

    # Train the best model using the best hyperparameters
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)

    # Get predicted probabilities for the positive class (class 1)
    probs = best_model.predict_proba(X_val)[:, 1]

    # Add to the probabilities dictionary
    probabilities[model_name] = probs

# Convert the probabilities dictionary to a DataFrame
probability_df = pd.DataFrame(probabilities)

# Save the probability dataset to a CSV file
probability_df.to_csv("N_PAAC_OPTUNA_probability_predictions.csv", index=False)

print("Dataset saved successfully!")
# Out:
# [I 2025-01-02 07:49:29,956] A new study created in memory with name: no-name-0f4a7977-78c9-4bec-8d98-6d273f1d910a
# [I 2025-01-02 07:49:30,138] Trial 0 finished with value: 0.7866666666666666 and parameters: {'C': 5.134602479704268, 'kernel': 'linear'}. Best is trial 0 with value: 0.7866666666666666.
# Optimizing SVM...
# [I 2025-01-02 07:49:30,343] Trial 1 finished with value: 0.7933333333333333 and parameters: {'C': 8.134146402513686, 'kernel': 'linear'}. Best is trial 1 with value: 0.7933333333333333.
# [I 2025-01-02 07:49:30,620] Trial 2 finished with value: 0.67 and parameters: {'C': 6.27932211275458, 'kernel': 'sigmoid'}. Best is trial 1 with value: 0
finished with value: 0.8833333333333333 and parameters: {'n_estimators': 254, 'learning_rate': 0.3798124374382809, 'max_depth': 7}. Best is trial 10 with value: 0.89.
# [I 2025-01-02 07:53:42,991] Trial 27 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 196, 'learning_rate': 0.49647774680081214, 'max_depth': 5}. Best is trial 10 with value: 0.89.
# [I 2025-01-02 07:53:49,217] Trial 28 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 97, 'learning_rate': 0.226457249209023, 'max_depth': 8}. Best is trial 10 with value: 0.89.
# [I 2025-01-02 07:53:58,550] Trial 29 finished with value: 0.85 and parameters: {'n_estimators': 153, 'learning_rate': 0.01761861948801266, 'max_depth': 19}. Best is trial 10 with value: 0.89.
# [I 2025-01-02 07:54:06,836] A new study created in memory with name: no-name-efc5b324-722e-43d3-a6ff-1a793aadc9fd
# Optimizing XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:07,729] Trial 0 finished with value: 0.87 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.19376777122536}. Best is trial 0 with value: 0.87.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:09,590] Trial 1 finished with value: 0.89 and parameters: {'n_estimators': 286, 'max_depth': 9, 'learning_rate': 0.068721609692426}. Best is trial 1 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:10,236] Trial 2 finished with value: 0.88 and parameters: {'n_estimators': 328, 'max_depth': 20, 'learning_rate': 0.4899260021305173}. Best is trial 1 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:11,154] Trial 3 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 459, 'max_depth': 17, 'learning_rate': 0.32265388521250166}. Best is trial 1 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:11,927] Trial 4 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 468, 'max_depth': 7, 'learning_rate': 0.39207692306577313}. Best is trial 1 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:12,307] Trial 5 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 174, 'max_depth': 3, 'learning_rate': 0.18583507980748287}. Best is trial 1 with value: 0.89.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:17,054] Trial 6 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 349, 'max_depth': 12, 'learning_rate': 0.06033352194495698}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:18,395] Trial 7 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 162, 'max_depth': 9, 'learning_rate': 0.3419845444722433}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:19,361] Trial 8 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 262, 'max_depth': 18, 'learning_rate': 0.2121570445495935}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:20,066] Trial 9 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 357, 'max_depth': 17, 'learning_rate': 0.43269080049029146}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:21,404] Trial 10 finished with value: 0.89 and parameters: {'n_estimators': 61, 'max_depth': 13, 'learning_rate': 0.028321608196832514}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:24,551] Trial 11 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 224, 'max_depth': 12, 'learning_rate': 0.023581279605441416}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:26,131] Trial 12 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 402, 'max_depth': 9, 'learning_rate': 0.10852481263159912}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:27,553] Trial 13 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 273, 'max_depth': 14, 'learning_rate': 0.11004662672703691}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:31,760] Trial 14 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 322, 'max_depth': 9, 'learning_rate': 0.09980303663178883}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:34,036] Trial 15 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.13161996268983164}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:35,025] Trial 16 finished with value: 0.89 and parameters: {'n_estimators': 402, 'max_depth': 15, 'learning_rate': 0.2592483118732598}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:36,251] Trial 17 finished with value: 0.89 and parameters: {'n_estimators': 322, 'max_depth': 11, 'learning_rate': 0.15119726363778055}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:37,041] Trial 18 finished with value: 0.88 and parameters: {'n_estimators': 219, 'max_depth': 11, 'learning_rate': 0.2660247972916102}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:37,850] Trial 19 finished with value: 0.89 and parameters: {'n_estimators': 103, 'max_depth': 6, 'learning_rate': 0.06285255947134612}. Best is trial 6 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:40,224] Trial 20 finished with value: 0.9 and parameters: {'n_estimators': 490, 'max_depth': 15, 'learning_rate': 0.07496665126006088}. Best is trial 20 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:42,831] Trial 21 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 440, 'max_depth': 15, 'learning_rate': 0.05777751710480691}. Best is trial 20 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:48,296] Trial 22 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 483, 'max_depth': 10, 'learning_rate': 0.08350864437935693}. Best is trial 20 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:49,716] Trial 23 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 496, 'max_depth': 13, 'learning_rate': 0.1536484645639719}. Best is trial 20 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:54,841] Trial 24 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 431, 'max_depth': 15, 'learning_rate': 0.017526746363048448}. Best is trial 20 with value: 0.9.
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [07:54:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-02 07:54:56,317] Trial 25 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 367, 'max_depth': 7, 'learning_rate': 0.10128019598570573}. Best is trial 20 with value: 0.9.
# ...
#   warnings.warn(
# [I 2025-01-02 07:56:53,785] Trial 11 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 91, 'hidden_layer_2': 11, 'learning_rate_init': 0.0024440133998972317}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:56:54,636] Trial 12 finished with value: 0.8566666666666667 and parameters: {'hidden_layer_1': 78, 'hidden_layer_2': 11, 'learning_rate_init': 0.03183158232878186}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:56:55,638] Trial 13 finished with value: 0.8533333333333334 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 58, 'learning_rate_init': 0.04730254511332005}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:56:56,857] Trial 14 finished with value: 0.8833333333333333 and parameters: {'hidden_layer_1': 89, 'hidden_layer_2': 100, 'learning_rate_init': 0.019237762612132198}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:56:58,587] Trial 15 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 99, 'hidden_layer_2': 99, 'learning_rate_init': 0.042899140357318115}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:57:01,243] Trial 16 finished with value: 0.8733333333333333 and parameters: {'hidden_layer_1': 86, 'hidden_layer_2': 82, 'learning_rate_init': 0.023489226221395505}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:57:03,040] Trial 17 finished with value: 0.8066666666666666 and parameters: {'hidden_layer_1': 40, 'hidden_layer_2': 100, 'learning_rate_init': 0.05833352831508461}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:57:04,726] Trial 18 finished with value: 0.86 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 69, 'learning_rate_init': 0.041249586249440716}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:57:05,637] Trial 19 finished with value: 0.8566666666666667 and parameters: {'hidden_layer_1': 72, 'hidden_layer_2': 83, 'learning_rate_init': 0.016475777737606407}. Best is trial 8 with value: 0.8833333333333333.
# [I 2025-01-02 07:57:06,290] Trial 20 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2': 89, 'learning_rate_init': 0.035682108483423784}. Best is trial 20 with value: 0.8866666666666667.
# [I 2025-01-02 07:57:07,142] Trial 21 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 61, 'hidden_layer_2': 91, 'learning_rate_init': 0.03162204634575844}. Best is trial 20 with value: 0.8866666666666667.
# [I 2025-01-02 07:57:08,049] Trial 22 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 89, 'learning_rate_init': 0.03491836115564516}. Best is trial 20 with value: 0.8866666666666667.
# [I 2025-01-02 07:57:09,059] Trial 23 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 62, 'hidden_layer_2': 74, 'learning_rate_init': 0.03082007772217451}. Best is trial 20 with value: 0.8866666666666667.
# [I 2025-01-02 07:57:09,712] Trial 24 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 44, 'hidden_layer_2': 88, 'learning_rate_init': 0.032469878165532824}. Best is trial 20 with value: 0.8866666666666667.
# [I 2025-01-02 07:57:10,307] Trial 25 finished with value: 0.8933333333333333 and parameters: {'hidden_layer_1': 57, 'hidden_layer_2': 62, 'learning_rate_init': 0.05009696933837844}. Best is trial 25 with value: 0.8933333333333333.
# [I 2025-01-02 07:57:11,293] Trial 26 finished with value: 0.85 and parameters: {'hidden_layer_1': 30, 'hidden_layer_2': 53, 'learning_rate_init': 0.052457014481302244}. Best is trial 25 with value: 0.8933333333333333.
# [I 2025-01-02 07:57:12,274] Trial 27 finished with value: 0.8366666666666667 and parameters: {'hidden_layer_1': 46, 'hidden_layer_2': 59, 'learning_rate_init': 0.06552838934530479}. Best is trial 25 with value: 0.8933333333333333.
# [I 2025-01-02 07:57:12,886] Trial 28 finished with value: 0.8833333333333333 and parameters: {'hidden_layer_1': 65, 'hidden_layer_2':
 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09970517103143495}. Best is trial 13 with value: 0.8833333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:16,420] Trial 16 finished with value: 0.8733333333333333 and parameters: {'layer_1': 135, 'layer_2': 95, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.03968637426834759}. Best is trial 13 with value: 0.8833333333333333.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:24,533] Trial 17 finished with value: 0.8966666666666666 and parameters: {'layer_1': 132, 'layer_2': 125, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05313610341913313}. Best is trial 17 with value: 0.8966666666666666.
# [I 2025-01-02 07:58:25,350] Trial 18 finished with value: 0.5 and parameters: {'layer_1': 134, 'layer_2': 127, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.08458325842569914}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:31,117] Trial 19 finished with value: 0.84 and parameters: {'layer_1': 148, 'layer_2': 150, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.024107994197214717}. Best is trial 17 with value: 0.8966666666666666.
# [I 2025-01-02 07:58:34,761] Trial 20 finished with value: 0.8533333333333334 and parameters: {'layer_1': 126, 'layer_2': 111, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.04572374905413493}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:42,375] Trial 21 finished with value: 0.88 and parameters: {'layer_1': 112, 'layer_2': 92, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05691785458660033}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:47,494] Trial 22 finished with value: 0.8733333333333333 and parameters: {'layer_1': 136, 'layer_2': 127, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06429687954106726}. Best is trial 17 with value: 0.8966666666666666.
# [I 2025-01-02 07:58:49,886] Trial 23 finished with value: 0.79 and parameters: {'layer_1': 118, 'layer_2': 91, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0022890333330656265}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:58:57,272] Trial 24 finished with value: 0.89 and parameters: {'layer_1': 100, 'layer_2': 109, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06183333824994299}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:59:01,456] Trial 25 finished with value: 0.87 and parameters: {'layer_1': 97, 'layer_2': 111, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0447150072067657}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:59:05,297] Trial 26 finished with value: 0.8633333333333333 and parameters: {'layer_1': 82, 'layer_2': 128, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06324196773280825}. Best is trial 17 with value: 0.8966666666666666.
# [I 2025-01-02 07:59:09,012] Trial 27 finished with value: 0.88 and parameters: {'layer_1': 104, 'layer_2': 111, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.08463939063868609}. Best is trial 17 with value: 0.8966666666666666.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-02 07:59:16,811] Trial 28 finished with value: 0.8333333333333334 and parameters: {'layer_1': 140, 'layer_2': 124, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.028554149710745082}. Best is trial 17 with value: 0.8966666666666666.
# [I 2025-01-02 07:59:20,868] Trial 29 finished with value: 0.8466666666666667 and parameters: {'layer_1': 127, 'layer_2': 135, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.047245078496605954}. Best is trial 17 with value: 0.8966666666666666.
# Dataset saved successfully!
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# Class Feature Vector (CFV)

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)])
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)])

# Split features and labels
X_train = main_data.drop("label", axis=1)
y_train = main_data["label"]
X_val = validation_data.drop("label", axis=1)
y_val = validation_data["label"]

# Define models with hyperparameter optimization (Optuna)
models = {
    "SVM": lambda trial: SVC(
         probability=True,
        C=trial.suggest_float("C", 0.1, 10.0),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    ),
    "Decision Tree": lambda trial: DecisionTreeClassifier(
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Random Forest": lambda trial: RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        min_samples_split=trial.suggest_int("min_samples_split", 2, 10)
    ),
    "Logistic Regression": lambda trial: LogisticRegression(
        C=trial.suggest_float("C", 0.1, 10.0),
        solver=trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    ),
    "k-NN": lambda trial: KNeighborsClassifier(
        n_neighbors=trial.suggest_int("n_neighbors", 3, 20)
    ),
    "Naive Bayes": lambda trial: GaussianNB(),
    "Gradient Boosting": lambda trial: GradientBoostingClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        max_depth=trial.suggest_int("max_depth", 3, 20)
    ),
    "XGBoost": lambda trial: XGBClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5),
        use_label_encoder=False,
        eval_metric="logloss"
    ),
    "LightGBM": lambda trial: LGBMClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        max_depth=trial.suggest_int("max_depth", 3, 20),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 0.5)
    ),
    "AdaBoost": lambda trial: AdaBoostClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 500),
        learning_rate=trial.suggest_float("learning_rate", 0.01, 1.0)
    ),
    "Neural Network": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("hidden_layer_1", 10, 100),
            trial.suggest_int("hidden_layer_2", 10, 100)
        ),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200
    ),
    "MLP": lambda trial: MLPClassifier(
        hidden_layer_sizes=(
            trial.suggest_int("layer_1", 50, 150),
            trial.suggest_int("layer_2", 50, 150)
        ),
        activation=trial.suggest_categorical("activation", ["logistic", "tanh", "relu"]),
        solver=trial.suggest_categorical("solver", ["adam", "sgd"]),
        learning_rate_init=trial.suggest_float("learning_rate_init", 0.001, 0.1),
        max_iter=200,
        random_state=42
    )
}

# Initialize a list to store the CFV data
cfv_data = []

# Define the optimization and prediction function
def optimize_and_predict(model_name, model_func):
    def objective(trial):
        model = model_func(trial)
        model.fit(X_train, y_train)
        preds = model.predict_proba(X_val)[:, 1]  # Get probability for class 1 (positive)
        return accuracy_score(y_val, model.predict(X_val))

    # Perform optimization with Optuna
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=30)

    # Return the best model
    best_model = model_func(study.best_trial)
    best_model.fit(X_train, y_train)
    preds = best_model.predict_proba(X_val)[:, 1]  # Using the probability for class 1 (positive)

    # Append predictions to CFV list
    return preds

# Train each model and generate predictions for CFV
for model_name, model_func in models.items():
    print(f"Training and predicting with {model_name}...")
    preds = optimize_and_predict(model_name, model_func)
    cfv_data.append(preds)

# Convert the CFV data into a DataFrame
cfv_df = pd.DataFrame(np.array(cfv_data).T, columns=models.keys())

# Optionally, add the true labels column
cfv_df["True_Label"] = y_val.values

# Save the CFV dataset to CSV
cfv_df.to_csv("CFV_PAAC.csv", index=False)
print("CFV dataset created and saved!")
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [I 2025-01-16 03:40:18,952] A new study created in memory with name: no-name-f876b2ea-6384-46df-8582-22ffca8091d4
# Training and predicting with SVM...
# [I 2025-01-16 03:40:19,646] Trial 0 finished with value: 0.9066666666666666 and parameters: {'C': 9.839031875532108, 'kernel': 'rbf'}. Best is trial 0 with value: 0.9066666666666666.
# [I 2025-01-16 03:40
 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.9066666666666666.
# [I 2025-01-16 03:40:30,959] A new study created in memory with name: no-name-ad5c2339-17f0-42cd-b9eb-ce35bfed995c
# [I 2025-01-16 03:40:31,001] Trial 0 finished with value: 0.79 and parameters: {'max_depth': 5, 'min_samples_split': 6}. Best is trial 0 with value: 0.79.
# [I 2025-01-16 03:40:31,068] Trial 1 finished with value: 0.8333333333333334 and parameters: {'max_depth': 20, 'min_samples_split': 6}. Best is trial 1 with value: 0.8333333333333334.
# [I 2025-01-16 03:40:31,129] Trial 2 finished with value: 0.83 and parameters: {'max_depth': 13, 'min_samples_split': 4}. Best is trial 1 with value: 0.8333333333333334.
# Training and predicting with Decision Tree...
# [I 2025-01-16 03:40:31,181] Trial 3 finished with value: 0.85 and parameters: {'max_depth': 7, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,248] Trial 4 finished with value: 0.8166666666666667 and parameters: {'max_depth': 20, 'min_samples_split': 3}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,313] Trial 5 finished with value: 0.8233333333333334 and parameters: {'max_depth': 17, 'min_samples_split': 10}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,376] Trial 6 finished with value: 0.83 and parameters: {'max_depth': 16, 'min_samples_split': 9}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,410] Trial 7 finished with value: 0.7433333333333333 and parameters: {'max_depth': 4, 'min_samples_split': 9}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,467] Trial 8 finished with value: 0.8233333333333334 and parameters: {'max_depth': 9, 'min_samples_split': 2}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,517] Trial 9 finished with value: 0.85 and parameters: {'max_depth': 7, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,596] Trial 10 finished with value: 0.83 and parameters: {'max_depth': 11, 'min_samples_split': 8}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,675] Trial 11 finished with value: 0.8333333333333334 and parameters: {'max_depth': 8, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,740] Trial 12 finished with value: 0.8466666666666667 and parameters: {'max_depth': 7, 'min_samples_split': 4}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,782] Trial 13 finished with value: 0.7266666666666667 and parameters: {'max_depth': 3, 'min_samples_split': 7}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,842] Trial 14 finished with value: 0.84 and parameters: {'max_depth': 6, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,915] Trial 15 finished with value: 0.83 and parameters: {'max_depth': 11, 'min_samples_split': 7}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:31,991] Trial 16 finished with value: 0.8166666666666667 and parameters: {'max_depth': 9, 'min_samples_split': 4}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,066] Trial 17 finished with value: 0.8233333333333334 and parameters: {'max_depth': 13, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,125] Trial 18 finished with value: 0.84 and parameters: {'max_depth': 6, 'min_samples_split': 2}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,198] Trial 19 finished with value: 0.8133333333333334 and parameters: {'max_depth': 9, 'min_samples_split': 6}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,239] Trial 20 finished with value: 0.7266666666666667 and parameters: {'max_depth': 3, 'min_samples_split': 3}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,304] Trial 21 finished with value: 0.8466666666666667 and parameters: {'max_depth': 7, 'min_samples_split': 4}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,367] Trial 22 finished with value: 0.8433333333333334 and parameters: {'max_depth': 7, 'min_samples_split': 3}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,421] Trial 23 finished with value: 0.79 and parameters: {'max_depth': 5, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,492] Trial 24 finished with value: 0.82 and parameters: {'max_depth': 10, 'min_samples_split': 4}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,568] Trial 25 finished with value: 0.8366666666666667 and parameters: {'max_depth': 13, 'min_samples_split': 7}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,636] Trial 26 finished with value: 0.8466666666666667 and parameters: {'max_depth': 7, 'min_samples_split': 5}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,712] Trial 27 finished with value: 0.82 and parameters: {'max_depth': 8, 'min_samples_split': 6}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,763] Trial 28 finished with value: 0.7933333333333333 and parameters: {'max_depth': 5, 'min_samples_split': 3}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,808] Trial 29 finished with value: 0.7466666666666667 and parameters: {'max_depth': 4, 'min_samples_split': 4}. Best is trial 3 with value: 0.85.
# [I 2025-01-16 03:40:32,855] A new study created in memory with name: no-name-15278f41-23d2-4441-a7da-04ca45c6a68c
# Training and predicting with Random Forest...
# [I 2025-01-16 03:40:33,906] Trial 0 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 295, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 0 with value: 0.8433333333333334.
# [I 2025-01-16 03:40:36,286] Trial 1 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 455, 'max_depth': 6, 'min_samples_split': 8}. Best is trial 1 with value: 0.8766666666666667.
# [I 2025-01-16 03:40:38,679] Trial 2 finished with value: 0.86 and parameters: {'n_estimators': 299, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 1 with value: 0.8766666666666667.
# [I 2025-01-16 03:40:42,446] Trial 3 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 419, 'max_depth': 13, 'min_samples_split': 7}. Best is trial 1 with value: 0.8766666666666667.
# [I 2025-01-16 03:40:42,796] Trial 4 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 51, 'max_depth': 12, 'min_samples_split': 8}. Best is trial 1 with value: 0.8766666666666667.
# [I 2025-01-16 03:40:45,872] Trial 5 finished with value: 0.88 and parameters: {'n_estimators': 478, 'max_depth': 9, 'min_samples_split': 3}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:47,015] Trial 6 finished with value: 0.87 and parameters: {'n_estimators': 155, 'max_depth': 15, 'min_samples_split': 2}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:48,405] Trial 7 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 385, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:49,935] Trial 8 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 251, 'max_depth': 8, 'min_samples_split': 4}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:50,328] Trial 9 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 72, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:54,614] Trial 10 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 489, 'max_depth': 19, 'min_samples_split': 2}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:57,942] Trial 11 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 461, 'max_depth': 8, 'min_samples_split': 10}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:40:59,874] Trial 12 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 360, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:03,104] Trial 13 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 482, 'max_depth': 10, 'min_samples_split': 6}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:05,286] Trial 14 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 414, 'max_depth': 6, 'min_samples_split': 8}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:08,373] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 344, 'max_depth': 14, 'min_samples_split': 6}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:10,485] Trial 16 finished with value: 0.87 and parameters: {'n_estimators': 208, 'max_depth': 17, 'min_samples_split': 5}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:13,059] Trial 17 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 341, 'max_depth': 14, 'min_samples_split': 3}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:14,648] Trial 18 finished with value: 0.8666666666666667 and parameters: {'n_estimators': 220, 'max_depth': 17, 'min_samples_split': 6}. Best is trial 5 with value: 0.88.
# [I 2025-01-16 03:41:16,848] Trial 19 finished with value: 0.8633333333333333 and parameters: {'n_estimators':
finished with value: 0.8466666666666667 and parameters: {'n_estimators': 375, 'learning_rate': 0.21362037994768202, 'max_depth': 16}. Best is trial 1 with value: 0.8466666666666667.
# [I 2025-01-16 03:42:03,617] Trial 2 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 267, 'learning_rate': 0.3065783176519324, 'max_depth': 11}. Best is trial 2 with value: 0.8766666666666667.
# [I 2025-01-16 03:42:08,718] Trial 3 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 96, 'learning_rate': 0.2543994588574834, 'max_depth': 7}. Best is trial 3 with value: 0.8866666666666667.
# [I 2025-01-16 03:42:16,300] Trial 4 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 276, 'learning_rate': 0.28108475492468304, 'max_depth': 9}. Best is trial 3 with value: 0.8866666666666667.
# [I 2025-01-16 03:42:31,029] Trial 5 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 436, 'learning_rate': 0.0770323597159196, 'max_depth': 16}. Best is trial 3 with value: 0.8866666666666667.
# [I 2025-01-16 03:42:38,539] Trial 6 finished with value: 0.89 and parameters: {'n_estimators': 302, 'learning_rate': 0.32779231166445655, 'max_depth': 10}. Best is trial 6 with value: 0.89.
# [I 2025-01-16 03:42:46,204] Trial 7 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 195, 'learning_rate': 0.02924816428973543, 'max_depth': 6}. Best is trial 6 with value: 0.89.
# [I 2025-01-16 03:42:56,656] Trial 8 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 356, 'learning_rate': 0.13632611969527378, 'max_depth': 4}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:42:59,332] Trial 9 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 337, 'learning_rate': 0.45833373900081037, 'max_depth': 13}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:43:13,800] Trial 10 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 500, 'learning_rate': 0.13620511281679604, 'max_depth': 4}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:43:24,552] Trial 11 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 495, 'learning_rate': 0.1409862692518187, 'max_depth': 3}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:43:34,612] Trial 12 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 484, 'learning_rate': 0.14876813307214654, 'max_depth': 3}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:43:50,846] Trial 13 finished with value: 0.88 and parameters: {'n_estimators': 392, 'learning_rate': 0.14329132707603462, 'max_depth': 6}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:43:59,772] Trial 14 finished with value: 0.88 and parameters: {'n_estimators': 425, 'learning_rate': 0.0827697167513792, 'max_depth': 3}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:44:10,726] Trial 15 finished with value: 0.88 and parameters: {'n_estimators': 225, 'learning_rate': 0.19294924616311243, 'max_depth': 7}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:44:32,476] Trial 16 finished with value: 0.83 and parameters: {'n_estimators': 344, 'learning_rate': 0.019441008954928313, 'max_depth': 20}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:44:46,553] Trial 17 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 453, 'learning_rate': 0.3797780167044814, 'max_depth': 5}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:44:51,988] Trial 18 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 76, 'learning_rate': 0.09622359640369574, 'max_depth': 9}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:44:57,681] Trial 19 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 388, 'learning_rate': 0.19854152384782292, 'max_depth': 13}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:07,067] Trial 20 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 323, 'learning_rate': 0.2324910302482744, 'max_depth': 4}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:14,311] Trial 21 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 269, 'learning_rate': 0.33460201875627976, 'max_depth': 9}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:23,468] Trial 22 finished with value: 0.89 and parameters: {'n_estimators': 258, 'learning_rate': 0.37276458561446746, 'max_depth': 8}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:27,440] Trial 23 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 123, 'learning_rate': 0.36914336449618446, 'max_depth': 5}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:34,846] Trial 24 finished with value: 0.8366666666666667 and parameters: {'n_estimators': 211, 'learning_rate': 0.1702088172145057, 'max_depth': 13}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:45:46,852] Trial 25 finished with value: 0.89 and parameters: {'n_estimators': 361, 'learning_rate': 0.4198219462721449, 'max_depth': 5}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:46:03,980] Trial 26 finished with value: 0.89 and parameters: {'n_estimators': 304, 'learning_rate': 0.11229812259176762, 'max_depth': 8}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:46:30,408] Trial 27 finished with value: 0.8433333333333334 and parameters: {'n_estimators': 406, 'learning_rate': 0.05023606482970305, 'max_depth': 11}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:46:37,528] Trial 28 finished with value: 0.87 and parameters: {'n_estimators': 237, 'learning_rate': 0.32022237103549556, 'max_depth': 4}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:46:44,532] Trial 29 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 158, 'learning_rate': 0.49048009981954244, 'max_depth': 7}. Best is trial 8 with value: 0.8966666666666666.
# [I 2025-01-16 03:46:54,694] A new study created in memory with name: no-name-8820fd31-c0f2-46b3-99a8-ad8ba0ccbf61
# Training and predicting with XGBoost...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:55,541] Trial 0 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 107, 'max_depth': 14, 'learning_rate': 0.20076425351385715}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:56,300] Trial 1 finished with value: 0.8733333333333333 and parameters: {'n_estimators': 451, 'max_depth': 5, 'learning_rate': 0.377595986820574}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:57,092] Trial 2 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 289, 'max_depth': 5, 'learning_rate': 0.22811998302136718}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:58,421] Trial 3 finished with value: 0.88 and parameters: {'n_estimators': 431, 'max_depth': 8, 'learning_rate': 0.26053971686869043}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:59,292] Trial 4 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 425, 'max_depth': 12, 'learning_rate': 0.4504796648664021}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:46:59,727] Trial 5 finished with value: 0.8533333333333334 and parameters: {'n_estimators': 137, 'max_depth': 3, 'learning_rate': 0.3124477187833872}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:46:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:00,586] Trial 6 finished with value: 0.8633333333333333 and parameters: {'n_estimators': 430, 'max_depth': 3, 'learning_rate': 0.37646158719652845}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:01,752] Trial 7 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 262, 'max_depth': 4, 'learning_rate': 0.4561302791644328}. Best is trial 0 with value: 0.8866666666666667.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:12,288] Trial 8 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 404, 'max_depth': 12, 'learning_rate': 0.02197640509293291}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:14,053] Trial 9 finished with value: 0.8766666666666667 and parameters: {'n_estimators': 296, 'max_depth': 18, 'learning_rate': 0.08979528572676355}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:21,594] Trial 10 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 349, 'max_depth': 19, 'learning_rate': 0.013102743990252881}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:23,324] Trial 11 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 53, 'max_depth': 14, 'learning_rate': 0.13037972926110508}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:24,510] Trial 12 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 178, 'max_depth': 15, 'learning_rate': 0.11844992878157942}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:25,478] Trial 13 finished with value: 0.88 and parameters: {'n_estimators': 50, 'max_depth': 10, 'learning_rate': 0.015420251240403549}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:26,734] Trial 14 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 213, 'max_depth': 15, 'learning_rate': 0.11864103243086932}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:28,802] Trial 15 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 350, 'max_depth': 9, 'learning_rate': 0.07262216621070638}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:30,077] Trial 16 finished with value: 0.89 and parameters: {'n_estimators': 367, 'max_depth': 12, 'learning_rate': 0.17101523420988768}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:31,607] Trial 17 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 499, 'max_depth': 17, 'learning_rate': 0.14489531431972924}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:35,629] Trial 18 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 230, 'max_depth': 13, 'learning_rate': 0.06036532396571018}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:38,061] Trial 19 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 56, 'max_depth': 7, 'learning_rate': 0.052682499521134005}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:39,111] Trial 20 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 383, 'max_depth': 16, 'learning_rate': 0.2716454348477989}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:41,314] Trial 21 finished with value: 0.8966666666666666 and parameters: {'n_estimators': 329, 'max_depth': 10, 'learning_rate': 0.06666528294824248}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:42,584] Trial 22 finished with value: 0.8833333333333333 and parameters: {'n_estimators': 321, 'max_depth': 10, 'learning_rate': 0.15684507958475594}. Best is trial 8 with value: 0.8966666666666666.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:47:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-01-16 03:47:44,262] Trial 23 finished with value: 0.8866666666666667 and parameters: {'n_estimators': 385, 'max_depth': 8, 'learning_rate': 0.09957731762372457}. Best is trial 8 with value: 0.8966666666666666.
# ...
#   warnings.warn(
# [I 2025-01-16 03:50:14,209] Trial 1 finished with value: 0.88 and parameters: {'hidden_layer_1': 97, 'hidden_layer_2': 60, 'learning_rate_init': 0.002460126574964733}. Best is trial 0 with value: 0.88.
# [I 2025-01-16 03:50:15,147] Trial 2 finished with value: 0.8633333333333333 and parameters: {'hidden_layer_1': 92, 'hidden_layer_2': 61, 'learning_rate_init': 0.09627868758327336}. Best is trial 0 with value: 0.88.
# [I 2025-01-16 03:50:15,749] Trial 3 finished with value: 0.89 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 18, 'learning_rate_init': 0.05819915764973432}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:16,187] Trial 4 finished with value: 0.8466666666666667 and parameters: {'hidden_layer_1': 26, 'hidden_layer_2': 18, 'learning_rate_init': 0.05316492876115966}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:17,262] Trial 5 finished with value: 0.86 and parameters: {'hidden_layer_1': 39, 'hidden_layer_2': 83, 'learning_rate_init': 0.079539283939001}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:18,857] Trial 6 finished with value: 0.87 and parameters: {'hidden_layer_1': 43, 'hidden_layer_2': 21, 'learning_rate_init': 0.09248730033701709}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:20,598] Trial 7 finished with value: 0.7666666666666667 and parameters: {'hidden_layer_1': 17, 'hidden_layer_2': 68, 'learning_rate_init': 0.043525121244930326}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:21,722] Trial 8 finished with value: 0.87 and parameters: {'hidden_layer_1': 84, 'hidden_layer_2': 15, 'learning_rate_init': 0.0932064205435269}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:22,413] Trial 9 finished with value: 0.84 and parameters: {'hidden_layer_1': 21, 'hidden_layer_2': 37, 'learning_rate_init': 0.06578528319805953}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:23,501] Trial 10 finished with value: 0.87 and parameters: {'hidden_layer_1': 64, 'hidden_layer_2': 35, 'learning_rate_init': 0.020167492615166333}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:24,223] Trial 11 finished with value: 0.8433333333333334 and parameters: {'hidden_layer_1': 60, 'hidden_layer_2': 95, 'learning_rate_init': 0.031546611746719626}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:25,045] Trial 12 finished with value: 0.8566666666666667 and parameters: {'hidden_layer_1': 73, 'hidden_layer_2': 44, 'learning_rate_init': 0.057201412947173666}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:25,898] Trial 13 finished with value: 0.87 and parameters: {'hidden_layer_1': 45, 'hidden_layer_2': 78, 'learning_rate_init': 0.03573957574306798}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:26,835] Trial 14 finished with value: 0.86 and parameters: {'hidden_layer_1': 76, 'hidden_layer_2': 92, 'learning_rate_init': 0.02071248936536811}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:27,871] Trial 15 finished with value: 0.87 and parameters: {'hidden_layer_1': 54, 'hidden_layer_2': 44, 'learning_rate_init': 0.06715324764938374}. Best is trial 3 with value: 0.89.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:50:29,763] Trial 16 finished with value: 0.8666666666666667 and parameters: {'hidden_layer_1': 29, 'hidden_layer_2': 73, 'learning_rate_init': 0.008093086953213306}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:30,286] Trial 17 finished with value: 0.84 and parameters: {'hidden_layer_1': 10, 'hidden_layer_2': 31, 'learning_rate_init': 0.04172611337261877}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:31,369] Trial 18 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 50, 'hidden_layer_2': 99, 'learning_rate_init': 0.023873344113595117}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:32,576] Trial 19 finished with value: 0.87 and parameters: {'hidden_layer_1': 52, 'hidden_layer_2': 51, 'learning_rate_init': 0.01811649603776503}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:33,643] Trial 20 finished with value: 0.8866666666666667 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 27, 'learning_rate_init': 0.07589626086829923}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:34,720] Trial 21 finished with value: 0.8333333333333334 and parameters: {'hidden_layer_1': 34, 'hidden_layer_2': 26, 'learning_rate_init': 0.07929158369774568}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:36,108] Trial 22 finished with value: 0.8566666666666667 and parameters: {'hidden_layer_1': 49, 'hidden_layer_2': 10, 'learning_rate_init': 0.0748757260786782}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:37,433] Trial 23 finished with value: 0.8766666666666667 and parameters: {'hidden_layer_1': 38, 'hidden_layer_2': 26, 'learning_rate_init': 0.060073531991811945}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:38,665] Trial 24 finished with value: 0.8333333333333334 and parameters: {'hidden_layer_1': 31, 'hidden_layer_2': 44, 'learning_rate_init': 0.048120285430274475}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:39,481] Trial 25 finished with value: 0.86 and parameters: {'hidden_layer_1': 63, 'hidden_layer_2': 13, 'learning_rate_init': 0.08587236097745357}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:40,328] Trial 26 finished with value: 0.8333333333333334 and parameters: {'hidden_layer_1': 22, 'hidden_layer_2': 85, 'learning_rate_init': 0.06851227819181112}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:41,233] Trial 27 finished with value: 0.8833333333333333 and parameters: {'hidden_layer_1': 46, 'hidden_layer_2': 23, 'learning_rate_init': 0.06154178573597026}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:41,792] Trial 28 finished with value: 0.8533333333333334 and parameters: {'hidden_layer_1': 36, 'hidden_layer_2': 55, 'learning_rate_init': 0.07466984765239584}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:42,651] Trial 29 finished with value: 0.87 and parameters: {'hidden_layer_1': 59, 'hidden_layer_2': 33, 'learning_rate_init': 0.026651923685933197}. Best is trial 3 with value: 0.89.
# [I 2025-01-16 03:50:43,409] A new study created in memory with name: no-name-25266fce-c451-4a3f-823e-42241fbbea64
# Training and predicting with MLP...
# [I 2025-01-16 03:50:46,025] Trial 0 finished with value: 0.8833333333333333 and parameters: {'layer_1': 120, 'layer_2': 124, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09552782850456322}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-16 03:50:46,427] Trial 1 finished with value: 0.5 and parameters: {'layer_1': 77, 'layer_2': 66, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.02875729407652898}. Best is trial 0 with value: 0.8833333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:50:50,483] Trial 2 finished with value: 0.8566666666666667 and parameters: {'layer_1': 56, 'layer_2': 123, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.023915772509062395}. Best is trial 0 with value: 0.8833333333333333.
# [I 2025-01-16 03:50:53,599] Trial 3 finished with value: 0.8933333333333333 and parameters: {'layer_1': 145, 'layer_2': 98, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.04947049148273258}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:50:54,140] Trial 4 finished with value: 0.5 and parameters: {'layer_1': 103, 'layer_2': 66, 'activation': 'logistic', 'solver': 'sgd', 'learning_rate_init': 0.04319098820697633}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:50:56,508] Trial 5 finished with value: 0.7833333333333333 and parameters: {'layer_1': 137, 'layer_2': 64, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09585672272976584}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:50:59,034] Trial 6 finished with value: 0.8333333333333334 and parameters: {'layer_1': 115, 'layer_2': 60, 'activation': 'relu', 'solver': 'sgd', 'learning_rate_init': 0.0218322305270614}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:00,131] Trial 7 finished with value: 0.78 and parameters: {'layer_1': 89, 'layer_2': 101, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0799173752446395}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:51:08,915] Trial 8 finished with value: 0.7866666666666666 and parameters: {'layer_1': 123, 'layer_2': 101, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.007014163234552517}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:11,900] Trial 9 finished with value: 0.7833333333333333 and parameters: {'layer_1': 54, 'layer_2': 129, 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.04270723616874099}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:13,675] Trial 10 finished with value: 0.86 and parameters: {'layer_1': 143, 'layer_2': 150, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06193779630839551}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:14,872] Trial 11 finished with value: 0.8333333333333334 and parameters: {'layer_1': 150, 'layer_2': 87, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06540437917216238}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:15,963] Trial 12 finished with value: 0.86 and parameters: {'layer_1': 129, 'layer_2': 119, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.09953569665052332}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:51:19,755] Trial 13 finished with value: 0.8833333333333333 and parameters: {'layer_1': 111, 'layer_2': 87, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07130799606118092}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:21,738] Trial 14 finished with value: 0.8566666666666667 and parameters: {'layer_1': 130, 'layer_2': 142, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08350460359091853}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:51:29,103] Trial 15 finished with value: 0.8766666666666667 and parameters: {'layer_1': 150, 'layer_2': 107, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.05508838927370906}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:51:33,037] Trial 16 finished with value: 0.87 and parameters: {'layer_1': 120, 'layer_2': 84, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.04696593808837901}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:34,528] Trial 17 finished with value: 0.8466666666666667 and parameters: {'layer_1': 101, 'layer_2': 110, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.08469754604360713}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:35,495] Trial 18 finished with value: 0.88 and parameters: {'layer_1': 136, 'layer_2': 133, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.03322484840704125}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:38,458] Trial 19 finished with value: 0.77 and parameters: {'layer_1': 88, 'layer_2': 116, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.003780590422103776}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:41,469] Trial 20 finished with value: 0.8033333333333333 and parameters: {'layer_1': 109, 'layer_2': 91, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.05718867846196471}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:44,793] Trial 21 finished with value: 0.88 and parameters: {'layer_1': 113, 'layer_2': 75, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07259961366783371}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:51:48,267] Trial 22 finished with value: 0.8433333333333334 and parameters: {'layer_1': 88, 'layer_2': 91, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07110497282062145}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:48,788] Trial 23 finished with value: 0.5 and parameters: {'layer_1': 124, 'layer_2': 79, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.09137973773228614}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:50,281] Trial 24 finished with value: 0.8 and parameters: {'layer_1': 137, 'layer_2': 94, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.06985582275615906}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:53,914] Trial 25 finished with value: 0.88 and parameters: {'layer_1': 108, 'layer_2': 51, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.07864188392987789}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:51:59,165] Trial 26 finished with value: 0.8666666666666667 and parameters: {'layer_1': 68, 'layer_2': 111, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.0900115026949067}. Best is trial 3 with value: 0.8933333333333333.
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-01-16 03:52:02,879] Trial 27 finished with value: 0.87 and parameters: {'layer_1': 93, 'layer_2': 97, 'activation': 'logistic', 'solver': 'adam', 'learning_rate_init': 0.03727556398290362}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:52:06,037] Trial 28 finished with value: 0.8766666666666667 and parameters: {'layer_1': 96, 'layer_2': 75, 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.05308225849633762}. Best is trial 3 with value: 0.8933333333333333.
# [I 2025-01-16 03:52:07,286] Trial 29 finished with value: 0.8166666666666667 and parameters: {'layer_1': 76, 'layer_2': 134, 'activation': 'relu', 'solver': 'adam', 'learning_rate_init': 0.06185780433010517}. Best is trial 3 with value: 0.8933333333333333.
# CFV dataset created and saved!

# %% [markdown]
# CPFV (Combined Probability and Class Feature Vector)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/work_3/8_PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")


# Combine positive and negative datasets
main_data = pd.concat([main_p.assign(label=1), main_n.assign(label=0)], ignore_index=True)
validation_data = pd.concat([validation_p.assign(label=1), validation_n.assign(label=0)], ignore_index=True)

# Separate features and labels
X_train = main_data.drop(columns=["label"])
y_train = main_data["label"]
X_val = validation_data.drop(columns=["label"])
y_val = validation_data["label"]

# Initialize models with their tuned hyperparameters
trained_models = {
    "SVM": SVC(C=1.0, kernel="rbf", probability=True),  # Example parameters
    "Decision Tree": DecisionTreeClassifier(max_depth=10, min_samples_split=5),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5),
    "Logistic Regression": LogisticRegression(C=1.0, solver="lbfgs"),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=10),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=10, learning_rate=0.1, use_label_encoder=False, eval_metric="logloss"),
    "LightGBM": LGBMClassifier(n_estimators=100, max_depth=10, learning_rate=0.1),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, learning_rate=0.1),
    "Neural Network (MLPClassifier)": MLPClassifier(hidden_layer_sizes=(100, 50), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200),
    "Multilayer Perceptron (Custom MLP)": MLPClassifier(hidden_layer_sizes=(128, 64), activation="relu", solver="adam", learning_rate_init=0.01, max_iter=200)
}

# Train all models on the training dataset
for model_name, model in trained_models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)

# Function to create CPFV dataset
def create_cpfv(models, X_data, y_data):
    cpfv_data = pd.DataFrame()
    for model_name, model in models.items():
        # Add predicted class labels
        cpfv_data[f"{model_name}_Class"] = model.predict(X_data)
        # Add predicted probabilities or decision scores
        if hasattr(model, "predict_proba"):
            cpfv_data[f"{model_name}_Prob"] = model.predict_proba(X_data)[:, 1]
        elif hasattr(model, "decision_function"):
            cpfv_data[f"{model_name}_Prob"] = model.decision_function(X_data)
        else:
            cpfv_data[f"{model_name}_Prob"] = cpfv_data[f"{model_name}_Class"]
    # Add true labels
    cpfv_data["True_Label"] = y_data.reset_index(drop=True)
    return cpfv_data

# Create CPFV dataset using validation data
cpfv_dataset = create_cpfv(trained_models, X_val, y_val)

# Save CPFV dataset to CSV
cpfv_dataset.to_csv("CPFV_PAAC.csv", index=False)
# Out:
# Training SVM...
# Training Decision Tree...
# Training Random Forest...
# Training Logistic Regression...
# Training k-NN...
# Training Naive Bayes...
# Training Gradient Boosting...
# Training XGBoost...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:57:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000655 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8616
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training AdaBoost...
# Training Neural Network (MLPClassifier)...
# Training Multilayer Perceptron (Custom MLP)...

# %% [markdown]
# # **Hyperperameter tune for RandomizedSearchCV**

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier # Import path for KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for RandomizedSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply random search
for model_name, model in models.items():
    print(f"Performing RandomizedSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform randomized search
    random_search = RandomizedSearchCV(model, param_grid, n_iter=10, cv=cv, scoring='accuracy', n_jobs=-1, random_state=42)
    random_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = random_search.best_params_
    best_scores.append(random_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)
# Out:
# Performing RandomizedSearchCV for SVM...
# Performing RandomizedSearchCV for Decision Tree...
# Performing RandomizedSearchCV for Random Forest...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 19 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan 0.87799319 0.87284668 0.8694095         nan        nan
#  0.87798579 0.87198831        nan 0.88142667]
#   warnings.warn(
# Performing RandomizedSearchCV for Logistic Regression...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Performing RandomizedSearchCV for k-NN...
# Performing RandomizedSearchCV for Naive Bayes...
# Performing RandomizedSearchCV for Gradient Boosting...
# Performing RandomizedSearchCV for XGBoost...
# Performing RandomizedSearchCV for LightGBM...
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001279 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8616
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Performing RandomizedSearchCV for CatBoost...
# Performing RandomizedSearchCV for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing RandomizedSearchCV for Neural Network...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#                   Model  Best Score  \
# 0                   SVM    0.895194
# 1         Decision Tree    0.821289
# 2         Random Forest    0.881427
# 3   Logistic Regression    0.774893
# 4                  k-NN    0.915821
# 5           Naive Bayes    0.741379
# 6     Gradient Boosting    0.894332
# 7               XGBoost    0.880579
# 8              LightGBM    0.884868
# 9              CatBoost    0.889156
# 10             AdaBoost    0.803241
# 11       Neural Network    0.821296
#
#                                       Best Parameters
# 0        {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
# 1   {'min_samples_split': 2, 'min_samples_leaf': 2...
# 2   {'n_estimators': 500, 'min_samples_split': 5, ...
# 3   {'solver': 'liblinear', 'penalty': 'l2', 'C': 10}
# 4   {'weights': 'distance', 'n_neighbors': 3, 'met...
# 5                              {'var_smoothing': 0.1}
# 6   {'n_estimators': 200, 'max_depth': 7, 'learnin...
# 7   {'n_estimators': 100, 'max_depth': 5, 'learnin...
# 8   {'n_estimators': 200, 'max_depth': -1, 'learni...
# 9   {'learning_rate': 0.2, 'iterations': 200, 'dep...
# 10        {'n_estimators': 200, 'learning_rate': 0.1}
# 11  {'model__num_units': 64, 'model__learning_rate...

# %%
# Storage for predictions and target column
probability_datasets = pd.DataFrame(y_train, columns=['Target'])

# Loop through models, perform random search, and save probabilities
for model_name, model in models.items():
    print(f"Performing RandomizedSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform randomized search
    random_search = RandomizedSearchCV(model,
                                       param_grid,
                                       n_iter=10,
                                       cv=cv,
                                       scoring='accuracy',
                                       n_jobs=-1,
                                       random_state=42)

    random_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = random_search.best_params_
    best_scores.append(random_search.best_score_)



    # Get probability predictions (if supported)
    if hasattr(random_search.best_estimator_, "predict_proba"):
        probabilities = random_search.best_estimator_.predict_proba(X_train)[:, 1]  # Probability for the positive class
        probability_datasets[f"{model_name}_Probabilities"] = probabilities
    else:
        # Fallback if probability prediction isn't supported
        predictions = random_search.best_estimator_.predict(X_train)
        probability_datasets[f"{model_name}_Predictions"] = predictions



# Display final dataset with probabilities
print(probability_datasets.head())

# Save the probability dataset to a CSV file
probability_datasets.to_csv("PAAC_Randomsearch_tune.csv", index=False)
print("Probability dataset saved to 'PAAC_Randomsearch_tune.csv'.")

# %% [markdown]
# # **Hyperparameter grids for GridSearchCV**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier

# Load datasets
main_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_main_positive.csv")
main_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_main_negative.csv")
validation_p = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_validation_positive.csv")
validation_n = pd.read_csv("/content/drive/MyDrive/Cell penetrating peptide/NEW_WORK/PAAC (Pseudo Amino Acid Composition)/paac_validation_negative.csv")

# Combine positive and negative samples
X_train = pd.concat([main_p, main_n])
y_train = np.concatenate([np.ones(len(main_p)), np.zeros(len(main_n))])

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Function to create a neural network model
def create_nn(num_units, dropout_rate, learning_rate, input_shape):
    model = Sequential([
        Dense(num_units, activation='relu', input_shape=input_shape),
        Dropout(dropout_rate),
        Dense(num_units, activation='relu'),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Model definitions and parameter grids for GridSearchCV
models = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Logistic Regression": LogisticRegression(),
    "k-NN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier(),
    "LightGBM": LGBMClassifier(),
    "CatBoost": CatBoostClassifier(verbose=0),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": KerasClassifier(
        model=create_nn,
        num_units=64,
        dropout_rate=0.2,
        learning_rate=0.001,
        input_shape=(X_train.shape[1],),
        epochs=5,
        batch_size=32,
        verbose=0
    )
}

# Parameter grids for each model
param_grids = {
    "SVM": {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly'], 'gamma': ['scale', 'auto']},
    "Decision Tree": {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    "Random Forest": {'n_estimators': [100, 200, 500], 'max_depth': [10, 20, None], 'max_features': ['auto', 'sqrt'], 'min_samples_split': [2, 5, 10]},
    "Logistic Regression": {'C': [0.1, 1, 10, 100], 'solver': ['liblinear', 'saga'], 'penalty': ['l2']},
    "k-NN": {'n_neighbors': [3, 5, 11, 19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']},
    "Naive Bayes": {'var_smoothing': np.logspace(-9, -1, 10)},
    "Gradient Boosting": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "XGBoost": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
    "LightGBM": {'n_estimators': [100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [10, 20, -1]},
    "CatBoost": {'depth': [6, 8, 10], 'learning_rate': [0.01, 0.1, 0.2], 'iterations': [100, 200]},
    "AdaBoost": {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    "Neural Network": {
        'model__num_units': [32, 64, 128],
        'model__dropout_rate': [0.1, 0.2, 0.3],
        'model__learning_rate': [0.001, 0.01, 0.1]
    }
}

# Results storage
best_params = {}
best_scores = []

# Loop through models and apply grid search
for model_name, model in models.items():
    print(f"Performing GridSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform grid search
    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = grid_search.best_params_
    best_scores.append(grid_search.best_score_)

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Model': list(models.keys()),
    'Best Score': best_scores,
    'Best Parameters': [best_params[model] for model in models]
})

print(results_df)
# Out:
# Performing GridSearchCV for SVM...
# Performing GridSearchCV for Decision Tree...
# Performing GridSearchCV for Random Forest...
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 135 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.87455972 0.88486384 0.88142297
#  0.87455602 0.87113364 0.88142297 0.87199201 0.8805757  0.87884416
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.86596123 0.88829732 0.88314711
#  0.87798949 0.87712742 0.88486384 0.87541439 0.86855853 0.87284298
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.86511026 0.87197721 0.88744635
#  0.87713852 0.88487124 0.88228504 0.87027157 0.87971363 0.87798949]
#   warnings.warn(
# Performing GridSearchCV for Logistic Regression...
# Performing GridSearchCV for k-NN...
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Performing GridSearchCV for Naive Bayes...
# Performing GridSearchCV for Gradient Boosting...
# Performing GridSearchCV for XGBoost...
# Performing GridSearchCV for LightGBM...
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# [LightGBM] [Info] Number of positive: 582, number of negative: 582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8616
# [LightGBM] [Info] Number of data points in the train set: 1164, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Performing GridSearchCV for CatBoost...
# Performing GridSearchCV for AdaBoost...
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Performing GridSearchCV for Neural Network...
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#                   Model  Best Score  \
# 0                   SVM    0.899497
# 1         Decision Tree    0.825596
# 2         Random Forest    0.888297
# 3   Logistic Regression    0.774893
# 4                  k-NN    0.915821
# 5           Naive Bayes    0.741379
# 6     Gradient Boosting    0.894321
# 7               XGBoost    0.882289
# 8              LightGBM    0.885726
# 9              CatBoost    0.900326
# 10             AdaBoost    0.803241
# 11       Neural Network    0.847073
#
#                                       Best Parameters
# 0       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 1   {'max_depth': 10, 'min_samples_leaf': 2, 'min_...
# 2   {'max_depth': 20, 'max_features': 'sqrt', 'min...
# 3   {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 4   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...
# 5                              {'var_smoothing': 0.1}
# 6   {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...
# 7   {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...
# 8   {'learning_rate': 0.1, 'max_depth': 20, 'n_est...
# 9   {'depth': 8, 'iterations': 200, 'learning_rate...
# 10        {'learning_rate': 0.1, 'n_estimators': 200}
# 11  {'model__dropout_rate': 0.1, 'model__learning_...

# %%
# Prepare the final dataset with probabilities and target
all_probabilities = []
all_targets = []

# Loop through models and apply grid search
for model_name, model in models.items():
    print(f"Performing GridSearchCV for {model_name}...")
    param_grid = param_grids[model_name]

    # Perform grid search
    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Store best parameters and score
    best_params[model_name] = grid_search.best_params_
    best_scores.append(grid_search.best_score_)

    # Predict probabilities using the best estimator
    best_model = grid_search.best_estimator_
    probabilities = best_model.predict_proba(X_train)[:, 1]  # Positive class probabilities

    # Append probabilities and targets for this model
    all_probabilities.append(probabilities)
    all_targets.append(y_train)

    # Combine probabilities, features, and target into a DataFrame
    model_data = X_train.copy()
    model_data[f"{model_name}_probability"] = probabilities
    model_data['target'] = y_train

    # Save to CSV
    output_path = f"/content/{model_name}_probabilities.csv"
    model_data.to_csv(output_path, index=False)
    print(f"Saved probabilities for {model_name} to {output_path}")

# Combine all model probabilities into a single DataFrame (optional)
final_dataset = pd.DataFrame({'target': y_train})
for idx, model_name in enumerate(models.keys()):
    final_dataset[f"{model_name}_probability"] = all_probabilities[idx]

# Save the combined dataset
final_output_path = "/content/combined_probabilities.csv"
final_dataset.to_csv(final_output_path, index=False)
print(f"Saved combined dataset to {final_output_path}")
